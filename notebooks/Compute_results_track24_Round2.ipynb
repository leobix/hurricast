# %%
import sys
sys.path.append("../")
from src import prepro, metrics, run, setup
import src.models.factory as model_factory
import config
import torch

import numpy as np
from src.utils import models
import os.path as osp
import pandas as pd

from xgboost import XGBClassifier
from xgboost import XGBRegressor
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_absolute_error
from src.utils.data_processing import *

from sklearn.linear_model import Lasso
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt



window_size = 8
predict_at = 8
full = False

tgt_intensity_cat_train = torch.LongTensor(np.load('../data/y_train_intensity_cat_1980_34_20_120_w' + str(window_size) + '_at_' + str(predict_at) + '.npy',
                                      allow_pickle=True))
tgt_intensity_cat_test = torch.LongTensor(np.load('../data/y_test_intensity_cat_1980_34_20_120_w' + str(window_size) + '_at_' + str(predict_at) + '.npy',
                                     allow_pickle=True))

tgt_intensity_train = torch.Tensor(np.load('../data/y_train_intensity_1980_34_20_120_w' + str(window_size) + '_at_' + str(predict_at) + '.npy',
                                  allow_pickle=True))
tgt_intensity_test = torch.Tensor(np.load('../data/y_test_intensity_1980_34_20_120_w' + str(window_size) + '_at_' + str(predict_at) + '.npy',
                                 allow_pickle=True))

tgt_intensity_cat_baseline_train = torch.LongTensor(np.load('../data/y_train_intensity_cat_baseline_1980_34_20_120_w' + str(window_size) + '_at_' + str(predict_at) + '.npy',  allow_pickle = True))
tgt_intensity_cat_baseline_test = torch.LongTensor(np.load('../data/y_test_intensity_cat_baseline_1980_34_20_120_w' + str(window_size) + '_at_' + str(predict_at) + '.npy', allow_pickle=True))

tgt_displacement_train = torch.Tensor(np.load('../data/y_train_displacement_1980_34_20_120_w' + str(window_size) + '_at_' + str(predict_at) + '.npy',
                                     allow_pickle=True))
tgt_displacement_test = torch.Tensor(np.load('../data/y_test_displacement_1980_34_20_120_w' + str(window_size) + '_at_' + str(predict_at) + '.npy',
                                    allow_pickle=True))

tgt_displacement_train_unst = torch.Tensor(np.load('../data/y_train_displacement_1980_34_20_120_w' + str(window_size) + '_at_' + str(predict_at) + '.npy',
                                     allow_pickle=True))
tgt_displacement_test_unst = torch.Tensor(np.load('../data/y_test_displacement_1980_34_20_120_w' + str(window_size) + '_at_' + str(predict_at) + '.npy',
                                    allow_pickle=True))

# %%
X_test_baseline = pd.DataFrame(np.load('../data/X_test_stat_1980_34_20_120_forecast_24_2012_v2_w' + str(window_size) + '_at_' + str(predict_at) + '.npy', allow_pickle=True))
#X_test_baseline = pd.DataFrame(np.load('../data/X_test_stat_1980_34_20_120_forecast_48_2012_v2_w' + str(window_size) + '_at_' + str(predict_at) + '.npy', allow_pickle=True))


names_baselines = ['YEAR', 'MONTH', 'DAY', 'HOUR', 'LAT', 'LON', 'WMO_WIND', 'WMO_PRES', 'DIST2LAND', 'STORM_SPEED', 'cos_day', 'sin_day', 'COS_STORM_DIR', 'SIN_STORM_DIR', 'COS_LAT', 'SIN_LAT', 'COS_LON', 'SIN_LON', 'wind_category', 'GFDL_24_lat', 'GFDL_24_lon', 'GFDL_24_vmax', 'GFDL_24_mslp', 'GFDL_24_COS_LAT', 'GFDL_24_SIN_LAT', 'GFDL_24_COS_LON', 'GFDL_24_SIN_LON', 'CMC_24_lat', 'CMC_24_lon', 'CMC_24_vmax', 'CMC_24_mslp', 'CMC_24_COS_LAT', 'CMC_24_SIN_LAT', 'CMC_24_COS_LON', 'CMC_24_SIN_LON', 'FSSE_24_lat', 'FSSE_24_lon', 'FSSE_24_vmax', 'FSSE_24_mslp', 'FSSE_24_COS_LAT', 'FSSE_24_SIN_LAT', 'FSSE_24_COS_LON', 'FSSE_24_SIN_LON', 'OFCL_24_lat', 'OFCL_24_lon', 'OFCL_24_vmax', 'OFCL_24_mslp', 'OFCL_24_COS_LAT', 'OFCL_24_SIN_LAT', 'OFCL_24_COS_LON', 'OFCL_24_SIN_LON', 'NGPS_24_lat', 'NGPS_24_lon', 'NGPS_24_vmax', 'NGPS_24_mslp', 'NGPS_24_COS_LAT', 'NGPS_24_SIN_LAT', 'NGPS_24_COS_LON', 'NGPS_24_SIN_LON', 'DSHP_24_lat', 'DSHP_24_lon', 'DSHP_24_vmax', 'DSHP_24_mslp', 'DSHP_24_COS_LAT', 'DSHP_24_SIN_LAT', 'DSHP_24_COS_LON', 'DSHP_24_SIN_LON', 'SHIP_24_lat', 'SHIP_24_lon', 'SHIP_24_vmax', 'SHIP_24_mslp', 'SHIP_24_COS_LAT', 'SHIP_24_SIN_LAT', 'SHIP_24_COS_LON', 'SHIP_24_SIN_LON', 'CLP5_24_lat', 'CLP5_24_lon', 'CLP5_24_vmax', 'CLP5_24_mslp', 'CLP5_24_COS_LAT', 'CLP5_24_SIN_LAT', 'CLP5_24_COS_LON', 'CLP5_24_SIN_LON', 'HWRF_24_lat', 'HWRF_24_lon', 'HWRF_24_vmax', 'HWRF_24_mslp', 'HWRF_24_COS_LAT', 'HWRF_24_SIN_LAT', 'HWRF_24_COS_LON', 'HWRF_24_SIN_LON', 'UKXI_24_lat', 'UKXI_24_lon', 'UKXI_24_vmax', 'UKXI_24_mslp', 'UKXI_24_COS_LAT', 'UKXI_24_SIN_LAT', 'UKXI_24_COS_LON', 'UKXI_24_SIN_LON', 'LBAR_24_lat', 'LBAR_24_lon', 'LBAR_24_vmax', 'LBAR_24_mslp', 'LBAR_24_COS_LAT', 'LBAR_24_SIN_LAT', 'LBAR_24_COS_LON', 'LBAR_24_SIN_LON', 'AEMN_24_lat', 'AEMN_24_lon', 'AEMN_24_vmax', 'AEMN_24_mslp', 'AEMN_24_COS_LAT', 'AEMN_24_SIN_LAT', 'AEMN_24_COS_LON', 'AEMN_24_SIN_LON', 'DISPLACEMENT_LAT_CLP5_24', 'DISPLACEMENT_LON_CLP5_24', 'DISPLACEMENT_LAT_SHIP_24', 'DISPLACEMENT_LON_SHIP_24', 'DISPLACEMENT_LAT_DSHP_24', 'DISPLACEMENT_LON_DSHP_24', 'DISPLACEMENT_LAT_LBAR_24', 'DISPLACEMENT_LON_LBAR_24', 'DISPLACEMENT_LAT_CMC_24', 'DISPLACEMENT_LON_CMC_24', 'DISPLACEMENT_LAT_NGPS_24', 'DISPLACEMENT_LON_NGPS_24', 'DISPLACEMENT_LAT_GFDL_24', 'DISPLACEMENT_LON_GFDL_24', 'DISPLACEMENT_LAT_HWRF_24', 'DISPLACEMENT_LON_HWRF_24', 'DISPLACEMENT_LAT_UKXI_24', 'DISPLACEMENT_LON_UKXI_24', 'DISPLACEMENT_LAT_FSSE_24', 'DISPLACEMENT_LON_FSSE_24', 'DISPLACEMENT_LAT_AEMN_24', 'DISPLACEMENT_LON_AEMN_24', 'DISPLACEMENT_LAT_OFCL_24', 'DISPLACEMENT_LON_OFCL_24', 'EMXI_24_lat', 'EMXI_24_lon', 'EMXI_24_vmax', 'EMXI_24_mslp', 'EMXI_24_COS_LAT', 'EMXI_24_SIN_LAT', 'EMXI_24_COS_LON', 'EMXI_24_SIN_LON', 'DISPLACEMENT_LAT_EMXI_24', 'DISPLACEMENT_LON_EMXI_24', 'GFSO_24_lat', 'GFSO_24_lon', 'GFSO_24_vmax', 'GFSO_24_mslp', 'GFSO_24_COS_LAT', 'GFSO_24_SIN_LAT', 'GFSO_24_COS_LON', 'GFSO_24_SIN_LON', 'DISPLACEMENT_LAT_GFSO_24', 'DISPLACEMENT_LON_GFSO_24', 'cat_basin_AN', 'cat_basin_EP', 'basin_NI', 'basin_SI', 'basin_SP', 'basin_WP', 'DISPLACEMENT_LAT', 'DISPLACEMENT_LON']
#names_baselines = ['YEAR', 'MONTH', 'DAY', 'HOUR', 'LAT', 'LON', 'WMO_WIND', 'WMO_PRES', 'DIST2LAND', 'STORM_SPEED', 'cos_day', 'sin_day', 'COS_STORM_DIR', 'SIN_STORM_DIR', 'COS_LAT', 'SIN_LAT', 'COS_LON', 'SIN_LON', 'wind_category', 'DSHP_24_lat', 'DSHP_24_lon', 'DSHP_24_vmax', 'DSHP_24_mslp', 'DSHP_24_COS_LAT', 'DSHP_24_SIN_LAT', 'DSHP_24_COS_LON', 'DSHP_24_SIN_LON', 'OFCL_24_lat', 'OFCL_24_lon', 'OFCL_24_vmax', 'OFCL_24_mslp', 'OFCL_24_COS_LAT', 'OFCL_24_SIN_LAT', 'OFCL_24_COS_LON', 'OFCL_24_SIN_LON', 'UKXI_24_lat', 'UKXI_24_lon', 'UKXI_24_vmax', 'UKXI_24_mslp', 'UKXI_24_COS_LAT', 'UKXI_24_SIN_LAT', 'UKXI_24_COS_LON', 'UKXI_24_SIN_LON', 'CMC_24_lat', 'CMC_24_lon', 'CMC_24_vmax', 'CMC_24_mslp', 'CMC_24_COS_LAT', 'CMC_24_SIN_LAT', 'CMC_24_COS_LON', 'CMC_24_SIN_LON', 'SHIP_24_lat', 'SHIP_24_lon', 'SHIP_24_vmax', 'SHIP_24_mslp', 'SHIP_24_COS_LAT', 'SHIP_24_SIN_LAT', 'SHIP_24_COS_LON', 'SHIP_24_SIN_LON', 'FSSE_24_lat', 'FSSE_24_lon', 'FSSE_24_vmax', 'FSSE_24_mslp', 'FSSE_24_COS_LAT', 'FSSE_24_SIN_LAT', 'FSSE_24_COS_LON', 'FSSE_24_SIN_LON', 'CLP5_24_lat', 'CLP5_24_lon', 'CLP5_24_vmax', 'CLP5_24_mslp', 'CLP5_24_COS_LAT', 'CLP5_24_SIN_LAT', 'CLP5_24_COS_LON', 'CLP5_24_SIN_LON', 'AEMN_24_lat', 'AEMN_24_lon', 'AEMN_24_vmax', 'AEMN_24_mslp', 'AEMN_24_COS_LAT', 'AEMN_24_SIN_LAT', 'AEMN_24_COS_LON', 'AEMN_24_SIN_LON', 'LBAR_24_lat', 'LBAR_24_lon', 'LBAR_24_vmax', 'LBAR_24_mslp', 'LBAR_24_COS_LAT', 'LBAR_24_SIN_LAT', 'LBAR_24_COS_LON', 'LBAR_24_SIN_LON', 'GFDL_24_lat', 'GFDL_24_lon', 'GFDL_24_vmax', 'GFDL_24_mslp', 'GFDL_24_COS_LAT', 'GFDL_24_SIN_LAT', 'GFDL_24_COS_LON', 'GFDL_24_SIN_LON', 'HWRF_24_lat', 'HWRF_24_lon', 'HWRF_24_vmax', 'HWRF_24_mslp', 'HWRF_24_COS_LAT', 'HWRF_24_SIN_LAT', 'HWRF_24_COS_LON', 'HWRF_24_SIN_LON', 'NGPS_24_lat', 'NGPS_24_lon', 'NGPS_24_vmax', 'NGPS_24_mslp', 'NGPS_24_COS_LAT', 'NGPS_24_SIN_LAT', 'NGPS_24_COS_LON', 'NGPS_24_SIN_LON', 'DISPLACEMENT_LAT_CLP5_24', 'DISPLACEMENT_LON_CLP5_24', 'DISPLACEMENT_LAT_SHIP_24', 'DISPLACEMENT_LON_SHIP_24', 'DISPLACEMENT_LAT_DSHP_24', 'DISPLACEMENT_LON_DSHP_24', 'DISPLACEMENT_LAT_LBAR_24', 'DISPLACEMENT_LON_LBAR_24', 'DISPLACEMENT_LAT_CMC_24', 'DISPLACEMENT_LON_CMC_24', 'DISPLACEMENT_LAT_NGPS_24', 'DISPLACEMENT_LON_NGPS_24', 'DISPLACEMENT_LAT_GFDL_24', 'DISPLACEMENT_LON_GFDL_24', 'DISPLACEMENT_LAT_HWRF_24', 'DISPLACEMENT_LON_HWRF_24', 'DISPLACEMENT_LAT_UKXI_24', 'DISPLACEMENT_LON_UKXI_24', 'DISPLACEMENT_LAT_FSSE_24', 'DISPLACEMENT_LON_FSSE_24', 'DISPLACEMENT_LAT_AEMN_24', 'DISPLACEMENT_LON_AEMN_24', 'DISPLACEMENT_LAT_OFCL_24', 'DISPLACEMENT_LON_OFCL_24', 'EMXI_24_lat', 'EMXI_24_lon', 'EMXI_24_vmax', 'EMXI_24_mslp', 'EMXI_24_COS_LAT', 'EMXI_24_SIN_LAT', 'EMXI_24_COS_LON', 'EMXI_24_SIN_LON', 'DISPLACEMENT_LAT_EMXI_24', 'DISPLACEMENT_LON_EMXI_24', 'GFSO_24_lat', 'GFSO_24_lon', 'GFSO_24_vmax', 'GFSO_24_mslp', 'GFSO_24_COS_LAT', 'GFSO_24_SIN_LAT', 'GFSO_24_COS_LON', 'GFSO_24_SIN_LON', 'DISPLACEMENT_LAT_GFSO_24', 'DISPLACEMENT_LON_GFSO_24', 'cat_basin_AN', 'cat_basin_EP', 'basin_NI', 'basin_SI', 'basin_SP', 'basin_WP', 'DISPLACEMENT_LAT', 'DISPLACEMENT_LON']
names_all_baselines = names_baselines * 8#args.window_size

for i in range(len(names_all_baselines)):
    names_all_baselines[i] += '_' + str(i // 167)

X_test_baseline.columns = names_all_baselines

# %%
########## PREPARING DATA FOR XGB

X_train = np.load('../data/X_train_stat_1980_34_20_120_w' + str(window_size) + '_at_' + str(predict_at) + '.npy',
            allow_pickle=True)
X_test = np.load('../data/X_test_stat_1980_34_20_120_w' + str(window_size) + '_at_' + str(predict_at) + '.npy',
            allow_pickle=True)

names = ['LAT', 'LON', 'WMO_WIND', 'WMO_PRES', 'DIST2LAND',
         'STORM_SPEED', 'cat_cos_day', 'cat_sign_day', 'COS_STORM_DIR', 'SIN_STORM_DIR',
         'COS_LAT', 'SIN_LAT', 'COS_LON', 'SIN_LON', 'cat_storm_category', 'cat_basin_AN',
         'cat_basin_EP', 'cat_basin_NI', 'cat_basin_SA',
         'cat_basin_SI', 'cat_basin_SP', 'cat_basin_WP', 'cat_nature_DS', 'cat_nature_ET',
         'cat_nature_MX', 'cat_nature_NR', 'cat_nature_SS', 'cat_nature_TS',
         'STORM_DISPLACEMENT_X', 'STORM_DISPLACEMENT_Y']

names_all = names * window_size

for i in range(len(names_all)):
    names_all[i] += '_' + str(i // 30)

X_train = pd.DataFrame(X_train)
X_test = pd.DataFrame(X_test)
X_train.columns = names_all
X_test.columns = names_all

cols = [c for c in X_train.columns if c.lower()[-2:] == '_0' or c.lower()[:3] != 'cat']

X_train = X_train[cols]
X_test = X_test[cols]

# %%
##Change intensity values from 10min to 1min by dividing by 0.93

col_wind = [col for col in X_train.columns if col[:8] == 'WMO_WIND']
for i in range(len(tgt_intensity_train)):
    if X_train['cat_basin_AN_0'].iloc[i]+X_train['cat_basin_EP_0'].iloc[i]<1:
        for col in col_wind:
            X_train[col].iloc[i] = X_train[col].iloc[i]/0.93
        tgt_intensity_train[i] = tgt_intensity_train[i]/0.93

for i in range(len(tgt_intensity_test)):
    if X_test['cat_basin_AN_0'].iloc[i]+X_test['cat_basin_EP_0'].iloc[i]<1:
        for col in col_wind:
            X_test[col].iloc[i] = X_test[col].iloc[i]/0.93
        tgt_intensity_test[i] = tgt_intensity_test[i]/0.93

# %%
X_train_embed_gru = np.load('../data/embeddings/X_train_embeds_1980_34_20_120_results8_16_20_44_28.npy', allow_pickle = True)
X_test_embed_gru = np.load('../data/embeddings/X_test_embeds_1980_34_20_120_results8_16_20_44_28.npy', allow_pickle = True)
#X_train_embed = np.load('../data/embeddings/X_train_embed_1980_34_20_120_intensity.npy', allow_pickle = True)
#X_test_embed = np.load('../data/embeddings/X_test_embed_1980_34_20_120_intensity.npy', allow_pickle = True)

#48
#X_train_embed = np.load('../data/embeddings/X_train_embed_1980_34_20_120_intensity_48.npy', allow_pickle = True)
#X_test_embed = np.load('../data/embeddings/X_test_embed_1980_34_20_120_intensity_48.npy', allow_pickle = True)

#X_train_embed = np.load('../data/embeddings/X_train_embed_1980_34_20_120_track_48.npy', allow_pickle = True)
#X_test_embed = np.load('../data/embeddings/X_test_embed_1980_34_20_120_track_48.npy', allow_pickle = True)

#Transfo embeds
X_train_embed = np.load('../data/embeds_train_small_10_7_23_43_22_088.npy', allow_pickle = True)
X_test_embed = np.load('../data/embeds_test_small_10_7_23_43_22_088.npy', allow_pickle = True)

X_train_total = np.concatenate((X_train, X_train_embed), axis = 1)
X_test_total = np.concatenate((X_test, X_test_embed), axis = 1)

X_train_total_gru = np.concatenate((X_train, X_train_embed_gru), axis = 1)
X_test_total_gru = np.concatenate((X_test, X_test_embed_gru), axis = 1)

# %% [markdown]
# n = X_test_baseline.shape[0]
# X_test_total = X_test_total[-n:]
# #tgt_intensity_test = tgt_intensity_test[-n:]
# X_test = X_test[-n:]
# X_test_embed = X_test_embed[-n:]
# X_test_embed_gru = X_test_embed_gru[-n:]
# tgt_displacement_test = tgt_displacement_test[-n:]
# m = 17094
#
# if full:
#     tgt_displacement_train = np.concatenate((tgt_displacement_train, tgt_displacement_test[:m]), axis = 0)
#     X_train = pd.concat((X_train, X_test[:m]), axis = 0)
#     X_train_embed = np.concatenate((X_train_embed, X_test_embed[:m]), axis = 0)
#     X_train_total = np.concatenate((X_train_total, X_test_total[:m]), axis = 0)

# %%
n = X_test_baseline.shape[0]
X_test_total = X_test_total[-n:]
tgt_displacement_test = tgt_displacement_test[-n:]
X_test = X_test[-n:]
X_test_embed = X_test_embed[-n:]
X_test_embed_gru = X_test_embed_gru[-n:]
X_test_total_gru = X_test_total_gru[-n:]
m = len(X_test_baseline[X_test_baseline['YEAR_0'] < 2016])
x_viz_train = np.load('../data/X_train_vision_comp_1980_34_20_120.npy', allow_pickle=True).reshape(-1, 3*5*3*3)
x_viz_test = np.load('../data/X_test_vision_comp_1980_34_20_120.npy', allow_pickle=True).reshape(-1, 3*5*3*3)[-n:]

if full:
    tgt_displacement_train = np.concatenate((tgt_displacement_train, tgt_displacement_test[:m]), axis = 0)
    X_train = pd.concat((X_train, X_test[:m]), axis = 0)
    X_train_embed = np.concatenate((X_train_embed, X_test_embed[:m]), axis = 0)
    X_train_total = np.concatenate((X_train_total, X_test_total[:m]), axis = 0)
    x_viz_train = np.concatenate((x_viz_train, x_viz_test[:m]), axis = 0)
    
X_train_total_comp = np.concatenate((X_train, x_viz_train), axis = 1)
X_test_total_comp = np.concatenate((X_test, x_viz_test), axis = 1)

# %%
###TRACK
mean_dx = tgt_displacement_train[:,0].mean()
std_dx = tgt_displacement_train[:,0].std()
tgt_displacement_train[:,0] = (tgt_displacement_train[:,0] - mean_dx)/std_dx
tgt_displacement_test[:,0] = (tgt_displacement_test[:,0] - mean_dx)/std_dx
std_dx = float(std_dx)
mean_dx = float(mean_dx)

mean_dy = tgt_displacement_train[:,1].mean()
std_dy = tgt_displacement_train[:,1].std()
tgt_displacement_train[:,1] = (tgt_displacement_train[:,1] - mean_dy)/std_dy
tgt_displacement_test[:,1] = (tgt_displacement_test[:,1] - mean_dy)/std_dy
std_dy = float(std_dy)
mean_dy = float(mean_dy)

# %%
#index = X_train[np.round(X_train['WMO_WIND_7']*1000%10, decimals = 2) == 0].index

# %%
#X_train = X_train[np.round(X_train['WMO_WIND_7']*1000%10, decimals = 2) == 0].reset_index()

# %%
#X_train_total = X_train_total[index]
#tgt_displacement_train = tgt_displacement_train[index]
#X_train_embed = X_train_embed[index]

# %%
#EP:
#We beat: SHIP, HWRF, GFSO, AEMN, DSHP, (GFDL, UKXI, CMC)
#We lose: OFCL, FSSE

#AN:
#We beat: SHIP, HWRF, GFSO, AEMN, GFDL, DSHP, (UKXI, CMC) 
#We lose: HWRF, OFCL, FSSE
# Out:
# (26800, 740)

# %%
def train_xgb_track(basin_only = False, sparse = False, max_depth = 8, n_estimators = 140, learning_rate = 0.15, subsample = 0.7, min_child_weight=5, basin = 'AN', forecast = 'SHIP', forecast2 = None):
    train_x = X_train_total
    train_y = X_train_total
    test_x = X_test_total
    test_y = X_test_total
    tgt_train = tgt_displacement_train
    if sparse:
        train_x, train_y = X_train_total_sparse_x, X_train_total_sparse_y
        test_x, test_y = X_test_total_sparse_x, X_test_total_sparse_y
    if basin_only:
        train_x = X_train_total[X_train['cat_basin_'+basin+'_0'] == 1]
        train_y = train_x
        tgt_train = tgt_displacement_train[X_train['cat_basin_'+basin+'_0'] == 1]
    xgb_x = XGBRegressor(max_depth=max_depth, n_estimators=n_estimators, learning_rate=learning_rate, subsample=subsample, min_child_weight=min_child_weight)
    xgb_x.fit(train_x, tgt_train[:, 0])
    xgb_y = XGBRegressor(max_depth=max_depth, n_estimators=n_estimators, learning_rate=learning_rate, subsample=subsample, min_child_weight=min_child_weight)
    xgb_y.fit(train_y, tgt_train[:, 1])
    DLATS_PRED = np.array(xgb_x.predict(test_x)) * std_dx + mean_dx
    DLONS_PRED = np.array(xgb_y.predict(test_y)) * std_dy + mean_dy
    LATS_PRED_ = X_test['LAT_7'] + DLATS_PRED
    LONS_PRED_ = X_test['LON_7'] + DLONS_PRED
    compare_perf_track(basin=basin, forecast=forecast, forecast2 = forecast2, LATS_PRED_=LATS_PRED_, LONS_PRED_=LONS_PRED_)

def train_xgb_track_all_years(use_forecast = False, basin_only = False, sparse = False, max_depth = 8, n_estimators = 140, learning_rate = 0.15, subsample = 0.7, min_child_weight=5, basin = 'AN', forecast = 'SHIP', forecast2 = None):
    train_x = X_train_total
    train_y = X_train_total
    test_x = X_test_total
    test_y = X_test_total
    tgt_train = tgt_displacement_train
    if sparse:
        train_x, train_y = X_train_total_sparse_x, X_train_total_sparse_y
        test_x, test_y = X_test_total_sparse_x, X_test_total_sparse_y
    if basin_only:
        train_x = X_train_total[X_train['cat_basin_'+basin+'_0'] == 1]
        train_y = train_x
        tgt_train = tgt_displacement_train[X_train['cat_basin_'+basin+'_0'] == 1]
    if use_forecast:
        train_for = X_train_forecasts
        tgt_train_for = tgt_train_dis_forecasts
        test_for = X_test_forecasts
        xgb_x = XGBRegressor(max_depth=max_depth, n_estimators=n_estimators, learning_rate=learning_rate, subsample=subsample, min_child_weight=min_child_weight)
        xgb_x.fit(train_for, tgt_train_for[:, 0])
        xgb_y = XGBRegressor(max_depth=max_depth, n_estimators=n_estimators, learning_rate=learning_rate, subsample=subsample, min_child_weight=min_child_weight)
        xgb_y.fit(train_for, tgt_train_for[:, 1])
        DLATS_PRED = np.array(xgb_x.predict(X_new)) * std_dx + mean_dx
        DLONS_PRED = np.array(xgb_y.predict(X_new)) * std_dy + mean_dy
    else:
        xgb_x = XGBRegressor(max_depth=max_depth, n_estimators=n_estimators, learning_rate=learning_rate,
                             subsample=subsample, min_child_weight=min_child_weight)
        xgb_x.fit(train_x, tgt_train[:, 0])
        xgb_y = XGBRegressor(max_depth=max_depth, n_estimators=n_estimators, learning_rate=learning_rate,
                             subsample=subsample, min_child_weight=min_child_weight)
        xgb_y.fit(train_y, tgt_train[:, 1])
        DLATS_PRED = np.array(xgb_x.predict(test_x)) * std_dx + mean_dx
        DLONS_PRED = np.array(xgb_y.predict(test_y)) * std_dy + mean_dy
    LATS_PRED_2012 = X_test['LAT_7'] + DLATS_PRED
    LONS_PRED_2012 = X_test['LON_7'] + DLONS_PRED
    compare_perf_track(basin=basin, forecast=forecast, forecast2 = forecast2, LATS_PRED_=LATS_PRED_2012, LONS_PRED_=LONS_PRED_2012)
    dict = {'year': [], 'num_samples': [], 'MAEs_full': [], 'std_full': [], 'MAES_2012': [], 'std_2012': [],
            'MAES_SHIP': [], 'std_SHIP': [], 'MAES_HWRF': [], 'std_HWRF': []}
    for year in range(2012, 2020):
        try:
            index = X_test_baseline.loc[
                X_test_baseline['YEAR'] < year].index
            X_test_to_train = X_test_total[index]
            train = np.concatenate((X_train_total, X_test_to_train), axis=0)
            tgt_train = np.concatenate((tgt_displacement_train, tgt_displacement_test[index]), axis=0)
            xgb_x = XGBRegressor(max_depth=max_depth, n_estimators=n_estimators, learning_rate=learning_rate,
                                 subsample=subsample, min_child_weight=min_child_weight)
            xgb_x.fit(train, tgt_train[:, 0])
            xgb_y = XGBRegressor(max_depth=max_depth, n_estimators=n_estimators, learning_rate=learning_rate,
                                 subsample=subsample, min_child_weight=min_child_weight)
            xgb_y.fit(train, tgt_train[:, 1])
            DLATS_PRED = np.array(xgb_x.predict(test_x)) * std_dx + mean_dx
            DLONS_PRED = np.array(xgb_y.predict(test_y)) * std_dy + mean_dy
            LATS_PRED_ = X_test['LAT_7'] + DLATS_PRED
            LONS_PRED_ = X_test['LON_7'] + DLONS_PRED
            compare_perf_track_per_year(dict, LATS_PRED_, LONS_PRED_, LATS_PRED_2012, LONS_PRED_2012, forecast=forecast,
                                            forecast2=forecast2, basin=basin,  year=year)
            print("\n")
        except:
            print("\n No forecasts for year ", year)
    return dict


def compare_perf_track(LATS_PRED_, LONS_PRED_, basin = 'AN', forecast = 'SHIP', forecast2 = None):
    mode = 'lat'
    if forecast2 != None:
        index = X_test_baseline.loc[
            X_test_baseline[forecast2 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast + '_24_' + mode + '_7'] > -320].loc[X_test_baseline[
                                                                             'cat_basin_' + basin + '_0'] == 1].index  # .loc[#X_test_baseline['SHIP_24_'+mode+'_7'] > 0].index
        baseline_ = X_test_baseline.loc[
            X_test_baseline[forecast2 + '_24_' + mode + '_7'] > -320].loc[X_test_baseline[forecast + '_24_'+mode+'_7'] > -320].loc[X_test_baseline['cat_basin_'+basin+'_0'] == 1]#.loc[#X_test_baseline['SHIP_24_'+mode+'_7'] > 0]
        LATS_BASE_2 = np.array(baseline_[forecast2 + '_24_lat_7'])
        LONS_BASE_2 = np.array(baseline_[forecast2 + '_24_lon_7'])
    else:
        index = X_test_baseline.loc[X_test_baseline[forecast + '_24_'+mode+'_7'] > -320].loc[X_test_baseline['cat_basin_'+basin+'_0'] == 1].index#.loc[#X_test_baseline['SHIP_24_'+mode+'_7'] > 0].index
        baseline_ = X_test_baseline.loc[X_test_baseline[forecast + '_24_'+mode+'_7'] > -320].loc[X_test_baseline['cat_basin_'+basin+'_0'] == 1]#.loc[#X_test_baseline['SHIP_24_'+mode+'_7'] > 0]
    LATS_TEST_ = np.array(X_test['LAT_7'] + np.array(tgt_displacement_test[:, 0])*std_dx+mean_dx)[index]
    LONS_TEST_ = np.array(X_test['LON_7'] + np.array(tgt_displacement_test[:, 1])*std_dy+mean_dy)[index]
    baseline_1_x = baseline_[forecast + '_24_'+mode+'_7']
    baseline_1_y = baseline_[forecast + '_24_lon_7']
    LATS_BASE = np.array(baseline_1_x)
    LONS_BASE = np.array(baseline_1_y)
    LATS_PRED_ = np.array(LATS_PRED_)[index]
    LONS_PRED_ = np.array(LONS_PRED_)[index]
    d_km_baseline = np.zeros(len(LATS_BASE))
    d_km_baseline2 = np.zeros(len(LATS_BASE))
    d_km_pred = np.zeros(len(LONS_PRED_))
    print(LATS_BASE_2)
    print(LONS_BASE_2)
    print(LATS_TEST_)
    print(LONS_TEST_)
    for i in range(len(LATS_BASE)):
        d_km_baseline[i] = get_distance_km(LONS_BASE[i], LATS_BASE[i], LONS_TEST_[i], LATS_TEST_[i])
        d_km_pred[i] = get_distance_km(LONS_PRED_[i], LATS_PRED_[i], LONS_TEST_[i], LATS_TEST_[i])
        if forecast2 != None:
            d_km_baseline2[i] = get_distance_km(LONS_BASE_2[i], LATS_BASE_2[i], LONS_TEST_[i], LATS_TEST_[i])
    print("Number of timesteps:", len(LATS_BASE))
    print(basin, 'Model | MAE | std')
    print(forecast, np.around(d_km_baseline.mean(), decimals = 2), np.around(d_km_baseline.std(), decimals = 2))
    print(str(forecast2), np.around(d_km_baseline2.mean(), decimals = 2), np.around(d_km_baseline2.std(), decimals = 2))
    print("Hurricast", np.around(d_km_pred.mean(), decimals = 2), np.around(d_km_pred.std(), decimals = 2))
    print("\nModel | Number of Busts > 200km | Percentage Bust")
    print(forecast, sum(d_km_baseline > 200), np.around(sum(d_km_baseline > 200)*100/len(LATS_BASE), decimals = 2))
    print(str(forecast2), sum(d_km_baseline2 > 200), np.around(sum(d_km_baseline2 > 200)*100/len(LATS_BASE), decimals =2))
    print("Hurricast", sum(d_km_pred > 200), np.around(sum(d_km_pred > 200)*100/len(LATS_BASE), decimals = 2))




def compare_perf_track_per_year(dict, LATS_PRED_, LONS_PRED_, LATS_PRED_2012, LONS_PRED_2012, year, basin = 'AN', forecast = 'SHIP', forecast2 = None):
    mode = 'lat'
    if forecast2 != None:
        index = X_test_baseline.loc[X_test_baseline['YEAR'] >= year].loc[
            X_test_baseline[forecast2 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast + '_24_' + mode + '_7'] > -320].loc[X_test_baseline[
                                                                             'cat_basin_' + basin + '_0'] == 1].index  # .loc[#X_test_baseline['SHIP_24_'+mode+'_7'] > 0].index
        baseline_ = X_test_baseline.loc[X_test_baseline['YEAR'] == year].loc[
            X_test_baseline[forecast2 + '_24_' + mode + '_7'] > -320].loc[X_test_baseline[forecast + '_24_'+mode+'_7'] > -320].loc[X_test_baseline['cat_basin_'+basin+'_0'] == 1]#.loc[#X_test_baseline['SHIP_24_'+mode+'_7'] > 0]
        LATS_BASE_2 = np.array(baseline_[forecast2 + '_24_lat_7'])
        LONS_BASE_2 = np.array(baseline_[forecast2 + '_24_lon_7'])
    else:
        index = X_test_baseline.loc[X_test_baseline['YEAR'] == year].loc[X_test_baseline[forecast + '_24_'+mode+'_7'] > -320].loc[X_test_baseline['cat_basin_'+basin+'_0'] == 1].index#.loc[#X_test_baseline['SHIP_24_'+mode+'_7'] > 0].index
        baseline_ = X_test_baseline.loc[X_test_baseline['YEAR'] == year].loc[X_test_baseline[forecast + '_24_'+mode+'_7'] > -320].loc[X_test_baseline['cat_basin_'+basin+'_0'] == 1]#.loc[#X_test_baseline['SHIP_24_'+mode+'_7'] > 0]
    LATS_TEST_ = X_test['LAT_7'] + np.array(tgt_displacement_test[:, 0])*std_dx+mean_dx
    LONS_TEST_ = X_test['LON_7'] + np.array(tgt_displacement_test[:, 1])*std_dy+mean_dy
    baseline_1_x = baseline_[forecast + '_24_'+mode+'_7']
    baseline_1_y = baseline_[forecast + '_24_lon_7']
    LATS_BASE = np.array(baseline_1_x)
    LONS_BASE = np.array(baseline_1_y)
    LATS_TEST_ = np.array(LATS_TEST_[index])
    LONS_TEST_ = np.array(LONS_TEST_[index])
    LATS_PRED_ = np.array(LATS_PRED_[index])
    LONS_PRED_ = np.array(LONS_PRED_[index])
    LATS_PRED_2012 = np.array(LATS_PRED_2012[index])
    LONS_PRED_2012 = np.array(LONS_PRED_2012[index])
    d_km_baseline = np.zeros(len(LATS_BASE))
    d_km_baseline2 = np.zeros(len(LATS_BASE))
    d_km_pred = np.zeros(len(LONS_PRED_))
    d_km_pred_2012 = np.zeros(len(LONS_PRED_))
    for i in range(len(LATS_BASE)):
        d_km_baseline[i] = get_distance_km(LONS_BASE[i], LATS_BASE[i], LONS_TEST_[i], LATS_TEST_[i])
        d_km_pred[i] = get_distance_km(LONS_PRED_[i], LATS_PRED_[i], LONS_TEST_[i], LATS_TEST_[i])
        d_km_pred_2012[i] = get_distance_km(LONS_PRED_2012[i], LATS_PRED_2012[i], LONS_TEST_[i], LATS_TEST_[i])
        if forecast2 != None:
            d_km_baseline2[i] = get_distance_km(LONS_BASE_2[i], LATS_BASE_2[i], LONS_TEST_[i], LATS_TEST_[i])
    print("Year", year, "Number of timesteps:", len(LATS_BASE))
    print(basin, 'Model | MAE | std')
    print(forecast, np.around(d_km_baseline.mean(), decimals = 2), np.around(d_km_baseline.std(), decimals = 2))
    print(str(forecast2), np.around(d_km_baseline2.mean(), decimals = 2), np.around(d_km_baseline2.std(), decimals = 2))
    print("Hurricast Max Data", np.around(d_km_pred.mean(), decimals = 2), np.around(d_km_pred.std(), decimals = 2))
    print("Hurricast Until 2012", np.around(d_km_pred_2012.mean(), decimals=2), np.around(d_km_pred_2012.std(), decimals=2))
    print("\nModel | Number of Busts > 200km | Percentage Bust")
    print(forecast, sum(d_km_baseline > 200), np.around(sum(d_km_baseline > 200)*100/len(LATS_BASE), decimals = 2))
    print(str(forecast2), sum(d_km_baseline2 > 200), np.around(sum(d_km_baseline2 > 200)*100/len(LATS_BASE), decimals =2))
    print("Hurricast", sum(d_km_pred > 200), np.around(sum(d_km_pred > 200)*100/len(LATS_BASE), decimals = 2))
    append_dict_track(dict, d_km_baseline, d_km_baseline2, d_km_pred, d_km_pred_2012, year)

def append_dict_track(dict, d_km_baseline, d_km_baseline2, d_km_pred, d_km_pred_2012, year):
    dict['year'].append(year)
    dict['num_samples'].append(len(d_km_baseline))
    dict['MAEs_full'].append(np.around(d_km_pred.mean(), decimals = 2))
    dict['std_full'].append(np.around(d_km_pred.std(), decimals = 2))
    dict['MAES_2012'].append(np.around(d_km_pred_2012.mean(), decimals = 2))
    dict['std_2012'].append(np.around(d_km_pred_2012.std(), decimals=2))
    dict['MAES_SHIP'].append(np.around(d_km_baseline.mean(), decimals = 2))
    dict['std_SHIP'].append(np.around(d_km_baseline.std(), decimals = 2))
    dict['MAES_HWRF'].append(np.around(d_km_baseline2.mean(), decimals =2))
    dict['std_HWRF'].append(np.around(d_km_baseline2.std(), decimals=2))

# %%
def train_xgb_track_all_years(train, test, tgt_train, max_depth = 8, n_estimators = 140, learning_rate = 0.05, subsample = 0.7, min_child_weight=5, basin = 'AN', forecast = 'SHIP', forecast2 = 'HWRF', forecast3 = 'OFCL', forecast4 = 'FSSE', forecast5 = 'GFSO', forecast6 = 'AEMN', forecast7 = 'CLP5'):    
    if False:
        xgb_x = XGBRegressor(max_depth=max_depth, n_estimators=n_estimators, learning_rate=learning_rate,
                             subsample=subsample, min_child_weight=min_child_weight)
        xgb_x.fit(train, tgt_train[:, 0])
        xgb_y = XGBRegressor(max_depth=max_depth, n_estimators=n_estimators, learning_rate=learning_rate,
                             subsample=subsample, min_child_weight=min_child_weight)
        xgb_y.fit(train, tgt_train[:, 1])
        DLATS_PRED = np.array(xgb_x.predict(test)) * std_dx + mean_dx
        DLONS_PRED = np.array(xgb_y.predict(test)) * std_dy + mean_dy
        LATS_PRED_2012 = X_test['LAT_7'] + DLATS_PRED
        LONS_PRED_2012 = X_test['LON_7'] + DLONS_PRED
        compare_perf_track_7cast(year = 2017, basin=basin, forecast='SHIP', forecast2 = 'HWRF', forecast3='OFCL', forecast4 = 'FSSE', forecast5='AEMN', forecast6 = 'GFSO', forecast7 = 'CLP5', LATS_PRED_= LATS_PRED_2012, LONS_PRED_=LONS_PRED_2012)
    dict = {'year':[], 'num_samples':[], 'MAEs_full':[], 'std_full':[], 'MAES_AEMN':[], 'std_AEMN':[], 'MAES_SHIP':[], 'std_SHIP':[], 'MAES_HWRF':[], 'std_HWRF':[], 'MAES_FSSE':[], 'std_FSSE':[], 'MAES_OFCL':[], 'std_OFCL':[], 'MAES_GFSO':[], 'std_GFSO':[], 'MAES_CLP5':[], 'std_CLP5':[]}
    for year in range(2017, 2020):
        #try:
            index = X_test_baseline.loc[
                X_test_baseline['YEAR_0'] < year].index
            X_test_to_train = np.array(test)[index]
            train2 = np.concatenate((train, X_test_to_train), axis=0)
            tgt_train2 = np.concatenate((tgt_train, tgt_displacement_test[index]), axis=0)
            xgb_x = XGBRegressor(max_depth=max_depth, n_estimators=n_estimators, learning_rate=learning_rate,
                                 subsample=subsample, min_child_weight=min_child_weight)
            xgb_x.fit(train2, tgt_train2[:, 0])
            xgb_y = XGBRegressor(max_depth=max_depth, n_estimators=n_estimators, learning_rate=learning_rate,
                                 subsample=subsample, min_child_weight=min_child_weight)
            xgb_y.fit(train2, tgt_train2[:, 1])
            DLATS_PRED = np.array(xgb_x.predict(np.array(test))) * std_dx + mean_dx
            DLONS_PRED = np.array(xgb_y.predict(np.array(test))) * std_dy + mean_dy
            LATS_PRED_ = X_test_baseline['LAT_7'] + DLATS_PRED
            LONS_PRED_ = X_test_baseline['LON_7'] + DLONS_PRED
            print("YEAR", year)
            #compare_perf_track_7cast(year = year, basin=basin, forecast='SHIP', forecast2 = 'HWRF', forecast3='OFCL', forecast4 = 'FSSE', forecast5='AEMN', forecast6 = 'GFSO', forecast7 = 'CLP5', LATS_PRED_= LATS_PRED_2012, LONS_PRED_=LONS_PRED_2012)
            compare_perf_track_7cast(dict = dict, year = year, basin=basin, forecast=forecast, forecast2 = forecast2, forecast3=forecast3, forecast4 = forecast4, forecast5=forecast5, forecast6 = forecast6, forecast7 = forecast7, LATS_PRED_= LATS_PRED_, LONS_PRED_=LONS_PRED_)
            print("\n")
        #except:
            #print("\n No forecasts for year ", year)
    return dict

# %%
def compare_perf_track_7cast(dict, LATS_PRED_, LONS_PRED_, year = 2017, basin = 'AN', forecast = 'SHIP', forecast2 = 'HWRF', forecast3 = 'OFCL', forecast4 = 'FSSE', forecast5 = 'GFSO', forecast6 = 'AEMN', forecast7 = 'CLP5'):
    mode = 'lat'
    if forecast2 != None:
        
        baseline_ = X_test_baseline.loc[X_test_baseline['YEAR_0'] == year].loc[
            X_test_baseline[forecast7 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast6 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast5 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast4 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast3 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast2 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast + '_24_' + mode + '_7'] > -320].loc[X_test_baseline['cat_basin_' + basin + '_0'] == 1]  # .loc[#X_test_baseline['SHIP_24_'+mode+'_7'] > 0].index
        if basin == 'EP':
            baseline_ = baseline_.loc[X_test_baseline['YEAR_0'] < 2019]
        index = baseline_.index
        LATS_BASE_2 = np.array(baseline_[forecast2 + '_24_lat_7'])
        LONS_BASE_2 = np.array(baseline_[forecast2 + '_24_lon_7'])
        LATS_BASE_3 = np.array(baseline_[forecast3 + '_24_lat_7'])
        LONS_BASE_3 = np.array(baseline_[forecast3 + '_24_lon_7'])
        LATS_BASE_4 = np.array(baseline_[forecast4 + '_24_lat_7'])
        LONS_BASE_4 = np.array(baseline_[forecast4 + '_24_lon_7'])
        LATS_BASE_5 = np.array(baseline_[forecast5 + '_24_lat_7'])
        LONS_BASE_5 = np.array(baseline_[forecast5 + '_24_lon_7'])
        LATS_BASE_6 = np.array(baseline_[forecast6 + '_24_lat_7'])
        LONS_BASE_6 = np.array(baseline_[forecast6 + '_24_lon_7'])
        LATS_BASE_7 = np.array(baseline_[forecast7 + '_24_lat_7'])
        LONS_BASE_7 = np.array(baseline_[forecast7 + '_24_lon_7'])
        
    LATS_TEST_ = np.array(X_test['LAT_7'] + np.array(tgt_displacement_test[:, 0])*std_dx+mean_dx)[index]
    LONS_TEST_ = np.array(X_test['LON_7'] + np.array(tgt_displacement_test[:, 1])*std_dy+mean_dy)[index]
    baseline_1_x = np.array(baseline_[forecast + '_24_'+mode+'_7'])
    baseline_1_y = np.array(baseline_[forecast + '_24_lon_7'])
    baseline_2_x = np.array(baseline_[forecast2 + '_24_'+mode+'_7'])
    baseline_2_y = np.array(baseline_[forecast2 + '_24_lon_7'])
    baseline_3_x = np.array(baseline_[forecast3 + '_24_'+mode+'_7'])
    baseline_3_y = np.array(baseline_[forecast3 + '_24_lon_7'])
    baseline_4_x = np.array(baseline_[forecast4 + '_24_'+mode+'_7'])
    baseline_4_y = np.array(baseline_[forecast4 + '_24_lon_7'])
    baseline_5_x = np.array(baseline_[forecast5 + '_24_'+mode+'_7'])
    baseline_5_y = np.array(baseline_[forecast5 + '_24_lon_7'])
    baseline_6_x = np.array(baseline_[forecast6 + '_24_'+mode+'_7'])
    baseline_6_y = np.array(baseline_[forecast6 + '_24_lon_7'])
    baseline_7_x = np.array(baseline_[forecast7 + '_24_'+mode+'_7'])
    baseline_7_y = np.array(baseline_[forecast7 + '_24_lon_7'])
    LATS_PRED_ = np.array(LATS_PRED_)[index]
    LONS_PRED_ = np.array(LONS_PRED_)[index]
    d_km_baseline = np.zeros(len(LATS_PRED_))
    d_km_baseline2 = np.zeros(len(LATS_PRED_))
    d_km_baseline3 = np.zeros(len(LATS_PRED_))
    d_km_baseline4 = np.zeros(len(LATS_PRED_))
    d_km_baseline5 = np.zeros(len(LATS_PRED_))
    d_km_baseline6 = np.zeros(len(LATS_PRED_))
    d_km_baseline7 = np.zeros(len(LATS_PRED_))
    d_km_consensus_ofcl, d_km_consensus_hurr = np.zeros(len(LATS_PRED_)), np.zeros(len(LATS_PRED_))
    d_km_pred = np.zeros(len(LONS_PRED_))
    for i in range(len(LATS_PRED_)):
        if baseline_2_y[i] > 160:
            baseline_1_y[i] -= 360
            baseline_6_y[i] -= 360
            baseline_5_y[i] -= 360
            baseline_2_y[i] -= 360
            baseline_3_y[i] -= 360
        if LONS_TEST_[i] > 160:
            LONS_PRED_[i] -= 360
        d_km_baseline[i] = get_distance_km(baseline_1_y[i], baseline_1_x[i], LONS_TEST_[i], LATS_TEST_[i])
        d_km_pred[i] = get_distance_km(LONS_PRED_[i], LATS_PRED_[i], LONS_TEST_[i], LATS_TEST_[i])
        d_km_baseline2[i] = get_distance_km(baseline_2_y[i], baseline_2_x[i], LONS_TEST_[i], LATS_TEST_[i])
        d_km_baseline3[i] = get_distance_km(baseline_3_y[i], baseline_3_x[i], LONS_TEST_[i], LATS_TEST_[i])
        d_km_baseline4[i] = get_distance_km(baseline_4_y[i], baseline_4_x[i], LONS_TEST_[i], LATS_TEST_[i])
        d_km_baseline5[i] = get_distance_km(baseline_5_y[i], baseline_5_x[i], LONS_TEST_[i], LATS_TEST_[i])
        d_km_baseline6[i] = get_distance_km(baseline_6_y[i], baseline_6_x[i], LONS_TEST_[i], LATS_TEST_[i])
        d_km_baseline7[i] = get_distance_km(baseline_7_y[i], baseline_7_x[i], LONS_TEST_[i], LATS_TEST_[i])
    print("Number of timesteps:", len(LATS_PRED_))
    print(basin, 'Model | MAE | std | %age busts (>200km)')
    print("Hurricast", np.around(d_km_pred.mean(), decimals = 2), np.around(d_km_pred.std(), decimals = 2), np.around(sum(d_km_pred > 200)*100/len(LATS_PRED_), decimals = 2))
    print(forecast, np.around(d_km_baseline.mean(), decimals = 2), np.around(d_km_baseline.std(), decimals = 2), np.around(sum(d_km_baseline > 200)*100/len(LATS_PRED_), decimals = 2))
    print(forecast2, np.around(d_km_baseline2.mean(), decimals = 2), np.around(d_km_baseline2.std(), decimals = 2), np.around(sum(d_km_baseline2 > 200)*100/len(LATS_PRED_), decimals = 2))
    print(str(forecast3), np.around(d_km_baseline3.mean(), decimals = 2), np.around(d_km_baseline3.std(), decimals = 2), np.around(sum(d_km_baseline3 > 200)*100/len(LATS_PRED_), decimals = 2))
    print(str(forecast4), np.around(d_km_baseline4.mean(), decimals = 2), np.around(d_km_baseline4.std(), decimals = 2), np.around(sum(d_km_baseline4 > 200)*100/len(LATS_PRED_), decimals = 2))
    print(str(forecast5), np.around(d_km_baseline5.mean(), decimals = 2), np.around(d_km_baseline5.std(), decimals = 2), np.around(sum(d_km_baseline5 > 200)*100/len(LATS_PRED_), decimals = 2))
    print(forecast6, np.around(d_km_baseline6.mean(), decimals = 2), np.around(d_km_baseline6.std(), decimals = 2), np.around(sum(d_km_baseline6 > 200)*100/len(LATS_PRED_), decimals = 2))
    print(forecast7, np.around(d_km_baseline7.mean(), decimals = 2), np.around(d_km_baseline7.std(), decimals = 2), np.around(sum(d_km_baseline7 > 200)*100/len(LATS_PRED_), decimals = 2))
    consensus_ofcl_x = (baseline_1_x+baseline_2_x+baseline_3_x+baseline_4_x + baseline_5_x + baseline_6_x)/6
    consensus_ofcl_y = (baseline_1_y+baseline_2_y+baseline_3_y+baseline_4_y + baseline_5_y + baseline_6_y)/6
    consensus_hurr_x = (consensus_ofcl_x*6+LATS_PRED_)/7
    consensus_hurr_y = (consensus_ofcl_y*6+LONS_PRED_)/7
    for i in range(len(LATS_PRED_)):
        d_km_consensus_ofcl[i] = get_distance_km(consensus_ofcl_y[i], consensus_ofcl_x[i], LONS_TEST_[i], LATS_TEST_[i])
        d_km_consensus_hurr[i] = get_distance_km(consensus_hurr_y[i], consensus_hurr_x[i], LONS_TEST_[i], LATS_TEST_[i])
    print("Consensus OFCL only", np.around(d_km_consensus_ofcl.mean(), decimals = 2), np.around(d_km_consensus_ofcl.std(), decimals = 2), np.around(sum(d_km_consensus_ofcl > 200)*100/len(LATS_PRED_), decimals = 2))
    print("Consensus OFCL + Hurricast", np.around(d_km_consensus_hurr.mean(), decimals = 2), np.around(d_km_consensus_hurr.std(), decimals = 2), np.around(sum(d_km_consensus_hurr > 200)*100/len(LATS_PRED_), decimals = 2))
    #return LONS_PRED_, baseline_1_y, baseline_2_y, baseline_3_y, baseline_4_y, baseline_5_y, baseline_6_y
    #return d_km_pred, np.array(X_test)[index]
    append_dict_track_7cast(dict, d_km_pred, d_km_baseline, d_km_baseline2, d_km_baseline3, d_km_baseline4, d_km_baseline5, d_km_baseline6, d_km_baseline7, year)

# %%
def append_dict_track_7cast(dict, d_km_pred, d_km_baseline, d_km_baseline2, d_km_baseline3, d_km_baseline4, d_km_baseline5, d_km_baseline6, d_km_baseline7, year):
    dict['year'].append(year)
    dict['num_samples'].append(len(d_km_pred))
    dict['MAEs_full'].append(np.around(d_km_pred.mean(), decimals = 2))
    dict['std_full'].append(np.around(d_km_pred.std(), decimals = 2))
    
    dict['MAES_SHIP'].append(np.around(d_km_baseline.mean(), decimals = 2))
    dict['std_SHIP'].append(np.around(d_km_baseline.std(), decimals = 2))
    
    dict['MAES_HWRF'].append(np.around(d_km_baseline2.mean(), decimals = 2))
    dict['std_HWRF'].append(np.around(d_km_baseline2.std(), decimals = 2))
    
    dict['MAES_OFCL'].append(np.around(d_km_baseline3.mean(), decimals = 2))
    dict['std_OFCL'].append(np.around(d_km_baseline3.std(), decimals = 2))
    
    dict['MAES_FSSE'].append(np.around(d_km_baseline4.mean(), decimals = 2))
    dict['std_FSSE'].append(np.around(d_km_baseline4.std(), decimals = 2))
    
    dict['MAES_AEMN'].append(np.around(d_km_baseline5.mean(), decimals = 2))
    dict['std_AEMN'].append(np.around(d_km_baseline5.std(), decimals = 2))
    
    dict['MAES_GFSO'].append(np.around(d_km_baseline6.mean(), decimals = 2))
    dict['std_GFSO'].append(np.around(d_km_baseline6.std(), decimals = 2))
    
    dict['MAES_CLP5'].append(np.around(d_km_baseline7.mean(), decimals = 2))
    dict['std_CLP5'].append(np.around(d_km_baseline7.std(), decimals = 2))

# %% [markdown]
# # Plots

# %%
d1 = train_xgb_track_all_years(max_depth=8, learning_rate=0.03, n_estimators=200, subsample=0.8, forecast7 = 'OFCL', forecast6 = 'OFCL', forecast5 = 'OFCL', forecast = 'OFCL', forecast4 = 'OFCL', forecast3 = 'OFCL', forecast2 = 'OFCL')
# Out:
# YEAR 2012
# Number of timesteps: 43
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 136.79 99.34 23.26
# OFCL 67.4 45.01 4.65
# OFCL 67.4 45.01 4.65
# OFCL 67.4 45.01 4.65
# OFCL 67.4 45.01 4.65
# OFCL 67.4 45.01 4.65
# OFCL 67.4 45.01 4.65
# OFCL 67.4 45.01 4.65
# Consensus OFCL only 67.4 45.01 4.65
# Consensus OFCL + Hurricast 63.38 46.36 2.33
#
#
# YEAR 2013
# Number of timesteps: 8
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 157.83 51.39 12.5
# OFCL 77.01 33.67 0.0
# OFCL 77.01 33.67 0.0
# OFCL 77.01 33.67 0.0
# OFCL 77.01 33.67 0.0
# OFCL 77.01 33.67 0.0
# OFCL 77.01 33.67 0.0
# OFCL 77.01 33.67 0.0
# Consensus OFCL only 77.01 33.67 0.0
# Consensus OFCL + Hurricast 55.28 19.96 0.0
#
#
# YEAR 2014
# Number of timesteps: 75
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 134.34 98.88 20.0
# OFCL 80.35 61.28 5.33
# OFCL 80.35 61.28 5.33
# OFCL 80.35 61.28 5.33
# OFCL 80.35 61.28 5.33
# OFCL 80.35 61.28 5.33
# OFCL 80.35 61.28 5.33
# OFCL 80.35 61.28 5.33
# Consensus OFCL only 80.35 61.28 5.33
# Consensus OFCL + Hurricast 75.72 55.81 2.67
#
#
# YEAR 2015
# Number of timesteps: 136
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 112.17 83.93 13.24
# OFCL 72.08 47.01 2.21
# OFCL 72.08 47.01 2.21
# OFCL 72.08 47.01 2.21
# OFCL 72.08 47.01 2.21
# OFCL 72.08 47.01 2.21
# OFCL 72.08 47.01 2.21
# OFCL 72.08 47.01 2.21
# Consensus OFCL only 72.08 47.01 2.21
# Consensus OFCL + Hurricast 66.85 47.96 2.94
#
#
# YEAR 2016
# Number of timesteps: 280
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 127.0 94.92 17.14
# OFCL 78.57 52.49 3.93
# OFCL 78.57 52.49 3.93
# OFCL 78.57 52.49 3.93
# OFCL 78.57 52.49 3.93
# OFCL 78.57 52.49 3.93
# OFCL 78.57 52.49 3.93
# OFCL 78.57 52.49 3.93
# Consensus OFCL only 78.57 52.49 3.93
# Consensus OFCL + Hurricast 74.38 47.57 1.07
#
#
# YEAR 2017
# Number of timesteps: 250
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 93.7 59.11 5.6
# OFCL 65.08 45.94 1.6
# OFCL 65.08 45.94 1.6
# OFCL 65.08 45.94 1.6
# OFCL 65.08 45.94 1.6
# OFCL 65.08 45.94 1.6
# OFCL 65.08 45.94 1.6
# OFCL 65.08 45.94 1.6
# Consensus OFCL only 65.08 45.94 1.6
# Consensus OFCL + Hurricast 60.71 43.93 1.6
#
#
# YEAR 2018
# Number of timesteps: 264
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.85 72.42 10.98
# OFCL 69.32 49.32 1.52
# OFCL 69.32 49.32 1.52
# OFCL 69.32 49.32 1.52
# OFCL 69.32 49.32 1.52
# OFCL 69.32 49.32 1.52
# OFCL 69.32 49.32 1.52
# OFCL 69.32 49.32 1.52
# Consensus OFCL only 69.32 49.32 1.52
# Consensus OFCL + Hurricast 67.4 46.53 0.76
#
#
# YEAR 2019
# Number of timesteps: 227
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 129.19 90.2 18.06
# OFCL 84.85 75.01 7.05
# OFCL 84.85 75.01 7.05
# OFCL 84.85 75.01 7.05
# OFCL 84.85 75.01 7.05
# OFCL 84.85 75.01 7.05
# OFCL 84.85 75.01 7.05
# OFCL 84.85 75.01 7.05
# Consensus OFCL only 84.85 75.01 7.05
# Consensus OFCL + Hurricast 78.88 69.19 5.73

# %%
d1 = train_xgb_track_all_years(basin = 'EP', max_depth=8, learning_rate=0.03, n_estimators=200, subsample=0.8, forecast7 = 'OFCL', forecast6 = 'OFCL', forecast5 = 'OFCL', forecast = 'OFCL', forecast4 = 'OFCL', forecast3 = 'OFCL', forecast2 = 'OFCL')
# Out:
# YEAR 2012
# Number of timesteps: 0
# EP Model | MAE | std | %age busts (>200km)
#
#  No forecasts for year  2012
# YEAR 2013
# Number of timesteps: 10
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 91.78 38.97 0.0
# OFCL 63.87 22.18 0.0
# OFCL 63.87 22.18 0.0
# OFCL 63.87 22.18 0.0
# OFCL 63.87 22.18 0.0
# OFCL 63.87 22.18 0.0
# OFCL 63.87 22.18 0.0
# OFCL 63.87 22.18 0.0
# Consensus OFCL only 63.87 22.18 0.0
# Consensus OFCL + Hurricast 63.32 21.52 0.0
#
#
# YEAR 2014
# Number of timesteps: 386
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 75.99 43.42 1.3
# OFCL 57.96 37.77 0.52
# OFCL 57.96 37.77 0.52
# OFCL 57.96 37.77 0.52
# OFCL 57.96 37.77 0.52
# OFCL 57.96 37.77 0.52
# OFCL 57.96 37.77 0.52
# OFCL 57.96 37.77 0.52
# Consensus OFCL only 123.76 643.12 1.55
# Consensus OFCL + Hurricast 109.48 551.39 1.55
#
#
# YEAR 2015
# Number of timesteps: 301
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 76.64 63.67 3.65
# OFCL 69.56 42.64 1.0
# OFCL 69.56 42.64 1.0
# OFCL 69.56 42.64 1.0
# OFCL 69.56 42.64 1.0
# OFCL 69.56 42.64 1.0
# OFCL 69.56 42.64 1.0
# OFCL 69.56 42.64 1.0
# Consensus OFCL only 69.56 42.64 1.0
# Consensus OFCL + Hurricast 64.77 40.84 0.66
#
#
# YEAR 2016
# Number of timesteps: 350
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 73.01 41.1 0.86
# OFCL 55.31 35.57 0.0
# OFCL 55.31 35.57 0.0
# OFCL 55.31 35.57 0.0
# OFCL 55.31 35.57 0.0
# OFCL 55.31 35.57 0.0
# OFCL 55.31 35.57 0.0
# OFCL 55.31 35.57 0.0
# Consensus OFCL only 55.31 35.57 0.0
# Consensus OFCL + Hurricast 52.46 34.3 0.0
#
#
# YEAR 2017
# Number of timesteps: 205
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 68.64 41.68 0.0
# OFCL 57.05 33.62 0.0
# OFCL 57.05 33.62 0.0
# OFCL 57.05 33.62 0.0
# OFCL 57.05 33.62 0.0
# OFCL 57.05 33.62 0.0
# OFCL 57.05 33.62 0.0
# OFCL 57.05 33.62 0.0
# Consensus OFCL only 57.05 33.62 0.0
# Consensus OFCL + Hurricast 53.64 30.08 0.0
#
#
# YEAR 2018
# Number of timesteps: 378
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 73.55 46.46 1.59
# OFCL 54.75 31.68 0.26
# OFCL 54.75 31.68 0.26
# OFCL 54.75 31.68 0.26
# OFCL 54.75 31.68 0.26
# OFCL 54.75 31.68 0.26
# OFCL 54.75 31.68 0.26
# OFCL 54.75 31.68 0.26
# Consensus OFCL only 116.73 601.27 1.32
# Consensus OFCL + Hurricast 104.42 516.78 1.32
#
#
# YEAR 2019
# Number of timesteps: 54
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 112.69 66.64 16.67
# OFCL 69.59 43.59 0.0
# OFCL 69.59 43.59 0.0
# OFCL 69.59 43.59 0.0
# OFCL 69.59 43.59 0.0
# OFCL 69.59 43.59 0.0
# OFCL 69.59 43.59 0.0
# OFCL 69.59 43.59 0.0
# Consensus OFCL only 69.59 43.59 0.0
# Consensus OFCL + Hurricast 69.71 44.33 1.85

# %%
d1 = train_xgb_track_all_years(max_depth=8, learning_rate=0.03, n_estimators=200, subsample=0.8)

# %%
d1['MAEs_full']
# Out:
# [150.19, 167.25, 142.25, 144.53, 150.51]

# %%
a = [113.34, 118.3, 89.07, 108.7, 121.65]

# %%
import matplotlib.pyplot as plt
years = [i for i in range(2015, 2020)]
plt.figure(figsize=(20,10))
plt.xticks(years, fontsize = 20)
plt.yticks([i for i in range(60, 220, 10)], fontsize = 20)
#plt.figtext(.5,.9,"Mean Average Error in km between 2015 and 2019 for different \n North Atlantic track forecast models with lead time 24h", fontsize=30, ha='center')
plt.plot(years, d1['MAES_CLP5'], label = 'CLP5', marker='o')
plt.plot(years, a, label = 'Hurricast', marker='o')
plt.plot(years, d1['MAES_SHIP'], label = 'SHIPS', marker='o')
plt.plot(years, d1['MAES_AEMN'], label = 'AEMN', marker='o')
plt.plot(years, d1['MAES_HWRF'], label = 'HWRF', marker='o')
plt.plot(years, d1['MAES_GFSO'], label = 'GFSO', marker='o')
plt.plot(years, d1['MAES_OFCL'], label = 'OFCL', marker='o')
plt.plot(years, d1['MAES_FSSE'], label = 'FSSE', marker='o')
plt.xlabel("Year", fontsize = 30)
plt.ylabel("MAE in km", fontsize = 30)
plt.legend(loc=1, prop={'size': 20})
plt.grid(linestyle='--')
plt.savefig("MAE_AN_track_24.jpg", dpi = 300)
#plt.title("Mean Average Error in km between 2015 and 2019 for each forecast model")
plt.show()

# %%
d2 = train_xgb_track_all_years(max_depth=5, learning_rate=0.03, n_estimators=300, subsample=0.8, basin = 'EP')
# Out:
# YEAR 2015
# Number of timesteps: 255
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 74.5 55.29 2.75
# SHIP 72.68 44.07 0.78
# HWRF 82.06 55.85 4.71
# OFCL 69.07 43.77 1.18
# FSSE 65.21 45.88 1.18
# AEMN 73.39 44.35 1.96
# GFSO 68.66 46.09 1.57
# CLP5 139.5 77.24 17.25
# Consensus OFCL only 63.58 40.15 0.39
# Consensus OFCL + Hurricast 58.57 37.94 0.78
#
#
# YEAR 2016
# Number of timesteps: 315
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 73.11 40.59 0.95
# SHIP 57.85 34.92 0.32
# HWRF 61.82 40.02 1.9
# OFCL 54.09 34.1 0.0
# FSSE 55.8 33.86 0.32
# AEMN 56.33 37.91 0.63
# GFSO 60.33 44.6 1.9
# CLP5 113.55 58.53 7.62
# Consensus OFCL only 50.84 33.91 0.0
# Consensus OFCL + Hurricast 48.64 32.24 0.0
#
#
# YEAR 2017
# Number of timesteps: 167
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 69.28 41.91 0.0
# SHIP 59.96 35.47 0.6
# HWRF 74.58 40.85 2.4
# OFCL 55.2 33.37 0.0
# FSSE 54.98 35.64 0.6
# AEMN 68.34 40.13 1.2
# GFSO 73.68 45.78 1.2
# CLP5 108.57 61.48 8.38
# Consensus OFCL only 57.64 34.02 0.6
# Consensus OFCL + Hurricast 53.8 30.38 0.0
#
#
# YEAR 2018
# Number of timesteps: 355
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 73.46 45.82 1.41
# SHIP 56.76 32.53 0.28
# HWRF 67.99 44.14 1.97
# OFCL 53.6 30.77 0.28
# FSSE 56.26 60.66 1.13
# AEMN 59.09 34.78 0.28
# GFSO 64.01 44.34 1.41
# CLP5 133.27 73.69 18.31
# Consensus OFCL only 50.88 32.97 0.28
# Consensus OFCL + Hurricast 47.25 29.9 0.28
#
#
# YEAR 2019
# Number of timesteps: 40
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 107.09 66.2 12.5
# SHIP 78.51 51.99 5.0
# HWRF 85.8 46.78 0.0
# OFCL 67.13 42.95 0.0
# FSSE 62.74 42.03 0.0
# AEMN 82.92 51.86 5.0
# GFSO 82.21 55.33 5.0
# CLP5 149.35 90.93 22.5
# Consensus OFCL only 61.33 36.43 0.0
# Consensus OFCL + Hurricast 61.91 36.38 0.0

# %%
# Out:
# [74.5, 73.11, 69.28, 73.46]

# %%
b = [72.32, 71.1, 67.85, 73.14]

# %%
years = [i for i in range(2015, 2019)]
plt.figure(figsize=(20,10))
plt.xticks(years, fontsize = 20)
plt.yticks([i for i in range(50, 140, 10)], fontsize = 20)
#plt.figtext(.5,.9,"Mean Average Error in km between 2015 and 2018 for different \n East Pacific track forecast models with lead time 24h", fontsize=30, ha='center')

plt.plot(years, d2['MAES_CLP5'][:-1], label = 'CLP5', marker ='o')
plt.plot(years, b, label = 'Hurricast', marker ='o')
plt.plot(years, d2['MAES_SHIP'][:-1], label = 'SHIPS', marker ='o')
plt.plot(years, d2['MAES_AEMN'][:-1], label = 'AEMN', marker ='o')
plt.plot(years, d2['MAES_HWRF'][:-1], label = 'HWRF', marker ='o')
plt.plot(years, d2['MAES_GFSO'][:-1], label = 'GFSO', marker ='o')
plt.plot(years, d2['MAES_OFCL'][:-1], label = 'OFCL', marker ='o')
plt.plot(years, d2['MAES_FSSE'][:-1], label = 'FSSE', marker ='o')

plt.xlabel("Year", fontsize = 30)
plt.ylabel("MAE in km", fontsize = 30)
plt.legend(loc=1, prop={'size': 20})
plt.grid(linestyle='--')
plt.savefig("MAE_EP_track_24.jpg", dpi = 300)
plt.show()

# %% [markdown]
# # Get results old

# %%
#TRAIN TOTAL
max_depth = 7
n_estimators = 200
learning_rate = 0.03
subsample = 0.8
min_child_weight=5
#col_sample_by_tree = 0.7
train_x = X_train_total
train_y = X_train_total
test_x = X_test_total
test_y = X_test_total
tgt_train = tgt_displacement_train
    
xgb_x = XGBRegressor(max_depth=max_depth, n_estimators=n_estimators, learning_rate=learning_rate, subsample=subsample, min_child_weight=min_child_weight)
xgb_x.fit(train_x, tgt_train[:, 0])
xgb_y = XGBRegressor(max_depth=max_depth, n_estimators=n_estimators, learning_rate=learning_rate, subsample=subsample, min_child_weight=min_child_weight)
xgb_y.fit(train_y, tgt_train[:, 1])
DLATS_PRED = np.array(xgb_x.predict(test_x)) * std_dx + mean_dx
DLONS_PRED = np.array(xgb_y.predict(test_y)) * std_dy + mean_dy
LATS_PRED_ = X_test['LAT_7'] + DLATS_PRED
LONS_PRED_ = X_test['LON_7'] + DLONS_PRED
compare_perf_track_7cast(year = 2017, basin='AN', forecast='SHIP', forecast2 = 'HWRF', forecast3='OFCL', forecast4 = 'FSSE', forecast5='AEMN', forecast6 = 'GFSO', forecast7 = 'CLP5', LATS_PRED_= LATS_PRED_, LONS_PRED_=LONS_PRED_)
compare_perf_track_7cast(year = 2017, basin='EP', forecast='SHIP', forecast2 = 'HWRF', forecast3='OFCL', forecast4 = 'FSSE', forecast5='AEMN', forecast6 = 'GFSO', forecast7 = 'CLP5', LATS_PRED_= LATS_PRED_, LONS_PRED_=LONS_PRED_)
# Out:
# Number of timesteps: 669
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 107.59 74.55 10.31
# SHIP 77.06 64.11 4.04
# HWRF 72.01 47.85 2.39
# OFCL 70.36 57.78 2.84
# FSSE 67.53 53.48 3.44
# AEMN 72.81 57.98 2.54
# GFSO 70.47 56.01 3.74
# CLP5 197.76 142.19 36.17
# Consensus OFCL only 62.67 50.49 2.09
# Consensus OFCL + Hurricast 60.38 47.39 1.49
# Number of timesteps: 522
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 71.38 44.01 0.96
# SHIP 57.78 33.53 0.38
# HWRF 70.1 43.23 2.11
# OFCL 54.11 31.63 0.19
# FSSE 55.85 53.93 0.96
# AEMN 62.05 36.83 0.57
# GFSO 67.11 45.03 1.34
# CLP5 125.37 70.95 15.13
# Consensus OFCL only 53.04 33.46 0.38
# Consensus OFCL + Hurricast 49.3 30.13 0.19

# %%
compare_perf_track_7cast(year = 2017, basin='AN', forecast='SHIP', forecast2 = 'HWRF', forecast3='OFCL', forecast4 = 'FSSE', forecast5='AEMN', forecast6 = 'GFSO', forecast7 = 'CLP5', LATS_PRED_= LATS_PRED_, LONS_PRED_=LONS_PRED_)
compare_perf_track_7cast(year = 2017, basin='EP', forecast='SHIP', forecast2 = 'HWRF', forecast3='OFCL', forecast4 = 'FSSE', forecast5='AEMN', forecast6 = 'GFSO', forecast7 = 'CLP5', LATS_PRED_= LATS_PRED_, LONS_PRED_=LONS_PRED_)
# Out:
# Number of timesteps: 669
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 107.16 74.34 11.36
# SHIP 77.06 64.11 4.04
# HWRF 72.01 47.85 2.39
# OFCL 70.36 57.78 2.84
# FSSE 67.53 53.48 3.44
# AEMN 72.81 57.98 2.54
# GFSO 70.47 56.01 3.74
# CLP5 197.76 142.19 36.17
# Consensus OFCL only 62.67 50.49 2.09
# Consensus OFCL + Hurricast 60.23 47.42 1.49
# Number of timesteps: 522
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 71.55 44.65 0.96
# SHIP 57.78 33.53 0.38
# HWRF 70.1 43.23 2.11
# OFCL 54.11 31.63 0.19
# FSSE 55.85 53.93 0.96
# AEMN 62.05 36.83 0.57
# GFSO 67.11 45.03 1.34
# CLP5 125.37 70.95 15.13
# Consensus OFCL only 53.04 33.46 0.38
# Consensus OFCL + Hurricast 49.3 29.91 0.19

# %%
compare_perf_track_7cast(year = 2017, basin='AN', forecast='SHIP', forecast2 = 'HWRF', forecast3='OFCL', forecast4 = 'FSSE', forecast5='AEMN', forecast6 = 'GFSO', forecast7 = 'CLP5', LATS_PRED_=LATS_PRED_, LONS_PRED_=LONS_PRED_)
compare_perf_track_7cast(year = 2017, basin='EP', forecast='SHIP', forecast2 = 'HWRF', forecast3='OFCL', forecast4 = 'FSSE', forecast5='AEMN', forecast6 = 'GFSO', forecast7 = 'CLP5', LATS_PRED_=LATS_PRED_, LONS_PRED_=LONS_PRED_)
# Out:
# Number of timesteps: 669
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 106.61 73.49 10.46
# SHIP 77.06 64.11 4.04
# HWRF 72.01 47.85 2.39
# OFCL 70.36 57.78 2.84
# FSSE 67.53 53.48 3.44
# AEMN 72.81 57.98 2.54
# GFSO 70.47 56.01 3.74
# CLP5 197.76 142.19 36.17
# Consensus OFCL only 62.67 50.49 2.09
# Consensus OFCL + Hurricast 60.35 47.4 1.49

# %%
#TRAIN TABULAR ONLY
max_depth = 7
n_estimators = 150
learning_rate = 0.03
subsample = 0.7
min_child_weight=5
#col_sample_by_tree = 0.7
train_x = np.array(X_train)[:,1:]
train_y = train_x
test_x = np.array(X_test)
test_y = test_x
tgt_train = tgt_displacement_train
    
xgb_x = XGBRegressor(max_depth=max_depth, n_estimators=n_estimators, learning_rate=learning_rate, subsample=subsample, min_child_weight=min_child_weight)
xgb_x.fit(train_x, tgt_train[:, 0])
xgb_y = XGBRegressor(max_depth=max_depth, n_estimators=n_estimators, learning_rate=learning_rate, subsample=subsample, min_child_weight=min_child_weight)
xgb_y.fit(train_y, tgt_train[:, 1])
DLATS_PRED = np.array(xgb_x.predict(test_x)) * std_dx + mean_dx
DLONS_PRED = np.array(xgb_y.predict(test_y)) * std_dy + mean_dy
LATS_PRED_ = X_test['LAT_7'] + DLATS_PRED
LONS_PRED_ = X_test['LON_7'] + DLONS_PRED
compare_perf_track_7cast(year = 2017, basin='AN', forecast='SHIP', forecast2 = 'HWRF', forecast3='OFCL', forecast4 = 'FSSE', forecast5='AEMN', forecast6 = 'GFSO', forecast7 = 'CLP5', LATS_PRED_= LATS_PRED_, LONS_PRED_=LONS_PRED_)
compare_perf_track_7cast(year = 2017, basin='EP', forecast='SHIP', forecast2 = 'HWRF', forecast3='OFCL', forecast4 = 'FSSE', forecast5='AEMN', forecast6 = 'GFSO', forecast7 = 'CLP5', LATS_PRED_= LATS_PRED_, LONS_PRED_=LONS_PRED_)
# Out:
# Number of timesteps: 669
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 173.49 120.58 29.45
# SHIP 77.06 64.11 4.04
# HWRF 72.01 47.85 2.39
# OFCL 70.36 57.78 2.84
# FSSE 67.53 53.48 3.44
# AEMN 72.81 57.98 2.54
# GFSO 70.47 56.01 3.74
# CLP5 197.76 142.19 36.17
# Consensus OFCL only 62.67 50.49 2.09
# Consensus OFCL + Hurricast 67.65 49.37 2.54
# Number of timesteps: 522
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 125.54 78.41 14.18
# SHIP 57.78 33.53 0.38
# HWRF 70.1 43.23 2.11
# OFCL 54.11 31.63 0.19
# FSSE 55.85 53.93 0.96
# AEMN 62.05 36.83 0.57
# GFSO 67.11 45.03 1.34
# CLP5 125.37 70.95 15.13
# Consensus OFCL only 53.04 33.46 0.38
# Consensus OFCL + Hurricast 52.92 31.36 0.19

# %%
#TRAIN EMBED ONLY
max_depth = 7
n_estimators = 150
learning_rate = 0.05
subsample = 0.7
min_child_weight=5
#col_sample_by_tree = 0.7
train_x = X_train_embed
train_y = train_x
test_x = X_test_embed
test_y = test_x
tgt_train = tgt_displacement_train
    
xgb_x = XGBRegressor(max_depth=max_depth, n_estimators=n_estimators, learning_rate=learning_rate, subsample=subsample, min_child_weight=min_child_weight)
xgb_x.fit(train_x, tgt_train[:, 0])
xgb_y = XGBRegressor(max_depth=max_depth, n_estimators=n_estimators, learning_rate=learning_rate, subsample=subsample, min_child_weight=min_child_weight)
xgb_y.fit(train_y, tgt_train[:, 1])
DLATS_PRED = np.array(xgb_x.predict(test_x)) * std_dx + mean_dx
DLONS_PRED = np.array(xgb_y.predict(test_y)) * std_dy + mean_dy
LATS_PRED_ = X_test['LAT_7'] + DLATS_PRED
LONS_PRED_ = X_test['LON_7'] + DLONS_PRED
compare_perf_track_7cast(year = 2017, basin='AN', forecast='SHIP', forecast2 = 'HWRF', forecast3='OFCL', forecast4 = 'FSSE', forecast5='AEMN', forecast6 = 'GFSO', forecast7 = 'CLP5', LATS_PRED_= LATS_PRED_, LONS_PRED_=LONS_PRED_)
compare_perf_track_7cast(year = 2017, basin='EP', forecast='SHIP', forecast2 = 'HWRF', forecast3='OFCL', forecast4 = 'FSSE', forecast5='AEMN', forecast6 = 'GFSO', forecast7 = 'CLP5', LATS_PRED_= LATS_PRED_, LONS_PRED_=LONS_PRED_)
# Out:
# Number of timesteps: 669
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 110.88 79.15 11.51
# SHIP 77.06 64.11 4.04
# HWRF 72.01 47.85 2.39
# OFCL 70.36 57.78 2.84
# FSSE 67.53 53.48 3.44
# AEMN 72.81 57.98 2.54
# GFSO 70.47 56.01 3.74
# CLP5 197.76 142.19 36.17
# Consensus OFCL only 62.67 50.49 2.09
# Consensus OFCL + Hurricast 60.8 47.42 1.49
# Number of timesteps: 522
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 71.69 43.7 0.57
# SHIP 57.78 33.53 0.38
# HWRF 70.1 43.23 2.11
# OFCL 54.11 31.63 0.19
# FSSE 55.85 53.93 0.96
# AEMN 62.05 36.83 0.57
# GFSO 67.11 45.03 1.34
# CLP5 125.37 70.95 15.13
# Consensus OFCL only 53.04 33.46 0.38
# Consensus OFCL + Hurricast 49.44 30.22 0.19

# %%
#OFCL + TABULAR ONLY
max_depth = 6
n_estimators = 150
learning_rate = 0.05
subsample = 0.7
min_child_weight=5
#col_sample_by_tree = 0.7
train_x = X_test_baseline[:m]
train_y = train_x
test_x = X_test_baseline
test_y = test_x
tgt_train = tgt_displacement_test[:m]
    
xgb_x = XGBRegressor(max_depth=max_depth, n_estimators=n_estimators, learning_rate=learning_rate, subsample=subsample, min_child_weight=min_child_weight)
xgb_x.fit(train_x, tgt_train[:, 0])
xgb_y = XGBRegressor(max_depth=max_depth, n_estimators=n_estimators, learning_rate=learning_rate, subsample=subsample, min_child_weight=min_child_weight)
xgb_y.fit(train_y, tgt_train[:, 1])
DLATS_PRED = np.array(xgb_x.predict(test_x)) * std_dx + mean_dx
DLONS_PRED = np.array(xgb_y.predict(test_y)) * std_dy + mean_dy
LATS_PRED_ = X_test['LAT_7'] + DLATS_PRED
LONS_PRED_ = X_test['LON_7'] + DLONS_PRED
compare_perf_track_7cast(year = 2017, basin='AN', forecast='SHIP', forecast2 = 'HWRF', forecast3='OFCL', forecast4 = 'FSSE', forecast5='AEMN', forecast6 = 'GFSO', forecast7 = 'CLP5', LATS_PRED_= LATS_PRED_, LONS_PRED_=LONS_PRED_)
compare_perf_track_7cast(year = 2017, basin='EP', forecast='SHIP', forecast2 = 'HWRF', forecast3='OFCL', forecast4 = 'FSSE', forecast5='AEMN', forecast6 = 'GFSO', forecast7 = 'CLP5', LATS_PRED_= LATS_PRED_, LONS_PRED_=LONS_PRED_)
# Out:
# Number of timesteps: 669
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 125.48 89.75 15.25
# SHIP 77.06 64.11 4.04
# HWRF 72.01 47.85 2.39
# OFCL 70.36 57.78 2.84
# FSSE 67.53 53.48 3.44
# AEMN 72.81 57.98 2.54
# GFSO 70.47 56.01 3.74
# CLP5 197.76 142.19 36.17
# Consensus OFCL only 62.67 50.49 2.09
# Consensus OFCL + Hurricast 64.15 48.08 1.79
# Number of timesteps: 522
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 73.56 44.74 1.53
# SHIP 57.78 33.53 0.38
# HWRF 70.1 43.23 2.11
# OFCL 54.11 31.63 0.19
# FSSE 55.85 53.93 0.96
# AEMN 62.05 36.83 0.57
# GFSO 67.11 45.03 1.34
# CLP5 125.37 70.95 15.13
# Consensus OFCL only 53.04 33.46 0.38
# Consensus OFCL + Hurricast 50.55 31.22 0.19

# %%
#OFCL + EMBED
max_depth = 7
n_estimators = 200
learning_rate = 0.05
subsample = 0.8
min_child_weight=5
#col_sample_by_tree = 0.7
train_x = np.concatenate((X_test_baseline[:m], X_test_embed[:m]), axis = 1)
train_y = train_x
test_x = np.concatenate((X_test_baseline, X_test_embed), axis = 1)
test_y = test_x
tgt_train = tgt_displacement_test[:m]
    
xgb_x = XGBRegressor(max_depth=max_depth, n_estimators=n_estimators, learning_rate=learning_rate, subsample=subsample, min_child_weight=min_child_weight)
xgb_x.fit(train_x, tgt_train[:, 0])
xgb_y = XGBRegressor(max_depth=max_depth, n_estimators=n_estimators, learning_rate=learning_rate, subsample=subsample, min_child_weight=min_child_weight)
xgb_y.fit(train_y, tgt_train[:, 1])
DLATS_PRED = np.array(xgb_x.predict(test_x)) * std_dx + mean_dx
DLONS_PRED = np.array(xgb_y.predict(test_y)) * std_dy + mean_dy
LATS_PRED_ = X_test['LAT_7'] + DLATS_PRED
LONS_PRED_ = X_test['LON_7'] + DLONS_PRED
compare_perf_track_7cast(year = 2017, basin='AN', forecast='SHIP', forecast2 = 'HWRF', forecast3='OFCL', forecast4 = 'FSSE', forecast5='AEMN', forecast6 = 'GFSO', forecast7 = 'CLP5', LATS_PRED_= LATS_PRED_, LONS_PRED_=LONS_PRED_)
compare_perf_track_7cast(year = 2017, basin='EP', forecast='SHIP', forecast2 = 'HWRF', forecast3='OFCL', forecast4 = 'FSSE', forecast5='AEMN', forecast6 = 'GFSO', forecast7 = 'CLP5', LATS_PRED_= LATS_PRED_, LONS_PRED_=LONS_PRED_)
# Out:
# Number of timesteps: 669
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 94.98 65.2 7.03
# SHIP 77.06 64.11 4.04
# HWRF 72.01 47.85 2.39
# OFCL 70.36 57.78 2.84
# FSSE 67.53 53.48 3.44
# AEMN 72.81 57.98 2.54
# GFSO 70.47 56.01 3.74
# CLP5 197.76 142.19 36.17
# Consensus OFCL only 62.67 50.49 2.09
# Consensus OFCL + Hurricast 60.85 47.9 1.49
# Number of timesteps: 522
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 62.99 37.23 0.38
# SHIP 57.78 33.53 0.38
# HWRF 70.1 43.23 2.11
# OFCL 54.11 31.63 0.19
# FSSE 55.85 53.93 0.96
# AEMN 62.05 36.83 0.57
# GFSO 67.11 45.03 1.34
# CLP5 125.37 70.95 15.13
# Consensus OFCL only 53.04 33.46 0.38
# Consensus OFCL + Hurricast 49.97 30.82 0.19

# %%
x_viz_train = np.load('../data/X_train_vision_comp_1980_34_20_120.npy', allow_pickle=True).reshape(-1, 3*5*3*3)
x_viz_test = np.load('../data/X_test_vision_comp_1980_34_20_120.npy', allow_pickle=True).reshape(-1, 3*5*3*3)[-n:]
x_viz_train = np.concatenate((x_viz_train, x_viz_test[:m]), axis = 0)
X_train_total_comp = np.concatenate((X_train, x_viz_train), axis = 1)
X_test_total_comp = np.concatenate((X_test, x_viz_test), axis = 1)

# %%
#TRAIN TOTAL COMP
max_depth = 9
n_estimators = 150
learning_rate = 0.05
subsample = 0.8
min_child_weight=5
#col_sample_by_tree = 0.7
train_x = X_train_total_comp
train_y = train_x
test_x = X_test_total_comp
test_y = test_x
tgt_train = tgt_displacement_train
    
xgb_x = XGBRegressor(max_depth=max_depth, n_estimators=n_estimators, learning_rate=learning_rate, subsample=subsample, min_child_weight=min_child_weight)
xgb_x.fit(train_x, tgt_train[:, 0])
xgb_y = XGBRegressor(max_depth=max_depth, n_estimators=n_estimators, learning_rate=learning_rate, subsample=subsample, min_child_weight=min_child_weight)
xgb_y.fit(train_y, tgt_train[:, 1])
DLATS_PRED = np.array(xgb_x.predict(test_x)) * std_dx + mean_dx
DLONS_PRED = np.array(xgb_y.predict(test_y)) * std_dy + mean_dy
LATS_PRED_ = X_test['LAT_7'] + DLATS_PRED
LONS_PRED_ = X_test['LON_7'] + DLONS_PRED
compare_perf_track_7cast(year = 2017, basin='AN', forecast='SHIP', forecast2 = 'HWRF', forecast3='OFCL', forecast4 = 'FSSE', forecast5='AEMN', forecast6 = 'GFSO', forecast7 = 'CLP5', LATS_PRED_= LATS_PRED_, LONS_PRED_=LONS_PRED_)
compare_perf_track_7cast(year = 2017, basin='EP', forecast='SHIP', forecast2 = 'HWRF', forecast3='OFCL', forecast4 = 'FSSE', forecast5='AEMN', forecast6 = 'GFSO', forecast7 = 'CLP5', LATS_PRED_= LATS_PRED_, LONS_PRED_=LONS_PRED_)
# Out:
# Number of timesteps: 669
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 134.37 96.2 17.64
# SHIP 77.06 64.11 4.04
# HWRF 72.01 47.85 2.39
# OFCL 70.36 57.78 2.84
# FSSE 67.53 53.48 3.44
# AEMN 72.81 57.98 2.54
# GFSO 70.47 56.01 3.74
# CLP5 197.76 142.19 36.17
# Consensus OFCL only 62.67 50.49 2.09
# Consensus OFCL + Hurricast 63.73 47.34 2.24
# Number of timesteps: 522
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 83.35 47.74 1.53
# SHIP 57.78 33.53 0.38
# HWRF 70.1 43.23 2.11
# OFCL 54.11 31.63 0.19
# FSSE 55.85 53.93 0.96
# AEMN 62.05 36.83 0.57
# GFSO 67.11 45.03 1.34
# CLP5 125.37 70.95 15.13
# Consensus OFCL only 53.04 33.46 0.38
# Consensus OFCL + Hurricast 49.45 30.4 0.19

# %%
compare_perf_track_7cast(year = 2017, basin='EP', forecast='SHIP', forecast2 = 'HWRF', forecast3='OFCL', forecast4 = 'FSSE', forecast5='AEMN', forecast6 = 'GFSO', forecast7 = 'CLP5', LATS_PRED_=LATS_PRED_, LONS_PRED_=LONS_PRED_)
# Out:
# Number of timesteps: 522
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 71.63 45.09 1.15
# SHIP 57.78 33.53 0.38
# HWRF 70.1 43.23 2.11
# OFCL 54.11 31.63 0.19
# FSSE 55.85 53.93 0.96
# AEMN 62.05 36.83 0.57
# GFSO 67.11 45.03 1.34
# CLP5 125.37 70.95 15.13
# Consensus OFCL only 53.04 33.46 0.38
# Consensus OFCL + Hurricast 49.34 30.18 0.19

# %%
compare_perf_track_7cast(year = 2017, basin='EP', forecast='SHIP', forecast2 = 'HWRF', forecast3='OFCL', forecast4 = 'FSSE', forecast5='AEMN', forecast6 = 'GFSO', forecast7 = 'CLP5', LATS_PRED_=LATS_PRED_, LONS_PRED_=LONS_PRED_)
# Out:
# Number of timesteps: 522
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 72.12 44.77 1.15
# SHIP 57.78 33.53 0.38
# HWRF 70.1 43.23 2.11
# OFCL 54.11 31.63 0.19
# FSSE 55.85 53.93 0.96
# AEMN 62.05 36.83 0.57
# GFSO 67.11 45.03 1.34
# CLP5 125.37 70.95 15.13
# Consensus OFCL only 53.04 33.46 0.38
# Consensus OFCL + Hurricast 49.34 30.08 0.19

# %% [markdown]
# # Consensus

# %%
max_depth = 7
n_estimators = 300
learning_rate = 0.03
subsample = 0.8
min_child_weight=5
#col_sample_by_tree = 0.7
train_x = X_train_total
train_y = X_train_total
test_x = X_test_total
test_y = test_x
tgt_train = tgt_displacement_train
    
xgb_x = XGBRegressor(max_depth=max_depth, n_estimators=n_estimators, learning_rate=learning_rate, subsample=subsample, min_child_weight=min_child_weight)
xgb_x.fit(train_x, tgt_train[:, 0])
xgb_y = XGBRegressor(max_depth=max_depth, n_estimators=n_estimators, learning_rate=learning_rate, subsample=subsample, min_child_weight=min_child_weight)
xgb_y.fit(train_y, tgt_train[:, 1])
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#        importance_type='gain', interaction_constraints='',
#        learning_rate=0.03, max_delta_step=0, max_depth=7,
#        min_child_weight=5, missing=nan, monotone_constraints='()',
#        n_estimators=300, n_jobs=0, num_parallel_tree=1,
#        objective='reg:squarederror', random_state=0, reg_alpha=0,
#        reg_lambda=1, scale_pos_weight=1, subsample=0.8,
#        tree_method='exact', validate_parameters=1, verbosity=None)

# %%
year = 2018
forecast='SHIP'
forecast2 = 'HWRF'
forecast3 = 'OFCL'
forecast4 = 'FSSE'
forecast5 = 'GFSO'
forecast6 = 'AEMN'
forecast7 = 'CLP5'
mode = 'lat'
basin = 'AN'
test = X_test_total
DLATS_PRED = np.array(xgb_x.predict(test_x)) * std_dx + mean_dx
DLONS_PRED = np.array(xgb_y.predict(test_y)) * std_dy + mean_dy
LATS_PRED_ = X_test['LAT_7'] + DLATS_PRED
LONS_PRED_ = X_test['LON_7'] + DLONS_PRED

if forecast2 != None:
    if True: 
        baseline_ = X_test_baseline.loc[X_test_baseline['YEAR_0'] < year].loc[
            X_test_baseline[forecast7 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast6 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast5 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast4 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast3 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast2 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast + '_24_' + mode + '_7'] > -320].loc[X_test_baseline['cat_basin_' + basin + '_0'] == 1]  # .loc[#X_test_baseline['SHIP_24_'+mode+'_7'] > 0].index
        if basin == 'EP':
            baseline_ = baseline_.loc[X_test_baseline['YEAR_0'] < 2019]
        index = baseline_.index
        LATS_BASE_2 = np.array(baseline_[forecast2 + '_24_lat_7'])
        LONS_BASE_2 = np.array(baseline_[forecast2 + '_24_lon_7'])
        LATS_BASE_3 = np.array(baseline_[forecast3 + '_24_lat_7'])
        LONS_BASE_3 = np.array(baseline_[forecast3 + '_24_lon_7'])
        LATS_BASE_4 = np.array(baseline_[forecast4 + '_24_lat_7'])
        LONS_BASE_4 = np.array(baseline_[forecast4 + '_24_lon_7'])
        LATS_BASE_5 = np.array(baseline_[forecast5 + '_24_lat_7'])
        LONS_BASE_5 = np.array(baseline_[forecast5 + '_24_lon_7'])
        LATS_BASE_6 = np.array(baseline_[forecast6 + '_24_lat_7'])
        LONS_BASE_6 = np.array(baseline_[forecast6 + '_24_lon_7'])
        LATS_BASE_7 = np.array(baseline_[forecast7 + '_24_lat_7'])
        LONS_BASE_7 = np.array(baseline_[forecast7 + '_24_lon_7'])
        
    LATS_TEST_t = np.array(X_test['LAT_7'] + np.array(tgt_displacement_test[:, 0])*std_dx+mean_dx)[index]
    LONS_TEST_t = np.array(X_test['LON_7'] + np.array(tgt_displacement_test[:, 1])*std_dy+mean_dy)[index]
    tgt_x = (np.array(tgt_displacement_test[:, 0])*std_dx+mean_dx)[index]
    tgt_y = (np.array(tgt_displacement_test[:, 1])*std_dy+mean_dy)[index]
    baseline_1_x = np.array(baseline_[forecast + '_24_'+mode+'_7'])
    baseline_1_y = np.array(baseline_[forecast + '_24_lon_7'])
    baseline_2_x = np.array(baseline_[forecast2 + '_24_'+mode+'_7'])
    baseline_2_y = np.array(baseline_[forecast2 + '_24_lon_7'])
    baseline_3_x = np.array(baseline_[forecast3 + '_24_'+mode+'_7'])
    baseline_3_y = np.array(baseline_[forecast3 + '_24_lon_7'])
    baseline_4_x = np.array(baseline_[forecast4 + '_24_'+mode+'_7'])
    baseline_4_y = np.array(baseline_[forecast4 + '_24_lon_7'])
    baseline_5_x = np.array(baseline_[forecast5 + '_24_'+mode+'_7'])
    baseline_5_y = np.array(baseline_[forecast5 + '_24_lon_7'])
    baseline_6_x = np.array(baseline_[forecast6 + '_24_'+mode+'_7'])
    baseline_6_y = np.array(baseline_[forecast6 + '_24_lon_7'])
    baseline_7_x = np.array(baseline_[forecast7 + '_24_'+mode+'_7'])
    baseline_7_y = np.array(baseline_[forecast7 + '_24_lon_7'])
    LATS_PRED_t = np.array(LATS_PRED_)[index]
    LONS_PRED_t = np.array(LONS_PRED_)[index]
    
    for i in range(len(LATS_PRED_t)):
        if baseline_2_y[i] > 160:
            baseline_1_y[i] -= 360
            baseline_6_y[i] -= 360
            baseline_5_y[i] -= 360
            baseline_2_y[i] -= 360
            baseline_3_y[i] -= 360
        if LONS_PRED_t[i] > 160:
            LONS_PRED_t[i] -= 360
            
            
    train_consensus_x = np.stack((baseline_1_x, baseline_2_x, baseline_3_x, baseline_4_x, baseline_5_x, baseline_6_x), axis = 1)
    train_consensus_y = np.stack((baseline_1_y, baseline_2_y, baseline_3_y, baseline_4_y, baseline_5_y, baseline_6_y), axis = 1)
    train_consensus_hurr_x = np.stack((baseline_1_x, baseline_2_x, baseline_3_x, baseline_4_x, baseline_5_x, baseline_6_x, LATS_PRED_t), axis = 1)
    train_consensus_hurr_y = np.stack((baseline_1_y, baseline_2_y, baseline_3_y, baseline_4_y, baseline_5_y, baseline_6_y, LONS_PRED_t), axis = 1)

base = np.array(X_test['LAT_7'])[index]
for a in base:
    if a > 160:
        a-=360
base_x = np.stack((base, base, base, base, base, base), axis = 1)
train_consensus_x = train_consensus_x - base_x
base_x = np.stack((base, base, base, base, base, base, base), axis = 1)
train_consensus_hurr_x = train_consensus_hurr_x - base_x

base = np.array(X_test['LON_7'])[index]
for a in base:
    if a > 160:
        a-=360
base_y = np.stack((base, base, base, base, base, base), axis = 1)
train_consensus_y = train_consensus_y - base_y
base_y = np.stack((base, base, base, base, base, base, base), axis = 1)
train_consensus_hurr_y = train_consensus_hurr_y - base_y

if forecast2 != None:
    if True:
        baseline_ = X_test_baseline.loc[X_test_baseline['YEAR_0'] == year].loc[
            X_test_baseline[forecast7 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast6 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast5 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast4 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast3 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast2 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast + '_24_' + mode + '_7'] > -320].loc[X_test_baseline['cat_basin_' + basin + '_0'] == 1]  # .loc[#X_test_baseline['SHIP_24_'+mode+'_7'] > 0].index
        if basin == 'EP':
            baseline_ = baseline_.loc[X_test_baseline['YEAR_0'] < 2019]
        index = baseline_.index
        LATS_BASE_2 = np.array(baseline_[forecast2 + '_24_lat_7'])
        LONS_BASE_2 = np.array(baseline_[forecast2 + '_24_lon_7'])
        LATS_BASE_3 = np.array(baseline_[forecast3 + '_24_lat_7'])
        LONS_BASE_3 = np.array(baseline_[forecast3 + '_24_lon_7'])
        LATS_BASE_4 = np.array(baseline_[forecast4 + '_24_lat_7'])
        LONS_BASE_4 = np.array(baseline_[forecast4 + '_24_lon_7'])
        LATS_BASE_5 = np.array(baseline_[forecast5 + '_24_lat_7'])
        LONS_BASE_5 = np.array(baseline_[forecast5 + '_24_lon_7'])
        LATS_BASE_6 = np.array(baseline_[forecast6 + '_24_lat_7'])
        LONS_BASE_6 = np.array(baseline_[forecast6 + '_24_lon_7'])
        LATS_BASE_7 = np.array(baseline_[forecast7 + '_24_lat_7'])
        LONS_BASE_7 = np.array(baseline_[forecast7 + '_24_lon_7'])
        
    LATS_TEST_te = np.array(X_test['LAT_7'] + np.array(tgt_displacement_test[:, 0])*std_dx+mean_dx)[index]
    LONS_TEST_te = np.array(X_test['LON_7'] + np.array(tgt_displacement_test[:, 1])*std_dy+mean_dy)[index]
    or_te_x = np.array(X_test['LAT_7'])[index]
    or_te_y = np.array(X_test['LON_7'])[index]
    baseline_1_x = np.array(baseline_[forecast + '_24_'+mode+'_7'])
    baseline_1_y = np.array(baseline_[forecast + '_24_lon_7'])
    baseline_2_x = np.array(baseline_[forecast2 + '_24_'+mode+'_7'])
    baseline_2_y = np.array(baseline_[forecast2 + '_24_lon_7'])
    baseline_3_x = np.array(baseline_[forecast3 + '_24_'+mode+'_7'])
    baseline_3_y = np.array(baseline_[forecast3 + '_24_lon_7'])
    baseline_4_x = np.array(baseline_[forecast4 + '_24_'+mode+'_7'])
    baseline_4_y = np.array(baseline_[forecast4 + '_24_lon_7'])
    baseline_5_x = np.array(baseline_[forecast5 + '_24_'+mode+'_7'])
    baseline_5_y = np.array(baseline_[forecast5 + '_24_lon_7'])
    baseline_6_x = np.array(baseline_[forecast6 + '_24_'+mode+'_7'])
    baseline_6_y = np.array(baseline_[forecast6 + '_24_lon_7'])
    baseline_7_x = np.array(baseline_[forecast7 + '_24_'+mode+'_7'])
    baseline_7_y = np.array(baseline_[forecast7 + '_24_lon_7'])
    LATS_PRED_te = np.array(LATS_PRED_)[index]
    LONS_PRED_te = np.array(LONS_PRED_)[index]
    
    for i in range(len(LATS_PRED_te)):
        if baseline_2_y[i] > 160:
            baseline_1_y[i] -= 360
            baseline_6_y[i] -= 360
            baseline_5_y[i] -= 360
            baseline_2_y[i] -= 360
            baseline_3_y[i] -= 360
        if LONS_PRED_te[i] > 160:
            LONS_PRED_te[i] -= 360
            
            
    test_consensus_x = np.stack((baseline_1_x, baseline_2_x, baseline_3_x, baseline_4_x, baseline_5_x, baseline_6_x), axis = 1)
    test_consensus_y = np.stack((baseline_1_y, baseline_2_y, baseline_3_y, baseline_4_y, baseline_5_y, baseline_6_y), axis = 1)
    test_consensus_hurr_x = np.stack((baseline_1_x, baseline_2_x, baseline_3_x, baseline_4_x, baseline_5_x, baseline_6_x, LATS_PRED_te), axis = 1)
    test_consensus_hurr_y = np.stack((baseline_1_y, baseline_2_y, baseline_3_y, baseline_4_y, baseline_5_y, baseline_6_y, LONS_PRED_te), axis = 1)

# %%
base = np.array(X_test['LAT_7'])[index]
for a in base:
    if a > 160:
        a-=360
base_x = np.stack((base, base, base, base, base, base), axis = 1)
test_consensus_x = test_consensus_x - base_x
base_x = np.stack((base, base, base, base, base, base, base), axis = 1)
test_consensus_hurr_x = test_consensus_hurr_x - base_x

base = np.array(X_test['LON_7'])[index]
for i in range(len(base)):
    if base[i] > 160:
        base[i]-=360
base_y = np.stack((base, base, base, base, base, base), axis = 1)
test_consensus_y = test_consensus_y - base_y
base_y = np.stack((base, base, base, base, base, base, base), axis = 1)
test_consensus_hurr_y = test_consensus_hurr_y - base_y

# %%
plt.plot(train_consensus_hurr_y)
plt.show()

# %%
ss = StandardScaler()
train_consensus_x = ss.fit_transform(train_consensus_x)
test_consensus_x = ss.transform(test_consensus_x)
ss2 = StandardScaler()
train_consensus_y = ss.fit_transform(train_consensus_y)
test_consensus_y = ss.transform(test_consensus_y)

ss3 = StandardScaler()
train_consensus_hurr_x = ss3.fit_transform(train_consensus_hurr_x)
test_consensus_hurr_x = ss3.transform(test_consensus_hurr_x)

ss4 = StandardScaler()
train_consensus_hurr_y = ss4.fit_transform(train_consensus_hurr_y)
test_consensus_hurr_y = ss4.transform(test_consensus_hurr_y)

# %%
#AN
m_x = Lasso(alpha = 1e-2)
m_x.fit(train_consensus_x, tgt_x)
preds_x = np.array(m_x.predict(test_consensus_x))+np.array(X_test['LAT_7'])[index]

m_y = Lasso(alpha = 1e-2)
m_y.fit(train_consensus_y, tgt_y)
preds_y = np.array(m_y.predict(test_consensus_y)) + base
d_km_pred = np.zeros(len(preds_y))
for i in range(len(LATS_PRED_te)):
    d_km_pred[i] = get_distance_km(preds_y[i], preds_x[i], LONS_TEST_te[i], LATS_TEST_te[i])
    
print("Number of timesteps:", len(LATS_PRED_te))
print(basin, 'Model | MAE | std | %age busts (>200km)')
print("Lasso consensus w/o hurricast", np.around(d_km_pred.mean(), decimals = 2), np.around(d_km_pred.std(), decimals = 2), np.around(sum(d_km_pred > 200)*100/len(LATS_PRED_te), decimals = 2))
# Out:
# Number of timesteps: 208
# AN Model | MAE | std | %age busts (>200km)
# Lasso consensus w/o hurricast 75.12 61.65 3.37

# %%
m_x.coef_
# Out:
# array([0.11675539, 0.12194418, 0.06753393, 0.04809728, 0.        ,
#        0.4216699 , 0.42720285], dtype=float32)

# %%
#AN
m_x = Lasso(alpha = 1e-2)
m_x.fit(train_consensus_hurr_x, tgt_x)
preds_x = np.array(m_x.predict(test_consensus_hurr_x))+np.array(X_test['LAT_7'])[index]

m_y = Lasso(alpha = 1e-5)
m_y.fit(train_consensus_hurr_y, tgt_y)
preds_y = np.array(m_y.predict(test_consensus_hurr_y)) + base
d_km_pred = np.zeros(len(preds_y))
for i in range(len(LATS_PRED_te)):
    d_km_pred[i] = get_distance_km(preds_y[i], preds_x[i], LONS_TEST_te[i], LATS_TEST_te[i])
    
print("Number of timesteps:", len(LATS_PRED_te))
print(basin, 'Model | MAE | std | %age busts (>200km)')
print("Lasso consensus w/ hurricast", np.around(d_km_pred.mean(), decimals = 2), np.around(d_km_pred.std(), decimals = 2), np.around(sum(d_km_pred > 200)*100/len(LATS_PRED_te), decimals = 2))
# Out:
# Number of timesteps: 234
# AN Model | MAE | std | %age busts (>200km)
# Lasso consensus w/ hurricast 55.27 37.77 0.43

# %%
m_x.coef_
# Out:
# array([0.06311011, 0.08034991, 0.12576918, 0.08482026, 0.        ,
#        0.37070432, 0.39127246], dtype=float32)

# %% [markdown]
# # Old again

# %%
index_t = X_train.loc[X_train['cat_basin_AN_0'] + X_train['cat_basin_EP_0'] == 1].index
index_te = X_test[:17094].loc[X_test['cat_basin_AN_0'] + X_test['cat_basin_EP_0'] == 1].index
train = np.concatenate((X_train_total[index_t], X_test_total[index_te]), axis = 0)
tgt_train_ = np.concatenate((tgt_displacement_train[index_t], tgt_displacement_test[index_te]), axis = 0)

# %%
#TRAIN TOTAL
max_depth = 7
n_estimators = 150
learning_rate = 0.05
subsample = 0.8
min_child_weight=5
#col_sample_by_tree = 0.7
train_x = train
train_y = train_x
test_x = X_test_total
test_y = X_test_total
tgt_train = tgt_train_
    
xgb_x = XGBRegressor(max_depth=max_depth, n_estimators=n_estimators, learning_rate=learning_rate, subsample=subsample, min_child_weight=min_child_weight)
xgb_x.fit(train_x, tgt_train[:, 0])
xgb_y = XGBRegressor(max_depth=max_depth, n_estimators=n_estimators, learning_rate=learning_rate, subsample=subsample, min_child_weight=min_child_weight)
xgb_y.fit(train_y, tgt_train[:, 1])
DLATS_PRED = np.array(xgb_x.predict(test_x)) * std_dx + mean_dx
DLONS_PRED = np.array(xgb_y.predict(test_y)) * std_dy + mean_dy
LATS_PRED_ = X_test['LAT_7'] + DLATS_PRED
LONS_PRED_ = X_test['LON_7'] + DLONS_PRED
compare_perf_track_7cast(year = 2017, basin='AN', forecast='SHIP', forecast2 = 'HWRF', forecast3='OFCL', forecast4 = 'FSSE', forecast5='AEMN', forecast6 = 'GFSO', forecast7 = 'CLP5', LATS_PRED_= LATS_PRED_, LONS_PRED_=LONS_PRED_)
compare_perf_track_7cast(year = 2017, basin='EP', forecast='SHIP', forecast2 = 'HWRF', forecast3='OFCL', forecast4 = 'FSSE', forecast5='AEMN', forecast6 = 'GFSO', forecast7 = 'CLP5', LATS_PRED_= LATS_PRED_, LONS_PRED_=LONS_PRED_)
# Out:
# Number of timesteps: 669
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 109.44 75.91 11.36
# SHIP 77.06 64.11 4.04
# HWRF 72.01 47.85 2.39
# OFCL 70.36 57.78 2.84
# FSSE 67.53 53.48 3.44
# AEMN 72.81 57.98 2.54
# GFSO 70.47 56.01 3.74
# CLP5 197.76 142.19 36.17
# Consensus OFCL only 62.67 50.49 2.09
# Consensus OFCL + Hurricast 60.48 47.27 1.49
# Number of timesteps: 522
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 71.31 43.96 0.77
# SHIP 57.78 33.53 0.38
# HWRF 70.1 43.23 2.11
# OFCL 54.11 31.63 0.19
# FSSE 55.85 53.93 0.96
# AEMN 62.05 36.83 0.57
# GFSO 67.11 45.03 1.34
# CLP5 125.37 70.95 15.13
# Consensus OFCL only 53.04 33.46 0.38
# Consensus OFCL + Hurricast 49.29 30.13 0.19

# %%
index_t = X_test_baseline[:m].loc[X_test_baseline['cat_basin_AN_0'] + X_test_baseline['cat_basin_EP_0'] == 1].index
train = np.concatenate((np.array(X_test_baseline[:m])[index_t], X_test_embed[index_t]), axis = 1)
tgt_train_ = tgt_displacement_test[index_t]

# %%
#TRAIN TOTAL
max_depth = 8
n_estimators = 150
learning_rate = 0.07
subsample = 0.7
min_child_weight=1
#col_sample_by_tree = 0.7
train_x = train
train_y = train_x
test_x = np.concatenate((X_test_baseline, X_test_embed), axis = 1)
test_y = test_x
tgt_train = tgt_train_
    
xgb_x = XGBRegressor(max_depth=max_depth, n_estimators=n_estimators, learning_rate=learning_rate, subsample=subsample, min_child_weight=min_child_weight)
xgb_x.fit(train_x, tgt_train[:, 0])
xgb_y = XGBRegressor(max_depth=max_depth, n_estimators=n_estimators, learning_rate=learning_rate, subsample=subsample, min_child_weight=min_child_weight)
xgb_y.fit(train_y, tgt_train[:, 1])
DLATS_PRED = np.array(xgb_x.predict(test_x)) * std_dx + mean_dx
DLONS_PRED = np.array(xgb_y.predict(test_y)) * std_dy + mean_dy
LATS_PRED_ = X_test['LAT_7'] + DLATS_PRED
LONS_PRED_ = X_test['LON_7'] + DLONS_PRED
a, b = compare_perf_track_7cast(year = 2017, basin='AN', forecast='SHIP', forecast2 = 'HWRF', forecast3='OFCL', forecast4 = 'FSSE', forecast5='AEMN', forecast6 = 'GFSO', forecast7 = 'CLP5', LATS_PRED_= LATS_PRED_, LONS_PRED_=LONS_PRED_)
c, d = compare_perf_track_7cast(year = 2017, basin='EP', forecast='SHIP', forecast2 = 'HWRF', forecast3='OFCL', forecast4 = 'FSSE', forecast5='AEMN', forecast6 = 'GFSO', forecast7 = 'CLP5', LATS_PRED_= LATS_PRED_, LONS_PRED_=LONS_PRED_)
# Out:
# Number of timesteps: 669
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 100.64 82.46 8.52
# SHIP 77.06 64.11 4.04
# HWRF 72.01 47.85 2.39
# OFCL 70.36 57.78 2.84
# FSSE 67.53 53.48 3.44
# AEMN 72.81 57.98 2.54
# GFSO 70.47 56.01 3.74
# CLP5 197.76 142.19 36.17
# Consensus OFCL only 62.67 50.49 2.09
# Consensus OFCL + Hurricast 61.57 48.15 1.49
# Number of timesteps: 522
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 58.91 32.78 0.38
# SHIP 57.78 33.53 0.38
# HWRF 70.1 43.23 2.11
# OFCL 54.11 31.63 0.19
# FSSE 55.85 53.93 0.96
# AEMN 62.05 36.83 0.57
# GFSO 67.11 45.03 1.34
# CLP5 125.37 70.95 15.13
# Consensus OFCL only 53.04 33.46 0.38
# Consensus OFCL + Hurricast 50.4 31.16 0.38

# %%
a[217:220] > 400
# Out:
# array([ True,  True,  True])

# %%
b = pd.DataFrame(b)
b.columns = cols

# %%
plt.plot(a, b['STORM_DISPLACEMENT_Y_7'], 'bo')

# %%
e = pd.DataFrame(a)
e.columns = ['Target']
# Out:
#          Target
# 0     29.570558
# 1     94.404688
# 2    144.106247
# 3    110.543451
# 4     30.600302
# ..          ...
# 664  356.724132
# 665   81.134094
# 666  306.872005
# 667  303.261238
# 668  391.611776
#
# [669 rows x 1 columns]

# %%
df = pd.concat((b, e), axis = 1)

# %%
df.iloc[217][-30:]
# Out:
# STORM_DISPLACEMENT_Y_5       0.566200
# LAT_6                       32.985100
# LON_6                      -30.674999
# WMO_WIND_6                  90.000000
# WMO_PRES_6                 966.500000
# DIST2LAND_6               1425.000000
# STORM_SPEED_6               17.000000
# COS_STORM_DIR_6              0.469472
# SIN_STORM_DIR_6              0.882948
# COS_LAT_6                    0.838812
# SIN_LAT_6                    0.544421
# COS_LON_6                    0.860075
# SIN_LON_6                   -0.510168
# STORM_DISPLACEMENT_X_6       0.385100
# STORM_DISPLACEMENT_Y_6       0.825000
# LAT_7                       33.400002
# LON_7                      -29.700001
# WMO_WIND_7                  95.000000
# WMO_PRES_7                 963.000000
# DIST2LAND_7               1353.000000
# STORM_SPEED_7               18.000000
# COS_STORM_DIR_7              0.438371
# SIN_STORM_DIR_7              0.898794
# COS_LAT_7                    0.834848
# SIN_LAT_7                    0.550481
# COS_LON_7                    0.868632
# SIN_LON_7                   -0.495459
# STORM_DISPLACEMENT_X_7       0.414900
# STORM_DISPLACEMENT_Y_7       0.975000
# Target                     417.674352
# Name: 217, dtype: float64

# %%
df.corrwith(df['Target'])[-30:]
# Out:
# STORM_DISPLACEMENT_Y_5    0.528886
# LAT_6                     0.361303
# LON_6                     0.257946
# WMO_WIND_6               -0.213017
# WMO_PRES_6                0.156788
# DIST2LAND_6               0.181879
# STORM_SPEED_6             0.430201
# COS_STORM_DIR_6           0.030040
# SIN_STORM_DIR_6           0.443096
# COS_LAT_6                -0.404716
# SIN_LAT_6                 0.349151
# COS_LON_6                 0.249357
# SIN_LON_6                 0.263808
# STORM_DISPLACEMENT_X_6    0.304211
# STORM_DISPLACEMENT_Y_6    0.543905
# LAT_7                     0.369798
# LON_7                     0.274303
# WMO_WIND_7               -0.215459
# WMO_PRES_7                0.160926
# DIST2LAND_7               0.183372
# STORM_SPEED_7             0.450341
# COS_STORM_DIR_7           0.029825
# SIN_STORM_DIR_7           0.435316
# COS_LAT_7                -0.414633
# SIN_LAT_7                 0.356799
# COS_LON_7                 0.263034
# SIN_LON_7                 0.285186
# STORM_DISPLACEMENT_X_7    0.318487
# STORM_DISPLACEMENT_Y_7    0.552833
# Target                    1.000000
# dtype: float64

# %% [markdown]
# # New results

# %% [markdown]
# ## STAT ONLY

# %%
train_xgb_track_all_years(X_train, X_test, tgt_displacement_train, max_depth=6, learning_rate=0.03, n_estimators=200, subsample=0.8, min_child_weight = 5, basin = 'EP')
# Out:
# YEAR 2016
# Number of timesteps: 315
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 83.34 49.27 3.49
# SHIP 57.85 34.92 0.32
# HWRF 61.82 40.02 1.9
# OFCL 54.09 34.1 0.0
# FSSE 55.8 33.86 0.32
# GFSO 60.33 44.6 1.9
# AEMN 56.33 37.91 0.63
# CLP5 113.55 58.53 7.62
# Consensus OFCL only 50.84 33.91 0.0
# Consensus OFCL + Hurricast 47.71 31.79 0.0
#
#
# YEAR 2017
# Number of timesteps: 167
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 74.73 41.61 0.6
# SHIP 59.96 35.47 0.6
# HWRF 74.58 40.85 2.4
# OFCL 55.2 33.37 0.0
# FSSE 54.98 35.64 0.6
# GFSO 73.68 45.78 1.2
# AEMN 68.34 40.13 1.2
# CLP5 108.57 61.48 8.38
# Consensus OFCL only 57.64 34.02 0.6
# Consensus OFCL + Hurricast 51.59 31.34 0.0
#
#
# YEAR 2018
# Number of timesteps: 355
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 93.21 52.67 3.94
# SHIP 56.76 32.53 0.28
# HWRF 67.99 44.14 1.97
# OFCL 53.6 30.77 0.28
# FSSE 56.26 60.66 1.13
# GFSO 64.01 44.34 1.41
# AEMN 59.09 34.78 0.28
# CLP5 133.27 73.69 18.31
# Consensus OFCL only 50.88 32.97 0.28
# Consensus OFCL + Hurricast 49.14 30.38 0.28
# {'MAES_AEMN': [60.33, 73.68, 64.01],
#  'MAES_CLP5': [113.55, 108.57, 133.27],
#  'MAES_FSSE': [55.8, 54.98, 56.26],
#  'MAES_GFSO': [56.33, 68.34, 59.09],
#  'MAES_HWRF': [61.82, 74.58, 67.99],
#  'MAES_OFCL': [54.09, 55.2, 53.6],
#  'MAES_SHIP': [57.85, 59.96, 56.76],
#  'MAEs_full': [83.34, 74.73, 93.21],
#  'num_samples': [315, 167, 355],
#  'std_AEMN': [44.6, 45.78, 44.34],
#  'std_CLP5': [58.53, 61.48, 73.69],
#  'std_FSSE': [33.86, 35.64, 60.66],
#  'std_GFSO': [37.91, 40.13, 34.78],
#  'std_HWRF': [40.02, 40.85, 44.14],
#  'std_OFCL': [34.1, 33.37, 30.77],
#  'std_SHIP': [34.92, 35.47, 32.53],
#  'std_full': [49.27, 41.61, 52.67],
#  'year': [2016, 2017, 2018]}

# %%
train_xgb_track_all_years(X_train, X_test, tgt_displacement_train, max_depth=6, learning_rate=0.03, n_estimators=200, subsample=0.8, min_child_weight = 5, basin = 'EP')
# Out:
# YEAR 2017
# Number of timesteps: 167
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 74.7 41.21 0.6
# SHIP 59.96 35.47 0.6
# HWRF 74.58 40.85 2.4
# OFCL 55.2 33.37 0.0
# FSSE 54.98 35.64 0.6
# GFSO 73.68 45.78 1.2
# AEMN 68.34 40.13 1.2
# CLP5 108.57 61.48 8.38
# Consensus OFCL only 57.64 34.02 0.6
# Consensus OFCL + Hurricast 51.69 31.29 0.0
#
#
# YEAR 2018
# Number of timesteps: 355
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 92.69 52.0 3.94
# SHIP 56.76 32.53 0.28
# HWRF 67.99 44.14 1.97
# OFCL 53.6 30.77 0.28
# FSSE 56.26 60.66 1.13
# GFSO 64.01 44.34 1.41
# AEMN 59.09 34.78 0.28
# CLP5 133.27 73.69 18.31
# Consensus OFCL only 50.88 32.97 0.28
# Consensus OFCL + Hurricast 49.09 30.3 0.28
#
#
# YEAR 2019
# Number of timesteps: 0
# EP Model | MAE | std | %age busts (>200km)
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-15-15f203bf527d> in <module>()
# ----> 1 train_xgb_track_all_years(X_train, X_test, tgt_displacement_train, max_depth=6, learning_rate=0.03, n_estimators=200, subsample=0.8, min_child_weight = 5, basin = 'EP')
#
# <ipython-input-12-e341c7853109> in train_xgb_track_all_years(train, test, tgt_train, max_depth, n_estimators, learning_rate, subsample, min_child_weight, basin, forecast, forecast2, forecast3, forecast4, forecast5, forecast6, forecast7)
#      32             print("YEAR", year)
#      33             #compare_perf_track_7cast(year = year, basin=basin, forecast='SHIP', forecast2 = 'HWRF', forecast3='OFCL', forecast4 = 'FSSE', forecast5='AEMN', forecast6 = 'GFSO', forecast7 = 'CLP5', LATS_PRED_= LATS_PRED_2012, LONS_PRED_=LONS_PRED_2012)
# ---> 34             compare_perf_track_7cast(dict = dict, year = year, basin=basin, forecast=forecast, forecast2 = forecast2, forecast3=forecast3, forecast4 = forecast4, forecast5=forecast5, forecast6 = forecast6, forecast7 = forecast7, LATS_PRED_= LATS_PRED_, LONS_PRED_=LONS_PRED_)
#      35             print("\n")
#      36         #except:
#
# <ipython-input-13-167b35af484c> in compare_perf_track_7cast(dict, LATS_PRED_, LONS_PRED_, year, basin, forecast, forecast2, forecast3, forecast4, forecast5, forecast6, forecast7)
#      73     print("Number of timesteps:", len(LATS_PRED_))
#      74     print(basin, 'Model | MAE | std | %age busts (>200km)')
# ---> 75     print("Hurricast", np.around(d_km_pred.mean(), decimals = 2), np.around(d_km_pred.std(), decimals = 2), np.around(sum(d_km_pred > 200)*100/len(LATS_PRED_), decimals = 2))
#      76     print(forecast, np.around(d_km_baseline.mean(), decimals = 2), np.around(d_km_baseline.std(), decimals = 2), np.around(sum(d_km_baseline > 200)*100/len(LATS_PRED_), decimals = 2))
#      77     print(forecast2, np.around(d_km_baseline2.mean(), decimals = 2), np.around(d_km_baseline2.std(), decimals = 2), np.around(sum(d_km_baseline2 > 200)*100/len(LATS_PRED_), decimals = 2))
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ## TENSOR COMP

# %%
train_xgb_track_all_years(X_train_total_comp, X_test_total_comp, tgt_displacement_train, max_depth=9, learning_rate=0.03, n_estimators=200, subsample=0.8, min_child_weight = 5, basin = 'EP')
# Out:
# YEAR 2016
# Number of timesteps: 315
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 80.45 48.16 3.49
# SHIP 57.85 34.92 0.32
# HWRF 61.82 40.02 1.9
# OFCL 54.09 34.1 0.0
# FSSE 55.8 33.86 0.32
# GFSO 60.33 44.6 1.9
# AEMN 56.33 37.91 0.63
# CLP5 113.55 58.53 7.62
# Consensus OFCL only 50.84 33.91 0.0
# Consensus OFCL + Hurricast 47.32 31.6 0.0
#
#
# YEAR 2017
# Number of timesteps: 167
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 72.09 39.81 0.6
# SHIP 59.96 35.47 0.6
# HWRF 74.58 40.85 2.4
# OFCL 55.2 33.37 0.0
# FSSE 54.98 35.64 0.6
# GFSO 73.68 45.78 1.2
# AEMN 68.34 40.13 1.2
# CLP5 108.57 61.48 8.38
# Consensus OFCL only 57.64 34.02 0.6
# Consensus OFCL + Hurricast 51.81 31.04 0.0
#
#
# YEAR 2018
# Number of timesteps: 355
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 88.19 50.13 2.25
# SHIP 56.76 32.53 0.28
# HWRF 67.99 44.14 1.97
# OFCL 53.6 30.77 0.28
# FSSE 56.26 60.66 1.13
# GFSO 64.01 44.34 1.41
# AEMN 59.09 34.78 0.28
# CLP5 133.27 73.69 18.31
# Consensus OFCL only 50.88 32.97 0.28
# Consensus OFCL + Hurricast 48.48 29.96 0.28
# {'MAES_AEMN': [60.33, 73.68, 64.01],
#  'MAES_CLP5': [113.55, 108.57, 133.27],
#  'MAES_FSSE': [55.8, 54.98, 56.26],
#  'MAES_GFSO': [56.33, 68.34, 59.09],
#  'MAES_HWRF': [61.82, 74.58, 67.99],
#  'MAES_OFCL': [54.09, 55.2, 53.6],
#  'MAES_SHIP': [57.85, 59.96, 56.76],
#  'MAEs_full': [80.45, 72.09, 88.19],
#  'num_samples': [315, 167, 355],
#  'std_AEMN': [44.6, 45.78, 44.34],
#  'std_CLP5': [58.53, 61.48, 73.69],
#  'std_FSSE': [33.86, 35.64, 60.66],
#  'std_GFSO': [37.91, 40.13, 34.78],
#  'std_HWRF': [40.02, 40.85, 44.14],
#  'std_OFCL': [34.1, 33.37, 30.77],
#  'std_SHIP': [34.92, 35.47, 32.53],
#  'std_full': [48.16, 39.81, 50.13],
#  'year': [2016, 2017, 2018]}

# %% [markdown]
# ## TOTAL

# %%
train_xgb_track_all_years(X_train_total, X_test_total, tgt_displacement_train, max_depth=8, learning_rate=0.05, n_estimators=300, subsample=0.9, min_child_weight = 5, basin = 'AN')
# Out:
# YEAR 2017
# Number of timesteps: 227
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 94.35 56.73 6.61
# SHIP 69.37 47.68 2.2
# HWRF 68.37 43.9 1.32
# OFCL 62.04 43.55 0.88
# FSSE 61.54 40.54 0.88
# GFSO 65.42 44.95 2.2
# AEMN 70.04 42.93 0.44
# CLP5 188.66 135.42 31.72
# Consensus OFCL only 58.32 39.58 0.88
# Consensus OFCL + Hurricast 55.54 37.5 0.88
#
#
# YEAR 2018
# Number of timesteps: 234
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 103.94 56.05 6.41
# SHIP 72.49 53.06 1.71
# HWRF 66.66 47.18 2.56
# OFCL 66.41 48.47 1.28
# FSSE 63.42 44.21 2.14
# GFSO 61.83 48.23 2.56
# AEMN 61.86 47.43 0.85
# CLP5 198.56 118.19 41.03
# Consensus OFCL only 55.09 43.11 0.85
# Consensus OFCL + Hurricast 55.44 39.03 0.85
#
#
# YEAR 2019
# Number of timesteps: 208
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 117.5 85.07 13.46
# SHIP 90.58 85.44 8.65
# HWRF 82.0 51.08 3.37
# OFCL 83.88 75.84 6.73
# FSSE 78.68 70.89 7.69
# GFSO 85.71 70.17 6.73
# AEMN 88.13 76.76 6.73
# CLP5 206.79 170.66 35.58
# Consensus OFCL only 75.94 64.34 4.81
# Consensus OFCL + Hurricast 72.24 60.52 3.85
# {'MAES_AEMN': [65.42, 61.83, 85.71],
#  'MAES_CLP5': [188.66, 198.56, 206.79],
#  'MAES_FSSE': [61.54, 63.42, 78.68],
#  'MAES_GFSO': [70.04, 61.86, 88.13],
#  'MAES_HWRF': [68.37, 66.66, 82.0],
#  'MAES_OFCL': [62.04, 66.41, 83.88],
#  'MAES_SHIP': [69.37, 72.49, 90.58],
#  'MAEs_full': [94.35, 103.94, 117.5],
#  'num_samples': [227, 234, 208],
#  'std_AEMN': [44.95, 48.23, 70.17],
#  'std_CLP5': [135.42, 118.19, 170.66],
#  'std_FSSE': [40.54, 44.21, 70.89],
#  'std_GFSO': [42.93, 47.43, 76.76],
#  'std_HWRF': [43.9, 47.18, 51.08],
#  'std_OFCL': [43.55, 48.47, 75.84],
#  'std_SHIP': [47.68, 53.06, 85.44],
#  'std_full': [56.73, 56.05, 85.07],
#  'year': [2017, 2018, 2019]}

# %%
train_xgb_track_all_years(X_train_total, X_test_total, tgt_displacement_train, max_depth=9, learning_rate=0.05, n_estimators=300, subsample=0.8, min_child_weight = 5, basin = 'AN')
# Out:
# YEAR 2017
# Number of timesteps: 227
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 95.84 58.6 7.49
# SHIP 69.37 47.68 2.2
# HWRF 68.37 43.9 1.32
# OFCL 62.04 43.55 0.88
# FSSE 61.54 40.54 0.88
# GFSO 65.42 44.95 2.2
# AEMN 70.04 42.93 0.44
# CLP5 188.66 135.42 31.72
# Consensus OFCL only 58.32 39.58 0.88
# Consensus OFCL + Hurricast 55.85 37.79 0.88
#
#
# YEAR 2018
# Number of timesteps: 234
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 101.52 55.08 5.98
# SHIP 72.49 53.06 1.71
# HWRF 66.66 47.18 2.56
# OFCL 66.41 48.47 1.28
# FSSE 63.42 44.21 2.14
# GFSO 61.83 48.23 2.56
# AEMN 61.86 47.43 0.85
# CLP5 198.56 118.19 41.03
# Consensus OFCL only 55.09 43.11 0.85
# Consensus OFCL + Hurricast 55.05 38.98 0.85
#
#
# YEAR 2019
# Number of timesteps: 208
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 117.92 86.41 12.5
# SHIP 90.58 85.44 8.65
# HWRF 82.0 51.08 3.37
# OFCL 83.88 75.84 6.73
# FSSE 78.68 70.89 7.69
# GFSO 85.71 70.17 6.73
# AEMN 88.13 76.76 6.73
# CLP5 206.79 170.66 35.58
# Consensus OFCL only 75.94 64.34 4.81
# Consensus OFCL + Hurricast 72.39 60.43 3.85
# {'MAES_AEMN': [65.42, 61.83, 85.71],
#  'MAES_CLP5': [188.66, 198.56, 206.79],
#  'MAES_FSSE': [61.54, 63.42, 78.68],
#  'MAES_GFSO': [70.04, 61.86, 88.13],
#  'MAES_HWRF': [68.37, 66.66, 82.0],
#  'MAES_OFCL': [62.04, 66.41, 83.88],
#  'MAES_SHIP': [69.37, 72.49, 90.58],
#  'MAEs_full': [95.84, 101.52, 117.92],
#  'num_samples': [227, 234, 208],
#  'std_AEMN': [44.95, 48.23, 70.17],
#  'std_CLP5': [135.42, 118.19, 170.66],
#  'std_FSSE': [40.54, 44.21, 70.89],
#  'std_GFSO': [42.93, 47.43, 76.76],
#  'std_HWRF': [43.9, 47.18, 51.08],
#  'std_OFCL': [43.55, 48.47, 75.84],
#  'std_SHIP': [47.68, 53.06, 85.44],
#  'std_full': [58.6, 55.08, 86.41],
#  'year': [2017, 2018, 2019]}

# %%
train_xgb_track_all_years(X_train_total, X_test_total, tgt_displacement_train, max_depth=9, learning_rate=0.05, n_estimators=300, subsample=0.9, min_child_weight = 1, basin = 'AN')
# Out:
# YEAR 2017
# Number of timesteps: 227
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 94.58 58.31 6.61
# SHIP 69.37 47.68 2.2
# HWRF 68.37 43.9 1.32
# OFCL 62.04 43.55 0.88
# FSSE 61.54 40.54 0.88
# GFSO 65.42 44.95 2.2
# AEMN 70.04 42.93 0.44
# CLP5 188.66 135.42 31.72
# Consensus OFCL only 58.32 39.58 0.88
# Consensus OFCL + Hurricast 55.83 37.68 0.88
#
#
# YEAR 2018
# Number of timesteps: 234
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 101.62 57.01 6.41
# SHIP 72.49 53.06 1.71
# HWRF 66.66 47.18 2.56
# OFCL 66.41 48.47 1.28
# FSSE 63.42 44.21 2.14
# GFSO 61.83 48.23 2.56
# AEMN 61.86 47.43 0.85
# CLP5 198.56 118.19 41.03
# Consensus OFCL only 55.09 43.11 0.85
# Consensus OFCL + Hurricast 55.23 39.06 0.85
#
#
# YEAR 2019
# Number of timesteps: 208
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 117.4 86.07 12.5
# SHIP 90.58 85.44 8.65
# HWRF 82.0 51.08 3.37
# OFCL 83.88 75.84 6.73
# FSSE 78.68 70.89 7.69
# GFSO 85.71 70.17 6.73
# AEMN 88.13 76.76 6.73
# CLP5 206.79 170.66 35.58
# Consensus OFCL only 75.94 64.34 4.81
# Consensus OFCL + Hurricast 72.57 60.52 3.85
# {'MAES_AEMN': [65.42, 61.83, 85.71],
#  'MAES_CLP5': [188.66, 198.56, 206.79],
#  'MAES_FSSE': [61.54, 63.42, 78.68],
#  'MAES_GFSO': [70.04, 61.86, 88.13],
#  'MAES_HWRF': [68.37, 66.66, 82.0],
#  'MAES_OFCL': [62.04, 66.41, 83.88],
#  'MAES_SHIP': [69.37, 72.49, 90.58],
#  'MAEs_full': [94.58, 101.62, 117.4],
#  'num_samples': [227, 234, 208],
#  'std_AEMN': [44.95, 48.23, 70.17],
#  'std_CLP5': [135.42, 118.19, 170.66],
#  'std_FSSE': [40.54, 44.21, 70.89],
#  'std_GFSO': [42.93, 47.43, 76.76],
#  'std_HWRF': [43.9, 47.18, 51.08],
#  'std_OFCL': [43.55, 48.47, 75.84],
#  'std_SHIP': [47.68, 53.06, 85.44],
#  'std_full': [58.31, 57.01, 86.07],
#  'year': [2017, 2018, 2019]}

# %%
#EMBED
train_xgb_track_all_years(X_train_embed, X_test_embed, tgt_displacement_train, max_depth=6, learning_rate=0.03, n_estimators=300, subsample=0.8, basin = 'AN')
# Out:
# YEAR 2017
# Number of timesteps: 227
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 97.81 59.43 8.37
# SHIP 69.37 47.68 2.2
# HWRF 68.37 43.9 1.32
# OFCL 62.04 43.55 0.88
# FSSE 61.54 40.54 0.88
# GFSO 65.42 44.95 2.2
# AEMN 70.04 42.93 0.44
# CLP5 188.66 135.42 31.72
# Consensus OFCL only 58.32 39.58 0.88
# Consensus OFCL + Hurricast 55.98 37.61 0.88
#
#
# YEAR 2018
# Number of timesteps: 234
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 104.49 55.2 5.56
# SHIP 72.49 53.06 1.71
# HWRF 66.66 47.18 2.56
# OFCL 66.41 48.47 1.28
# FSSE 63.42 44.21 2.14
# GFSO 61.83 48.23 2.56
# AEMN 61.86 47.43 0.85
# CLP5 198.56 118.19 41.03
# Consensus OFCL only 55.09 43.11 0.85
# Consensus OFCL + Hurricast 55.29 39.25 0.85
#
#
# YEAR 2019
# Number of timesteps: 208
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 118.62 84.57 13.94
# SHIP 90.58 85.44 8.65
# HWRF 82.0 51.08 3.37
# OFCL 83.88 75.84 6.73
# FSSE 78.68 70.89 7.69
# GFSO 85.71 70.17 6.73
# AEMN 88.13 76.76 6.73
# CLP5 206.79 170.66 35.58
# Consensus OFCL only 75.94 64.34 4.81
# Consensus OFCL + Hurricast 72.62 60.6 3.85
# {'MAES_AEMN': [65.42, 61.83, 85.71],
#  'MAES_CLP5': [188.66, 198.56, 206.79],
#  'MAES_FSSE': [61.54, 63.42, 78.68],
#  'MAES_GFSO': [70.04, 61.86, 88.13],
#  'MAES_HWRF': [68.37, 66.66, 82.0],
#  'MAES_OFCL': [62.04, 66.41, 83.88],
#  'MAES_SHIP': [69.37, 72.49, 90.58],
#  'MAEs_full': [97.81, 104.49, 118.62],
#  'num_samples': [227, 234, 208],
#  'std_AEMN': [44.95, 48.23, 70.17],
#  'std_CLP5': [135.42, 118.19, 170.66],
#  'std_FSSE': [40.54, 44.21, 70.89],
#  'std_GFSO': [42.93, 47.43, 76.76],
#  'std_HWRF': [43.9, 47.18, 51.08],
#  'std_OFCL': [43.55, 48.47, 75.84],
#  'std_SHIP': [47.68, 53.06, 85.44],
#  'std_full': [59.43, 55.2, 84.57],
#  'year': [2017, 2018, 2019]}

# %%
train_xgb_track_all_years(X_train_embed, X_test_embed, tgt_displacement_train, max_depth=7, learning_rate=0.03, n_estimators=300, subsample=0.8, basin = 'AN')
# Out:
# YEAR 2017
# Number of timesteps: 227
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 96.45 57.84 7.49
# SHIP 69.37 47.68 2.2
# HWRF 68.37 43.9 1.32
# OFCL 62.04 43.55 0.88
# FSSE 61.54 40.54 0.88
# GFSO 65.42 44.95 2.2
# AEMN 70.04 42.93 0.44
# CLP5 188.66 135.42 31.72
# Consensus OFCL only 58.32 39.58 0.88
# Consensus OFCL + Hurricast 56.0 37.61 0.88
#
#
# YEAR 2018
# Number of timesteps: 234
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 104.02 56.46 5.56
# SHIP 72.49 53.06 1.71
# HWRF 66.66 47.18 2.56
# OFCL 66.41 48.47 1.28
# FSSE 63.42 44.21 2.14
# GFSO 61.83 48.23 2.56
# AEMN 61.86 47.43 0.85
# CLP5 198.56 118.19 41.03
# Consensus OFCL only 55.09 43.11 0.85
# Consensus OFCL + Hurricast 55.27 39.16 0.85
#
#
# YEAR 2019
# Number of timesteps: 208
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 118.78 85.34 13.94
# SHIP 90.58 85.44 8.65
# HWRF 82.0 51.08 3.37
# OFCL 83.88 75.84 6.73
# FSSE 78.68 70.89 7.69
# GFSO 85.71 70.17 6.73
# AEMN 88.13 76.76 6.73
# CLP5 206.79 170.66 35.58
# Consensus OFCL only 75.94 64.34 4.81
# Consensus OFCL + Hurricast 72.54 60.62 3.85
# {'MAES_AEMN': [65.42, 61.83, 85.71],
#  'MAES_CLP5': [188.66, 198.56, 206.79],
#  'MAES_FSSE': [61.54, 63.42, 78.68],
#  'MAES_GFSO': [70.04, 61.86, 88.13],
#  'MAES_HWRF': [68.37, 66.66, 82.0],
#  'MAES_OFCL': [62.04, 66.41, 83.88],
#  'MAES_SHIP': [69.37, 72.49, 90.58],
#  'MAEs_full': [96.45, 104.02, 118.78],
#  'num_samples': [227, 234, 208],
#  'std_AEMN': [44.95, 48.23, 70.17],
#  'std_CLP5': [135.42, 118.19, 170.66],
#  'std_FSSE': [40.54, 44.21, 70.89],
#  'std_GFSO': [42.93, 47.43, 76.76],
#  'std_HWRF': [43.9, 47.18, 51.08],
#  'std_OFCL': [43.55, 48.47, 75.84],
#  'std_SHIP': [47.68, 53.06, 85.44],
#  'std_full': [57.84, 56.46, 85.34],
#  'year': [2017, 2018, 2019]}

# %%
train_xgb_track_all_years(X_train_embed, X_test_embed, tgt_displacement_train, max_depth=9, learning_rate=0.03, n_estimators=300, subsample=0.8, basin = 'AN')
# Out:
# YEAR 2017
# Number of timesteps: 227
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 96.1 56.8 7.05
# SHIP 69.37 47.68 2.2
# HWRF 68.37 43.9 1.32
# OFCL 62.04 43.55 0.88
# FSSE 61.54 40.54 0.88
# GFSO 65.42 44.95 2.2
# AEMN 70.04 42.93 0.44
# CLP5 188.66 135.42 31.72
# Consensus OFCL only 58.32 39.58 0.88
# Consensus OFCL + Hurricast 55.82 37.65 0.88
#
#
# YEAR 2018
# Number of timesteps: 234
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 103.6 57.36 6.84
# SHIP 72.49 53.06 1.71
# HWRF 66.66 47.18 2.56
# OFCL 66.41 48.47 1.28
# FSSE 63.42 44.21 2.14
# GFSO 61.83 48.23 2.56
# AEMN 61.86 47.43 0.85
# CLP5 198.56 118.19 41.03
# Consensus OFCL only 55.09 43.11 0.85
# Consensus OFCL + Hurricast 55.17 39.0 0.85
#
#
# YEAR 2019
# Number of timesteps: 208
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 119.15 83.12 14.42
# SHIP 90.58 85.44 8.65
# HWRF 82.0 51.08 3.37
# OFCL 83.88 75.84 6.73
# FSSE 78.68 70.89 7.69
# GFSO 85.71 70.17 6.73
# AEMN 88.13 76.76 6.73
# CLP5 206.79 170.66 35.58
# Consensus OFCL only 75.94 64.34 4.81
# Consensus OFCL + Hurricast 72.71 60.46 3.85
# {'MAES_AEMN': [65.42, 61.83, 85.71],
#  'MAES_CLP5': [188.66, 198.56, 206.79],
#  'MAES_FSSE': [61.54, 63.42, 78.68],
#  'MAES_GFSO': [70.04, 61.86, 88.13],
#  'MAES_HWRF': [68.37, 66.66, 82.0],
#  'MAES_OFCL': [62.04, 66.41, 83.88],
#  'MAES_SHIP': [69.37, 72.49, 90.58],
#  'MAEs_full': [96.1, 103.6, 119.15],
#  'num_samples': [227, 234, 208],
#  'std_AEMN': [44.95, 48.23, 70.17],
#  'std_CLP5': [135.42, 118.19, 170.66],
#  'std_FSSE': [40.54, 44.21, 70.89],
#  'std_GFSO': [42.93, 47.43, 76.76],
#  'std_HWRF': [43.9, 47.18, 51.08],
#  'std_OFCL': [43.55, 48.47, 75.84],
#  'std_SHIP': [47.68, 53.06, 85.44],
#  'std_full': [56.8, 57.36, 83.12],
#  'year': [2017, 2018, 2019]}

# %%
train_xgb_track_all_years(X_train_embed, X_test_embed, tgt_displacement_train, max_depth=8, learning_rate=0.03, n_estimators=300, subsample=0.8, basin = 'AN')
# Out:
# YEAR 2017
# Number of timesteps: 227
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 96.89 58.97 7.93
# SHIP 69.37 47.68 2.2
# HWRF 68.37 43.9 1.32
# OFCL 62.04 43.55 0.88
# FSSE 61.54 40.54 0.88
# GFSO 65.42 44.95 2.2
# AEMN 70.04 42.93 0.44
# CLP5 188.66 135.42 31.72
# Consensus OFCL only 58.32 39.58 0.88
# Consensus OFCL + Hurricast 56.01 37.62 0.88
#
#
# YEAR 2018
# Number of timesteps: 234
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 104.31 56.59 5.98
# SHIP 72.49 53.06 1.71
# HWRF 66.66 47.18 2.56
# OFCL 66.41 48.47 1.28
# FSSE 63.42 44.21 2.14
# GFSO 61.83 48.23 2.56
# AEMN 61.86 47.43 0.85
# CLP5 198.56 118.19 41.03
# Consensus OFCL only 55.09 43.11 0.85
# Consensus OFCL + Hurricast 55.25 39.23 0.85
#
#
# YEAR 2019
# Number of timesteps: 208
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 119.25 83.66 13.94
# SHIP 90.58 85.44 8.65
# HWRF 82.0 51.08 3.37
# OFCL 83.88 75.84 6.73
# FSSE 78.68 70.89 7.69
# GFSO 85.71 70.17 6.73
# AEMN 88.13 76.76 6.73
# CLP5 206.79 170.66 35.58
# Consensus OFCL only 75.94 64.34 4.81
# Consensus OFCL + Hurricast 72.62 60.58 3.85
# {'MAES_AEMN': [65.42, 61.83, 85.71],
#  'MAES_CLP5': [188.66, 198.56, 206.79],
#  'MAES_FSSE': [61.54, 63.42, 78.68],
#  'MAES_GFSO': [70.04, 61.86, 88.13],
#  'MAES_HWRF': [68.37, 66.66, 82.0],
#  'MAES_OFCL': [62.04, 66.41, 83.88],
#  'MAES_SHIP': [69.37, 72.49, 90.58],
#  'MAEs_full': [96.89, 104.31, 119.25],
#  'num_samples': [227, 234, 208],
#  'std_AEMN': [44.95, 48.23, 70.17],
#  'std_CLP5': [135.42, 118.19, 170.66],
#  'std_FSSE': [40.54, 44.21, 70.89],
#  'std_GFSO': [42.93, 47.43, 76.76],
#  'std_HWRF': [43.9, 47.18, 51.08],
#  'std_OFCL': [43.55, 48.47, 75.84],
#  'std_SHIP': [47.68, 53.06, 85.44],
#  'std_full': [58.97, 56.59, 83.66],
#  'year': [2017, 2018, 2019]}

# %%
train_xgb_track_all_years(X_train_embed, X_test_embed, tgt_displacement_train, max_depth=7, learning_rate=0.03, n_estimators=300, subsample=0.8, basin = 'AN')
# Out:
# YEAR 2017
# Number of timesteps: 227
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 96.45 57.84 7.49
# SHIP 69.37 47.68 2.2
# HWRF 68.37 43.9 1.32
# OFCL 62.04 43.55 0.88
# FSSE 61.54 40.54 0.88
# GFSO 65.42 44.95 2.2
# AEMN 70.04 42.93 0.44
# CLP5 188.66 135.42 31.72
# Consensus OFCL only 58.32 39.58 0.88
# Consensus OFCL + Hurricast 56.0 37.61 0.88
#
#
# YEAR 2018
# Number of timesteps: 234
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 104.02 56.46 5.56
# SHIP 72.49 53.06 1.71
# HWRF 66.66 47.18 2.56
# OFCL 66.41 48.47 1.28
# FSSE 63.42 44.21 2.14
# GFSO 61.83 48.23 2.56
# AEMN 61.86 47.43 0.85
# CLP5 198.56 118.19 41.03
# Consensus OFCL only 55.09 43.11 0.85
# Consensus OFCL + Hurricast 55.27 39.16 0.85
#
#
# YEAR 2019
# Number of timesteps: 208
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 118.78 85.34 13.94
# SHIP 90.58 85.44 8.65
# HWRF 82.0 51.08 3.37
# OFCL 83.88 75.84 6.73
# FSSE 78.68 70.89 7.69
# GFSO 85.71 70.17 6.73
# AEMN 88.13 76.76 6.73
# CLP5 206.79 170.66 35.58
# Consensus OFCL only 75.94 64.34 4.81
# Consensus OFCL + Hurricast 72.54 60.62 3.85
# {'MAES_AEMN': [65.42, 61.83, 85.71],
#  'MAES_CLP5': [188.66, 198.56, 206.79],
#  'MAES_FSSE': [61.54, 63.42, 78.68],
#  'MAES_GFSO': [70.04, 61.86, 88.13],
#  'MAES_HWRF': [68.37, 66.66, 82.0],
#  'MAES_OFCL': [62.04, 66.41, 83.88],
#  'MAES_SHIP': [69.37, 72.49, 90.58],
#  'MAEs_full': [96.45, 104.02, 118.78],
#  'num_samples': [227, 234, 208],
#  'std_AEMN': [44.95, 48.23, 70.17],
#  'std_CLP5': [135.42, 118.19, 170.66],
#  'std_FSSE': [40.54, 44.21, 70.89],
#  'std_GFSO': [42.93, 47.43, 76.76],
#  'std_HWRF': [43.9, 47.18, 51.08],
#  'std_OFCL': [43.55, 48.47, 75.84],
#  'std_SHIP': [47.68, 53.06, 85.44],
#  'std_full': [57.84, 56.46, 85.34],
#  'year': [2017, 2018, 2019]}

# %% [markdown]
# ## OPERATIONAL FORECASTS

# %% [markdown]
# ### X_test_baseline only

# %%
train_xgb_track_all_years(X_test_baseline[:m], X_test_baseline, tgt_displacement_test[:m], max_depth=6, learning_rate=0.03, n_estimators=300, subsample=0.8, basin = 'AN')
# Out:
# YEAR 2017
# Number of timesteps: 227
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 110.27 78.78 12.78
# SHIP 69.37 47.68 2.2
# HWRF 68.37 43.9 1.32
# OFCL 62.04 43.55 0.88
# FSSE 61.54 40.54 0.88
# GFSO 65.42 44.95 2.2
# AEMN 70.04 42.93 0.44
# CLP5 188.66 135.42 31.72
# Consensus OFCL only 58.32 39.58 0.88
# Consensus OFCL + Hurricast 57.84 39.01 0.44
#
#
#
#  No forecasts for year  2017
# YEAR 2018
# Number of timesteps: 234
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 121.96 73.26 11.11
# SHIP 72.49 53.06 1.71
# HWRF 66.66 47.18 2.56
# OFCL 66.41 48.47 1.28
# FSSE 63.42 44.21 2.14
# GFSO 61.83 48.23 2.56
# AEMN 61.86 47.43 0.85
# CLP5 198.56 118.19 41.03
# Consensus OFCL only 55.09 43.11 0.85
# Consensus OFCL + Hurricast 59.1 41.51 1.28
#
#
#
#  No forecasts for year  2018
# YEAR 2019
# Number of timesteps: 208
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 108.12 83.21 10.1
# SHIP 90.58 85.44 8.65
# HWRF 82.0 51.08 3.37
# OFCL 83.88 75.84 6.73
# FSSE 78.68 70.89 7.69
# GFSO 85.71 70.17 6.73
# AEMN 88.13 76.76 6.73
# CLP5 206.79 170.66 35.58
# Consensus OFCL only 75.94 64.34 4.81
# Consensus OFCL + Hurricast 74.92 60.58 4.81
#
#
#
#  No forecasts for year  2019
# {'MAES_AEMN': [65.42, 61.83, 85.71],
#  'MAES_CLP5': [188.66, 198.56, 206.79],
#  'MAES_FSSE': [61.54, 63.42, 78.68],
#  'MAES_GFSO': [70.04, 61.86, 88.13],
#  'MAES_HWRF': [68.37, 66.66, 82.0],
#  'MAES_OFCL': [62.04, 66.41, 83.88],
#  'MAES_SHIP': [69.37, 72.49, 90.58],
#  'MAEs_full': [110.27, 121.96, 108.12],
#  'num_samples': [227, 234, 208],
#  'std_AEMN': [44.95, 48.23, 70.17],
#  'std_CLP5': [135.42, 118.19, 170.66],
#  'std_FSSE': [40.54, 44.21, 70.89],
#  'std_GFSO': [42.93, 47.43, 76.76],
#  'std_HWRF': [43.9, 47.18, 51.08],
#  'std_OFCL': [43.55, 48.47, 75.84],
#  'std_SHIP': [47.68, 53.06, 85.44],
#  'std_full': [78.78, 73.26, 83.21],
#  'year': [2017, 2018, 2019]}

# %%
train = X_test_baseline[:m].loc[X_test_baseline['cat_basin_AN_0'] +  X_test_baseline['cat_basin_EP_0'] == 1]
tgt_train = tgt_displacement_test[:m][train.index]
train_xgb_track_all_years(train, X_test_baseline, tgt_train, max_depth=7, learning_rate=0.03, n_estimators=300, subsample=0.8, basin = 'AN')
# Out:
# YEAR 2017
# Number of timesteps: 227
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 104.05 78.06 9.25
# SHIP 69.37 47.68 2.2
# HWRF 68.37 43.9 1.32
# OFCL 62.04 43.55 0.88
# FSSE 61.54 40.54 0.88
# GFSO 65.42 44.95 2.2
# AEMN 70.04 42.93 0.44
# CLP5 188.66 135.42 31.72
# Consensus OFCL only 58.32 39.58 0.88
# Consensus OFCL + Hurricast 58.12 39.22 0.44
#
#
#
#  No forecasts for year  2017
# YEAR 2018
# Number of timesteps: 234
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.79 79.58 11.54
# SHIP 72.49 53.06 1.71
# HWRF 66.66 47.18 2.56
# OFCL 66.41 48.47 1.28
# FSSE 63.42 44.21 2.14
# GFSO 61.83 48.23 2.56
# AEMN 61.86 47.43 0.85
# CLP5 198.56 118.19 41.03
# Consensus OFCL only 55.09 43.11 0.85
# Consensus OFCL + Hurricast 58.63 41.64 1.28
#
#
#
#  No forecasts for year  2018
# YEAR 2019
# Number of timesteps: 208
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 102.44 88.96 10.1
# SHIP 90.58 85.44 8.65
# HWRF 82.0 51.08 3.37
# OFCL 83.88 75.84 6.73
# FSSE 78.68 70.89 7.69
# GFSO 85.71 70.17 6.73
# AEMN 88.13 76.76 6.73
# CLP5 206.79 170.66 35.58
# Consensus OFCL only 75.94 64.34 4.81
# Consensus OFCL + Hurricast 75.16 62.3 4.33
#
#
#
#  No forecasts for year  2019
# {'MAES_AEMN': [65.42, 61.83, 85.71],
#  'MAES_CLP5': [188.66, 198.56, 206.79],
#  'MAES_FSSE': [61.54, 63.42, 78.68],
#  'MAES_GFSO': [70.04, 61.86, 88.13],
#  'MAES_HWRF': [68.37, 66.66, 82.0],
#  'MAES_OFCL': [62.04, 66.41, 83.88],
#  'MAES_SHIP': [69.37, 72.49, 90.58],
#  'MAEs_full': [104.05, 115.79, 102.44],
#  'num_samples': [227, 234, 208],
#  'std_AEMN': [44.95, 48.23, 70.17],
#  'std_CLP5': [135.42, 118.19, 170.66],
#  'std_FSSE': [40.54, 44.21, 70.89],
#  'std_GFSO': [42.93, 47.43, 76.76],
#  'std_HWRF': [43.9, 47.18, 51.08],
#  'std_OFCL': [43.55, 48.47, 75.84],
#  'std_SHIP': [47.68, 53.06, 85.44],
#  'std_full': [78.06, 79.58, 88.96],
#  'year': [2017, 2018, 2019]}

# %% [markdown]
# ### X_test_baseline + Embeds

# %%
train_xgb_track_all_years(np.concatenate((X_test_baseline[:m], X_test_embed[:m]), axis =1), np.concatenate((X_test_baseline, X_test_embed), axis =1), tgt_displacement_test[:m], 
                          max_depth=9, learning_rate=0.03, n_estimators=300, subsample=0.9, min_child_weight = 5, basin = 'EP')
# Out:
# YEAR 2016
# Number of timesteps: 315
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 69.51 43.46 1.27
# SHIP 57.85 34.92 0.32
# HWRF 61.82 40.02 1.9
# OFCL 54.09 34.1 0.0
# FSSE 55.8 33.86 0.32
# GFSO 60.33 44.6 1.9
# AEMN 56.33 37.91 0.63
# CLP5 113.55 58.53 7.62
# Consensus OFCL only 50.84 33.91 0.0
# Consensus OFCL + Hurricast 49.25 33.05 0.0
#
#
# YEAR 2017
# Number of timesteps: 167
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 58.95 31.91 0.0
# SHIP 59.96 35.47 0.6
# HWRF 74.58 40.85 2.4
# OFCL 55.2 33.37 0.0
# FSSE 54.98 35.64 0.6
# GFSO 73.68 45.78 1.2
# AEMN 68.34 40.13 1.2
# CLP5 108.57 61.48 8.38
# Consensus OFCL only 57.64 34.02 0.6
# Consensus OFCL + Hurricast 54.26 31.37 0.6
#
#
# YEAR 2018
# Number of timesteps: 355
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 60.89 35.55 0.28
# SHIP 56.76 32.53 0.28
# HWRF 67.99 44.14 1.97
# OFCL 53.6 30.77 0.28
# FSSE 56.26 60.66 1.13
# GFSO 64.01 44.34 1.41
# AEMN 59.09 34.78 0.28
# CLP5 133.27 73.69 18.31
# Consensus OFCL only 50.88 32.97 0.28
# Consensus OFCL + Hurricast 48.05 30.57 0.28
# {'MAES_AEMN': [60.33, 73.68, 64.01],
#  'MAES_CLP5': [113.55, 108.57, 133.27],
#  'MAES_FSSE': [55.8, 54.98, 56.26],
#  'MAES_GFSO': [56.33, 68.34, 59.09],
#  'MAES_HWRF': [61.82, 74.58, 67.99],
#  'MAES_OFCL': [54.09, 55.2, 53.6],
#  'MAES_SHIP': [57.85, 59.96, 56.76],
#  'MAEs_full': [69.51, 58.95, 60.89],
#  'num_samples': [315, 167, 355],
#  'std_AEMN': [44.6, 45.78, 44.34],
#  'std_CLP5': [58.53, 61.48, 73.69],
#  'std_FSSE': [33.86, 35.64, 60.66],
#  'std_GFSO': [37.91, 40.13, 34.78],
#  'std_HWRF': [40.02, 40.85, 44.14],
#  'std_OFCL': [34.1, 33.37, 30.77],
#  'std_SHIP': [34.92, 35.47, 32.53],
#  'std_full': [43.46, 31.91, 35.55],
#  'year': [2016, 2017, 2018]}

# %%
train_xgb_track_all_years(np.concatenate((X_test_baseline[:m], X_test_embed[:m]), axis =1), np.concatenate((X_test_baseline, X_test_embed), axis =1), tgt_displacement_test[:m], 
                          max_depth=8, learning_rate=0.05, n_estimators=300, subsample=0.9, min_child_weight = 5, basin = 'EP')
# Out:
# YEAR 2016
# Number of timesteps: 315
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 68.54 42.53 0.95
# SHIP 57.85 34.92 0.32
# HWRF 61.82 40.02 1.9
# OFCL 54.09 34.1 0.0
# FSSE 55.8 33.86 0.32
# GFSO 60.33 44.6 1.9
# AEMN 56.33 37.91 0.63
# CLP5 113.55 58.53 7.62
# Consensus OFCL only 50.84 33.91 0.0
# Consensus OFCL + Hurricast 49.02 32.89 0.0
#
#
# YEAR 2017
# Number of timesteps: 167
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 60.0 33.92 0.0
# SHIP 59.96 35.47 0.6
# HWRF 74.58 40.85 2.4
# OFCL 55.2 33.37 0.0
# FSSE 54.98 35.64 0.6
# GFSO 73.68 45.78 1.2
# AEMN 68.34 40.13 1.2
# CLP5 108.57 61.48 8.38
# Consensus OFCL only 57.64 34.02 0.6
# Consensus OFCL + Hurricast 54.38 31.27 0.0
#
#
# YEAR 2018
# Number of timesteps: 355
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 61.93 35.82 0.56
# SHIP 56.76 32.53 0.28
# HWRF 67.99 44.14 1.97
# OFCL 53.6 30.77 0.28
# FSSE 56.26 60.66 1.13
# GFSO 64.01 44.34 1.41
# AEMN 59.09 34.78 0.28
# CLP5 133.27 73.69 18.31
# Consensus OFCL only 50.88 32.97 0.28
# Consensus OFCL + Hurricast 48.16 30.49 0.28
# {'MAES_AEMN': [60.33, 73.68, 64.01],
#  'MAES_CLP5': [113.55, 108.57, 133.27],
#  'MAES_FSSE': [55.8, 54.98, 56.26],
#  'MAES_GFSO': [56.33, 68.34, 59.09],
#  'MAES_HWRF': [61.82, 74.58, 67.99],
#  'MAES_OFCL': [54.09, 55.2, 53.6],
#  'MAES_SHIP': [57.85, 59.96, 56.76],
#  'MAEs_full': [68.54, 60.0, 61.93],
#  'num_samples': [315, 167, 355],
#  'std_AEMN': [44.6, 45.78, 44.34],
#  'std_CLP5': [58.53, 61.48, 73.69],
#  'std_FSSE': [33.86, 35.64, 60.66],
#  'std_GFSO': [37.91, 40.13, 34.78],
#  'std_HWRF': [40.02, 40.85, 44.14],
#  'std_OFCL': [34.1, 33.37, 30.77],
#  'std_SHIP': [34.92, 35.47, 32.53],
#  'std_full': [42.53, 33.92, 35.82],
#  'year': [2016, 2017, 2018]}

# %%
train = X_test_baseline[:m].loc[X_test_baseline['cat_basin_AN_0'] +  X_test_baseline['cat_basin_EP_0'] == 1]
tgt_train = tgt_displacement_test[:m][train.index]
train = np.concatenate((train, X_train_embed[train.index]), axis = 1)
train_xgb_track_all_years(train, np.concatenate((X_test_baseline, X_test_embed), axis =1), tgt_train, max_depth=9, learning_rate=0.03, n_estimators=300, subsample=0.8, basin = 'EP')
# Out:
# YEAR 2016
# Number of timesteps: 315
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 63.24 40.06 0.63
# SHIP 57.85 34.92 0.32
# HWRF 61.82 40.02 1.9
# OFCL 54.09 34.1 0.0
# FSSE 55.8 33.86 0.32
# GFSO 60.33 44.6 1.9
# AEMN 56.33 37.91 0.63
# CLP5 113.55 58.53 7.62
# Consensus OFCL only 50.84 33.91 0.0
# Consensus OFCL + Hurricast 49.1 32.77 0.0
#
#
# YEAR 2017
# Number of timesteps: 167
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 54.17 29.66 0.0
# SHIP 59.96 35.47 0.6
# HWRF 74.58 40.85 2.4
# OFCL 55.2 33.37 0.0
# FSSE 54.98 35.64 0.6
# GFSO 73.68 45.78 1.2
# AEMN 68.34 40.13 1.2
# CLP5 108.57 61.48 8.38
# Consensus OFCL only 57.64 34.02 0.6
# Consensus OFCL + Hurricast 53.74 31.53 0.6
#
#
# YEAR 2018
# Number of timesteps: 355
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 60.92 34.79 0.56
# SHIP 56.76 32.53 0.28
# HWRF 67.99 44.14 1.97
# OFCL 53.6 30.77 0.28
# FSSE 56.26 60.66 1.13
# GFSO 64.01 44.34 1.41
# AEMN 59.09 34.78 0.28
# CLP5 133.27 73.69 18.31
# Consensus OFCL only 50.88 32.97 0.28
# Consensus OFCL + Hurricast 48.94 30.38 0.28
# {'MAES_AEMN': [60.33, 73.68, 64.01],
#  'MAES_CLP5': [113.55, 108.57, 133.27],
#  'MAES_FSSE': [55.8, 54.98, 56.26],
#  'MAES_GFSO': [56.33, 68.34, 59.09],
#  'MAES_HWRF': [61.82, 74.58, 67.99],
#  'MAES_OFCL': [54.09, 55.2, 53.6],
#  'MAES_SHIP': [57.85, 59.96, 56.76],
#  'MAEs_full': [63.24, 54.17, 60.92],
#  'num_samples': [315, 167, 355],
#  'std_AEMN': [44.6, 45.78, 44.34],
#  'std_CLP5': [58.53, 61.48, 73.69],
#  'std_FSSE': [33.86, 35.64, 60.66],
#  'std_GFSO': [37.91, 40.13, 34.78],
#  'std_HWRF': [40.02, 40.85, 44.14],
#  'std_OFCL': [34.1, 33.37, 30.77],
#  'std_SHIP': [34.92, 35.47, 32.53],
#  'std_full': [40.06, 29.66, 34.79],
#  'year': [2016, 2017, 2018]}

# %%
train = X_test_baseline[:m].loc[X_test_baseline['cat_basin_AN_0'] +  X_test_baseline['cat_basin_EP_0'] == 1]
tgt_train = tgt_displacement_test[:m][train.index]
train = np.concatenate((train, X_train_embed[train.index]), axis = 1)
train_xgb_track_all_years(train, np.concatenate((X_test_baseline, X_test_embed), axis =1), tgt_train, max_depth=8, learning_rate=0.05, n_estimators=300, subsample=0.9, basin = 'EP')
# Out:
# YEAR 2016
# Number of timesteps: 315
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 62.56 40.72 1.27
# SHIP 57.85 34.92 0.32
# HWRF 61.82 40.02 1.9
# OFCL 54.09 34.1 0.0
# FSSE 55.8 33.86 0.32
# GFSO 60.33 44.6 1.9
# AEMN 56.33 37.91 0.63
# CLP5 113.55 58.53 7.62
# Consensus OFCL only 50.84 33.91 0.0
# Consensus OFCL + Hurricast 49.28 32.95 0.0
#
#
# YEAR 2017
# Number of timesteps: 167
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 52.59 30.46 0.0
# SHIP 59.96 35.47 0.6
# HWRF 74.58 40.85 2.4
# OFCL 55.2 33.37 0.0
# FSSE 54.98 35.64 0.6
# GFSO 73.68 45.78 1.2
# AEMN 68.34 40.13 1.2
# CLP5 108.57 61.48 8.38
# Consensus OFCL only 57.64 34.02 0.6
# Consensus OFCL + Hurricast 53.94 31.61 0.6
#
#
# YEAR 2018
# Number of timesteps: 355
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 60.79 34.53 0.28
# SHIP 56.76 32.53 0.28
# HWRF 67.99 44.14 1.97
# OFCL 53.6 30.77 0.28
# FSSE 56.26 60.66 1.13
# GFSO 64.01 44.34 1.41
# AEMN 59.09 34.78 0.28
# CLP5 133.27 73.69 18.31
# Consensus OFCL only 50.88 32.97 0.28
# Consensus OFCL + Hurricast 49.12 30.69 0.28
# {'MAES_AEMN': [60.33, 73.68, 64.01],
#  'MAES_CLP5': [113.55, 108.57, 133.27],
#  'MAES_FSSE': [55.8, 54.98, 56.26],
#  'MAES_GFSO': [56.33, 68.34, 59.09],
#  'MAES_HWRF': [61.82, 74.58, 67.99],
#  'MAES_OFCL': [54.09, 55.2, 53.6],
#  'MAES_SHIP': [57.85, 59.96, 56.76],
#  'MAEs_full': [62.56, 52.59, 60.79],
#  'num_samples': [315, 167, 355],
#  'std_AEMN': [44.6, 45.78, 44.34],
#  'std_CLP5': [58.53, 61.48, 73.69],
#  'std_FSSE': [33.86, 35.64, 60.66],
#  'std_GFSO': [37.91, 40.13, 34.78],
#  'std_HWRF': [40.02, 40.85, 44.14],
#  'std_OFCL': [34.1, 33.37, 30.77],
#  'std_SHIP': [34.92, 35.47, 32.53],
#  'std_full': [40.72, 30.46, 34.53],
#  'year': [2016, 2017, 2018]}

# %%
train = X_test_baseline[:m].loc[X_test_baseline['cat_basin_AN_0'] +  X_test_baseline['cat_basin_EP_0'] == 1]
tgt_train = tgt_displacement_test[:m][train.index]
train = np.concatenate((train, X_train_embed[train.index]), axis = 1)
train_xgb_track_all_years(train, np.concatenate((X_test_baseline, X_test_embed), axis =1), tgt_train, max_depth=8, learning_rate=0.05, n_estimators=300, subsample=0.9, basin = 'EP')
# Out:
# YEAR 2016
# Number of timesteps: 315
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 62.78 40.26 0.0
# SHIP 57.85 34.92 0.32
# HWRF 61.82 40.02 1.9
# OFCL 54.09 34.1 0.0
# FSSE 55.8 33.86 0.32
# GFSO 60.33 44.6 1.9
# AEMN 56.33 37.91 0.63
# CLP5 113.55 58.53 7.62
# Consensus OFCL only 50.84 33.91 0.0
# Consensus OFCL + Hurricast 49.22 32.78 0.0
#
#
# YEAR 2017
# Number of timesteps: 167
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 54.98 29.73 0.0
# SHIP 59.96 35.47 0.6
# HWRF 74.58 40.85 2.4
# OFCL 55.2 33.37 0.0
# FSSE 54.98 35.64 0.6
# GFSO 73.68 45.78 1.2
# AEMN 68.34 40.13 1.2
# CLP5 108.57 61.48 8.38
# Consensus OFCL only 57.64 34.02 0.6
# Consensus OFCL + Hurricast 53.53 31.29 0.6
#
#
# YEAR 2018
# Number of timesteps: 355
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 61.79 34.07 0.28
# SHIP 56.76 32.53 0.28
# HWRF 67.99 44.14 1.97
# OFCL 53.6 30.77 0.28
# FSSE 56.26 60.66 1.13
# GFSO 64.01 44.34 1.41
# AEMN 59.09 34.78 0.28
# CLP5 133.27 73.69 18.31
# Consensus OFCL only 50.88 32.97 0.28
# Consensus OFCL + Hurricast 49.12 30.8 0.28
# {'MAES_AEMN': [60.33, 73.68, 64.01],
#  'MAES_CLP5': [113.55, 108.57, 133.27],
#  'MAES_FSSE': [55.8, 54.98, 56.26],
#  'MAES_GFSO': [56.33, 68.34, 59.09],
#  'MAES_HWRF': [61.82, 74.58, 67.99],
#  'MAES_OFCL': [54.09, 55.2, 53.6],
#  'MAES_SHIP': [57.85, 59.96, 56.76],
#  'MAEs_full': [62.78, 54.98, 61.79],
#  'num_samples': [315, 167, 355],
#  'std_AEMN': [44.6, 45.78, 44.34],
#  'std_CLP5': [58.53, 61.48, 73.69],
#  'std_FSSE': [33.86, 35.64, 60.66],
#  'std_GFSO': [37.91, 40.13, 34.78],
#  'std_HWRF': [40.02, 40.85, 44.14],
#  'std_OFCL': [34.1, 33.37, 30.77],
#  'std_SHIP': [34.92, 35.47, 32.53],
#  'std_full': [40.26, 29.73, 34.07],
#  'year': [2016, 2017, 2018]}

# %% [markdown]
# # REVISION VALIDATION

# %%
def train_xgb_track_all_years_REVISION(train, test, tgt_train, max_depth = 8, n_estimators = 140, learning_rate = 0.05, subsample = 0.7, min_child_weight=5, basin = 'AN', forecast = 'SHIP', forecast2 = 'HWRF', forecast3 = 'OFCL', forecast4 = 'FSSE', forecast5 = 'GFSO', forecast6 = 'AEMN', forecast7 = 'CLP5'):    
    dict = {'year':[], 'num_samples':[], 'HURR_2012':[], 'HURR_full':[], 'AEMN':[], 'HWRF':[], 'FSSE':[], 'OFCL':[], 'GFSO':[], 'CLP5':[], 
                       'Consensus_wo_HURR':[], 'Consensus_w_HURR':[]} 
    
    dict_consensus = {'TRUTH_DLAT_2012_2020_test':[], 'TRUTH_DLON_2012_2020_test':[], 
                      'TRUTH_DLAT_2012_2016_val':[], 'TRUTH_DLON_2012_2016_val':[],
                      'TRUTH_DLAT_1980_2016_train':[], 'TRUTH_DLON_1980_2016_train':[],
                      'DLAT_2012_2016_xgb2012_val':[], 'DLON_2012_2016_xgb2012_val':[], 
                      'DLAT_2012_2020_xgb2012_test':[], 'DLON_2012_2020_xgb2012_test':[],
                      'DLAT_1980_2016_xgb2016_train':[], 'DLON_1980_2016_xgb2016_train':[], 
                      'DLAT_2012_2020_xgb2016_test':[], 'DLON_2012_2020_xgb2016_test':[],
                      }

    if True:
        xgb_x = XGBRegressor(max_depth=max_depth, n_estimators=n_estimators, learning_rate=learning_rate,
                             subsample=subsample, min_child_weight=min_child_weight, tree_method='gpu_hist', gpu_id=0)
        xgb_x.fit(train, tgt_train[:, 0])
        xgb_y = XGBRegressor(max_depth=max_depth, n_estimators=n_estimators, learning_rate=learning_rate,
                             subsample=subsample, min_child_weight=min_child_weight, tree_method='gpu_hist', gpu_id=0)
        xgb_y.fit(train, tgt_train[:, 1])
        DLATS_PRED = np.array(xgb_x.predict(test)) * std_dx + mean_dx
        DLONS_PRED = np.array(xgb_y.predict(test)) * std_dy + mean_dy
        LATS_PRED_2012 = X_test['LAT_7'] + DLATS_PRED
        LONS_PRED_2012 = X_test['LON_7'] + DLONS_PRED
        compare_perf_track_7cast_REVISION(dict = dict, year = 2016, basin=basin, forecast='SHIP', forecast2 = 'HWRF', forecast3='OFCL', forecast4 = 'FSSE', forecast5='AEMN', forecast6 = 'GFSO', forecast7 = 'CLP5', LATS_PRED_= LATS_PRED_2012, LONS_PRED_=LONS_PRED_2012)
    
    index = X_test_baseline.loc[
                X_test_baseline['YEAR_0'] < 2016].index
    X_test_to_train = np.array(test)[index]
    train2 = np.concatenate((train, X_test_to_train), axis=0)
    tgt_train2 = np.concatenate((tgt_train, tgt_displacement_test[index]), axis=0)
    #add previous values to dict
    dict_consensus['DLAT_2012_2016_xgb2012_val'].append(xgb_x.predict(X_test_to_train))
    dict_consensus['DLON_2012_2016_xgb2012_val'].append(xgb_y.predict(X_test_to_train))
    
    dict_consensus['DLAT_2012_2020_xgb2012_test'].append(xgb_x.predict(np.array(test)))
    dict_consensus['DLON_2012_2020_xgb2012_test'].append(xgb_y.predict(np.array(test)))
    
    dict_consensus['TRUTH_DLAT_2012_2016_val'].append(np.array(tgt_displacement_test[index])[:, 0])
    dict_consensus['TRUTH_DLON_2012_2016_val'].append(np.array(tgt_displacement_test[index])[:, 1])
    
    dict_consensus['TRUTH_DLAT_2012_2020_test'].append(tgt_displacement_test[:, 0])
    dict_consensus['TRUTH_DLON_2012_2020_test'].append(tgt_displacement_test[:, 1])
    
    dict_consensus['TRUTH_DLAT_1980_2016_train'].append(tgt_train2[:, 0])
    dict_consensus['TRUTH_DLON_1980_2016_train'].append(tgt_train2[:, 1])   
    
    xgb_x = XGBRegressor(max_depth=max_depth, n_estimators=n_estimators, learning_rate=learning_rate,
                                 subsample=subsample, min_child_weight=min_child_weight, tree_method='gpu_hist', gpu_id=0)
    xgb_x.fit(train2, tgt_train2[:, 0])
    xgb_y = XGBRegressor(max_depth=max_depth, n_estimators=n_estimators, learning_rate=learning_rate,
                                 subsample=subsample, min_child_weight=min_child_weight, tree_method='gpu_hist', gpu_id=0)
    xgb_y.fit(train2, tgt_train2[:, 1])
    DLATS_PRED = np.array(xgb_x.predict(np.array(test))) * std_dx + mean_dx
    DLONS_PRED = np.array(xgb_y.predict(np.array(test))) * std_dy + mean_dy
    LATS_PRED_ = X_test_baseline['LAT_7'] + DLATS_PRED
    LONS_PRED_ = X_test_baseline['LON_7'] + DLONS_PRED
    compare_perf_track_7cast_REVISION(dict = dict, year = 2016, basin=basin, forecast='SHIP', forecast2 = 'HWRF', forecast3='OFCL', forecast4 = 'FSSE', forecast5='AEMN', forecast6 = 'GFSO', forecast7 = 'CLP5', LATS_PRED_= LATS_PRED_, LONS_PRED_=LONS_PRED_)
    
    dict_consensus['DLAT_1980_2016_xgb2016_train'].append(xgb_x.predict(train2))
    dict_consensus['DLON_1980_2016_xgb2016_train'].append(xgb_y.predict(train2))
    
    dict_consensus['DLAT_2012_2020_xgb2016_test'].append(xgb_x.predict(np.array(test)))
    dict_consensus['DLON_2012_2020_xgb2016_test'].append(xgb_y.predict(np.array(test)))
    
    
    return dict, dict_consensus

# %%
def validate_track(X_train, tgt_train, X_val):    
    best_score = 1000
    best_depth, best_est, best_lr, best_subs, best_min_child = 0, 0, 0, 0, 0

    for max_depth in [7, 8]:
        for n_estimators in [150, 200,300]:
            for learning_rate in [0.1, 0.07, 0.05]:
                for subsample in [0.8, 0.9, 1]:
                    for min_child_weight in [1, 3, 5]:
                        xgb_x = XGBRegressor(max_depth=max_depth, n_estimators=n_estimators, learning_rate=learning_rate,
                             subsample=subsample, min_child_weight=min_child_weight, tree_method='gpu_hist', gpu_id=0)
                        xgb_x.fit(X_train, tgt_train[:, 0])
                        xgb_y = XGBRegressor(max_depth=max_depth, n_estimators=n_estimators, learning_rate=learning_rate,
                                             subsample=subsample, min_child_weight=min_child_weight, tree_method='gpu_hist', gpu_id=0)
                        xgb_y.fit(X_train, tgt_train[:, 1])
                        DLATS_PRED = np.array(xgb_x.predict(X_val)) * std_dx + mean_dx
                        DLONS_PRED = np.array(xgb_y.predict(X_val)) * std_dy + mean_dy
                        LATS_PRED_ = X_test['LAT_7'][:len(X_val)] + DLATS_PRED
                        LONS_PRED_ = X_test['LON_7'][:len(X_val)] + DLONS_PRED
                        
                        score = compare_perf_track_7cast_val(LATS_PRED_, LONS_PRED_, basin = 'AN')
                        
                        print('max_depth: ', max_depth, 'n_estimators: ', n_estimators, 
                              'lr: ', learning_rate, 'subsample: ', subsample, 'min_child_weight: ', min_child_weight)
                        print("MAE intensity: ", score, '\n')
                        if score < best_score:
                            print("BEST SCORE SO FAR")
                            best_score = score
                            best_depth, best_est, best_lr, best_subs, best_min_child = max_depth, n_estimators, learning_rate, subsample, min_child_weight
    print("#### BEST RESULTS ####")
    print('best_depth = ', best_depth, '\nbest_est = ', best_est, 
                              '\nbest_lr = ', best_lr, '\nbest_subs = ', best_subs, '\nbest_min_child = ', best_min_child)
    return best_depth, best_est, best_lr, best_subs, best_min_child

# %%
def compare_perf_track_7cast_REVISION(dict, LATS_PRED_, LONS_PRED_, year = 2016, basin = 'AN', forecast = 'SHIP', forecast2 = 'HWRF', forecast3 = 'OFCL', forecast4 = 'FSSE', forecast5 = 'AEMN', forecast6 = 'GFSO', forecast7 = 'CLP5'):
    mode = 'lat'
    if forecast2 != None:
        
        baseline_ = X_test_baseline.loc[X_test_baseline['YEAR_0'] >= year].loc[
            X_test_baseline[forecast7 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast6 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast5 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast4 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast3 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast2 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast + '_24_' + mode + '_7'] > -320].loc[X_test_baseline['cat_basin_' + basin + '_0'] == 1]  # .loc[#X_test_baseline['SHIP_24_'+mode+'_7'] > 0].index
        if basin == 'EP':
            baseline_ = baseline_.loc[X_test_baseline['YEAR_0'] < 2019]
        index = baseline_.index
        LATS_BASE_2 = np.array(baseline_[forecast2 + '_24_lat_7'])
        LONS_BASE_2 = np.array(baseline_[forecast2 + '_24_lon_7'])
        LATS_BASE_3 = np.array(baseline_[forecast3 + '_24_lat_7'])
        LONS_BASE_3 = np.array(baseline_[forecast3 + '_24_lon_7'])
        LATS_BASE_4 = np.array(baseline_[forecast4 + '_24_lat_7'])
        LONS_BASE_4 = np.array(baseline_[forecast4 + '_24_lon_7'])
        LATS_BASE_5 = np.array(baseline_[forecast5 + '_24_lat_7'])
        LONS_BASE_5 = np.array(baseline_[forecast5 + '_24_lon_7'])
        LATS_BASE_6 = np.array(baseline_[forecast6 + '_24_lat_7'])
        LONS_BASE_6 = np.array(baseline_[forecast6 + '_24_lon_7'])
        LATS_BASE_7 = np.array(baseline_[forecast7 + '_24_lat_7'])
        LONS_BASE_7 = np.array(baseline_[forecast7 + '_24_lon_7'])
        
    LATS_TEST_ = np.array(X_test['LAT_7'] + np.array(tgt_displacement_test[:, 0])*std_dx+mean_dx)[index]
    LONS_TEST_ = np.array(X_test['LON_7'] + np.array(tgt_displacement_test[:, 1])*std_dy+mean_dy)[index]
    baseline_1_x = np.array(baseline_[forecast + '_24_'+mode+'_7'])
    baseline_1_y = np.array(baseline_[forecast + '_24_lon_7'])
    baseline_2_x = np.array(baseline_[forecast2 + '_24_'+mode+'_7'])
    baseline_2_y = np.array(baseline_[forecast2 + '_24_lon_7'])
    baseline_3_x = np.array(baseline_[forecast3 + '_24_'+mode+'_7'])
    baseline_3_y = np.array(baseline_[forecast3 + '_24_lon_7'])
    baseline_4_x = np.array(baseline_[forecast4 + '_24_'+mode+'_7'])
    baseline_4_y = np.array(baseline_[forecast4 + '_24_lon_7'])
    baseline_5_x = np.array(baseline_[forecast5 + '_24_'+mode+'_7'])
    baseline_5_y = np.array(baseline_[forecast5 + '_24_lon_7'])
    baseline_6_x = np.array(baseline_[forecast6 + '_24_'+mode+'_7'])
    baseline_6_y = np.array(baseline_[forecast6 + '_24_lon_7'])
    baseline_7_x = np.array(baseline_[forecast7 + '_24_'+mode+'_7'])
    baseline_7_y = np.array(baseline_[forecast7 + '_24_lon_7'])
    LATS_PRED_ = np.array(LATS_PRED_)[index]
    LONS_PRED_ = np.array(LONS_PRED_)[index]
    d_km_baseline = np.zeros(len(LATS_PRED_))
    d_km_baseline2 = np.zeros(len(LATS_PRED_))
    d_km_baseline3 = np.zeros(len(LATS_PRED_))
    d_km_baseline4 = np.zeros(len(LATS_PRED_))
    d_km_baseline5 = np.zeros(len(LATS_PRED_))
    d_km_baseline6 = np.zeros(len(LATS_PRED_))
    d_km_baseline7 = np.zeros(len(LATS_PRED_))
    d_km_consensus_ofcl, d_km_consensus_hurr = np.zeros(len(LATS_PRED_)), np.zeros(len(LATS_PRED_))
    d_km_pred = np.zeros(len(LONS_PRED_))
    for i in range(len(LATS_PRED_)):
        if baseline_2_y[i] > 160:
            baseline_1_y[i] -= 360
            baseline_6_y[i] -= 360
            baseline_5_y[i] -= 360
            baseline_2_y[i] -= 360
            baseline_3_y[i] -= 360
        if LONS_TEST_[i] > 160:
            LONS_PRED_[i] -= 360
        d_km_baseline[i] = get_distance_km(baseline_1_y[i], baseline_1_x[i], LONS_TEST_[i], LATS_TEST_[i])
        d_km_pred[i] = get_distance_km(LONS_PRED_[i], LATS_PRED_[i], LONS_TEST_[i], LATS_TEST_[i])
        d_km_baseline2[i] = get_distance_km(baseline_2_y[i], baseline_2_x[i], LONS_TEST_[i], LATS_TEST_[i])
        d_km_baseline3[i] = get_distance_km(baseline_3_y[i], baseline_3_x[i], LONS_TEST_[i], LATS_TEST_[i])
        d_km_baseline4[i] = get_distance_km(baseline_4_y[i], baseline_4_x[i], LONS_TEST_[i], LATS_TEST_[i])
        d_km_baseline5[i] = get_distance_km(baseline_5_y[i], baseline_5_x[i], LONS_TEST_[i], LATS_TEST_[i])
        d_km_baseline6[i] = get_distance_km(baseline_6_y[i], baseline_6_x[i], LONS_TEST_[i], LATS_TEST_[i])
        d_km_baseline7[i] = get_distance_km(baseline_7_y[i], baseline_7_x[i], LONS_TEST_[i], LATS_TEST_[i])
    print("Number of timesteps:", len(LATS_PRED_))
    print(basin, 'Model | MAE | std | %age busts (>200km)')
    print("Hurricast", np.around(d_km_pred.mean(), decimals = 2), np.around(d_km_pred.std(), decimals = 2), np.around(sum(d_km_pred > 200)*100/len(LATS_PRED_), decimals = 2))
    print(forecast, np.around(d_km_baseline.mean(), decimals = 2), np.around(d_km_baseline.std(), decimals = 2), np.around(sum(d_km_baseline > 200)*100/len(LATS_PRED_), decimals = 2))
    print(forecast2, np.around(d_km_baseline2.mean(), decimals = 2), np.around(d_km_baseline2.std(), decimals = 2), np.around(sum(d_km_baseline2 > 200)*100/len(LATS_PRED_), decimals = 2))
    print(str(forecast3), np.around(d_km_baseline3.mean(), decimals = 2), np.around(d_km_baseline3.std(), decimals = 2), np.around(sum(d_km_baseline3 > 200)*100/len(LATS_PRED_), decimals = 2))
    print(str(forecast4), np.around(d_km_baseline4.mean(), decimals = 2), np.around(d_km_baseline4.std(), decimals = 2), np.around(sum(d_km_baseline4 > 200)*100/len(LATS_PRED_), decimals = 2))
    print(str(forecast5), np.around(d_km_baseline5.mean(), decimals = 2), np.around(d_km_baseline5.std(), decimals = 2), np.around(sum(d_km_baseline5 > 200)*100/len(LATS_PRED_), decimals = 2))
    print(forecast6, np.around(d_km_baseline6.mean(), decimals = 2), np.around(d_km_baseline6.std(), decimals = 2), np.around(sum(d_km_baseline6 > 200)*100/len(LATS_PRED_), decimals = 2))
    print(forecast7, np.around(d_km_baseline7.mean(), decimals = 2), np.around(d_km_baseline7.std(), decimals = 2), np.around(sum(d_km_baseline7 > 200)*100/len(LATS_PRED_), decimals = 2))
    #consensus_ofcl_x = (baseline_1_x+baseline_2_x+baseline_3_x+baseline_4_x + baseline_5_x + baseline_6_x)/6
    consensus_ofcl_x = (baseline_2_x+baseline_4_x + baseline_5_x + baseline_6_x)/4
    #consensus_ofcl_y = (baseline_1_y+baseline_2_y+baseline_3_y+baseline_4_y + baseline_5_y + baseline_6_y)/6
    consensus_ofcl_y = (baseline_2_y+baseline_4_y + baseline_5_y + baseline_6_y)/4
    consensus_hurr_x = (consensus_ofcl_x*4+LATS_PRED_)/5
    consensus_hurr_y = (consensus_ofcl_y*4+LONS_PRED_)/5
    for i in range(len(LATS_PRED_)):
        d_km_consensus_ofcl[i] = get_distance_km(consensus_ofcl_y[i], consensus_ofcl_x[i], LONS_TEST_[i], LATS_TEST_[i])
        d_km_consensus_hurr[i] = get_distance_km(consensus_hurr_y[i], consensus_hurr_x[i], LONS_TEST_[i], LATS_TEST_[i])
    print("Consensus OFCL only", np.around(d_km_consensus_ofcl.mean(), decimals = 2), np.around(d_km_consensus_ofcl.std(), decimals = 2), np.around(sum(d_km_consensus_ofcl > 200)*100/len(LATS_PRED_), decimals = 2))
    print("Consensus OFCL + Hurricast", np.around(d_km_consensus_hurr.mean(), decimals = 2), np.around(d_km_consensus_hurr.std(), decimals = 2), np.around(sum(d_km_consensus_hurr > 200)*100/len(LATS_PRED_), decimals = 2))
    #return LONS_PRED_, baseline_1_y, baseline_2_y, baseline_3_y, baseline_4_y, baseline_5_y, baseline_6_y
    #return d_km_pred, np.array(X_test)[index]
    append_dict_track_7cast_REVISION(dict, d_km_pred, d_km_baseline, d_km_baseline2, d_km_baseline3, d_km_baseline4, d_km_baseline5, d_km_baseline6, d_km_baseline7, d_km_consensus_ofcl, d_km_consensus_hurr, year)

# %%
def append_dict_track_7cast_REVISION(dict, d_km_pred, d_km_baseline, d_km_baseline2, d_km_baseline3, d_km_baseline4, d_km_baseline5, d_km_baseline6, d_km_baseline7, d_km_consensus_ofcl, d_km_consensus_hurr, year):
    dict['year'].append(year)
    dict['num_samples'].append(len(d_km_pred))
    dict['HURR_full'].append(d_km_pred)
    
    #dict['MAES_SHIP'].append(np.around(d_km_baseline.mean(), decimals = 2))
    #dict['std_SHIP'].append(np.around(d_km_baseline.std(), decimals = 2))
    
    dict['HWRF'].append(d_km_baseline2)
    
    dict['OFCL'].append(d_km_baseline3)
    
    dict['FSSE'].append(d_km_baseline4)
    
    dict['AEMN'].append(d_km_baseline5)
    
    dict['GFSO'].append(d_km_baseline6)
    
    dict['CLP5'].append(d_km_baseline7)
    
    dict['Consensus_wo_HURR'].append(d_km_consensus_ofcl)
    
    dict['Consensus_w_HURR'].append(d_km_consensus_hurr)

# %%
def create_df_boxplots(dict, dict_consensus, df, df_2012_train, df_2012_test, df_2016_train, df_2016_test, name):
    '''
    given a dictionary with all results, returns a dataframe
    name should be the corresponding Hurr model name
    '''
    print("full1", dict['HURR_full'][1].shape)
    print("full0", dict['HURR_full'][0].shape)
    df[name+'_2016'] = dict['HURR_full'][1]
    df[name+'_2012'] = dict['HURR_full'][0]
    #df_val[name+'_val_2012'] = dict['HURR_val_2012'][0]
    #df_val[name+'_val_2016'] = dict['HURR_val_2016'][0]
    #df_tot[name+'_val_1980_2016'] = dict['HURR_val_1980_2016'][0]
    #df_tot[name+'_truth_1980_2016'] = dict['TRUTH_1980_2016'][0]
    df_2012_train['TRUTH_DLAT_2012_2016_val'] = dict_consensus['TRUTH_DLAT_2012_2016_val'][0]
    df_2012_train['TRUTH_DLON_2012_2016_val'] = dict_consensus['TRUTH_DLON_2012_2016_val'][0]
    
    df_2012_test['TRUTH_DLAT_2012_2020_test'] = dict_consensus['TRUTH_DLAT_2012_2020_test'][0]
    df_2012_test['TRUTH_DLON_2012_2020_test'] = dict_consensus['TRUTH_DLON_2012_2020_test'][0]
    
    df_2016_test['TRUTH_DLAT_2012_2020_test'] = dict_consensus['TRUTH_DLAT_2012_2020_test'][0]
    df_2016_test['TRUTH_DLON_2012_2020_test'] = dict_consensus['TRUTH_DLON_2012_2020_test'][0]
    
    df_2016_train['TRUTH_DLAT_1980_2016_train'] = dict_consensus['TRUTH_DLAT_1980_2016_train'][0]
    df_2016_train['TRUTH_DLON_1980_2016_train'] = dict_consensus['TRUTH_DLON_1980_2016_train'][0]
    
    df_2012_train[name+'_DLAT_2012_2016_xgb2012_val'] = dict_consensus['DLAT_2012_2016_xgb2012_val'][0]
    df_2012_train[name+'_DLON_2012_2016_xgb2012_val'] = dict_consensus['DLON_2012_2016_xgb2012_val'][0]
    
    df_2012_test[name+'_DLAT_2012_2020_xgb2012_test'] = dict_consensus['DLAT_2012_2020_xgb2012_test'][0]
    df_2012_test[name+'_DLON_2012_2020_xgb2012_test'] = dict_consensus['DLON_2012_2020_xgb2012_test'][0]
    
    df_2016_train[name+'_DLAT_1980_2016_xgb2016_train'] = dict_consensus['DLAT_1980_2016_xgb2016_train'][0]
    df_2016_train[name+'_DLON_1980_2016_xgb2016_train'] = dict_consensus['DLON_1980_2016_xgb2016_train'][0]
    
    df_2016_test[name+'_DLAT_2012_2020_xgb2016_test'] = dict_consensus['DLAT_2012_2020_xgb2016_test'][0]
    df_2016_test[name+'_DLON_2012_2020_xgb2016_test'] = dict_consensus['DLON_2012_2020_xgb2016_test'][0]
    
    df['CLP5'] = dict['CLP5'][0]
    #df['TRUTH'] = dict['TRUTH'][0]
    df['HWRF'] = dict['HWRF'][0]
    df['OFCL'] = dict['OFCL'][0]
    df['FSSE'] = dict['FSSE'][0]
    df['GFSO'] = dict['GFSO'][0]
    df['AEMN'] = dict['AEMN'][0]
    df['Consensus_wo_HURR'] = dict['Consensus_wo_HURR'][0]
    df['Consensus_'+ name] = dict['Consensus_w_HURR'][0]
    return df, df_2012_train, df_2012_test, df_2016_train, df_2016_test

# %%
index = X_test_baseline.loc[X_test_baseline['YEAR_0'] < 2016].index
X_val = np.array(X_test)[index]
X_train_ = np.array(X_train)
#validate_track(X_train_, tgt_displacement_train, X_val)

# %% [markdown]
# # Results REVISION

# %%
index = X_test_baseline.loc[X_test_baseline['YEAR_0'] < 2016].index

# %% [markdown]
# ## STAT ONLY

# %%
X_val = np.array(X_test)[index]
X_train_ = np.array(X_train)

# %%
validate_track(X_train_, np.array(tgt_displacement_train), X_val)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-d1ce8fdda962> in <module>
# ----> 1 validate_track(X_train_, np.array(tgt_displacement_train), X_val)
#
# <ipython-input-13-811de62409da> in validate_track(X_train, tgt_train, X_val)
#      19                         LONS_PRED_ = X_test['LON_7'][:len(X_val)] + DLONS_PRED
#      20
# ---> 21                         score = compare_perf_track_7cast_val(LATS_PRED_, LONS_PRED_, basin = 'AN')
#      22
#      23                         print('max_depth: ', max_depth, 'n_estimators: ', n_estimators,
#
# NameError: name 'compare_perf_track_7cast_val' is not defined

# %%
best_depth =  8 
best_est =  300 
best_lr =  0.05 
best_subs =  0.9 
best_min_child =  3

# %%
#NA
d_stat_only_NA, d_boxplot_stat_only_NA = train_xgb_track_all_years_REVISION(X_train_, np.array(X_test), np.array(tgt_displacement_train), max_depth = best_depth, n_estimators = best_est, learning_rate = best_lr, subsample = best_subs, min_child_weight=best_min_child, basin = 'AN')
# Out:
# Number of timesteps: 899
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 143.58 108.35 20.69
# SHIP 77.46 60.88 3.56
# HWRF 74.98 49.1 2.56
# OFCL 71.24 55.52 2.78
# FSSE 68.92 52.56 3.56
# AEMN 73.2 54.98 2.34
# GFSO 70.55 54.27 3.34
# CLP5 201.24 149.25 37.15
# Consensus OFCL only 63.81 47.82 2.11
# Consensus OFCL + Hurricast 65.58 44.77 1.89
# Number of timesteps: 899
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 143.76 108.59 21.47
# SHIP 77.46 60.88 3.56
# HWRF 74.98 49.1 2.56
# OFCL 71.24 55.52 2.78
# FSSE 68.92 52.56 3.56
# AEMN 73.2 54.98 2.34
# GFSO 70.55 54.27 3.34
# CLP5 201.24 149.25 37.15
# Consensus OFCL only 63.81 47.82 2.11
# Consensus OFCL + Hurricast 65.63 44.34 1.89

# %%
#EP
d_stat_only_EP, d_boxplot_stat_only_EP = train_xgb_track_all_years_REVISION(X_train_, np.array(X_test), np.array(tgt_displacement_train), max_depth = best_depth, n_estimators = best_est, learning_rate = best_lr, subsample = best_subs, min_child_weight=best_min_child, basin = 'EP')
# Out:
# Number of timesteps: 837
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 80.74 47.73 1.91
# SHIP 57.81 34.06 0.36
# HWRF 66.98 42.24 2.03
# OFCL 54.1 32.59 0.12
# FSSE 55.83 47.39 0.72
# AEMN 59.9 37.34 0.6
# GFSO 64.56 44.99 1.55
# CLP5 120.92 66.79 12.31
# Consensus OFCL only 55.07 36.57 0.72
# Consensus OFCL + Hurricast 49.32 31.43 0.24
# Number of timesteps: 837
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 80.95 47.26 2.03
# SHIP 57.81 34.06 0.36
# HWRF 66.98 42.24 2.03
# OFCL 54.1 32.59 0.12
# FSSE 55.83 47.39 0.72
# AEMN 59.9 37.34 0.6
# GFSO 64.56 44.99 1.55
# CLP5 120.92 66.79 12.31
# Consensus OFCL only 55.07 36.57 0.72
# Consensus OFCL + Hurricast 49.37 31.55 0.24

# %% [markdown]
# ## Stat + GRU

# %%
X_val = np.array(X_test_total_gru)[index]
X_train_ = np.array(X_train_total_gru)

# %%
validate_track(X_train_, tgt_displacement_train, X_val)
# Out:
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.37 87.33 11.42
# max_depth:  7 n_estimators:  150 lr:  0.1 subsample:  0.8 min_child_weight:  1
# MAE intensity:  111.37
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.49 87.74 11.42
# max_depth:  7 n_estimators:  150 lr:  0.1 subsample:  0.8 min_child_weight:  3
# MAE intensity:  111.49
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.29 87.13 11.19
# max_depth:  7 n_estimators:  150 lr:  0.1 subsample:  0.8 min_child_weight:  5
# MAE intensity:  111.29
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.47 87.56 11.35
# max_depth:  7 n_estimators:  150 lr:  0.1 subsample:  0.9 min_child_weight:  1
# MAE intensity:  111.47
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.17 87.5 11.33
# max_depth:  7 n_estimators:  150 lr:  0.1 subsample:  0.9 min_child_weight:  3
# MAE intensity:  111.17
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.15 87.34 11.32
# max_depth:  7 n_estimators:  150 lr:  0.1 subsample:  0.9 min_child_weight:  5
# MAE intensity:  111.15
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.36 87.66 11.41
# max_depth:  7 n_estimators:  150 lr:  0.1 subsample:  1 min_child_weight:  1
# MAE intensity:  111.36
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.71 87.38 11.57
# max_depth:  7 n_estimators:  150 lr:  0.1 subsample:  1 min_child_weight:  3
# MAE intensity:  111.71
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.17 87.1 11.31
# max_depth:  7 n_estimators:  150 lr:  0.1 subsample:  1 min_child_weight:  5
# MAE intensity:  111.17
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.15 87.5 11.15
# max_depth:  7 n_estimators:  150 lr:  0.07 subsample:  0.8 min_child_weight:  1
# MAE intensity:  111.15
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.21 87.37 11.39
# max_depth:  7 n_estimators:  150 lr:  0.07 subsample:  0.8 min_child_weight:  3
# MAE intensity:  111.21
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.14 87.39 11.1
# max_depth:  7 n_estimators:  150 lr:  0.07 subsample:  0.8 min_child_weight:  5
# MAE intensity:  111.14
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.06 87.37 11.25
# max_depth:  7 n_estimators:  150 lr:  0.07 subsample:  0.9 min_child_weight:  1
# MAE intensity:  111.06
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.19 87.21 11.35
# max_depth:  7 n_estimators:  150 lr:  0.07 subsample:  0.9 min_child_weight:  3
# MAE intensity:  111.19
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 110.94 87.15 11.19
# max_depth:  7 n_estimators:  150 lr:  0.07 subsample:  0.9 min_child_weight:  5
# MAE intensity:  110.94
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.35 87.2 11.44
# max_depth:  7 n_estimators:  150 lr:  0.07 subsample:  1 min_child_weight:  1
# MAE intensity:  111.35
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.17 87.02 11.43
# max_depth:  7 n_estimators:  150 lr:  0.07 subsample:  1 min_child_weight:  3
# MAE intensity:  111.17
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.11 87.15 11.34
# max_depth:  7 n_estimators:  150 lr:  0.07 subsample:  1 min_child_weight:  5
# MAE intensity:  111.11
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.0 87.16 11.16
# max_depth:  7 n_estimators:  150 lr:  0.05 subsample:  0.8 min_child_weight:  1
# MAE intensity:  111.0
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.08 87.04 11.23
# max_depth:  7 n_estimators:  150 lr:  0.05 subsample:  0.8 min_child_weight:  3
# MAE intensity:  111.08
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.21 87.18 11.31
# max_depth:  7 n_estimators:  150 lr:  0.05 subsample:  0.8 min_child_weight:  5
# MAE intensity:  111.21
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.21 87.24 11.36
# max_depth:  7 n_estimators:  150 lr:  0.05 subsample:  0.9 min_child_weight:  1
# MAE intensity:  111.21
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.18 87.23 11.28
# max_depth:  7 n_estimators:  150 lr:  0.05 subsample:  0.9 min_child_weight:  3
# MAE intensity:  111.18
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.05 87.09 11.34
# max_depth:  7 n_estimators:  150 lr:  0.05 subsample:  0.9 min_child_weight:  5
# MAE intensity:  111.05
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.11 87.09 11.44
# max_depth:  7 n_estimators:  150 lr:  0.05 subsample:  1 min_child_weight:  1
# MAE intensity:  111.11
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.14 86.97 11.37
# max_depth:  7 n_estimators:  150 lr:  0.05 subsample:  1 min_child_weight:  3
# MAE intensity:  111.14
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.08 86.85 11.34
# max_depth:  7 n_estimators:  150 lr:  0.05 subsample:  1 min_child_weight:  5
# MAE intensity:  111.08
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.29 87.39 11.42
# max_depth:  7 n_estimators:  200 lr:  0.1 subsample:  0.8 min_child_weight:  1
# MAE intensity:  111.29
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.48 87.81 11.37
# max_depth:  7 n_estimators:  200 lr:  0.1 subsample:  0.8 min_child_weight:  3
# MAE intensity:  111.48
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.37 87.28 11.31
# max_depth:  7 n_estimators:  200 lr:  0.1 subsample:  0.8 min_child_weight:  5
# MAE intensity:  111.37
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.53 87.65 11.34
# max_depth:  7 n_estimators:  200 lr:  0.1 subsample:  0.9 min_child_weight:  1
# MAE intensity:  111.53
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.16 87.5 11.37
# max_depth:  7 n_estimators:  200 lr:  0.1 subsample:  0.9 min_child_weight:  3
# MAE intensity:  111.16
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.13 87.36 11.34
# max_depth:  7 n_estimators:  200 lr:  0.1 subsample:  0.9 min_child_weight:  5
# MAE intensity:  111.13
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.36 87.73 11.53
# max_depth:  7 n_estimators:  200 lr:  0.1 subsample:  1 min_child_weight:  1
# MAE intensity:  111.36
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.78 87.54 11.51
# max_depth:  7 n_estimators:  200 lr:  0.1 subsample:  1 min_child_weight:  3
# MAE intensity:  111.78
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.23 87.19 11.5
# max_depth:  7 n_estimators:  200 lr:  0.1 subsample:  1 min_child_weight:  5
# MAE intensity:  111.23
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.0 87.51 11.24
# max_depth:  7 n_estimators:  200 lr:  0.07 subsample:  0.8 min_child_weight:  1
# MAE intensity:  111.0
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.13 87.45 11.38
# max_depth:  7 n_estimators:  200 lr:  0.07 subsample:  0.8 min_child_weight:  3
# MAE intensity:  111.13
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.1 87.5 11.26
# max_depth:  7 n_estimators:  200 lr:  0.07 subsample:  0.8 min_child_weight:  5
# MAE intensity:  111.1
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 110.97 87.47 11.41
# max_depth:  7 n_estimators:  200 lr:  0.07 subsample:  0.9 min_child_weight:  1
# MAE intensity:  110.97
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.15 87.24 11.35
# max_depth:  7 n_estimators:  200 lr:  0.07 subsample:  0.9 min_child_weight:  3
# MAE intensity:  111.15
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 110.9 87.26 11.29
# max_depth:  7 n_estimators:  200 lr:  0.07 subsample:  0.9 min_child_weight:  5
# MAE intensity:  110.9
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.26 87.26 11.52
# max_depth:  7 n_estimators:  200 lr:  0.07 subsample:  1 min_child_weight:  1
# MAE intensity:  111.26
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.17 87.04 11.44
# max_depth:  7 n_estimators:  200 lr:  0.07 subsample:  1 min_child_weight:  3
# MAE intensity:  111.17
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.09 87.23 11.4
# max_depth:  7 n_estimators:  200 lr:  0.07 subsample:  1 min_child_weight:  5
# MAE intensity:  111.09
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 110.95 87.16 11.26
# max_depth:  7 n_estimators:  200 lr:  0.05 subsample:  0.8 min_child_weight:  1
# MAE intensity:  110.95
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.02 87.03 11.26
# max_depth:  7 n_estimators:  200 lr:  0.05 subsample:  0.8 min_child_weight:  3
# MAE intensity:  111.02
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.11 87.21 11.26
# max_depth:  7 n_estimators:  200 lr:  0.05 subsample:  0.8 min_child_weight:  5
# MAE intensity:  111.11
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.11 87.17 11.31
# max_depth:  7 n_estimators:  200 lr:  0.05 subsample:  0.9 min_child_weight:  1
# MAE intensity:  111.11
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.05 87.18 11.26
# max_depth:  7 n_estimators:  200 lr:  0.05 subsample:  0.9 min_child_weight:  3
# MAE intensity:  111.05
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 110.94 87.05 11.24
# max_depth:  7 n_estimators:  200 lr:  0.05 subsample:  0.9 min_child_weight:  5
# MAE intensity:  110.94
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.04 87.06 11.31
# max_depth:  7 n_estimators:  200 lr:  0.05 subsample:  1 min_child_weight:  1
# MAE intensity:  111.04
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.04 86.87 11.34
# max_depth:  7 n_estimators:  200 lr:  0.05 subsample:  1 min_child_weight:  3
# MAE intensity:  111.04
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.08 86.93 11.31
# max_depth:  7 n_estimators:  200 lr:  0.05 subsample:  1 min_child_weight:  5
# MAE intensity:  111.08
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.32 87.59 11.49
# max_depth:  7 n_estimators:  300 lr:  0.1 subsample:  0.8 min_child_weight:  1
# MAE intensity:  111.32
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.46 87.85 11.35
# max_depth:  7 n_estimators:  300 lr:  0.1 subsample:  0.8 min_child_weight:  3
# MAE intensity:  111.46
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.51 87.42 11.27
# max_depth:  7 n_estimators:  300 lr:  0.1 subsample:  0.8 min_child_weight:  5
# MAE intensity:  111.51
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.65 87.76 11.29
# max_depth:  7 n_estimators:  300 lr:  0.1 subsample:  0.9 min_child_weight:  1
# MAE intensity:  111.65
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.16 87.74 11.37
# max_depth:  7 n_estimators:  300 lr:  0.1 subsample:  0.9 min_child_weight:  3
# MAE intensity:  111.16
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.3 87.52 11.47
# max_depth:  7 n_estimators:  300 lr:  0.1 subsample:  0.9 min_child_weight:  5
# MAE intensity:  111.3
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.44 87.92 11.5
# max_depth:  7 n_estimators:  300 lr:  0.1 subsample:  1 min_child_weight:  1
# MAE intensity:  111.44
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.75 87.79 11.5
# max_depth:  7 n_estimators:  300 lr:  0.1 subsample:  1 min_child_weight:  3
# MAE intensity:  111.75
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.41 87.42 11.54
# max_depth:  7 n_estimators:  300 lr:  0.1 subsample:  1 min_child_weight:  5
# MAE intensity:  111.41
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 110.87 87.49 11.24
# max_depth:  7 n_estimators:  300 lr:  0.07 subsample:  0.8 min_child_weight:  1
# MAE intensity:  110.87
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.0 87.56 11.31
# max_depth:  7 n_estimators:  300 lr:  0.07 subsample:  0.8 min_child_weight:  3
# MAE intensity:  111.0
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 110.96 87.57 11.18
# max_depth:  7 n_estimators:  300 lr:  0.07 subsample:  0.8 min_child_weight:  5
# MAE intensity:  110.96
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 110.98 87.59 11.34
# max_depth:  7 n_estimators:  300 lr:  0.07 subsample:  0.9 min_child_weight:  1
# MAE intensity:  110.98
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.1 87.33 11.39
# max_depth:  7 n_estimators:  300 lr:  0.07 subsample:  0.9 min_child_weight:  3
# MAE intensity:  111.1
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 110.81 87.3 11.34
# max_depth:  7 n_estimators:  300 lr:  0.07 subsample:  0.9 min_child_weight:  5
# MAE intensity:  110.81
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.22 87.45 11.57
# max_depth:  7 n_estimators:  300 lr:  0.07 subsample:  1 min_child_weight:  1
# MAE intensity:  111.22
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.18 87.15 11.44
# max_depth:  7 n_estimators:  300 lr:  0.07 subsample:  1 min_child_weight:  3
# MAE intensity:  111.18
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.1 87.44 11.43
# max_depth:  7 n_estimators:  300 lr:  0.07 subsample:  1 min_child_weight:  5
# MAE intensity:  111.1
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 110.8 87.19 11.24
# max_depth:  7 n_estimators:  300 lr:  0.05 subsample:  0.8 min_child_weight:  1
# MAE intensity:  110.8
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 110.95 87.07 11.3
# max_depth:  7 n_estimators:  300 lr:  0.05 subsample:  0.8 min_child_weight:  3
# MAE intensity:  110.95
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 110.87 87.19 11.21
# max_depth:  7 n_estimators:  300 lr:  0.05 subsample:  0.8 min_child_weight:  5
# MAE intensity:  110.87
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.03 87.2 11.22
# max_depth:  7 n_estimators:  300 lr:  0.05 subsample:  0.9 min_child_weight:  1
# MAE intensity:  111.03
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 110.88 87.14 11.04
# max_depth:  7 n_estimators:  300 lr:  0.05 subsample:  0.9 min_child_weight:  3
# MAE intensity:  110.88
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 110.84 87.0 11.3
# max_depth:  7 n_estimators:  300 lr:  0.05 subsample:  0.9 min_child_weight:  5
# MAE intensity:  110.84
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 110.95 87.08 11.36
# max_depth:  7 n_estimators:  300 lr:  0.05 subsample:  1 min_child_weight:  1
# MAE intensity:  110.95
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 110.88 86.93 11.35
# max_depth:  7 n_estimators:  300 lr:  0.05 subsample:  1 min_child_weight:  3
# MAE intensity:  110.88
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 110.92 87.0 11.38
# max_depth:  7 n_estimators:  300 lr:  0.05 subsample:  1 min_child_weight:  5
# MAE intensity:  110.92
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.69 88.05 11.54
# max_depth:  8 n_estimators:  150 lr:  0.1 subsample:  0.8 min_child_weight:  1
# MAE intensity:  111.69
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.55 87.58 11.46
# max_depth:  8 n_estimators:  150 lr:  0.1 subsample:  0.8 min_child_weight:  3
# MAE intensity:  111.55
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.39 87.77 11.5
# max_depth:  8 n_estimators:  150 lr:  0.1 subsample:  0.8 min_child_weight:  5
# MAE intensity:  111.39
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.49 88.11 11.47
# max_depth:  8 n_estimators:  150 lr:  0.1 subsample:  0.9 min_child_weight:  1
# MAE intensity:  111.49
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.16 87.75 11.29
# max_depth:  8 n_estimators:  150 lr:  0.1 subsample:  0.9 min_child_weight:  3
# MAE intensity:  111.16
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.48 87.54 11.47
# max_depth:  8 n_estimators:  150 lr:  0.1 subsample:  0.9 min_child_weight:  5
# MAE intensity:  111.48
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.49 87.85 11.51
# max_depth:  8 n_estimators:  150 lr:  0.1 subsample:  1 min_child_weight:  1
# MAE intensity:  111.49
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.35 87.86 11.49
# max_depth:  8 n_estimators:  150 lr:  0.1 subsample:  1 min_child_weight:  3
# MAE intensity:  111.35
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.38 87.84 11.56
# max_depth:  8 n_estimators:  150 lr:  0.1 subsample:  1 min_child_weight:  5
# MAE intensity:  111.38
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.23 87.56 11.18
# max_depth:  8 n_estimators:  150 lr:  0.07 subsample:  0.8 min_child_weight:  1
# MAE intensity:  111.23
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.15 87.82 11.26
# max_depth:  8 n_estimators:  150 lr:  0.07 subsample:  0.8 min_child_weight:  3
# MAE intensity:  111.15
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.47 87.51 11.44
# max_depth:  8 n_estimators:  150 lr:  0.07 subsample:  0.8 min_child_weight:  5
# MAE intensity:  111.47
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.39 87.74 11.36
# max_depth:  8 n_estimators:  150 lr:  0.07 subsample:  0.9 min_child_weight:  1
# MAE intensity:  111.39
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.01 87.43 11.26
# max_depth:  8 n_estimators:  150 lr:  0.07 subsample:  0.9 min_child_weight:  3
# MAE intensity:  111.01
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.09 87.4 11.28
# max_depth:  8 n_estimators:  150 lr:  0.07 subsample:  0.9 min_child_weight:  5
# MAE intensity:  111.09
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.33 87.54 11.57
# max_depth:  8 n_estimators:  150 lr:  0.07 subsample:  1 min_child_weight:  1
# MAE intensity:  111.33
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.05 87.48 11.47
# max_depth:  8 n_estimators:  150 lr:  0.07 subsample:  1 min_child_weight:  3
# MAE intensity:  111.05
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.25 87.6 11.55
# max_depth:  8 n_estimators:  150 lr:  0.07 subsample:  1 min_child_weight:  5
# MAE intensity:  111.25
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.02 87.5 11.31
# max_depth:  8 n_estimators:  150 lr:  0.05 subsample:  0.8 min_child_weight:  1
# MAE intensity:  111.02
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 110.91 87.35 11.08
# max_depth:  8 n_estimators:  150 lr:  0.05 subsample:  0.8 min_child_weight:  3
# MAE intensity:  110.91
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.0 87.55 11.36
# max_depth:  8 n_estimators:  150 lr:  0.05 subsample:  0.8 min_child_weight:  5
# MAE intensity:  111.0
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.09 87.62 11.28
# max_depth:  8 n_estimators:  150 lr:  0.05 subsample:  0.9 min_child_weight:  1
# MAE intensity:  111.09
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 110.96 87.15 11.39
# max_depth:  8 n_estimators:  150 lr:  0.05 subsample:  0.9 min_child_weight:  3
# MAE intensity:  110.96
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.09 87.17 11.26
# max_depth:  8 n_estimators:  150 lr:  0.05 subsample:  0.9 min_child_weight:  5
# MAE intensity:  111.09
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.35 87.47 11.36
# max_depth:  8 n_estimators:  150 lr:  0.05 subsample:  1 min_child_weight:  1
# MAE intensity:  111.35
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.05 87.11 11.38
# max_depth:  8 n_estimators:  150 lr:  0.05 subsample:  1 min_child_weight:  3
# MAE intensity:  111.05
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.38 87.43 11.33
# max_depth:  8 n_estimators:  150 lr:  0.05 subsample:  1 min_child_weight:  5
# MAE intensity:  111.38
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.79 88.09 11.67
# max_depth:  8 n_estimators:  200 lr:  0.1 subsample:  0.8 min_child_weight:  1
# MAE intensity:  111.79
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.64 87.76 11.6
# max_depth:  8 n_estimators:  200 lr:  0.1 subsample:  0.8 min_child_weight:  3
# MAE intensity:  111.64
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.5 87.9 11.55
# max_depth:  8 n_estimators:  200 lr:  0.1 subsample:  0.8 min_child_weight:  5
# MAE intensity:  111.5
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.63 88.12 11.47
# max_depth:  8 n_estimators:  200 lr:  0.1 subsample:  0.9 min_child_weight:  1
# MAE intensity:  111.63
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.23 87.69 11.48
# max_depth:  8 n_estimators:  200 lr:  0.1 subsample:  0.9 min_child_weight:  3
# MAE intensity:  111.23
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.56 87.68 11.56
# max_depth:  8 n_estimators:  200 lr:  0.1 subsample:  0.9 min_child_weight:  5
# MAE intensity:  111.56
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.45 87.82 11.5
# max_depth:  8 n_estimators:  200 lr:  0.1 subsample:  1 min_child_weight:  1
# MAE intensity:  111.45
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.46 87.98 11.53
# max_depth:  8 n_estimators:  200 lr:  0.1 subsample:  1 min_child_weight:  3
# MAE intensity:  111.46
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.36 87.91 11.39
# max_depth:  8 n_estimators:  200 lr:  0.1 subsample:  1 min_child_weight:  5
# MAE intensity:  111.36
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.24 87.71 11.21
# max_depth:  8 n_estimators:  200 lr:  0.07 subsample:  0.8 min_child_weight:  1
# MAE intensity:  111.24
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.15 87.95 11.37
# max_depth:  8 n_estimators:  200 lr:  0.07 subsample:  0.8 min_child_weight:  3
# MAE intensity:  111.15
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.45 87.49 11.5
# max_depth:  8 n_estimators:  200 lr:  0.07 subsample:  0.8 min_child_weight:  5
# MAE intensity:  111.45
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.38 87.78 11.42
# max_depth:  8 n_estimators:  200 lr:  0.07 subsample:  0.9 min_child_weight:  1
# MAE intensity:  111.38
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.06 87.36 11.25
# max_depth:  8 n_estimators:  200 lr:  0.07 subsample:  0.9 min_child_weight:  3
# MAE intensity:  111.06
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.06 87.47 11.29
# max_depth:  8 n_estimators:  200 lr:  0.07 subsample:  0.9 min_child_weight:  5
# MAE intensity:  111.06
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.35 87.66 11.61
# max_depth:  8 n_estimators:  200 lr:  0.07 subsample:  1 min_child_weight:  1
# MAE intensity:  111.35
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.03 87.58 11.51
# max_depth:  8 n_estimators:  200 lr:  0.07 subsample:  1 min_child_weight:  3
# MAE intensity:  111.03
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.2 87.47 11.44
# max_depth:  8 n_estimators:  200 lr:  0.07 subsample:  1 min_child_weight:  5
# MAE intensity:  111.2
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 110.96 87.56 11.34
# max_depth:  8 n_estimators:  200 lr:  0.05 subsample:  0.8 min_child_weight:  1
# MAE intensity:  110.96
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 110.88 87.39 11.08
# max_depth:  8 n_estimators:  200 lr:  0.05 subsample:  0.8 min_child_weight:  3
# MAE intensity:  110.88
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 110.99 87.59 11.34
# max_depth:  8 n_estimators:  200 lr:  0.05 subsample:  0.8 min_child_weight:  5
# MAE intensity:  110.99
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 110.96 87.57 11.24
# max_depth:  8 n_estimators:  200 lr:  0.05 subsample:  0.9 min_child_weight:  1
# MAE intensity:  110.96
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 110.89 87.17 11.36
# max_depth:  8 n_estimators:  200 lr:  0.05 subsample:  0.9 min_child_weight:  3
# MAE intensity:  110.89
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.1 87.3 11.35
# max_depth:  8 n_estimators:  200 lr:  0.05 subsample:  0.9 min_child_weight:  5
# MAE intensity:  111.1
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.38 87.53 11.42
# max_depth:  8 n_estimators:  200 lr:  0.05 subsample:  1 min_child_weight:  1
# MAE intensity:  111.38
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.05 87.15 11.39
# max_depth:  8 n_estimators:  200 lr:  0.05 subsample:  1 min_child_weight:  3
# MAE intensity:  111.05
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.32 87.46 11.34
# max_depth:  8 n_estimators:  200 lr:  0.05 subsample:  1 min_child_weight:  5
# MAE intensity:  111.32
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 112.11 88.15 11.57
# max_depth:  8 n_estimators:  300 lr:  0.1 subsample:  0.8 min_child_weight:  1
# MAE intensity:  112.11
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.92 87.97 11.57
# max_depth:  8 n_estimators:  300 lr:  0.1 subsample:  0.8 min_child_weight:  3
# MAE intensity:  111.92
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.91 88.04 11.65
# max_depth:  8 n_estimators:  300 lr:  0.1 subsample:  0.8 min_child_weight:  5
# MAE intensity:  111.91
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.74 88.3 11.53
# max_depth:  8 n_estimators:  300 lr:  0.1 subsample:  0.9 min_child_weight:  1
# MAE intensity:  111.74
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.34 87.82 11.52
# max_depth:  8 n_estimators:  300 lr:  0.1 subsample:  0.9 min_child_weight:  3
# MAE intensity:  111.34
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.78 87.75 11.62
# max_depth:  8 n_estimators:  300 lr:  0.1 subsample:  0.9 min_child_weight:  5
# MAE intensity:  111.78
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.78 87.95 11.52
# max_depth:  8 n_estimators:  300 lr:  0.1 subsample:  1 min_child_weight:  1
# MAE intensity:  111.78
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.56 88.24 11.59
# max_depth:  8 n_estimators:  300 lr:  0.1 subsample:  1 min_child_weight:  3
# MAE intensity:  111.56
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.52 88.08 11.43
# max_depth:  8 n_estimators:  300 lr:  0.1 subsample:  1 min_child_weight:  5
# MAE intensity:  111.52
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.32 87.81 11.2
# max_depth:  8 n_estimators:  300 lr:  0.07 subsample:  0.8 min_child_weight:  1
# MAE intensity:  111.32
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.32 88.11 11.38
# max_depth:  8 n_estimators:  300 lr:  0.07 subsample:  0.8 min_child_weight:  3
# MAE intensity:  111.32
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.45 87.62 11.39
# max_depth:  8 n_estimators:  300 lr:  0.07 subsample:  0.8 min_child_weight:  5
# MAE intensity:  111.45
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.45 87.87 11.44
# max_depth:  8 n_estimators:  300 lr:  0.07 subsample:  0.9 min_child_weight:  1
# MAE intensity:  111.45
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.14 87.5 11.24
# max_depth:  8 n_estimators:  300 lr:  0.07 subsample:  0.9 min_child_weight:  3
# MAE intensity:  111.14
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.12 87.65 11.25
# max_depth:  8 n_estimators:  300 lr:  0.07 subsample:  0.9 min_child_weight:  5
# MAE intensity:  111.12
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.4 87.79 11.5
# max_depth:  8 n_estimators:  300 lr:  0.07 subsample:  1 min_child_weight:  1
# MAE intensity:  111.4
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.09 87.67 11.44
# max_depth:  8 n_estimators:  300 lr:  0.07 subsample:  1 min_child_weight:  3
# MAE intensity:  111.09
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.29 87.46 11.5
# max_depth:  8 n_estimators:  300 lr:  0.07 subsample:  1 min_child_weight:  5
# MAE intensity:  111.29
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 110.85 87.69 11.3
# max_depth:  8 n_estimators:  300 lr:  0.05 subsample:  0.8 min_child_weight:  1
# MAE intensity:  110.85
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 110.8 87.46 11.12
# max_depth:  8 n_estimators:  300 lr:  0.05 subsample:  0.8 min_child_weight:  3
# MAE intensity:  110.8
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 110.96 87.52 11.36
# max_depth:  8 n_estimators:  300 lr:  0.05 subsample:  0.8 min_child_weight:  5
# MAE intensity:  110.96
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 110.96 87.67 11.4
# max_depth:  8 n_estimators:  300 lr:  0.05 subsample:  0.9 min_child_weight:  1
# MAE intensity:  110.96
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 110.77 87.2 11.4
# max_depth:  8 n_estimators:  300 lr:  0.05 subsample:  0.9 min_child_weight:  3
# MAE intensity:  110.77
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.01 87.36 11.29
# max_depth:  8 n_estimators:  300 lr:  0.05 subsample:  0.9 min_child_weight:  5
# MAE intensity:  111.01
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.31 87.6 11.47
# max_depth:  8 n_estimators:  300 lr:  0.05 subsample:  1 min_child_weight:  1
# MAE intensity:  111.31
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.0 87.24 11.37
# max_depth:  8 n_estimators:  300 lr:  0.05 subsample:  1 min_child_weight:  3
# MAE intensity:  111.0
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.21 87.5 11.3
# max_depth:  8 n_estimators:  300 lr:  0.05 subsample:  1 min_child_weight:  5
# MAE intensity:  111.21
#
# #### BEST RESULTS ####
# best_depth =  8
# best_est =  300
# best_lr =  0.05
# best_subs =  0.9
# best_min_child =  3
# (8, 300, 0.05, 0.9, 3)

# %%
best_depth =  8 
best_est =  300 
best_lr =  0.05 
best_subs =  0.8 
best_min_child =  3

# %%
#NA
d_stat_gru_NA, d_boxplot_stat_gru_NA = train_xgb_track_all_years_REVISION(X_train_, np.array(X_test_total_gru), np.array(tgt_displacement_train), max_depth = best_depth, n_estimators = best_est, learning_rate = best_lr, subsample = best_subs, min_child_weight=best_min_child, basin = 'AN')
# Out:
# Number of timesteps: 899
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 111.17 79.42 12.24
# SHIP 77.46 60.88 3.56
# HWRF 74.98 49.1 2.56
# OFCL 71.24 55.52 2.78
# FSSE 68.92 52.56 3.56
# AEMN 73.2 54.98 2.34
# GFSO 70.55 54.27 3.34
# CLP5 201.24 149.25 37.15
# Consensus OFCL only 63.81 47.82 2.11
# Consensus OFCL + Hurricast 60.96 43.51 1.0
# Number of timesteps: 899
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 110.62 79.56 11.57
# SHIP 77.46 60.88 3.56
# HWRF 74.98 49.1 2.56
# OFCL 71.24 55.52 2.78
# FSSE 68.92 52.56 3.56
# AEMN 73.2 54.98 2.34
# GFSO 70.55 54.27 3.34
# CLP5 201.24 149.25 37.15
# Consensus OFCL only 63.81 47.82 2.11
# Consensus OFCL + Hurricast 61.03 43.6 1.0

# %%
#EP
d_stat_gru_EP, d_boxplot_stat_gru_EP = train_xgb_track_all_years_REVISION(X_train_, np.array(X_test_total_gru), np.array(tgt_displacement_train), max_depth = best_depth, n_estimators = best_est, learning_rate = best_lr, subsample = best_subs, min_child_weight=best_min_child, basin = 'EP')
# Out:
# Number of timesteps: 837
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 72.78 43.82 0.96
# SHIP 57.81 34.06 0.36
# HWRF 66.98 42.24 2.03
# OFCL 54.1 32.59 0.12
# FSSE 55.83 47.39 0.72
# AEMN 59.9 37.34 0.6
# GFSO 64.56 44.99 1.55
# CLP5 120.92 66.79 12.31
# Consensus OFCL only 55.07 36.57 0.72
# Consensus OFCL + Hurricast 50.06 31.6 0.12
# Number of timesteps: 837
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 71.53 43.03 0.96
# SHIP 57.81 34.06 0.36
# HWRF 66.98 42.24 2.03
# OFCL 54.1 32.59 0.12
# FSSE 55.83 47.39 0.72
# AEMN 59.9 37.34 0.6
# GFSO 64.56 44.99 1.55
# CLP5 120.92 66.79 12.31
# Consensus OFCL only 55.07 36.57 0.72
# Consensus OFCL + Hurricast 49.85 31.46 0.12

# %%
#EP 2019 included
d_stat_gru_EP, d_boxplot_stat_gru_EP = train_xgb_track_all_years_REVISION(X_train_, np.array(X_test_total_gru), np.array(tgt_displacement_train), max_depth = best_depth, n_estimators = best_est, learning_rate = best_lr, subsample = best_subs, min_child_weight=best_min_child, basin = 'EP')
# Out:
# Number of timesteps: 837
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 72.78 43.82 0.96
# SHIP 57.81 34.06 0.36
# HWRF 66.98 42.24 2.03
# OFCL 54.1 32.59 0.12
# FSSE 55.83 47.39 0.72
# AEMN 59.9 37.34 0.6
# GFSO 64.56 44.99 1.55
# CLP5 120.92 66.79 12.31
# Consensus OFCL only 55.07 36.57 0.72
# Consensus OFCL + Hurricast 50.06 31.6 0.12
# Number of timesteps: 837
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 71.53 43.03 0.96
# SHIP 57.81 34.06 0.36
# HWRF 66.98 42.24 2.03
# OFCL 54.1 32.59 0.12
# FSSE 55.83 47.39 0.72
# AEMN 59.9 37.34 0.6
# GFSO 64.56 44.99 1.55
# CLP5 120.92 66.79 12.31
# Consensus OFCL only 55.07 36.57 0.72
# Consensus OFCL + Hurricast 49.85 31.46 0.12

# %% [markdown]
# ## GRU Only

# %%
X_val = np.array(X_test_embed_gru)[index]
X_train_ = np.array(X_train_embed_gru)

# %%
validate_track(X_train_, tgt_displacement_train, X_val)
# Out:
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.53 90.48 12.19
# max_depth:  7 n_estimators:  150 lr:  0.1 subsample:  0.8 min_child_weight:  1
# MAE intensity:  114.53
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.44 90.57 12.07
# max_depth:  7 n_estimators:  150 lr:  0.1 subsample:  0.8 min_child_weight:  3
# MAE intensity:  114.44
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.55 90.53 12.2
# max_depth:  7 n_estimators:  150 lr:  0.1 subsample:  0.8 min_child_weight:  5
# MAE intensity:  114.55
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.52 90.46 12.06
# max_depth:  7 n_estimators:  150 lr:  0.1 subsample:  0.9 min_child_weight:  1
# MAE intensity:  114.52
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.48 90.66 12.2
# max_depth:  7 n_estimators:  150 lr:  0.1 subsample:  0.9 min_child_weight:  3
# MAE intensity:  114.48
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.21 90.15 11.95
# max_depth:  7 n_estimators:  150 lr:  0.1 subsample:  0.9 min_child_weight:  5
# MAE intensity:  114.21
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.61 90.5 12.19
# max_depth:  7 n_estimators:  150 lr:  0.1 subsample:  1 min_child_weight:  1
# MAE intensity:  114.61
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.7 90.23 12.2
# max_depth:  7 n_estimators:  150 lr:  0.1 subsample:  1 min_child_weight:  3
# MAE intensity:  114.7
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.55 90.46 11.96
# max_depth:  7 n_estimators:  150 lr:  0.1 subsample:  1 min_child_weight:  5
# MAE intensity:  114.55
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.28 90.32 12.15
# max_depth:  7 n_estimators:  150 lr:  0.07 subsample:  0.8 min_child_weight:  1
# MAE intensity:  114.28
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.35 90.31 12.15
# max_depth:  7 n_estimators:  150 lr:  0.07 subsample:  0.8 min_child_weight:  3
# MAE intensity:  114.35
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.45 90.23 12.22
# max_depth:  7 n_estimators:  150 lr:  0.07 subsample:  0.8 min_child_weight:  5
# MAE intensity:  114.45
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.55 90.46 12.18
# max_depth:  7 n_estimators:  150 lr:  0.07 subsample:  0.9 min_child_weight:  1
# MAE intensity:  114.55
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.52 90.43 12.18
# max_depth:  7 n_estimators:  150 lr:  0.07 subsample:  0.9 min_child_weight:  3
# MAE intensity:  114.52
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.31 90.11 12.16
# max_depth:  7 n_estimators:  150 lr:  0.07 subsample:  0.9 min_child_weight:  5
# MAE intensity:  114.31
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.47 90.41 12.15
# max_depth:  7 n_estimators:  150 lr:  0.07 subsample:  1 min_child_weight:  1
# MAE intensity:  114.47
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.42 90.2 12.12
# max_depth:  7 n_estimators:  150 lr:  0.07 subsample:  1 min_child_weight:  3
# MAE intensity:  114.42
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.48 90.4 12.23
# max_depth:  7 n_estimators:  150 lr:  0.07 subsample:  1 min_child_weight:  5
# MAE intensity:  114.48
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.34 90.28 12.12
# max_depth:  7 n_estimators:  150 lr:  0.05 subsample:  0.8 min_child_weight:  1
# MAE intensity:  114.34
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.45 90.29 12.11
# max_depth:  7 n_estimators:  150 lr:  0.05 subsample:  0.8 min_child_weight:  3
# MAE intensity:  114.45
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.27 90.14 12.07
# max_depth:  7 n_estimators:  150 lr:  0.05 subsample:  0.8 min_child_weight:  5
# MAE intensity:  114.27
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.42 90.17 12.17
# max_depth:  7 n_estimators:  150 lr:  0.05 subsample:  0.9 min_child_weight:  1
# MAE intensity:  114.42
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.45 90.22 12.15
# max_depth:  7 n_estimators:  150 lr:  0.05 subsample:  0.9 min_child_weight:  3
# MAE intensity:  114.45
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.42 90.19 12.17
# max_depth:  7 n_estimators:  150 lr:  0.05 subsample:  0.9 min_child_weight:  5
# MAE intensity:  114.42
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.47 90.29 12.17
# max_depth:  7 n_estimators:  150 lr:  0.05 subsample:  1 min_child_weight:  1
# MAE intensity:  114.47
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.46 90.29 12.16
# max_depth:  7 n_estimators:  150 lr:  0.05 subsample:  1 min_child_weight:  3
# MAE intensity:  114.46
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.51 90.34 12.25
# max_depth:  7 n_estimators:  150 lr:  0.05 subsample:  1 min_child_weight:  5
# MAE intensity:  114.51
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.55 90.42 12.21
# max_depth:  7 n_estimators:  200 lr:  0.1 subsample:  0.8 min_child_weight:  1
# MAE intensity:  114.55
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.46 90.55 12.11
# max_depth:  7 n_estimators:  200 lr:  0.1 subsample:  0.8 min_child_weight:  3
# MAE intensity:  114.46
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.58 90.66 12.17
# max_depth:  7 n_estimators:  200 lr:  0.1 subsample:  0.8 min_child_weight:  5
# MAE intensity:  114.58
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.53 90.55 12.07
# max_depth:  7 n_estimators:  200 lr:  0.1 subsample:  0.9 min_child_weight:  1
# MAE intensity:  114.53
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.47 90.64 12.17
# max_depth:  7 n_estimators:  200 lr:  0.1 subsample:  0.9 min_child_weight:  3
# MAE intensity:  114.47
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.17 90.15 12.03
# max_depth:  7 n_estimators:  200 lr:  0.1 subsample:  0.9 min_child_weight:  5
# MAE intensity:  114.17
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.62 90.62 12.2
# max_depth:  7 n_estimators:  200 lr:  0.1 subsample:  1 min_child_weight:  1
# MAE intensity:  114.62
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.76 90.3 12.2
# max_depth:  7 n_estimators:  200 lr:  0.1 subsample:  1 min_child_weight:  3
# MAE intensity:  114.76
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.56 90.41 12.09
# max_depth:  7 n_estimators:  200 lr:  0.1 subsample:  1 min_child_weight:  5
# MAE intensity:  114.56
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.25 90.31 12.09
# max_depth:  7 n_estimators:  200 lr:  0.07 subsample:  0.8 min_child_weight:  1
# MAE intensity:  114.25
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.33 90.22 12.2
# max_depth:  7 n_estimators:  200 lr:  0.07 subsample:  0.8 min_child_weight:  3
# MAE intensity:  114.33
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.43 90.28 12.16
# max_depth:  7 n_estimators:  200 lr:  0.07 subsample:  0.8 min_child_weight:  5
# MAE intensity:  114.43
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.52 90.45 12.15
# max_depth:  7 n_estimators:  200 lr:  0.07 subsample:  0.9 min_child_weight:  1
# MAE intensity:  114.52
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.5 90.41 12.22
# max_depth:  7 n_estimators:  200 lr:  0.07 subsample:  0.9 min_child_weight:  3
# MAE intensity:  114.5
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.29 90.08 12.14
# max_depth:  7 n_estimators:  200 lr:  0.07 subsample:  0.9 min_child_weight:  5
# MAE intensity:  114.29
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.44 90.45 12.17
# max_depth:  7 n_estimators:  200 lr:  0.07 subsample:  1 min_child_weight:  1
# MAE intensity:  114.44
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.37 90.16 12.22
# max_depth:  7 n_estimators:  200 lr:  0.07 subsample:  1 min_child_weight:  3
# MAE intensity:  114.37
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.45 90.42 12.22
# max_depth:  7 n_estimators:  200 lr:  0.07 subsample:  1 min_child_weight:  5
# MAE intensity:  114.45
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.28 90.25 12.15
# max_depth:  7 n_estimators:  200 lr:  0.05 subsample:  0.8 min_child_weight:  1
# MAE intensity:  114.28
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.34 90.3 12.04
# max_depth:  7 n_estimators:  200 lr:  0.05 subsample:  0.8 min_child_weight:  3
# MAE intensity:  114.34
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.17 90.15 12.02
# max_depth:  7 n_estimators:  200 lr:  0.05 subsample:  0.8 min_child_weight:  5
# MAE intensity:  114.17
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.32 90.1 12.2
# max_depth:  7 n_estimators:  200 lr:  0.05 subsample:  0.9 min_child_weight:  1
# MAE intensity:  114.32
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.37 90.22 12.19
# max_depth:  7 n_estimators:  200 lr:  0.05 subsample:  0.9 min_child_weight:  3
# MAE intensity:  114.37
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.36 90.17 12.17
# max_depth:  7 n_estimators:  200 lr:  0.05 subsample:  0.9 min_child_weight:  5
# MAE intensity:  114.36
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.41 90.28 12.21
# max_depth:  7 n_estimators:  200 lr:  0.05 subsample:  1 min_child_weight:  1
# MAE intensity:  114.41
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.37 90.25 12.11
# max_depth:  7 n_estimators:  200 lr:  0.05 subsample:  1 min_child_weight:  3
# MAE intensity:  114.37
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.43 90.33 12.2
# max_depth:  7 n_estimators:  200 lr:  0.05 subsample:  1 min_child_weight:  5
# MAE intensity:  114.43
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.72 90.48 12.28
# max_depth:  7 n_estimators:  300 lr:  0.1 subsample:  0.8 min_child_weight:  1
# MAE intensity:  114.72
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.56 90.59 12.17
# max_depth:  7 n_estimators:  300 lr:  0.1 subsample:  0.8 min_child_weight:  3
# MAE intensity:  114.56
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.74 90.97 12.37
# max_depth:  7 n_estimators:  300 lr:  0.1 subsample:  0.8 min_child_weight:  5
# MAE intensity:  114.74
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.65 90.66 12.02
# max_depth:  7 n_estimators:  300 lr:  0.1 subsample:  0.9 min_child_weight:  1
# MAE intensity:  114.65
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.58 90.68 12.21
# max_depth:  7 n_estimators:  300 lr:  0.1 subsample:  0.9 min_child_weight:  3
# MAE intensity:  114.58
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.41 90.47 12.1
# max_depth:  7 n_estimators:  300 lr:  0.1 subsample:  0.9 min_child_weight:  5
# MAE intensity:  114.41
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.61 90.68 12.2
# max_depth:  7 n_estimators:  300 lr:  0.1 subsample:  1 min_child_weight:  1
# MAE intensity:  114.61
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.87 90.39 12.2
# max_depth:  7 n_estimators:  300 lr:  0.1 subsample:  1 min_child_weight:  3
# MAE intensity:  114.87
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.69 90.54 12.15
# max_depth:  7 n_estimators:  300 lr:  0.1 subsample:  1 min_child_weight:  5
# MAE intensity:  114.69
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.21 90.38 12.07
# max_depth:  7 n_estimators:  300 lr:  0.07 subsample:  0.8 min_child_weight:  1
# MAE intensity:  114.21
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.37 90.4 12.2
# max_depth:  7 n_estimators:  300 lr:  0.07 subsample:  0.8 min_child_weight:  3
# MAE intensity:  114.37
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.42 90.31 12.14
# max_depth:  7 n_estimators:  300 lr:  0.07 subsample:  0.8 min_child_weight:  5
# MAE intensity:  114.42
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.53 90.57 12.09
# max_depth:  7 n_estimators:  300 lr:  0.07 subsample:  0.9 min_child_weight:  1
# MAE intensity:  114.53
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.45 90.39 12.22
# max_depth:  7 n_estimators:  300 lr:  0.07 subsample:  0.9 min_child_weight:  3
# MAE intensity:  114.45
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.28 90.1 12.03
# max_depth:  7 n_estimators:  300 lr:  0.07 subsample:  0.9 min_child_weight:  5
# MAE intensity:  114.28
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.43 90.51 12.19
# max_depth:  7 n_estimators:  300 lr:  0.07 subsample:  1 min_child_weight:  1
# MAE intensity:  114.43
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.34 90.09 12.25
# max_depth:  7 n_estimators:  300 lr:  0.07 subsample:  1 min_child_weight:  3
# MAE intensity:  114.34
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.45 90.44 12.12
# max_depth:  7 n_estimators:  300 lr:  0.07 subsample:  1 min_child_weight:  5
# MAE intensity:  114.45
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.22 90.23 12.21
# max_depth:  7 n_estimators:  300 lr:  0.05 subsample:  0.8 min_child_weight:  1
# MAE intensity:  114.22
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.31 90.19 12.07
# max_depth:  7 n_estimators:  300 lr:  0.05 subsample:  0.8 min_child_weight:  3
# MAE intensity:  114.31
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.07 90.13 12.06
# max_depth:  7 n_estimators:  300 lr:  0.05 subsample:  0.8 min_child_weight:  5
# MAE intensity:  114.07
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.27 90.11 12.09
# max_depth:  7 n_estimators:  300 lr:  0.05 subsample:  0.9 min_child_weight:  1
# MAE intensity:  114.27
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.25 90.14 12.21
# max_depth:  7 n_estimators:  300 lr:  0.05 subsample:  0.9 min_child_weight:  3
# MAE intensity:  114.25
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.29 90.2 12.11
# max_depth:  7 n_estimators:  300 lr:  0.05 subsample:  0.9 min_child_weight:  5
# MAE intensity:  114.29
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.35 90.27 12.09
# max_depth:  7 n_estimators:  300 lr:  0.05 subsample:  1 min_child_weight:  1
# MAE intensity:  114.35
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.31 90.2 11.99
# max_depth:  7 n_estimators:  300 lr:  0.05 subsample:  1 min_child_weight:  3
# MAE intensity:  114.31
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.36 90.27 12.16
# max_depth:  7 n_estimators:  300 lr:  0.05 subsample:  1 min_child_weight:  5
# MAE intensity:  114.36
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.67 90.6 12.14
# max_depth:  8 n_estimators:  150 lr:  0.1 subsample:  0.8 min_child_weight:  1
# MAE intensity:  114.67
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.72 90.57 12.27
# max_depth:  8 n_estimators:  150 lr:  0.1 subsample:  0.8 min_child_weight:  3
# MAE intensity:  114.72
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.71 90.64 12.2
# max_depth:  8 n_estimators:  150 lr:  0.1 subsample:  0.8 min_child_weight:  5
# MAE intensity:  114.71
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.74 90.61 12.22
# max_depth:  8 n_estimators:  150 lr:  0.1 subsample:  0.9 min_child_weight:  1
# MAE intensity:  114.74
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.47 90.68 12.35
# max_depth:  8 n_estimators:  150 lr:  0.1 subsample:  0.9 min_child_weight:  3
# MAE intensity:  114.47
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.7 90.8 12.25
# max_depth:  8 n_estimators:  150 lr:  0.1 subsample:  0.9 min_child_weight:  5
# MAE intensity:  114.7
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.74 90.83 12.39
# max_depth:  8 n_estimators:  150 lr:  0.1 subsample:  1 min_child_weight:  1
# MAE intensity:  114.74
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.65 90.69 12.32
# max_depth:  8 n_estimators:  150 lr:  0.1 subsample:  1 min_child_weight:  3
# MAE intensity:  114.65
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.76 90.51 12.43
# max_depth:  8 n_estimators:  150 lr:  0.1 subsample:  1 min_child_weight:  5
# MAE intensity:  114.76
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.43 90.51 11.94
# max_depth:  8 n_estimators:  150 lr:  0.07 subsample:  0.8 min_child_weight:  1
# MAE intensity:  114.43
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.36 90.65 12.16
# max_depth:  8 n_estimators:  150 lr:  0.07 subsample:  0.8 min_child_weight:  3
# MAE intensity:  114.36
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.41 90.45 12.08
# max_depth:  8 n_estimators:  150 lr:  0.07 subsample:  0.8 min_child_weight:  5
# MAE intensity:  114.41
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.39 90.51 12.11
# max_depth:  8 n_estimators:  150 lr:  0.07 subsample:  0.9 min_child_weight:  1
# MAE intensity:  114.39
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.39 90.55 12.13
# max_depth:  8 n_estimators:  150 lr:  0.07 subsample:  0.9 min_child_weight:  3
# MAE intensity:  114.39
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.42 90.33 12.35
# max_depth:  8 n_estimators:  150 lr:  0.07 subsample:  0.9 min_child_weight:  5
# MAE intensity:  114.42
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.53 90.44 12.2
# max_depth:  8 n_estimators:  150 lr:  0.07 subsample:  1 min_child_weight:  1
# MAE intensity:  114.53
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.43 90.42 12.2
# max_depth:  8 n_estimators:  150 lr:  0.07 subsample:  1 min_child_weight:  3
# MAE intensity:  114.43
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.47 90.38 12.12
# max_depth:  8 n_estimators:  150 lr:  0.07 subsample:  1 min_child_weight:  5
# MAE intensity:  114.47
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.35 90.31 12.02
# max_depth:  8 n_estimators:  150 lr:  0.05 subsample:  0.8 min_child_weight:  1
# MAE intensity:  114.35
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.33 90.33 12.2
# max_depth:  8 n_estimators:  150 lr:  0.05 subsample:  0.8 min_child_weight:  3
# MAE intensity:  114.33
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.22 90.32 12.13
# max_depth:  8 n_estimators:  150 lr:  0.05 subsample:  0.8 min_child_weight:  5
# MAE intensity:  114.22
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.45 90.51 12.17
# max_depth:  8 n_estimators:  150 lr:  0.05 subsample:  0.9 min_child_weight:  1
# MAE intensity:  114.45
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.36 90.35 12.16
# max_depth:  8 n_estimators:  150 lr:  0.05 subsample:  0.9 min_child_weight:  3
# MAE intensity:  114.36
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.37 90.33 12.12
# max_depth:  8 n_estimators:  150 lr:  0.05 subsample:  0.9 min_child_weight:  5
# MAE intensity:  114.37
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.51 90.5 12.29
# max_depth:  8 n_estimators:  150 lr:  0.05 subsample:  1 min_child_weight:  1
# MAE intensity:  114.51
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.44 90.65 12.27
# max_depth:  8 n_estimators:  150 lr:  0.05 subsample:  1 min_child_weight:  3
# MAE intensity:  114.44
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.4 90.74 12.25
# max_depth:  8 n_estimators:  150 lr:  0.05 subsample:  1 min_child_weight:  5
# MAE intensity:  114.4
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.77 90.52 12.18
# max_depth:  8 n_estimators:  200 lr:  0.1 subsample:  0.8 min_child_weight:  1
# MAE intensity:  114.77
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.81 90.63 12.36
# max_depth:  8 n_estimators:  200 lr:  0.1 subsample:  0.8 min_child_weight:  3
# MAE intensity:  114.81
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.82 90.65 12.1
# max_depth:  8 n_estimators:  200 lr:  0.1 subsample:  0.8 min_child_weight:  5
# MAE intensity:  114.82
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.8 90.61 12.15
# max_depth:  8 n_estimators:  200 lr:  0.1 subsample:  0.9 min_child_weight:  1
# MAE intensity:  114.8
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.54 90.77 12.33
# max_depth:  8 n_estimators:  200 lr:  0.1 subsample:  0.9 min_child_weight:  3
# MAE intensity:  114.54
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.83 90.81 12.35
# max_depth:  8 n_estimators:  200 lr:  0.1 subsample:  0.9 min_child_weight:  5
# MAE intensity:  114.83
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.82 90.87 12.43
# max_depth:  8 n_estimators:  200 lr:  0.1 subsample:  1 min_child_weight:  1
# MAE intensity:  114.82
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.75 90.67 12.36
# max_depth:  8 n_estimators:  200 lr:  0.1 subsample:  1 min_child_weight:  3
# MAE intensity:  114.75
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.9 90.64 12.43
# max_depth:  8 n_estimators:  200 lr:  0.1 subsample:  1 min_child_weight:  5
# MAE intensity:  114.9
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.38 90.43 11.99
# max_depth:  8 n_estimators:  200 lr:  0.07 subsample:  0.8 min_child_weight:  1
# MAE intensity:  114.38
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.35 90.65 12.17
# max_depth:  8 n_estimators:  200 lr:  0.07 subsample:  0.8 min_child_weight:  3
# MAE intensity:  114.35
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.42 90.4 12.02
# max_depth:  8 n_estimators:  200 lr:  0.07 subsample:  0.8 min_child_weight:  5
# MAE intensity:  114.42
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.43 90.57 12.19
# max_depth:  8 n_estimators:  200 lr:  0.07 subsample:  0.9 min_child_weight:  1
# MAE intensity:  114.43
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.39 90.51 12.22
# max_depth:  8 n_estimators:  200 lr:  0.07 subsample:  0.9 min_child_weight:  3
# MAE intensity:  114.39
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.46 90.29 12.31
# max_depth:  8 n_estimators:  200 lr:  0.07 subsample:  0.9 min_child_weight:  5
# MAE intensity:  114.46
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.53 90.46 12.2
# max_depth:  8 n_estimators:  200 lr:  0.07 subsample:  1 min_child_weight:  1
# MAE intensity:  114.53
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.47 90.43 12.28
# max_depth:  8 n_estimators:  200 lr:  0.07 subsample:  1 min_child_weight:  3
# MAE intensity:  114.47
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.46 90.39 12.09
# max_depth:  8 n_estimators:  200 lr:  0.07 subsample:  1 min_child_weight:  5
# MAE intensity:  114.46
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.32 90.3 12.06
# max_depth:  8 n_estimators:  200 lr:  0.05 subsample:  0.8 min_child_weight:  1
# MAE intensity:  114.32
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.28 90.32 12.21
# max_depth:  8 n_estimators:  200 lr:  0.05 subsample:  0.8 min_child_weight:  3
# MAE intensity:  114.28
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.17 90.28 12.12
# max_depth:  8 n_estimators:  200 lr:  0.05 subsample:  0.8 min_child_weight:  5
# MAE intensity:  114.17
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.4 90.5 12.21
# max_depth:  8 n_estimators:  200 lr:  0.05 subsample:  0.9 min_child_weight:  1
# MAE intensity:  114.4
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.33 90.35 12.15
# max_depth:  8 n_estimators:  200 lr:  0.05 subsample:  0.9 min_child_weight:  3
# MAE intensity:  114.33
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.32 90.35 12.11
# max_depth:  8 n_estimators:  200 lr:  0.05 subsample:  0.9 min_child_weight:  5
# MAE intensity:  114.32
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.46 90.58 12.26
# max_depth:  8 n_estimators:  200 lr:  0.05 subsample:  1 min_child_weight:  1
# MAE intensity:  114.46
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.42 90.61 12.25
# max_depth:  8 n_estimators:  200 lr:  0.05 subsample:  1 min_child_weight:  3
# MAE intensity:  114.42
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.38 90.71 12.27
# max_depth:  8 n_estimators:  200 lr:  0.05 subsample:  1 min_child_weight:  5
# MAE intensity:  114.38
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.04 90.6 12.21
# max_depth:  8 n_estimators:  300 lr:  0.1 subsample:  0.8 min_child_weight:  1
# MAE intensity:  115.04
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.92 90.65 12.38
# max_depth:  8 n_estimators:  300 lr:  0.1 subsample:  0.8 min_child_weight:  3
# MAE intensity:  114.92
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.05 90.79 12.28
# max_depth:  8 n_estimators:  300 lr:  0.1 subsample:  0.8 min_child_weight:  5
# MAE intensity:  115.05
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.08 90.71 12.27
# max_depth:  8 n_estimators:  300 lr:  0.1 subsample:  0.9 min_child_weight:  1
# MAE intensity:  115.08
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.73 90.95 12.41
# max_depth:  8 n_estimators:  300 lr:  0.1 subsample:  0.9 min_child_weight:  3
# MAE intensity:  114.73
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.06 90.88 12.33
# max_depth:  8 n_estimators:  300 lr:  0.1 subsample:  0.9 min_child_weight:  5
# MAE intensity:  115.06
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.99 90.87 12.38
# max_depth:  8 n_estimators:  300 lr:  0.1 subsample:  1 min_child_weight:  1
# MAE intensity:  114.99
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.01 90.67 12.43
# max_depth:  8 n_estimators:  300 lr:  0.1 subsample:  1 min_child_weight:  3
# MAE intensity:  115.01
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.17 90.76 12.41
# max_depth:  8 n_estimators:  300 lr:  0.1 subsample:  1 min_child_weight:  5
# MAE intensity:  115.17
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.58 90.51 11.93
# max_depth:  8 n_estimators:  300 lr:  0.07 subsample:  0.8 min_child_weight:  1
# MAE intensity:  114.58
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.44 90.67 12.18
# max_depth:  8 n_estimators:  300 lr:  0.07 subsample:  0.8 min_child_weight:  3
# MAE intensity:  114.44
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.56 90.5 12.1
# max_depth:  8 n_estimators:  300 lr:  0.07 subsample:  0.8 min_child_weight:  5
# MAE intensity:  114.56
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.49 90.58 12.16
# max_depth:  8 n_estimators:  300 lr:  0.07 subsample:  0.9 min_child_weight:  1
# MAE intensity:  114.49
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.51 90.55 12.18
# max_depth:  8 n_estimators:  300 lr:  0.07 subsample:  0.9 min_child_weight:  3
# MAE intensity:  114.51
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.58 90.34 12.38
# max_depth:  8 n_estimators:  300 lr:  0.07 subsample:  0.9 min_child_weight:  5
# MAE intensity:  114.58
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.6 90.44 12.16
# max_depth:  8 n_estimators:  300 lr:  0.07 subsample:  1 min_child_weight:  1
# MAE intensity:  114.6
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.58 90.44 12.32
# max_depth:  8 n_estimators:  300 lr:  0.07 subsample:  1 min_child_weight:  3
# MAE intensity:  114.58
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.5 90.37 12.17
# max_depth:  8 n_estimators:  300 lr:  0.07 subsample:  1 min_child_weight:  5
# MAE intensity:  114.5

# %%
#NA
d_gru_only_NA, d_boxplot_gru_only_NA = train_xgb_track_all_years_REVISION(X_train_, np.array(X_test_embed_gru), tgt_displacement_train, max_depth = best_depth, n_estimators = best_est, learning_rate = best_lr, subsample = best_subs, min_child_weight=best_min_child, basin = 'AN')
# Out:
# Number of timesteps: 899
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.23 83.86 13.35
# SHIP 77.46 60.88 3.56
# HWRF 74.98 49.1 2.56
# OFCL 71.24 55.52 2.78
# FSSE 68.92 52.56 3.56
# AEMN 73.2 54.98 2.34
# GFSO 70.55 54.27 3.34
# CLP5 201.24 149.25 37.15
# Consensus OFCL only 63.81 47.82 2.11
# Consensus OFCL + Hurricast 61.5 43.37 1.0
# Number of timesteps: 899
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.13 83.21 12.79
# SHIP 77.46 60.88 3.56
# HWRF 74.98 49.1 2.56
# OFCL 71.24 55.52 2.78
# FSSE 68.92 52.56 3.56
# AEMN 73.2 54.98 2.34
# GFSO 70.55 54.27 3.34
# CLP5 201.24 149.25 37.15
# Consensus OFCL only 63.81 47.82 2.11
# Consensus OFCL + Hurricast 61.52 43.33 1.0

# %%
#NA
d_gru_only_EP, d_boxplot_gru_only_EP = train_xgb_track_all_years_REVISION(X_train_, np.array(X_test_embed_gru), tgt_displacement_train, max_depth = best_depth, n_estimators = best_est, learning_rate = best_lr, subsample = best_subs, min_child_weight=best_min_child, basin = 'EP')
# Out:
# Number of timesteps: 837
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 73.09 43.17 1.08
# SHIP 57.81 34.06 0.36
# HWRF 66.98 42.24 2.03
# OFCL 54.1 32.59 0.12
# FSSE 55.83 47.39 0.72
# AEMN 59.9 37.34 0.6
# GFSO 64.56 44.99 1.55
# CLP5 120.92 66.79 12.31
# Consensus OFCL only 55.07 36.57 0.72
# Consensus OFCL + Hurricast 50.43 31.91 0.24
# Number of timesteps: 837
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 72.55 42.68 0.96
# SHIP 57.81 34.06 0.36
# HWRF 66.98 42.24 2.03
# OFCL 54.1 32.59 0.12
# FSSE 55.83 47.39 0.72
# AEMN 59.9 37.34 0.6
# GFSO 64.56 44.99 1.55
# CLP5 120.92 66.79 12.31
# Consensus OFCL only 55.07 36.57 0.72
# Consensus OFCL + Hurricast 50.32 31.85 0.24

# %%
#NA
d_gru_only_EP, d_boxplot_gru_only_EP = train_xgb_track_all_years_REVISION(X_train_, np.array(X_test_embed_gru), tgt_displacement_train, max_depth = best_depth, n_estimators = best_est, learning_rate = best_lr, subsample = best_subs, min_child_weight=best_min_child, basin = 'EP')
# Out:
# Number of timesteps: 877
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 74.75 45.37 1.71
# SHIP 58.75 35.34 0.57
# HWRF 67.84 42.64 1.94
# OFCL 54.69 33.24 0.11
# FSSE 56.15 47.18 0.68
# AEMN 60.95 38.43 0.8
# GFSO 65.36 45.66 1.71
# CLP5 122.22 68.34 12.77
# Consensus OFCL only 52.63 33.83 0.23
# Consensus OFCL + Hurricast 49.82 31.51 0.11
# Number of timesteps: 877
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 74.28 44.84 1.71
# SHIP 58.75 35.34 0.57
# HWRF 67.84 42.64 1.94
# OFCL 54.69 33.24 0.11
# FSSE 56.15 47.18 0.68
# AEMN 60.95 38.43 0.8
# GFSO 65.36 45.66 1.71
# CLP5 122.22 68.34 12.77
# Consensus OFCL only 52.63 33.83 0.23
# Consensus OFCL + Hurricast 49.74 31.49 0.11

# %% [markdown]
# ## Transfo only

# %%
X_val = np.array(X_test_embed)[index]
X_train_ = np.array(X_train_embed)

# %%
validate_track(X_train_, tgt_displacement_train, X_val)
# Out:
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.01 91.45 12.47
# max_depth:  7 n_estimators:  150 lr:  0.1 subsample:  0.8 min_child_weight:  1
# MAE intensity:  115.01
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.11 91.32 12.58
# max_depth:  7 n_estimators:  150 lr:  0.1 subsample:  0.8 min_child_weight:  3
# MAE intensity:  115.11
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.09 91.73 12.43
# max_depth:  7 n_estimators:  150 lr:  0.1 subsample:  0.8 min_child_weight:  5
# MAE intensity:  115.09
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.05 91.3 12.56
# max_depth:  7 n_estimators:  150 lr:  0.1 subsample:  0.9 min_child_weight:  1
# MAE intensity:  115.05
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.03 91.42 12.59
# max_depth:  7 n_estimators:  150 lr:  0.1 subsample:  0.9 min_child_weight:  3
# MAE intensity:  115.03
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.01 90.79 12.72
# max_depth:  7 n_estimators:  150 lr:  0.1 subsample:  0.9 min_child_weight:  5
# MAE intensity:  115.01
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.99 91.41 12.35
# max_depth:  7 n_estimators:  150 lr:  0.1 subsample:  1 min_child_weight:  1
# MAE intensity:  114.99
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.15 91.1 12.3
# max_depth:  7 n_estimators:  150 lr:  0.1 subsample:  1 min_child_weight:  3
# MAE intensity:  115.15
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.12 91.13 12.35
# max_depth:  7 n_estimators:  150 lr:  0.1 subsample:  1 min_child_weight:  5
# MAE intensity:  115.12
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.77 91.09 12.44
# max_depth:  7 n_estimators:  150 lr:  0.07 subsample:  0.8 min_child_weight:  1
# MAE intensity:  114.77
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.76 91.06 12.44
# max_depth:  7 n_estimators:  150 lr:  0.07 subsample:  0.8 min_child_weight:  3
# MAE intensity:  114.76
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.56 90.59 12.32
# max_depth:  7 n_estimators:  150 lr:  0.07 subsample:  0.8 min_child_weight:  5
# MAE intensity:  114.56
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.69 90.88 12.42
# max_depth:  7 n_estimators:  150 lr:  0.07 subsample:  0.9 min_child_weight:  1
# MAE intensity:  114.69
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.76 90.97 12.52
# max_depth:  7 n_estimators:  150 lr:  0.07 subsample:  0.9 min_child_weight:  3
# MAE intensity:  114.76
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.7 90.77 12.45
# max_depth:  7 n_estimators:  150 lr:  0.07 subsample:  0.9 min_child_weight:  5
# MAE intensity:  114.7
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.67 90.99 12.3
# max_depth:  7 n_estimators:  150 lr:  0.07 subsample:  1 min_child_weight:  1
# MAE intensity:  114.67
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.63 90.59 12.38
# max_depth:  7 n_estimators:  150 lr:  0.07 subsample:  1 min_child_weight:  3
# MAE intensity:  114.63
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.61 90.82 12.41
# max_depth:  7 n_estimators:  150 lr:  0.07 subsample:  1 min_child_weight:  5
# MAE intensity:  114.61
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.59 90.68 12.38
# max_depth:  7 n_estimators:  150 lr:  0.05 subsample:  0.8 min_child_weight:  1
# MAE intensity:  114.59
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.4 90.48 12.29
# max_depth:  7 n_estimators:  150 lr:  0.05 subsample:  0.8 min_child_weight:  3
# MAE intensity:  114.4
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.62 90.77 12.49
# max_depth:  7 n_estimators:  150 lr:  0.05 subsample:  0.8 min_child_weight:  5
# MAE intensity:  114.62
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.53 90.66 12.31
# max_depth:  7 n_estimators:  150 lr:  0.05 subsample:  0.9 min_child_weight:  1
# MAE intensity:  114.53
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.8 90.68 12.33
# max_depth:  7 n_estimators:  150 lr:  0.05 subsample:  0.9 min_child_weight:  3
# MAE intensity:  114.8
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.42 90.36 12.4
# max_depth:  7 n_estimators:  150 lr:  0.05 subsample:  0.9 min_child_weight:  5
# MAE intensity:  114.42
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.67 90.53 12.49
# max_depth:  7 n_estimators:  150 lr:  0.05 subsample:  1 min_child_weight:  1
# MAE intensity:  114.67
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.63 90.47 12.46
# max_depth:  7 n_estimators:  150 lr:  0.05 subsample:  1 min_child_weight:  3
# MAE intensity:  114.63
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.64 90.54 12.37
# max_depth:  7 n_estimators:  150 lr:  0.05 subsample:  1 min_child_weight:  5
# MAE intensity:  114.64
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.19 91.61 12.54
# max_depth:  7 n_estimators:  200 lr:  0.1 subsample:  0.8 min_child_weight:  1
# MAE intensity:  115.19
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.26 91.59 12.54
# max_depth:  7 n_estimators:  200 lr:  0.1 subsample:  0.8 min_child_weight:  3
# MAE intensity:  115.26
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.23 91.88 12.58
# max_depth:  7 n_estimators:  200 lr:  0.1 subsample:  0.8 min_child_weight:  5
# MAE intensity:  115.23
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.1 91.33 12.7
# max_depth:  7 n_estimators:  200 lr:  0.1 subsample:  0.9 min_child_weight:  1
# MAE intensity:  115.1
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.14 91.47 12.58
# max_depth:  7 n_estimators:  200 lr:  0.1 subsample:  0.9 min_child_weight:  3
# MAE intensity:  115.14
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.25 91.05 12.69
# max_depth:  7 n_estimators:  200 lr:  0.1 subsample:  0.9 min_child_weight:  5
# MAE intensity:  115.25
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.18 91.51 12.42
# max_depth:  7 n_estimators:  200 lr:  0.1 subsample:  1 min_child_weight:  1
# MAE intensity:  115.18
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.27 91.08 12.4
# max_depth:  7 n_estimators:  200 lr:  0.1 subsample:  1 min_child_weight:  3
# MAE intensity:  115.27
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.39 91.27 12.35
# max_depth:  7 n_estimators:  200 lr:  0.1 subsample:  1 min_child_weight:  5
# MAE intensity:  115.39
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.86 91.25 12.45
# max_depth:  7 n_estimators:  200 lr:  0.07 subsample:  0.8 min_child_weight:  1
# MAE intensity:  114.86
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.78 91.18 12.31
# max_depth:  7 n_estimators:  200 lr:  0.07 subsample:  0.8 min_child_weight:  3
# MAE intensity:  114.78
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.56 90.81 12.24
# max_depth:  7 n_estimators:  200 lr:  0.07 subsample:  0.8 min_child_weight:  5
# MAE intensity:  114.56
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.71 90.94 12.41
# max_depth:  7 n_estimators:  200 lr:  0.07 subsample:  0.9 min_child_weight:  1
# MAE intensity:  114.71
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.7 91.09 12.43
# max_depth:  7 n_estimators:  200 lr:  0.07 subsample:  0.9 min_child_weight:  3
# MAE intensity:  114.7
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.68 90.93 12.46
# max_depth:  7 n_estimators:  200 lr:  0.07 subsample:  0.9 min_child_weight:  5
# MAE intensity:  114.68
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.7 91.06 12.46
# max_depth:  7 n_estimators:  200 lr:  0.07 subsample:  1 min_child_weight:  1
# MAE intensity:  114.7
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.6 90.63 12.41
# max_depth:  7 n_estimators:  200 lr:  0.07 subsample:  1 min_child_weight:  3
# MAE intensity:  114.6
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.71 90.94 12.43
# max_depth:  7 n_estimators:  200 lr:  0.07 subsample:  1 min_child_weight:  5
# MAE intensity:  114.71
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.56 90.91 12.38
# max_depth:  7 n_estimators:  200 lr:  0.05 subsample:  0.8 min_child_weight:  1
# MAE intensity:  114.56
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.34 90.62 12.36
# max_depth:  7 n_estimators:  200 lr:  0.05 subsample:  0.8 min_child_weight:  3
# MAE intensity:  114.34
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.61 90.97 12.38
# max_depth:  7 n_estimators:  200 lr:  0.05 subsample:  0.8 min_child_weight:  5
# MAE intensity:  114.61
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.46 90.7 12.28
# max_depth:  7 n_estimators:  200 lr:  0.05 subsample:  0.9 min_child_weight:  1
# MAE intensity:  114.46
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.79 90.75 12.22
# max_depth:  7 n_estimators:  200 lr:  0.05 subsample:  0.9 min_child_weight:  3
# MAE intensity:  114.79
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.41 90.45 12.31
# max_depth:  7 n_estimators:  200 lr:  0.05 subsample:  0.9 min_child_weight:  5
# MAE intensity:  114.41
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.6 90.6 12.43
# max_depth:  7 n_estimators:  200 lr:  0.05 subsample:  1 min_child_weight:  1
# MAE intensity:  114.6
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.6 90.66 12.53
# max_depth:  7 n_estimators:  200 lr:  0.05 subsample:  1 min_child_weight:  3
# MAE intensity:  114.6
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.6 90.66 12.33
# max_depth:  7 n_estimators:  200 lr:  0.05 subsample:  1 min_child_weight:  5
# MAE intensity:  114.6
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.46 91.77 12.48
# max_depth:  7 n_estimators:  300 lr:  0.1 subsample:  0.8 min_child_weight:  1
# MAE intensity:  115.46
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.65 91.87 12.64
# max_depth:  7 n_estimators:  300 lr:  0.1 subsample:  0.8 min_child_weight:  3
# MAE intensity:  115.65
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.55 92.08 12.63
# max_depth:  7 n_estimators:  300 lr:  0.1 subsample:  0.8 min_child_weight:  5
# MAE intensity:  115.55
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.5 91.62 12.88
# max_depth:  7 n_estimators:  300 lr:  0.1 subsample:  0.9 min_child_weight:  1
# MAE intensity:  115.5
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.59 91.66 12.71
# max_depth:  7 n_estimators:  300 lr:  0.1 subsample:  0.9 min_child_weight:  3
# MAE intensity:  115.59
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.54 91.15 12.67
# max_depth:  7 n_estimators:  300 lr:  0.1 subsample:  0.9 min_child_weight:  5
# MAE intensity:  115.54
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.67 91.64 12.57
# max_depth:  7 n_estimators:  300 lr:  0.1 subsample:  1 min_child_weight:  1
# MAE intensity:  115.67
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.74 91.16 12.62
# max_depth:  7 n_estimators:  300 lr:  0.1 subsample:  1 min_child_weight:  3
# MAE intensity:  115.74
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.75 91.48 12.64
# max_depth:  7 n_estimators:  300 lr:  0.1 subsample:  1 min_child_weight:  5
# MAE intensity:  115.75
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.0 91.36 12.53
# max_depth:  7 n_estimators:  300 lr:  0.07 subsample:  0.8 min_child_weight:  1
# MAE intensity:  115.0
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.93 91.36 12.53
# max_depth:  7 n_estimators:  300 lr:  0.07 subsample:  0.8 min_child_weight:  3
# MAE intensity:  114.93
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.7 90.84 12.33
# max_depth:  7 n_estimators:  300 lr:  0.07 subsample:  0.8 min_child_weight:  5
# MAE intensity:  114.7
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.8 91.07 12.45
# max_depth:  7 n_estimators:  300 lr:  0.07 subsample:  0.9 min_child_weight:  1
# MAE intensity:  114.8
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.79 91.09 12.49
# max_depth:  7 n_estimators:  300 lr:  0.07 subsample:  0.9 min_child_weight:  3
# MAE intensity:  114.79
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.86 91.1 12.4
# max_depth:  7 n_estimators:  300 lr:  0.07 subsample:  0.9 min_child_weight:  5
# MAE intensity:  114.86
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.93 91.13 12.5
# max_depth:  7 n_estimators:  300 lr:  0.07 subsample:  1 min_child_weight:  1
# MAE intensity:  114.93
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.78 90.82 12.5
# max_depth:  7 n_estimators:  300 lr:  0.07 subsample:  1 min_child_weight:  3
# MAE intensity:  114.78
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.96 91.06 12.58
# max_depth:  7 n_estimators:  300 lr:  0.07 subsample:  1 min_child_weight:  5
# MAE intensity:  114.96
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.48 90.93 12.27
# max_depth:  7 n_estimators:  300 lr:  0.05 subsample:  0.8 min_child_weight:  1
# MAE intensity:  114.48
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.39 90.78 12.24
# max_depth:  7 n_estimators:  300 lr:  0.05 subsample:  0.8 min_child_weight:  3
# MAE intensity:  114.39
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.6 91.08 12.3
# max_depth:  7 n_estimators:  300 lr:  0.05 subsample:  0.8 min_child_weight:  5
# MAE intensity:  114.6
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.53 90.9 12.22
# max_depth:  7 n_estimators:  300 lr:  0.05 subsample:  0.9 min_child_weight:  1
# MAE intensity:  114.53
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.87 90.93 12.25
# max_depth:  7 n_estimators:  300 lr:  0.05 subsample:  0.9 min_child_weight:  3
# MAE intensity:  114.87
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.39 90.59 12.31
# max_depth:  7 n_estimators:  300 lr:  0.05 subsample:  0.9 min_child_weight:  5
# MAE intensity:  114.39
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.64 90.58 12.42
# max_depth:  7 n_estimators:  300 lr:  0.05 subsample:  1 min_child_weight:  1
# MAE intensity:  114.64
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.64 90.81 12.46
# max_depth:  7 n_estimators:  300 lr:  0.05 subsample:  1 min_child_weight:  3
# MAE intensity:  114.64
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.64 90.79 12.36
# max_depth:  7 n_estimators:  300 lr:  0.05 subsample:  1 min_child_weight:  5
# MAE intensity:  114.64
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.3 91.58 12.29
# max_depth:  8 n_estimators:  150 lr:  0.1 subsample:  0.8 min_child_weight:  1
# MAE intensity:  115.3
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.16 91.33 12.45
# max_depth:  8 n_estimators:  150 lr:  0.1 subsample:  0.8 min_child_weight:  3
# MAE intensity:  115.16
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.27 91.53 12.56
# max_depth:  8 n_estimators:  150 lr:  0.1 subsample:  0.8 min_child_weight:  5
# MAE intensity:  115.27
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.39 91.43 12.7
# max_depth:  8 n_estimators:  150 lr:  0.1 subsample:  0.9 min_child_weight:  1
# MAE intensity:  115.39
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.47 91.34 12.72
# max_depth:  8 n_estimators:  150 lr:  0.1 subsample:  0.9 min_child_weight:  3
# MAE intensity:  115.47
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.3 91.3 12.61
# max_depth:  8 n_estimators:  150 lr:  0.1 subsample:  0.9 min_child_weight:  5
# MAE intensity:  115.3
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.33 90.94 12.66
# max_depth:  8 n_estimators:  150 lr:  0.1 subsample:  1 min_child_weight:  1
# MAE intensity:  115.33
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.41 91.37 12.44
# max_depth:  8 n_estimators:  150 lr:  0.1 subsample:  1 min_child_weight:  3
# MAE intensity:  115.41
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.64 91.29 12.72
# max_depth:  8 n_estimators:  150 lr:  0.1 subsample:  1 min_child_weight:  5
# MAE intensity:  115.64
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.74 91.16 12.6
# max_depth:  8 n_estimators:  150 lr:  0.07 subsample:  0.8 min_child_weight:  1
# MAE intensity:  114.74
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.54 90.83 12.39
# max_depth:  8 n_estimators:  150 lr:  0.07 subsample:  0.8 min_child_weight:  3
# MAE intensity:  114.54
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.62 90.71 12.31
# max_depth:  8 n_estimators:  150 lr:  0.07 subsample:  0.8 min_child_weight:  5
# MAE intensity:  114.62
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.89 91.17 12.42
# max_depth:  8 n_estimators:  150 lr:  0.07 subsample:  0.9 min_child_weight:  1
# MAE intensity:  114.89
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.98 91.16 12.48
# max_depth:  8 n_estimators:  150 lr:  0.07 subsample:  0.9 min_child_weight:  3
# MAE intensity:  114.98
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.89 90.94 12.42
# max_depth:  8 n_estimators:  150 lr:  0.07 subsample:  0.9 min_child_weight:  5
# MAE intensity:  114.89
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.13 90.94 12.59
# max_depth:  8 n_estimators:  150 lr:  0.07 subsample:  1 min_child_weight:  1
# MAE intensity:  115.13
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.92 91.01 12.45
# max_depth:  8 n_estimators:  150 lr:  0.07 subsample:  1 min_child_weight:  3
# MAE intensity:  114.92
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.1 91.14 12.65
# max_depth:  8 n_estimators:  150 lr:  0.07 subsample:  1 min_child_weight:  5
# MAE intensity:  115.1
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.6 90.69 12.43
# max_depth:  8 n_estimators:  150 lr:  0.05 subsample:  0.8 min_child_weight:  1
# MAE intensity:  114.6
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.71 90.94 12.54
# max_depth:  8 n_estimators:  150 lr:  0.05 subsample:  0.8 min_child_weight:  3
# MAE intensity:  114.71
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.68 90.77 12.53
# max_depth:  8 n_estimators:  150 lr:  0.05 subsample:  0.8 min_child_weight:  5
# MAE intensity:  114.68
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.57 90.83 12.35
# max_depth:  8 n_estimators:  150 lr:  0.05 subsample:  0.9 min_child_weight:  1
# MAE intensity:  114.57
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.67 90.88 12.4
# max_depth:  8 n_estimators:  150 lr:  0.05 subsample:  0.9 min_child_weight:  3
# MAE intensity:  114.67
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.71 90.85 12.41
# max_depth:  8 n_estimators:  150 lr:  0.05 subsample:  0.9 min_child_weight:  5
# MAE intensity:  114.71
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.7 90.71 12.5
# max_depth:  8 n_estimators:  150 lr:  0.05 subsample:  1 min_child_weight:  1
# MAE intensity:  114.7
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.75 90.68 12.48
# max_depth:  8 n_estimators:  150 lr:  0.05 subsample:  1 min_child_weight:  3
# MAE intensity:  114.75
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.84 90.97 12.44
# max_depth:  8 n_estimators:  150 lr:  0.05 subsample:  1 min_child_weight:  5
# MAE intensity:  114.84
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.49 91.73 12.39
# max_depth:  8 n_estimators:  200 lr:  0.1 subsample:  0.8 min_child_weight:  1
# MAE intensity:  115.49
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.46 91.45 12.56
# max_depth:  8 n_estimators:  200 lr:  0.1 subsample:  0.8 min_child_weight:  3
# MAE intensity:  115.46
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.45 91.56 12.69
# max_depth:  8 n_estimators:  200 lr:  0.1 subsample:  0.8 min_child_weight:  5
# MAE intensity:  115.45
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.59 91.54 12.69
# max_depth:  8 n_estimators:  200 lr:  0.1 subsample:  0.9 min_child_weight:  1
# MAE intensity:  115.59
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.62 91.32 12.76
# max_depth:  8 n_estimators:  200 lr:  0.1 subsample:  0.9 min_child_weight:  3
# MAE intensity:  115.62
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.46 91.35 12.61
# max_depth:  8 n_estimators:  200 lr:  0.1 subsample:  0.9 min_child_weight:  5
# MAE intensity:  115.46
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.64 90.89 12.77
# max_depth:  8 n_estimators:  200 lr:  0.1 subsample:  1 min_child_weight:  1
# MAE intensity:  115.64
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.65 91.53 12.58
# max_depth:  8 n_estimators:  200 lr:  0.1 subsample:  1 min_child_weight:  3
# MAE intensity:  115.65
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.9 91.35 12.8
# max_depth:  8 n_estimators:  200 lr:  0.1 subsample:  1 min_child_weight:  5
# MAE intensity:  115.9
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.84 91.26 12.59
# max_depth:  8 n_estimators:  200 lr:  0.07 subsample:  0.8 min_child_weight:  1
# MAE intensity:  114.84
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.63 90.9 12.43
# max_depth:  8 n_estimators:  200 lr:  0.07 subsample:  0.8 min_child_weight:  3
# MAE intensity:  114.63
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.73 90.82 12.35
# max_depth:  8 n_estimators:  200 lr:  0.07 subsample:  0.8 min_child_weight:  5
# MAE intensity:  114.73
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.98 91.13 12.38
# max_depth:  8 n_estimators:  200 lr:  0.07 subsample:  0.9 min_child_weight:  1
# MAE intensity:  114.98
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.08 91.23 12.57
# max_depth:  8 n_estimators:  200 lr:  0.07 subsample:  0.9 min_child_weight:  3
# MAE intensity:  115.08
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.03 91.07 12.39
# max_depth:  8 n_estimators:  200 lr:  0.07 subsample:  0.9 min_child_weight:  5
# MAE intensity:  115.03
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.27 90.98 12.53
# max_depth:  8 n_estimators:  200 lr:  0.07 subsample:  1 min_child_weight:  1
# MAE intensity:  115.27
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.11 91.09 12.43
# max_depth:  8 n_estimators:  200 lr:  0.07 subsample:  1 min_child_weight:  3
# MAE intensity:  115.11
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.21 91.2 12.55
# max_depth:  8 n_estimators:  200 lr:  0.07 subsample:  1 min_child_weight:  5
# MAE intensity:  115.21
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.67 90.83 12.48
# max_depth:  8 n_estimators:  200 lr:  0.05 subsample:  0.8 min_child_weight:  1
# MAE intensity:  114.67
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.74 91.1 12.49
# max_depth:  8 n_estimators:  200 lr:  0.05 subsample:  0.8 min_child_weight:  3
# MAE intensity:  114.74
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.76 90.87 12.51
# max_depth:  8 n_estimators:  200 lr:  0.05 subsample:  0.8 min_child_weight:  5
# MAE intensity:  114.76
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.57 90.96 12.34
# max_depth:  8 n_estimators:  200 lr:  0.05 subsample:  0.9 min_child_weight:  1
# MAE intensity:  114.57
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.72 91.0 12.35
# max_depth:  8 n_estimators:  200 lr:  0.05 subsample:  0.9 min_child_weight:  3
# MAE intensity:  114.72
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.78 90.98 12.38
# max_depth:  8 n_estimators:  200 lr:  0.05 subsample:  0.9 min_child_weight:  5
# MAE intensity:  114.78
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.71 90.79 12.51
# max_depth:  8 n_estimators:  200 lr:  0.05 subsample:  1 min_child_weight:  1
# MAE intensity:  114.71
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.75 90.74 12.46
# max_depth:  8 n_estimators:  200 lr:  0.05 subsample:  1 min_child_weight:  3
# MAE intensity:  114.75
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.83 91.0 12.51
# max_depth:  8 n_estimators:  200 lr:  0.05 subsample:  1 min_child_weight:  5
# MAE intensity:  114.83
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 116.05 92.06 12.7
# max_depth:  8 n_estimators:  300 lr:  0.1 subsample:  0.8 min_child_weight:  1
# MAE intensity:  116.05
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 116.02 91.77 12.72
# max_depth:  8 n_estimators:  300 lr:  0.1 subsample:  0.8 min_child_weight:  3
# MAE intensity:  116.02
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.99 91.7 12.78
# max_depth:  8 n_estimators:  300 lr:  0.1 subsample:  0.8 min_child_weight:  5
# MAE intensity:  115.99
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 116.01 91.77 12.87
# max_depth:  8 n_estimators:  300 lr:  0.1 subsample:  0.9 min_child_weight:  1
# MAE intensity:  116.01
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 116.02 91.49 12.77
# max_depth:  8 n_estimators:  300 lr:  0.1 subsample:  0.9 min_child_weight:  3
# MAE intensity:  116.02
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 116.02 91.53 12.82
# max_depth:  8 n_estimators:  300 lr:  0.1 subsample:  0.9 min_child_weight:  5
# MAE intensity:  116.02
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 116.08 91.05 12.93
# max_depth:  8 n_estimators:  300 lr:  0.1 subsample:  1 min_child_weight:  1
# MAE intensity:  116.08
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 116.2 91.69 12.86
# max_depth:  8 n_estimators:  300 lr:  0.1 subsample:  1 min_child_weight:  3
# MAE intensity:  116.2
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 116.42 91.51 12.98
# max_depth:  8 n_estimators:  300 lr:  0.1 subsample:  1 min_child_weight:  5
# MAE intensity:  116.42
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.18 91.55 12.72
# max_depth:  8 n_estimators:  300 lr:  0.07 subsample:  0.8 min_child_weight:  1
# MAE intensity:  115.18
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.02 90.91 12.44
# max_depth:  8 n_estimators:  300 lr:  0.07 subsample:  0.8 min_child_weight:  3
# MAE intensity:  115.02
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.12 90.86 12.41
# max_depth:  8 n_estimators:  300 lr:  0.07 subsample:  0.8 min_child_weight:  5
# MAE intensity:  115.12
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.33 91.32 12.49
# max_depth:  8 n_estimators:  300 lr:  0.07 subsample:  0.9 min_child_weight:  1
# MAE intensity:  115.33
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.37 91.4 12.59
# max_depth:  8 n_estimators:  300 lr:  0.07 subsample:  0.9 min_child_weight:  3
# MAE intensity:  115.37
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.24 91.27 12.48
# max_depth:  8 n_estimators:  300 lr:  0.07 subsample:  0.9 min_child_weight:  5
# MAE intensity:  115.24
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.64 91.14 12.67
# max_depth:  8 n_estimators:  300 lr:  0.07 subsample:  1 min_child_weight:  1
# MAE intensity:  115.64
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.43 91.14 12.51
# max_depth:  8 n_estimators:  300 lr:  0.07 subsample:  1 min_child_weight:  3
# MAE intensity:  115.43
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 115.53 91.3 12.58
# max_depth:  8 n_estimators:  300 lr:  0.07 subsample:  1 min_child_weight:  5
# MAE intensity:  115.53
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.82 91.02 12.55
# max_depth:  8 n_estimators:  300 lr:  0.05 subsample:  0.8 min_child_weight:  1
# MAE intensity:  114.82
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.92 91.26 12.56
# max_depth:  8 n_estimators:  300 lr:  0.05 subsample:  0.8 min_child_weight:  3
# MAE intensity:  114.92
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.87 90.97 12.45
# max_depth:  8 n_estimators:  300 lr:  0.05 subsample:  0.8 min_child_weight:  5
# MAE intensity:  114.87
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.62 91.03 12.41
# max_depth:  8 n_estimators:  300 lr:  0.05 subsample:  0.9 min_child_weight:  1
# MAE intensity:  114.62
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.91 91.12 12.41
# max_depth:  8 n_estimators:  300 lr:  0.05 subsample:  0.9 min_child_weight:  3
# MAE intensity:  114.91
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.9 91.01 12.48
# max_depth:  8 n_estimators:  300 lr:  0.05 subsample:  0.9 min_child_weight:  5
# MAE intensity:  114.9
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.79 90.9 12.48
# max_depth:  8 n_estimators:  300 lr:  0.05 subsample:  1 min_child_weight:  1
# MAE intensity:  114.79
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.87 90.81 12.48
# max_depth:  8 n_estimators:  300 lr:  0.05 subsample:  1 min_child_weight:  3
# MAE intensity:  114.87
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.99 91.06 12.48
# max_depth:  8 n_estimators:  300 lr:  0.05 subsample:  1 min_child_weight:  5
# MAE intensity:  114.99
#
# #### BEST RESULTS ####
# best_depth =  7
# best_est =  200
# best_lr =  0.05
# best_subs =  0.8
# best_min_child =  3
# (7, 200, 0.05, 0.8, 3)

# %%
best_depth =  7 
best_est =  200 
best_lr =  0.05 
best_subs =  0.8 
best_min_child =  3

# %%
d_transfo_only_NA, d_boxplot_transfo_only_NA = train_xgb_track_all_years_REVISION(X_train_, np.array(X_test_embed), tgt_displacement_train, max_depth = best_depth, n_estimators = best_est, learning_rate = best_lr, subsample = best_subs, min_child_weight=best_min_child, basin = 'AN')
# Out:
# Number of timesteps: 899
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 110.43 73.07 10.12
# SHIP 77.46 60.88 3.56
# HWRF 74.98 49.1 2.56
# OFCL 71.24 55.52 2.78
# FSSE 68.92 52.56 3.56
# AEMN 73.2 54.98 2.34
# GFSO 70.55 54.27 3.34
# CLP5 201.24 149.25 37.15
# Consensus OFCL only 63.81 47.82 2.11
# Consensus OFCL + Hurricast 61.7 42.6 1.11
# Number of timesteps: 899
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 110.08 71.17 10.23
# SHIP 77.46 60.88 3.56
# HWRF 74.98 49.1 2.56
# OFCL 71.24 55.52 2.78
# FSSE 68.92 52.56 3.56
# AEMN 73.2 54.98 2.34
# GFSO 70.55 54.27 3.34
# CLP5 201.24 149.25 37.15
# Consensus OFCL only 63.81 47.82 2.11
# Consensus OFCL + Hurricast 61.65 42.54 1.11

# %%
d_transfo_only_EP, d_boxplot_transfo_only_EP = train_xgb_track_all_years_REVISION(X_train_, np.array(X_test_embed), tgt_displacement_train, max_depth = best_depth, n_estimators = best_est, learning_rate = best_lr, subsample = best_subs, min_child_weight=best_min_child, basin = 'EP')
# Out:
# Number of timesteps: 837
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 73.69 44.74 1.79
# SHIP 57.81 34.06 0.36
# HWRF 66.98 42.24 2.03
# OFCL 54.1 32.59 0.12
# FSSE 55.83 47.39 0.72
# AEMN 59.9 37.34 0.6
# GFSO 64.56 44.99 1.55
# CLP5 120.92 66.79 12.31
# Consensus OFCL only 55.07 36.57 0.72
# Consensus OFCL + Hurricast 49.97 32.36 0.24
# Number of timesteps: 837
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 73.37 43.94 1.43
# SHIP 57.81 34.06 0.36
# HWRF 66.98 42.24 2.03
# OFCL 54.1 32.59 0.12
# FSSE 55.83 47.39 0.72
# AEMN 59.9 37.34 0.6
# GFSO 64.56 44.99 1.55
# CLP5 120.92 66.79 12.31
# Consensus OFCL only 55.07 36.57 0.72
# Consensus OFCL + Hurricast 49.96 32.38 0.24

# %%
d_transfo_only_EP, d_boxplot_transfo_only_EP = train_xgb_track_all_years_REVISION(X_train_, np.array(X_test_embed), tgt_displacement_train, max_depth = best_depth, n_estimators = best_est, learning_rate = best_lr, subsample = best_subs, min_child_weight=best_min_child, basin = 'EP')
# Out:
# Number of timesteps: 877
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 75.17 46.84 2.28
# SHIP 58.75 35.34 0.57
# HWRF 67.84 42.64 1.94
# OFCL 54.69 33.24 0.11
# FSSE 56.15 47.18 0.68
# AEMN 60.95 38.43 0.8
# GFSO 65.36 45.66 1.71
# CLP5 122.22 68.34 12.77
# Consensus OFCL only 52.63 33.83 0.23
# Consensus OFCL + Hurricast 49.52 31.71 0.11
# Number of timesteps: 877
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 74.8 46.11 1.94
# SHIP 58.75 35.34 0.57
# HWRF 67.84 42.64 1.94
# OFCL 54.69 33.24 0.11
# FSSE 56.15 47.18 0.68
# AEMN 60.95 38.43 0.8
# GFSO 65.36 45.66 1.71
# CLP5 122.22 68.34 12.77
# Consensus OFCL only 52.63 33.83 0.23
# Consensus OFCL + Hurricast 49.5 31.69 0.11

# %% [markdown]
# ## Stat + transfo

# %%
X_val = np.array(X_test_total)[index]
X_train_ = np.array(X_train_total)

# %%
validate_track(X_train_, tgt_displacement_train, X_val)
# Out:
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.39 91.14 12.38
# max_depth:  7 n_estimators:  200 lr:  0.1 subsample:  0.8 min_child_weight:  1
# MAE intensity:  113.39
# BEST SCORE SO FAR
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.58 91.37 12.29
# max_depth:  7 n_estimators:  200 lr:  0.1 subsample:  0.8 min_child_weight:  3
# MAE intensity:  113.58
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.35 90.81 12.39
# max_depth:  7 n_estimators:  200 lr:  0.1 subsample:  0.9 min_child_weight:  1
# MAE intensity:  113.35
# BEST SCORE SO FAR
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.91 91.18 12.35
# max_depth:  7 n_estimators:  200 lr:  0.1 subsample:  0.9 min_child_weight:  3
# MAE intensity:  113.91
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.5 91.03 12.22
# max_depth:  7 n_estimators:  200 lr:  0.1 subsample:  1 min_child_weight:  1
# MAE intensity:  113.5
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.91 91.5 12.31
# max_depth:  7 n_estimators:  200 lr:  0.1 subsample:  1 min_child_weight:  3
# MAE intensity:  113.91
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.33 90.73 12.25
# max_depth:  7 n_estimators:  200 lr:  0.07 subsample:  0.8 min_child_weight:  1
# MAE intensity:  113.33
# BEST SCORE SO FAR
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.1 90.8 12.28
# max_depth:  7 n_estimators:  200 lr:  0.07 subsample:  0.8 min_child_weight:  3
# MAE intensity:  113.1
# BEST SCORE SO FAR
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.1 90.75 12.12
# max_depth:  7 n_estimators:  200 lr:  0.07 subsample:  0.9 min_child_weight:  1
# MAE intensity:  113.1
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.02 90.6 12.27
# max_depth:  7 n_estimators:  200 lr:  0.07 subsample:  0.9 min_child_weight:  3
# MAE intensity:  113.02
# BEST SCORE SO FAR
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.25 90.69 12.38
# max_depth:  7 n_estimators:  200 lr:  0.07 subsample:  1 min_child_weight:  1
# MAE intensity:  113.25
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.13 90.51 12.21
# max_depth:  7 n_estimators:  200 lr:  0.07 subsample:  1 min_child_weight:  3
# MAE intensity:  113.13
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.2 91.01 12.07
# max_depth:  7 n_estimators:  200 lr:  0.05 subsample:  0.8 min_child_weight:  1
# MAE intensity:  113.2
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.17 90.74 12.1
# max_depth:  7 n_estimators:  200 lr:  0.05 subsample:  0.8 min_child_weight:  3
# MAE intensity:  113.17
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.34 90.73 12.31
# max_depth:  7 n_estimators:  200 lr:  0.05 subsample:  0.9 min_child_weight:  1
# MAE intensity:  113.34
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.41 90.51 12.25
# max_depth:  7 n_estimators:  200 lr:  0.05 subsample:  0.9 min_child_weight:  3
# MAE intensity:  113.41
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.27 90.65 12.34
# max_depth:  7 n_estimators:  200 lr:  0.05 subsample:  1 min_child_weight:  1
# MAE intensity:  113.27
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.46 90.81 12.29
# max_depth:  7 n_estimators:  200 lr:  0.05 subsample:  1 min_child_weight:  3
# MAE intensity:  113.46
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.59 91.24 12.33
# max_depth:  7 n_estimators:  300 lr:  0.1 subsample:  0.8 min_child_weight:  1
# MAE intensity:  113.59
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.71 91.51 12.22
# max_depth:  7 n_estimators:  300 lr:  0.1 subsample:  0.8 min_child_weight:  3
# MAE intensity:  113.71
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.37 90.75 12.34
# max_depth:  7 n_estimators:  300 lr:  0.1 subsample:  0.9 min_child_weight:  1
# MAE intensity:  113.37
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.86 91.37 12.38
# max_depth:  7 n_estimators:  300 lr:  0.1 subsample:  0.9 min_child_weight:  3
# MAE intensity:  113.86
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.65 90.99 12.22
# max_depth:  7 n_estimators:  300 lr:  0.1 subsample:  1 min_child_weight:  1
# MAE intensity:  113.65
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.03 91.46 12.33
# max_depth:  7 n_estimators:  300 lr:  0.1 subsample:  1 min_child_weight:  3
# MAE intensity:  114.03
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.3 90.97 12.21
# max_depth:  7 n_estimators:  300 lr:  0.07 subsample:  0.8 min_child_weight:  1
# MAE intensity:  113.3
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.04 91.08 12.24
# max_depth:  7 n_estimators:  300 lr:  0.07 subsample:  0.8 min_child_weight:  3
# MAE intensity:  113.04
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 112.97 90.85 12.2
# max_depth:  7 n_estimators:  300 lr:  0.07 subsample:  0.9 min_child_weight:  1
# MAE intensity:  112.97
# BEST SCORE SO FAR
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.01 90.89 12.21
# max_depth:  7 n_estimators:  300 lr:  0.07 subsample:  0.9 min_child_weight:  3
# MAE intensity:  113.01
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.14 90.61 12.3
# max_depth:  7 n_estimators:  300 lr:  0.07 subsample:  1 min_child_weight:  1
# MAE intensity:  113.14
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.1 90.7 12.25
# max_depth:  7 n_estimators:  300 lr:  0.07 subsample:  1 min_child_weight:  3
# MAE intensity:  113.1
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 112.92 91.16 12.03
# max_depth:  7 n_estimators:  300 lr:  0.05 subsample:  0.8 min_child_weight:  1
# MAE intensity:  112.92
# BEST SCORE SO FAR
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 112.94 90.88 12.09
# max_depth:  7 n_estimators:  300 lr:  0.05 subsample:  0.8 min_child_weight:  3
# MAE intensity:  112.94
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.05 90.77 12.17
# max_depth:  7 n_estimators:  300 lr:  0.05 subsample:  0.9 min_child_weight:  1
# MAE intensity:  113.05
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.16 90.55 12.33
# max_depth:  7 n_estimators:  300 lr:  0.05 subsample:  0.9 min_child_weight:  3
# MAE intensity:  113.16
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.1 90.74 12.29
# max_depth:  7 n_estimators:  300 lr:  0.05 subsample:  1 min_child_weight:  1
# MAE intensity:  113.1
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.34 90.88 12.15
# max_depth:  7 n_estimators:  300 lr:  0.05 subsample:  1 min_child_weight:  3
# MAE intensity:  113.34
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.86 91.36 12.31
# max_depth:  8 n_estimators:  200 lr:  0.1 subsample:  0.8 min_child_weight:  1
# MAE intensity:  113.86
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.75 91.52 12.37
# max_depth:  8 n_estimators:  200 lr:  0.1 subsample:  0.8 min_child_weight:  3
# MAE intensity:  113.75
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.99 91.1 12.43
# max_depth:  8 n_estimators:  200 lr:  0.1 subsample:  0.9 min_child_weight:  1
# MAE intensity:  113.99
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.61 91.37 12.37
# max_depth:  8 n_estimators:  200 lr:  0.1 subsample:  0.9 min_child_weight:  3
# MAE intensity:  113.61
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.52 91.08 12.36
# max_depth:  8 n_estimators:  200 lr:  0.1 subsample:  1 min_child_weight:  1
# MAE intensity:  113.52
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.89 91.28 12.39
# max_depth:  8 n_estimators:  200 lr:  0.1 subsample:  1 min_child_weight:  3
# MAE intensity:  113.89
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.21 90.97 12.43
# max_depth:  8 n_estimators:  200 lr:  0.07 subsample:  0.8 min_child_weight:  1
# MAE intensity:  113.21
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.17 91.02 12.18
# max_depth:  8 n_estimators:  200 lr:  0.07 subsample:  0.8 min_child_weight:  3
# MAE intensity:  113.17
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.11 90.94 12.23
# max_depth:  8 n_estimators:  200 lr:  0.07 subsample:  0.9 min_child_weight:  1
# MAE intensity:  113.11
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.2 90.93 12.21
# max_depth:  8 n_estimators:  200 lr:  0.07 subsample:  0.9 min_child_weight:  3
# MAE intensity:  113.2
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.36 90.55 12.22
# max_depth:  8 n_estimators:  200 lr:  0.07 subsample:  1 min_child_weight:  1
# MAE intensity:  113.36
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.23 90.55 12.18
# max_depth:  8 n_estimators:  200 lr:  0.07 subsample:  1 min_child_weight:  3
# MAE intensity:  113.23
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.12 90.62 12.26
# max_depth:  8 n_estimators:  200 lr:  0.05 subsample:  0.8 min_child_weight:  1
# MAE intensity:  113.12
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.0 90.84 12.22
# max_depth:  8 n_estimators:  200 lr:  0.05 subsample:  0.8 min_child_weight:  3
# MAE intensity:  113.0
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.2 90.65 12.22
# max_depth:  8 n_estimators:  200 lr:  0.05 subsample:  0.9 min_child_weight:  1
# MAE intensity:  113.2
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.39 90.52 12.18
# max_depth:  8 n_estimators:  200 lr:  0.05 subsample:  0.9 min_child_weight:  3
# MAE intensity:  113.39
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.05 90.42 12.24
# max_depth:  8 n_estimators:  200 lr:  0.05 subsample:  1 min_child_weight:  1
# MAE intensity:  113.05
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.2 90.76 12.17
# max_depth:  8 n_estimators:  200 lr:  0.05 subsample:  1 min_child_weight:  3
# MAE intensity:  113.2
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.04 91.49 12.22
# max_depth:  8 n_estimators:  300 lr:  0.1 subsample:  0.8 min_child_weight:  1
# MAE intensity:  114.04
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.1 91.56 12.44
# max_depth:  8 n_estimators:  300 lr:  0.1 subsample:  0.8 min_child_weight:  3
# MAE intensity:  114.1
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.23 91.29 12.51
# max_depth:  8 n_estimators:  300 lr:  0.1 subsample:  0.9 min_child_weight:  1
# MAE intensity:  114.23
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.88 91.32 12.26
# max_depth:  8 n_estimators:  300 lr:  0.1 subsample:  0.9 min_child_weight:  3
# MAE intensity:  113.88
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.63 90.99 12.41
# max_depth:  8 n_estimators:  300 lr:  0.1 subsample:  1 min_child_weight:  1
# MAE intensity:  113.63
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.09 91.36 12.32
# max_depth:  8 n_estimators:  300 lr:  0.1 subsample:  1 min_child_weight:  3
# MAE intensity:  114.09
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.3 91.05 12.39
# max_depth:  8 n_estimators:  300 lr:  0.07 subsample:  0.8 min_child_weight:  1
# MAE intensity:  113.3
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.26 91.12 12.22
# max_depth:  8 n_estimators:  300 lr:  0.07 subsample:  0.8 min_child_weight:  3
# MAE intensity:  113.26
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.21 90.8 12.33
# max_depth:  8 n_estimators:  300 lr:  0.07 subsample:  0.9 min_child_weight:  1
# MAE intensity:  113.21
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.25 91.01 12.23
# max_depth:  8 n_estimators:  300 lr:  0.07 subsample:  0.9 min_child_weight:  3
# MAE intensity:  113.25
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.44 90.67 12.25
# max_depth:  8 n_estimators:  300 lr:  0.07 subsample:  1 min_child_weight:  1
# MAE intensity:  113.44
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.27 90.66 12.04
# max_depth:  8 n_estimators:  300 lr:  0.07 subsample:  1 min_child_weight:  3
# MAE intensity:  113.27
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 112.94 90.63 12.13
# max_depth:  8 n_estimators:  300 lr:  0.05 subsample:  0.8 min_child_weight:  1
# MAE intensity:  112.94
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 112.87 90.92 12.27
# max_depth:  8 n_estimators:  300 lr:  0.05 subsample:  0.8 min_child_weight:  3
# MAE intensity:  112.87
# BEST SCORE SO FAR
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.04 90.7 12.09
# max_depth:  8 n_estimators:  300 lr:  0.05 subsample:  0.9 min_child_weight:  1
# MAE intensity:  113.04
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.26 90.59 12.16
# max_depth:  8 n_estimators:  300 lr:  0.05 subsample:  0.9 min_child_weight:  3
# MAE intensity:  113.26
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 112.95 90.41 12.15
# max_depth:  8 n_estimators:  300 lr:  0.05 subsample:  1 min_child_weight:  1
# MAE intensity:  112.95
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 112.99 90.72 12.11
# max_depth:  8 n_estimators:  300 lr:  0.05 subsample:  1 min_child_weight:  3
# MAE intensity:  112.99
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.27 91.79 12.39
# max_depth:  9 n_estimators:  200 lr:  0.1 subsample:  0.8 min_child_weight:  1
# MAE intensity:  114.27
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.17 91.32 12.47
# max_depth:  9 n_estimators:  200 lr:  0.1 subsample:  0.8 min_child_weight:  3
# MAE intensity:  114.17
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.55 91.7 12.47
# max_depth:  9 n_estimators:  200 lr:  0.1 subsample:  0.9 min_child_weight:  1
# MAE intensity:  114.55
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.4 91.49 12.38
# max_depth:  9 n_estimators:  200 lr:  0.1 subsample:  0.9 min_child_weight:  3
# MAE intensity:  114.4
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.35 91.4 12.44
# max_depth:  9 n_estimators:  200 lr:  0.1 subsample:  1 min_child_weight:  1
# MAE intensity:  114.35
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.95 91.98 12.13
# max_depth:  9 n_estimators:  200 lr:  0.1 subsample:  1 min_child_weight:  3
# MAE intensity:  113.95
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.67 90.92 12.26
# max_depth:  9 n_estimators:  200 lr:  0.07 subsample:  0.8 min_child_weight:  1
# MAE intensity:  113.67
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.7 90.81 12.26
# max_depth:  9 n_estimators:  200 lr:  0.07 subsample:  0.8 min_child_weight:  3
# MAE intensity:  113.7
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.65 91.35 12.43
# max_depth:  9 n_estimators:  200 lr:  0.07 subsample:  0.9 min_child_weight:  1
# MAE intensity:  113.65
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.57 91.07 12.25
# max_depth:  9 n_estimators:  200 lr:  0.07 subsample:  0.9 min_child_weight:  3
# MAE intensity:  113.57
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.68 90.85 12.18
# max_depth:  9 n_estimators:  200 lr:  0.07 subsample:  1 min_child_weight:  1
# MAE intensity:  113.68
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.83 91.03 12.2
# max_depth:  9 n_estimators:  200 lr:  0.07 subsample:  1 min_child_weight:  3
# MAE intensity:  113.83
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.04 90.49 12.09
# max_depth:  9 n_estimators:  200 lr:  0.05 subsample:  0.8 min_child_weight:  1
# MAE intensity:  113.04
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.22 90.83 12.26
# max_depth:  9 n_estimators:  200 lr:  0.05 subsample:  0.8 min_child_weight:  3
# MAE intensity:  113.22
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.27 90.88 12.17
# max_depth:  9 n_estimators:  200 lr:  0.05 subsample:  0.9 min_child_weight:  1
# MAE intensity:  113.27
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.45 91.07 12.31
# max_depth:  9 n_estimators:  200 lr:  0.05 subsample:  0.9 min_child_weight:  3
# MAE intensity:  113.45
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.46 90.95 12.17
# max_depth:  9 n_estimators:  200 lr:  0.05 subsample:  1 min_child_weight:  1
# MAE intensity:  113.46
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.4 90.76 12.12
# max_depth:  9 n_estimators:  200 lr:  0.05 subsample:  1 min_child_weight:  3
# MAE intensity:  113.4
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.65 91.78 12.48
# max_depth:  9 n_estimators:  300 lr:  0.1 subsample:  0.8 min_child_weight:  1
# MAE intensity:  114.65
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.5 91.44 12.35
# max_depth:  9 n_estimators:  300 lr:  0.1 subsample:  0.8 min_child_weight:  3
# MAE intensity:  114.5
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.85 91.69 12.47
# max_depth:  9 n_estimators:  300 lr:  0.1 subsample:  0.9 min_child_weight:  1
# MAE intensity:  114.85
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.74 91.42 12.46
# max_depth:  9 n_estimators:  300 lr:  0.1 subsample:  0.9 min_child_weight:  3
# MAE intensity:  114.74
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.54 91.4 12.43
# max_depth:  9 n_estimators:  300 lr:  0.1 subsample:  1 min_child_weight:  1
# MAE intensity:  114.54
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.3 91.95 12.17
# max_depth:  9 n_estimators:  300 lr:  0.1 subsample:  1 min_child_weight:  3
# MAE intensity:  114.3
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.81 90.91 12.31
# max_depth:  9 n_estimators:  300 lr:  0.07 subsample:  0.8 min_child_weight:  1
# MAE intensity:  113.81
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.84 90.81 12.28
# max_depth:  9 n_estimators:  300 lr:  0.07 subsample:  0.8 min_child_weight:  3
# MAE intensity:  113.84
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.85 91.4 12.48
# max_depth:  9 n_estimators:  300 lr:  0.07 subsample:  0.9 min_child_weight:  1
# MAE intensity:  113.85
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.82 91.11 12.18
# max_depth:  9 n_estimators:  300 lr:  0.07 subsample:  0.9 min_child_weight:  3
# MAE intensity:  113.82
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.83 90.96 12.22
# max_depth:  9 n_estimators:  300 lr:  0.07 subsample:  1 min_child_weight:  1
# MAE intensity:  113.83
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 114.02 91.04 12.22
# max_depth:  9 n_estimators:  300 lr:  0.07 subsample:  1 min_child_weight:  3
# MAE intensity:  114.02
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.02 90.5 12.1
# max_depth:  9 n_estimators:  300 lr:  0.05 subsample:  0.8 min_child_weight:  1
# MAE intensity:  113.02
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.21 90.81 12.32
# max_depth:  9 n_estimators:  300 lr:  0.05 subsample:  0.8 min_child_weight:  3
# MAE intensity:  113.21
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.29 90.98 12.28
# max_depth:  9 n_estimators:  300 lr:  0.05 subsample:  0.9 min_child_weight:  1
# MAE intensity:  113.29
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.41 91.21 12.34
# max_depth:  9 n_estimators:  300 lr:  0.05 subsample:  0.9 min_child_weight:  3
# MAE intensity:  113.41
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.43 91.04 12.28
# max_depth:  9 n_estimators:  300 lr:  0.05 subsample:  1 min_child_weight:  1
# MAE intensity:  113.43
# Number of timesteps: 13849
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 113.35 90.72 12.07
# max_depth:  9 n_estimators:  300 lr:  0.05 subsample:  1 min_child_weight:  3
# MAE intensity:  113.35
# #### BEST RESULTS ####
# best_depth =  8
# best_est =  300
# best_lr =  0.05
# best_subs =  0.8
# best_min_child =  3
# (8, 300, 0.05, 0.8, 3)

# %%
best_depth =  8 
best_est =  300 
best_lr =  0.05 
best_subs =  0.8 
best_min_child =  3

# %%
#NA
d_stat_transfo_NA, d_boxplot_stat_transfo_NA = train_xgb_track_all_years_REVISION(X_train_, np.array(X_test_total), np.array(tgt_displacement_train), max_depth = best_depth, n_estimators = best_est, learning_rate = best_lr, subsample = best_subs, min_child_weight=best_min_child, basin = 'AN')
# Out:
# Number of timesteps: 899
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 109.12 72.31 10.01
# SHIP 77.46 60.88 3.56
# HWRF 74.98 49.1 2.56
# OFCL 71.24 55.52 2.78
# FSSE 68.92 52.56 3.56
# AEMN 73.2 54.98 2.34
# GFSO 70.55 54.27 3.34
# CLP5 201.24 149.25 37.15
# Consensus OFCL only 63.81 47.82 2.11
# Consensus OFCL + Hurricast 61.5 42.49 1.0
# Number of timesteps: 899
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 109.08 71.15 10.01
# SHIP 77.46 60.88 3.56
# HWRF 74.98 49.1 2.56
# OFCL 71.24 55.52 2.78
# FSSE 68.92 52.56 3.56
# AEMN 73.2 54.98 2.34
# GFSO 70.55 54.27 3.34
# CLP5 201.24 149.25 37.15
# Consensus OFCL only 63.81 47.82 2.11
# Consensus OFCL + Hurricast 61.49 42.45 1.0

# %%
#EP
d_stat_transfo_EP, d_boxplot_stat_transfo_EP = train_xgb_track_all_years_REVISION(X_train_, np.array(X_test_total), np.array(tgt_displacement_train), max_depth = best_depth, n_estimators = best_est, learning_rate = best_lr, subsample = best_subs, min_child_weight=best_min_child, basin = 'EP')
# Out:
# Number of timesteps: 837
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 72.06 43.29 1.55
# SHIP 57.81 34.06 0.36
# HWRF 66.98 42.24 2.03
# OFCL 54.1 32.59 0.12
# FSSE 55.83 47.39 0.72
# AEMN 59.9 37.34 0.6
# GFSO 64.56 44.99 1.55
# CLP5 120.92 66.79 12.31
# Consensus OFCL only 55.07 36.57 0.72
# Consensus OFCL + Hurricast 49.68 32.15 0.12
# Number of timesteps: 837
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 72.32 42.8 1.08
# SHIP 57.81 34.06 0.36
# HWRF 66.98 42.24 2.03
# OFCL 54.1 32.59 0.12
# FSSE 55.83 47.39 0.72
# AEMN 59.9 37.34 0.6
# GFSO 64.56 44.99 1.55
# CLP5 120.92 66.79 12.31
# Consensus OFCL only 55.07 36.57 0.72
# Consensus OFCL + Hurricast 49.71 32.08 0.24

# %% [markdown]
# ## Stat + comp

# %%
X_val = np.array(X_test_total_comp)[index]
X_train_ = np.array(X_train_total_comp)

# %%
validate_track(X_train_, tgt_displacement_train, X_val)
# Out:
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 147.25 122.83 21.68
# max_depth:  7 n_estimators:  150 lr:  0.1 subsample:  0.8 min_child_weight:  1
# MAE intensity:  147.25
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 147.7 122.63 21.92
# max_depth:  7 n_estimators:  150 lr:  0.1 subsample:  0.8 min_child_weight:  3
# MAE intensity:  147.7
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.98 121.77 21.94
# max_depth:  7 n_estimators:  150 lr:  0.1 subsample:  0.8 min_child_weight:  5
# MAE intensity:  146.98
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 147.13 121.42 21.77
# max_depth:  7 n_estimators:  150 lr:  0.1 subsample:  0.9 min_child_weight:  1
# MAE intensity:  147.13
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 147.12 121.48 21.9
# max_depth:  7 n_estimators:  150 lr:  0.1 subsample:  0.9 min_child_weight:  3
# MAE intensity:  147.12
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.89 122.14 21.61
# max_depth:  7 n_estimators:  150 lr:  0.1 subsample:  0.9 min_child_weight:  5
# MAE intensity:  146.89
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 147.07 121.56 21.6
# max_depth:  7 n_estimators:  150 lr:  0.1 subsample:  1 min_child_weight:  1
# MAE intensity:  147.07
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 147.17 121.83 21.76
# max_depth:  7 n_estimators:  150 lr:  0.1 subsample:  1 min_child_weight:  3
# MAE intensity:  147.17
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 147.33 121.73 21.78
# max_depth:  7 n_estimators:  150 lr:  0.1 subsample:  1 min_child_weight:  5
# MAE intensity:  147.33
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 147.42 122.17 21.69
# max_depth:  7 n_estimators:  150 lr:  0.07 subsample:  0.8 min_child_weight:  1
# MAE intensity:  147.42
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.83 121.57 21.53
# max_depth:  7 n_estimators:  150 lr:  0.07 subsample:  0.8 min_child_weight:  3
# MAE intensity:  146.83
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 147.37 121.5 21.65
# max_depth:  7 n_estimators:  150 lr:  0.07 subsample:  0.8 min_child_weight:  5
# MAE intensity:  147.37
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 147.3 121.23 21.67
# max_depth:  7 n_estimators:  150 lr:  0.07 subsample:  0.9 min_child_weight:  1
# MAE intensity:  147.3
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 147.21 121.55 21.79
# max_depth:  7 n_estimators:  150 lr:  0.07 subsample:  0.9 min_child_weight:  3
# MAE intensity:  147.21
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 147.22 121.81 21.68
# max_depth:  7 n_estimators:  150 lr:  0.07 subsample:  0.9 min_child_weight:  5
# MAE intensity:  147.22
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 147.39 121.79 22.0
# max_depth:  7 n_estimators:  150 lr:  0.07 subsample:  1 min_child_weight:  1
# MAE intensity:  147.39
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 147.19 121.27 21.84
# max_depth:  7 n_estimators:  150 lr:  0.07 subsample:  1 min_child_weight:  3
# MAE intensity:  147.19
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 147.14 121.61 21.71
# max_depth:  7 n_estimators:  150 lr:  0.07 subsample:  1 min_child_weight:  5
# MAE intensity:  147.14
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 147.42 122.19 21.72
# max_depth:  7 n_estimators:  150 lr:  0.05 subsample:  0.8 min_child_weight:  1
# MAE intensity:  147.42
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 147.29 122.0 21.54
# max_depth:  7 n_estimators:  150 lr:  0.05 subsample:  0.8 min_child_weight:  3
# MAE intensity:  147.29
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 147.52 122.17 21.49
# max_depth:  7 n_estimators:  150 lr:  0.05 subsample:  0.8 min_child_weight:  5
# MAE intensity:  147.52
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 147.48 121.79 21.68
# max_depth:  7 n_estimators:  150 lr:  0.05 subsample:  0.9 min_child_weight:  1
# MAE intensity:  147.48
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 147.42 121.34 21.68
# max_depth:  7 n_estimators:  150 lr:  0.05 subsample:  0.9 min_child_weight:  3
# MAE intensity:  147.42
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 147.31 121.49 21.64
# max_depth:  7 n_estimators:  150 lr:  0.05 subsample:  0.9 min_child_weight:  5
# MAE intensity:  147.31
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 147.59 122.03 21.79
# max_depth:  7 n_estimators:  150 lr:  0.05 subsample:  1 min_child_weight:  1
# MAE intensity:  147.59
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 147.59 122.72 21.86
# max_depth:  7 n_estimators:  150 lr:  0.05 subsample:  1 min_child_weight:  3
# MAE intensity:  147.59
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 147.67 122.26 21.76
# max_depth:  7 n_estimators:  150 lr:  0.05 subsample:  1 min_child_weight:  5
# MAE intensity:  147.67
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.97 122.84 21.46
# max_depth:  7 n_estimators:  200 lr:  0.1 subsample:  0.8 min_child_weight:  1
# MAE intensity:  146.97
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 147.24 122.17 21.55
# max_depth:  7 n_estimators:  200 lr:  0.1 subsample:  0.8 min_child_weight:  3
# MAE intensity:  147.24
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.63 121.45 21.8
# max_depth:  7 n_estimators:  200 lr:  0.1 subsample:  0.8 min_child_weight:  5
# MAE intensity:  146.63
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.65 121.09 21.77
# max_depth:  7 n_estimators:  200 lr:  0.1 subsample:  0.9 min_child_weight:  1
# MAE intensity:  146.65
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.75 120.92 21.68
# max_depth:  7 n_estimators:  200 lr:  0.1 subsample:  0.9 min_child_weight:  3
# MAE intensity:  146.75
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.56 121.9 21.47
# max_depth:  7 n_estimators:  200 lr:  0.1 subsample:  0.9 min_child_weight:  5
# MAE intensity:  146.56
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.53 121.26 21.58
# max_depth:  7 n_estimators:  200 lr:  0.1 subsample:  1 min_child_weight:  1
# MAE intensity:  146.53
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.85 121.38 21.54
# max_depth:  7 n_estimators:  200 lr:  0.1 subsample:  1 min_child_weight:  3
# MAE intensity:  146.85
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.81 121.43 21.79
# max_depth:  7 n_estimators:  200 lr:  0.1 subsample:  1 min_child_weight:  5
# MAE intensity:  146.81
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.96 121.65 21.63
# max_depth:  7 n_estimators:  200 lr:  0.07 subsample:  0.8 min_child_weight:  1
# MAE intensity:  146.96
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.52 121.27 21.62
# max_depth:  7 n_estimators:  200 lr:  0.07 subsample:  0.8 min_child_weight:  3
# MAE intensity:  146.52
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 147.02 121.09 21.65
# max_depth:  7 n_estimators:  200 lr:  0.07 subsample:  0.8 min_child_weight:  5
# MAE intensity:  147.02
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.92 121.03 21.63
# max_depth:  7 n_estimators:  200 lr:  0.07 subsample:  0.9 min_child_weight:  1
# MAE intensity:  146.92
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.75 120.99 21.67
# max_depth:  7 n_estimators:  200 lr:  0.07 subsample:  0.9 min_child_weight:  3
# MAE intensity:  146.75
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.81 121.33 21.66
# max_depth:  7 n_estimators:  200 lr:  0.07 subsample:  0.9 min_child_weight:  5
# MAE intensity:  146.81
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 147.07 121.4 21.88
# max_depth:  7 n_estimators:  200 lr:  0.07 subsample:  1 min_child_weight:  1
# MAE intensity:  147.07
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.81 120.92 21.72
# max_depth:  7 n_estimators:  200 lr:  0.07 subsample:  1 min_child_weight:  3
# MAE intensity:  146.81
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.75 121.2 21.73
# max_depth:  7 n_estimators:  200 lr:  0.07 subsample:  1 min_child_weight:  5
# MAE intensity:  146.75
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.99 121.63 21.61
# max_depth:  7 n_estimators:  200 lr:  0.05 subsample:  0.8 min_child_weight:  1
# MAE intensity:  146.99
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.93 121.54 21.55
# max_depth:  7 n_estimators:  200 lr:  0.05 subsample:  0.8 min_child_weight:  3
# MAE intensity:  146.93
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 147.1 121.7 21.42
# max_depth:  7 n_estimators:  200 lr:  0.05 subsample:  0.8 min_child_weight:  5
# MAE intensity:  147.1
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 147.06 121.33 21.61
# max_depth:  7 n_estimators:  200 lr:  0.05 subsample:  0.9 min_child_weight:  1
# MAE intensity:  147.06
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.9 120.72 21.85
# max_depth:  7 n_estimators:  200 lr:  0.05 subsample:  0.9 min_child_weight:  3
# MAE intensity:  146.9
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.87 120.9 21.55
# max_depth:  7 n_estimators:  200 lr:  0.05 subsample:  0.9 min_child_weight:  5
# MAE intensity:  146.87
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 147.03 121.56 21.66
# max_depth:  7 n_estimators:  200 lr:  0.05 subsample:  1 min_child_weight:  1
# MAE intensity:  147.03
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 147.25 122.44 21.79
# max_depth:  7 n_estimators:  200 lr:  0.05 subsample:  1 min_child_weight:  3
# MAE intensity:  147.25
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 147.24 121.84 21.79
# max_depth:  7 n_estimators:  200 lr:  0.05 subsample:  1 min_child_weight:  5
# MAE intensity:  147.24
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.26 122.34 21.15
# max_depth:  7 n_estimators:  300 lr:  0.1 subsample:  0.8 min_child_weight:  1
# MAE intensity:  146.26
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.79 121.8 21.23
# max_depth:  7 n_estimators:  300 lr:  0.1 subsample:  0.8 min_child_weight:  3
# MAE intensity:  146.79
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.04 121.15 21.45
# max_depth:  7 n_estimators:  300 lr:  0.1 subsample:  0.8 min_child_weight:  5
# MAE intensity:  146.04
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.97 120.85 21.5
# max_depth:  7 n_estimators:  300 lr:  0.1 subsample:  0.9 min_child_weight:  1
# MAE intensity:  145.97
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.17 120.57 21.4
# max_depth:  7 n_estimators:  300 lr:  0.1 subsample:  0.9 min_child_weight:  3
# MAE intensity:  146.17
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.07 121.73 21.39
# max_depth:  7 n_estimators:  300 lr:  0.1 subsample:  0.9 min_child_weight:  5
# MAE intensity:  146.07
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.88 120.96 21.35
# max_depth:  7 n_estimators:  300 lr:  0.1 subsample:  1 min_child_weight:  1
# MAE intensity:  145.88
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.05 121.0 21.31
# max_depth:  7 n_estimators:  300 lr:  0.1 subsample:  1 min_child_weight:  3
# MAE intensity:  146.05
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.07 121.09 21.46
# max_depth:  7 n_estimators:  300 lr:  0.1 subsample:  1 min_child_weight:  5
# MAE intensity:  146.07
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.37 121.13 21.55
# max_depth:  7 n_estimators:  300 lr:  0.07 subsample:  0.8 min_child_weight:  1
# MAE intensity:  146.37
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.9 120.76 21.25
# max_depth:  7 n_estimators:  300 lr:  0.07 subsample:  0.8 min_child_weight:  3
# MAE intensity:  145.9
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.3 120.82 21.39
# max_depth:  7 n_estimators:  300 lr:  0.07 subsample:  0.8 min_child_weight:  5
# MAE intensity:  146.3
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.24 120.45 21.25
# max_depth:  7 n_estimators:  300 lr:  0.07 subsample:  0.9 min_child_weight:  1
# MAE intensity:  146.24
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.88 120.33 21.45
# max_depth:  7 n_estimators:  300 lr:  0.07 subsample:  0.9 min_child_weight:  3
# MAE intensity:  145.88
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.93 120.75 21.32
# max_depth:  7 n_estimators:  300 lr:  0.07 subsample:  0.9 min_child_weight:  5
# MAE intensity:  145.93
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.33 120.99 21.52
# max_depth:  7 n_estimators:  300 lr:  0.07 subsample:  1 min_child_weight:  1
# MAE intensity:  146.33
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.82 120.34 21.47
# max_depth:  7 n_estimators:  300 lr:  0.07 subsample:  1 min_child_weight:  3
# MAE intensity:  145.82
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.12 120.75 21.58
# max_depth:  7 n_estimators:  300 lr:  0.07 subsample:  1 min_child_weight:  5
# MAE intensity:  146.12
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.35 120.97 21.43
# max_depth:  7 n_estimators:  300 lr:  0.05 subsample:  0.8 min_child_weight:  1
# MAE intensity:  146.35
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.24 121.12 21.45
# max_depth:  7 n_estimators:  300 lr:  0.05 subsample:  0.8 min_child_weight:  3
# MAE intensity:  146.24
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.4 120.98 21.4
# max_depth:  7 n_estimators:  300 lr:  0.05 subsample:  0.8 min_child_weight:  5
# MAE intensity:  146.4
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.28 120.87 21.55
# max_depth:  7 n_estimators:  300 lr:  0.05 subsample:  0.9 min_child_weight:  1
# MAE intensity:  146.28
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.18 120.18 21.6
# max_depth:  7 n_estimators:  300 lr:  0.05 subsample:  0.9 min_child_weight:  3
# MAE intensity:  146.18
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.26 120.47 21.56
# max_depth:  7 n_estimators:  300 lr:  0.05 subsample:  0.9 min_child_weight:  5
# MAE intensity:  146.26
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.47 121.04 21.54
# max_depth:  7 n_estimators:  300 lr:  0.05 subsample:  1 min_child_weight:  1
# MAE intensity:  146.47
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.55 121.9 21.6
# max_depth:  7 n_estimators:  300 lr:  0.05 subsample:  1 min_child_weight:  3
# MAE intensity:  146.55
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.55 121.09 21.63
# max_depth:  7 n_estimators:  300 lr:  0.05 subsample:  1 min_child_weight:  5
# MAE intensity:  146.55
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.48 121.48 21.48
# max_depth:  8 n_estimators:  150 lr:  0.1 subsample:  0.8 min_child_weight:  1
# MAE intensity:  146.48
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.43 120.87 21.73
# max_depth:  8 n_estimators:  150 lr:  0.1 subsample:  0.8 min_child_weight:  3
# MAE intensity:  146.43
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.67 121.3 21.41
# max_depth:  8 n_estimators:  150 lr:  0.1 subsample:  0.8 min_child_weight:  5
# MAE intensity:  146.67
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.23 120.69 21.33
# max_depth:  8 n_estimators:  150 lr:  0.1 subsample:  0.9 min_child_weight:  1
# MAE intensity:  146.23
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.11 121.66 21.37
# max_depth:  8 n_estimators:  150 lr:  0.1 subsample:  0.9 min_child_weight:  3
# MAE intensity:  146.11
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.16 121.21 21.32
# max_depth:  8 n_estimators:  150 lr:  0.1 subsample:  0.9 min_child_weight:  5
# MAE intensity:  146.16
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.12 121.4 21.31
# max_depth:  8 n_estimators:  150 lr:  0.1 subsample:  1 min_child_weight:  1
# MAE intensity:  146.12
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.22 121.02 21.6
# max_depth:  8 n_estimators:  150 lr:  0.1 subsample:  1 min_child_weight:  3
# MAE intensity:  146.22
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.16 120.98 21.66
# max_depth:  8 n_estimators:  150 lr:  0.1 subsample:  1 min_child_weight:  5
# MAE intensity:  146.16
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.83 120.65 21.27
# max_depth:  8 n_estimators:  150 lr:  0.07 subsample:  0.8 min_child_weight:  1
# MAE intensity:  145.83
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.89 120.71 21.3
# max_depth:  8 n_estimators:  150 lr:  0.07 subsample:  0.8 min_child_weight:  3
# MAE intensity:  145.89
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.9 120.57 21.27
# max_depth:  8 n_estimators:  150 lr:  0.07 subsample:  0.8 min_child_weight:  5
# MAE intensity:  145.9
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.16 120.79 21.5
# max_depth:  8 n_estimators:  150 lr:  0.07 subsample:  0.9 min_child_weight:  1
# MAE intensity:  146.16
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.86 121.1 21.45
# max_depth:  8 n_estimators:  150 lr:  0.07 subsample:  0.9 min_child_weight:  3
# MAE intensity:  145.86
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.94 120.73 21.43
# max_depth:  8 n_estimators:  150 lr:  0.07 subsample:  0.9 min_child_weight:  5
# MAE intensity:  145.94
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.23 121.54 21.46
# max_depth:  8 n_estimators:  150 lr:  0.07 subsample:  1 min_child_weight:  1
# MAE intensity:  146.23
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.19 121.87 21.31
# max_depth:  8 n_estimators:  150 lr:  0.07 subsample:  1 min_child_weight:  3
# MAE intensity:  146.19
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.03 121.6 21.32
# max_depth:  8 n_estimators:  150 lr:  0.07 subsample:  1 min_child_weight:  5
# MAE intensity:  146.03
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.8 121.08 21.45
# max_depth:  8 n_estimators:  150 lr:  0.05 subsample:  0.8 min_child_weight:  1
# MAE intensity:  145.8
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.96 121.01 21.3
# max_depth:  8 n_estimators:  150 lr:  0.05 subsample:  0.8 min_child_weight:  3
# MAE intensity:  145.96
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.88 120.88 21.48
# max_depth:  8 n_estimators:  150 lr:  0.05 subsample:  0.8 min_child_weight:  5
# MAE intensity:  145.88
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.21 120.79 21.42
# max_depth:  8 n_estimators:  150 lr:  0.05 subsample:  0.9 min_child_weight:  1
# MAE intensity:  146.21
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.97 120.77 21.49
# max_depth:  8 n_estimators:  150 lr:  0.05 subsample:  0.9 min_child_weight:  3
# MAE intensity:  145.97
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.97 120.62 21.55
# max_depth:  8 n_estimators:  150 lr:  0.05 subsample:  0.9 min_child_weight:  5
# MAE intensity:  145.97
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.07 121.19 21.41
# max_depth:  8 n_estimators:  150 lr:  0.05 subsample:  1 min_child_weight:  1
# MAE intensity:  146.07
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.33 121.55 21.58
# max_depth:  8 n_estimators:  150 lr:  0.05 subsample:  1 min_child_weight:  3
# MAE intensity:  146.33
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.32 121.25 21.53
# max_depth:  8 n_estimators:  150 lr:  0.05 subsample:  1 min_child_weight:  5
# MAE intensity:  146.32
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.36 121.24 21.45
# max_depth:  8 n_estimators:  200 lr:  0.1 subsample:  0.8 min_child_weight:  1
# MAE intensity:  146.36
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.22 120.57 21.8
# max_depth:  8 n_estimators:  200 lr:  0.1 subsample:  0.8 min_child_weight:  3
# MAE intensity:  146.22
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.53 120.96 21.54
# max_depth:  8 n_estimators:  200 lr:  0.1 subsample:  0.8 min_child_weight:  5
# MAE intensity:  146.53
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.02 120.63 21.37
# max_depth:  8 n_estimators:  200 lr:  0.1 subsample:  0.9 min_child_weight:  1
# MAE intensity:  146.02
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.81 121.55 21.38
# max_depth:  8 n_estimators:  200 lr:  0.1 subsample:  0.9 min_child_weight:  3
# MAE intensity:  145.81
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.93 121.15 21.43
# max_depth:  8 n_estimators:  200 lr:  0.1 subsample:  0.9 min_child_weight:  5
# MAE intensity:  145.93
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.73 121.17 21.16
# max_depth:  8 n_estimators:  200 lr:  0.1 subsample:  1 min_child_weight:  1
# MAE intensity:  145.73
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.99 120.95 21.47
# max_depth:  8 n_estimators:  200 lr:  0.1 subsample:  1 min_child_weight:  3
# MAE intensity:  145.99
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.99 120.89 21.59
# max_depth:  8 n_estimators:  200 lr:  0.1 subsample:  1 min_child_weight:  5
# MAE intensity:  145.99
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.51 120.41 21.29
# max_depth:  8 n_estimators:  200 lr:  0.07 subsample:  0.8 min_child_weight:  1
# MAE intensity:  145.51
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.72 120.61 21.22
# max_depth:  8 n_estimators:  200 lr:  0.07 subsample:  0.8 min_child_weight:  3
# MAE intensity:  145.72
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.37 120.13 21.19
# max_depth:  8 n_estimators:  200 lr:  0.07 subsample:  0.8 min_child_weight:  5
# MAE intensity:  145.37
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.9 120.53 21.23
# max_depth:  8 n_estimators:  200 lr:  0.07 subsample:  0.9 min_child_weight:  1
# MAE intensity:  145.9
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.53 120.62 21.33
# max_depth:  8 n_estimators:  200 lr:  0.07 subsample:  0.9 min_child_weight:  3
# MAE intensity:  145.53
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.71 120.46 21.38
# max_depth:  8 n_estimators:  200 lr:  0.07 subsample:  0.9 min_child_weight:  5
# MAE intensity:  145.71
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.84 121.12 21.25
# max_depth:  8 n_estimators:  200 lr:  0.07 subsample:  1 min_child_weight:  1
# MAE intensity:  145.84
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.91 121.77 21.16
# max_depth:  8 n_estimators:  200 lr:  0.07 subsample:  1 min_child_weight:  3
# MAE intensity:  145.91
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.8 121.39 21.32
# max_depth:  8 n_estimators:  200 lr:  0.07 subsample:  1 min_child_weight:  5
# MAE intensity:  145.8
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.34 120.62 21.4
# max_depth:  8 n_estimators:  200 lr:  0.05 subsample:  0.8 min_child_weight:  1
# MAE intensity:  145.34
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.68 120.7 21.18
# max_depth:  8 n_estimators:  200 lr:  0.05 subsample:  0.8 min_child_weight:  3
# MAE intensity:  145.68
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.54 120.38 21.51
# max_depth:  8 n_estimators:  200 lr:  0.05 subsample:  0.8 min_child_weight:  5
# MAE intensity:  145.54
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.76 120.31 21.45
# max_depth:  8 n_estimators:  200 lr:  0.05 subsample:  0.9 min_child_weight:  1
# MAE intensity:  145.76
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.6 120.4 21.45
# max_depth:  8 n_estimators:  200 lr:  0.05 subsample:  0.9 min_child_weight:  3
# MAE intensity:  145.6
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.63 120.18 21.34
# max_depth:  8 n_estimators:  200 lr:  0.05 subsample:  0.9 min_child_weight:  5
# MAE intensity:  145.63
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.73 120.75 21.31
# max_depth:  8 n_estimators:  200 lr:  0.05 subsample:  1 min_child_weight:  1
# MAE intensity:  145.73
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.1 121.21 21.48
# max_depth:  8 n_estimators:  200 lr:  0.05 subsample:  1 min_child_weight:  3
# MAE intensity:  146.1
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.96 120.93 21.55
# max_depth:  8 n_estimators:  200 lr:  0.05 subsample:  1 min_child_weight:  5
# MAE intensity:  145.96
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.33 121.08 21.4
# max_depth:  8 n_estimators:  300 lr:  0.1 subsample:  0.8 min_child_weight:  1
# MAE intensity:  146.33
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.96 120.37 21.61
# max_depth:  8 n_estimators:  300 lr:  0.1 subsample:  0.8 min_child_weight:  3
# MAE intensity:  145.96
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 146.57 120.71 21.45
# max_depth:  8 n_estimators:  300 lr:  0.1 subsample:  0.8 min_child_weight:  5
# MAE intensity:  146.57
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.86 120.57 21.27
# max_depth:  8 n_estimators:  300 lr:  0.1 subsample:  0.9 min_child_weight:  1
# MAE intensity:  145.86
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.62 121.3 21.29
# max_depth:  8 n_estimators:  300 lr:  0.1 subsample:  0.9 min_child_weight:  3
# MAE intensity:  145.62
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.8 121.14 21.44
# max_depth:  8 n_estimators:  300 lr:  0.1 subsample:  0.9 min_child_weight:  5
# MAE intensity:  145.8
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.32 120.93 20.82
# max_depth:  8 n_estimators:  300 lr:  0.1 subsample:  1 min_child_weight:  1
# MAE intensity:  145.32
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.62 120.68 21.47
# max_depth:  8 n_estimators:  300 lr:  0.1 subsample:  1 min_child_weight:  3
# MAE intensity:  145.62
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.65 120.53 21.49
# max_depth:  8 n_estimators:  300 lr:  0.1 subsample:  1 min_child_weight:  5
# MAE intensity:  145.65
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.08 120.23 21.11
# max_depth:  8 n_estimators:  300 lr:  0.07 subsample:  0.8 min_child_weight:  1
# MAE intensity:  145.08
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.23 120.33 20.99
# max_depth:  8 n_estimators:  300 lr:  0.07 subsample:  0.8 min_child_weight:  3
# MAE intensity:  145.23
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 144.9 119.85 20.85
# max_depth:  8 n_estimators:  300 lr:  0.07 subsample:  0.8 min_child_weight:  5
# MAE intensity:  144.9
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.44 120.28 21.24
# max_depth:  8 n_estimators:  300 lr:  0.07 subsample:  0.9 min_child_weight:  1
# MAE intensity:  145.44
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.06 120.15 21.17
# max_depth:  8 n_estimators:  300 lr:  0.07 subsample:  0.9 min_child_weight:  3
# MAE intensity:  145.06
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.25 120.14 21.06
# max_depth:  8 n_estimators:  300 lr:  0.07 subsample:  0.9 min_child_weight:  5
# MAE intensity:  145.25
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.21 120.78 21.08
# max_depth:  8 n_estimators:  300 lr:  0.07 subsample:  1 min_child_weight:  1
# MAE intensity:  145.21
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.42 121.37 20.9
# max_depth:  8 n_estimators:  300 lr:  0.07 subsample:  1 min_child_weight:  3
# MAE intensity:  145.42
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.38 121.12 21.2
# max_depth:  8 n_estimators:  300 lr:  0.07 subsample:  1 min_child_weight:  5
# MAE intensity:  145.38
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 144.7 120.09 21.15
# max_depth:  8 n_estimators:  300 lr:  0.05 subsample:  0.8 min_child_weight:  1
# MAE intensity:  144.7
#
# BEST SCORE SO FAR
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.25 120.48 21.02
# max_depth:  8 n_estimators:  300 lr:  0.05 subsample:  0.8 min_child_weight:  3
# MAE intensity:  145.25
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.04 119.95 21.35
# max_depth:  8 n_estimators:  300 lr:  0.05 subsample:  0.8 min_child_weight:  5
# MAE intensity:  145.04
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.16 119.79 21.23
# max_depth:  8 n_estimators:  300 lr:  0.05 subsample:  0.9 min_child_weight:  1
# MAE intensity:  145.16
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.09 119.91 21.1
# max_depth:  8 n_estimators:  300 lr:  0.05 subsample:  0.9 min_child_weight:  3
# MAE intensity:  145.09
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.14 119.85 21.14
# max_depth:  8 n_estimators:  300 lr:  0.05 subsample:  0.9 min_child_weight:  5
# MAE intensity:  145.14
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.14 120.36 21.02
# max_depth:  8 n_estimators:  300 lr:  0.05 subsample:  1 min_child_weight:  1
# MAE intensity:  145.14
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.4 120.79 21.41
# max_depth:  8 n_estimators:  300 lr:  0.05 subsample:  1 min_child_weight:  3
# MAE intensity:  145.4
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 145.45 120.59 21.4
# max_depth:  8 n_estimators:  300 lr:  0.05 subsample:  1 min_child_weight:  5
# MAE intensity:  145.45
#
# #### BEST RESULTS ####
# best_depth =  8
# best_est =  300
# best_lr =  0.05
# best_subs =  0.8
# best_min_child =  1
# (8, 300, 0.05, 0.8, 1)

# %%
best_depth =  8 
best_est =  300 
best_lr =  0.05 
best_subs =  0.8 
best_min_child =  1

# %%
d_stat_comp_NA, d_boxplot_stat_comp_NA = train_xgb_track_all_years_REVISION(X_train_, np.array(X_test_total_comp), np.array(tgt_displacement_train), max_depth = best_depth, n_estimators = best_est, learning_rate = best_lr, subsample = best_subs, min_child_weight=best_min_child, basin = 'AN')
# Out:
# Number of timesteps: 899
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 140.22 107.99 19.13
# SHIP 77.46 60.88 3.56
# HWRF 74.98 49.1 2.56
# OFCL 71.24 55.52 2.78
# FSSE 68.92 52.56 3.56
# AEMN 73.2 54.98 2.34
# GFSO 70.55 54.27 3.34
# CLP5 201.24 149.25 37.15
# Consensus OFCL only 63.81 47.82 2.11
# Consensus OFCL + Hurricast 65.31 44.71 2.0
# Number of timesteps: 899
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 140.04 107.55 18.58
# SHIP 77.46 60.88 3.56
# HWRF 74.98 49.1 2.56
# OFCL 71.24 55.52 2.78
# FSSE 68.92 52.56 3.56
# AEMN 73.2 54.98 2.34
# GFSO 70.55 54.27 3.34
# CLP5 201.24 149.25 37.15
# Consensus OFCL only 63.81 47.82 2.11
# Consensus OFCL + Hurricast 65.2 44.47 1.89

# %%
d_stat_comp_EP, d_boxplot_stat_comp_EP = train_xgb_track_all_years_REVISION(X_train_, np.array(X_test_total_comp), np.array(tgt_displacement_train), max_depth = best_depth, n_estimators = best_est, learning_rate = best_lr, subsample = best_subs, min_child_weight=best_min_child, basin = 'EP')
# Out:
# Number of timesteps: 837
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 81.69 48.44 2.03
# SHIP 57.81 34.06 0.36
# HWRF 66.98 42.24 2.03
# OFCL 54.1 32.59 0.12
# FSSE 55.83 47.39 0.72
# AEMN 59.9 37.34 0.6
# GFSO 64.56 44.99 1.55
# CLP5 120.92 66.79 12.31
# Consensus OFCL only 55.07 36.57 0.72
# Consensus OFCL + Hurricast 49.57 31.71 0.24
# Number of timesteps: 837
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 81.31 47.22 2.03
# SHIP 57.81 34.06 0.36
# HWRF 66.98 42.24 2.03
# OFCL 54.1 32.59 0.12
# FSSE 55.83 47.39 0.72
# AEMN 59.9 37.34 0.6
# GFSO 64.56 44.99 1.55
# CLP5 120.92 66.79 12.31
# Consensus OFCL only 55.07 36.57 0.72
# Consensus OFCL + Hurricast 49.56 31.74 0.36

# %% [markdown]
# # Ensemble

# %%
df, df_2012_train, df_2012_test, df_2016_train, df_2016_test = pd.DataFrame(), pd.DataFrame(), pd.DataFrame(), pd.DataFrame(), pd.DataFrame()
df, df_2012_train, df_2012_test, df_2016_train, df_2016_test = create_df_boxplots(dict=d_stat_only_EP, dict_consensus=d_boxplot_stat_only_EP, df = df, df_2012_train= df_2012_train, df_2012_test = df_2012_test, df_2016_train = df_2016_train, df_2016_test = df_2016_test, name = 'HURR_STAT')
#df, df_2012_train, df_2012_test, df_2016_train, df_2016_test = create_df_boxplots(dict=d_gru_only_EP, dict_consensus=d_boxplot_gru_only_EP, df = df, df_2012_train= df_2012_train, df_2012_test = df_2012_test, df_2016_train = df_2016_train, df_2016_test = df_2016_test, name = 'HURR_GRU_ONLY')
#df, df_2012_train, df_2012_test, df_2016_train, df_2016_test = create_df_boxplots(dict=d_transfo_only_EP, dict_consensus=d_boxplot_transfo_only_EP, df = df, df_2012_train= df_2012_train, df_2012_test = df_2012_test, df_2016_train = df_2016_train, df_2016_test = df_2016_test, name = 'HURR_TRANSFO_ONLY')
df, df_2012_train, df_2012_test, df_2016_train, df_2016_test = create_df_boxplots(dict=d_stat_gru_EP, dict_consensus=d_boxplot_stat_gru_EP, df = df, df_2012_train= df_2012_train, df_2012_test = df_2012_test, df_2016_train = df_2016_train, df_2016_test = df_2016_test, name = 'HURR_STAT_GRU')
df, df_2012_train, df_2012_test, df_2016_train, df_2016_test = create_df_boxplots(dict=d_stat_transfo_EP, dict_consensus=d_boxplot_stat_transfo_EP, df = df, df_2012_train= df_2012_train, df_2012_test = df_2012_test, df_2016_train = df_2016_train, df_2016_test = df_2016_test, name = 'HURR_STAT_TRANSFO')
df, df_2012_train, df_2012_test, df_2016_train, df_2016_test = create_df_boxplots(dict=d_stat_comp_EP, dict_consensus=d_boxplot_stat_comp_EP, df = df, df_2012_train= df_2012_train, df_2012_test = df_2012_test, df_2016_train = df_2016_train, df_2016_test = df_2016_test, name = 'HURR_STAT_COMP')
# Out:
# full1 (837,)
# full0 (837,)
# full1 (837,)
# full0 (837,)
# full1 (837,)
# full0 (837,)
# full1 (837,)
# full0 (837,)

# %%
df.to_csv('EP_BOXPLOT_TRACK_v3.csv')

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import ElasticNet
from sklearn.neural_network import MLPRegressor

# %%
mode = 'lat'
basin = 'AN'
forecast = 'SHIP'
forecast2 = 'HWRF'
forecast3 = 'OFCL' 
forecast4 = 'FSSE' 
forecast5 = 'GFSO' 
forecast6 = 'AEMN' 
forecast7 = 'CLP5'

test_ = X_test_baseline.loc[X_test_baseline['YEAR_0'] >= 2016].loc[
            X_test_baseline[forecast7 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast6 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast5 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast4 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast3 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast2 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast + '_24_' + mode + '_7'] > -320].loc[X_test_baseline['cat_basin_' + basin + '_0'] == 1]  # .loc[#X_test_baseline['SHIP_24_'+mode+'_7'] > 0].index

#if basin == 'EP':
    #test_ = test_.loc[X_test_baseline['YEAR_0'] < 2019]
    
index = test_.index

# %%
#2016 model
#Version trained until 2016 but with data from 1980-2016
consensus_test = np.array(df_2016_test)[index][:,2:]
consensus_test_lat = consensus_test[:, ::2]
consensus_test_lon = consensus_test[:, 1::2]
tgt_test_lat = np.array(df_2016_test['TRUTH_DLAT_2012_2020_test'])[index]
tgt_test_lon = np.array(df_2016_test['TRUTH_DLON_2012_2020_test'])[index]
tgt_test = np.array(df_2016_test[['TRUTH_DLAT_2012_2020_test', 'TRUTH_DLON_2012_2020_test']])[index]

consensus_val = np.array(df_2016_train)[:,2:]
consensus_val_lat = consensus_val[:, ::2]
consensus_val_lon = consensus_val[:, 1::2]
tgt_val_lat = np.array(df_2016_train['TRUTH_DLAT_1980_2016_train'])
tgt_val_lon = np.array(df_2016_train['TRUTH_DLON_1980_2016_train'])
tgt_val = np.array(df_2016_train[['TRUTH_DLAT_1980_2016_train', 'TRUTH_DLON_1980_2016_train']])

# %%
#2012 model 
#Version trained until 2012
consensus_test = np.array(df_2012_test)[index][:,2:]
consensus_test_lat = consensus_test[:, ::2]
consensus_test_lon = consensus_test[:, 1::2]
tgt_test_lat = np.array(df_2012_test['TRUTH_DLAT_2012_2020_test'])[index]
tgt_test_lon = np.array(df_2012_test['TRUTH_DLON_2012_2020_test'])[index]
tgt_test = np.array(df_2012_test[['TRUTH_DLAT_2012_2020_test', 'TRUTH_DLON_2012_2020_test']])[index]

consensus_val = np.array(df_2012_train)[:,2:]
consensus_val_lat = consensus_val[:, ::2]
consensus_val_lon = consensus_val[:, 1::2]
tgt_val_lat = np.array(df_2012_train['TRUTH_DLAT_2012_2016_val'])
tgt_val_lon = np.array(df_2012_train['TRUTH_DLON_2012_2016_val'])
tgt_val = np.array(df_2012_train[['TRUTH_DLAT_2012_2016_val', 'TRUTH_DLON_2012_2016_val']])

# %% [markdown]
# ## EP

# %%
mode = 'lat'
basin = 'EP'
forecast = 'SHIP'
forecast2 = 'HWRF'
forecast3 = 'OFCL' 
forecast4 = 'FSSE' 
forecast5 = 'GFSO' 
forecast6 = 'AEMN' 
forecast7 = 'CLP5'

test_ = X_test_baseline.loc[X_test_baseline['YEAR_0'] >= 2016].loc[
            X_test_baseline[forecast7 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast6 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast5 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast4 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast3 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast2 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast + '_24_' + mode + '_7'] > -320].loc[X_test_baseline['cat_basin_' + basin + '_0'] == 1]  # .loc[#X_test_baseline['SHIP_24_'+mode+'_7'] > 0].index

if basin == 'EP':
    test_ = test_.loc[X_test_baseline['YEAR_0'] < 2019]
    
index = test_.index


test_2 = X_test_baseline.loc[X_test_baseline['YEAR_0'] < 2016].loc[X_test_baseline['cat_basin_' + basin + '_0'] == 1]
index2 = test_2.index

test_3 = X_test_baseline.loc[X_test_baseline['YEAR_0'] < 2016]
index3 = test_3.index

# %%
#2012 model 
#Version trained until 2012
consensus_test = np.array(df_2012_test)[index][:,2:]
consensus_test_lat = consensus_test[:, ::2]
consensus_test_lon = consensus_test[:, 1::2]
tgt_test_lat = np.array(df_2012_test['TRUTH_DLAT_2012_2020_test'])[index]
tgt_test_lon = np.array(df_2012_test['TRUTH_DLON_2012_2020_test'])[index]
tgt_test = np.array(df_2012_test[['TRUTH_DLAT_2012_2020_test', 'TRUTH_DLON_2012_2020_test']])[index]

consensus_val = np.array(df_2012_train)[:,2:]
consensus_val_lat = consensus_val[:, ::2]
consensus_val_lon = consensus_val[:, 1::2]
tgt_val_lat = np.array(df_2012_train['TRUTH_DLAT_2012_2016_val'])
tgt_val_lon = np.array(df_2012_train['TRUTH_DLON_2012_2016_val'])
tgt_val = np.array(df_2012_train[['TRUTH_DLAT_2012_2016_val', 'TRUTH_DLON_2012_2016_val']])

# %%
#2012 model 
#Version trained until 2012
consensus_test = np.concatenate((np.array(df_2012_test)[index][:,2:],np.array(X_test[['COS_LAT_7', 'SIN_LAT_7']])[index]), axis = 1)
consensus_test_lat = consensus_test[:, ::2]
consensus_test_lon = consensus_test[:, 1::2]
tgt_test_lat = np.array(df_2012_test['TRUTH_DLAT_2012_2020_test'])[index]
tgt_test_lon = np.array(df_2012_test['TRUTH_DLON_2012_2020_test'])[index]
tgt_test = np.array(df_2012_test[['TRUTH_DLAT_2012_2020_test', 'TRUTH_DLON_2012_2020_test']])[index]

consensus_val = np.concatenate((np.array(df_2012_train)[:,2:], np.array(X_test[['COS_LAT_7', 'SIN_LAT_7']])[index3]), axis = 1)
consensus_val_lat = consensus_val[:, ::2]
consensus_val_lon = consensus_val[:, 1::2]
tgt_val_lat = np.array(df_2012_train['TRUTH_DLAT_2012_2016_val'])
tgt_val_lon = np.array(df_2012_train['TRUTH_DLON_2012_2016_val'])
tgt_val = np.array(df_2012_train[['TRUTH_DLAT_2012_2016_val', 'TRUTH_DLON_2012_2016_val']])

# %% [markdown]
# 2012 model
# #Version trained until 2012
# consensus_test = np.array(df_2012_test)[index][:,2:]
# consensus_test_lat = consensus_test[:, ::2]
# consensus_test_lon = consensus_test[:, 1::2]
# tgt_test_lat = np.array(df_2012_test['TRUTH_DLAT_2012_2020_test'])[index]
# tgt_test_lon = np.array(df_2012_test['TRUTH_DLON_2012_2020_test'])[index]
# tgt_test = np.array(df_2012_test[['TRUTH_DLAT_2012_2020_test', 'TRUTH_DLON_2012_2020_test']])[index]
#
# consensus_val = np.array(df_2012_train)[:,2:][index2]
# consensus_val_lat = consensus_val[:, ::2]
# consensus_val_lon = consensus_val[:, 1::2]
# tgt_val_lat = np.array(df_2012_train['TRUTH_DLAT_2012_2016_val'])[index2]
# tgt_val_lon = np.array(df_2012_train['TRUTH_DLON_2012_2016_val'])[index2]
# tgt_val = np.array(df_2012_train[['TRUTH_DLAT_2012_2016_val', 'TRUTH_DLON_2012_2016_val']])[index2]

# %%
# EP
# Set the parameters by cross-validation
tuned_parameters = [{'l1_ratio': [0.5, 0.3, 0.8, 0.1, 0.9], 'alpha': [1, 2, 0.1, 0.05, 0.01, 0.001, 0.0001, 0.2, 0.3, 10]}]

scores = ['neg_mean_absolute_error', 'neg_mean_squared_error']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf_lat = GridSearchCV(
        ElasticNet(), tuned_parameters, scoring= score
    )
    clf_lat.fit(consensus_val_lat, tgt_val_lat)

    print("Best parameters set found on development set:")
    print()
    print(clf_lat.best_params_)
    print()
    '''
    print("Grid scores on development set:")
    print()
    means = clf_lat.cv_results_['mean_test_score']
    stds = clf_lat.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf_lat.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()
    '''
    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    
    ############# LONGITUDE #############
    clf_lon = GridSearchCV(
        ElasticNet(), tuned_parameters, scoring= score
    )
    clf_lon.fit(consensus_val_lon, tgt_val_lon)

    print("Best parameters set found on development set:")
    print()
    print(clf_lon.best_params_)
    print()
    '''
    print("Grid scores on development set:")
    print()
    means = clf_lon.cv_results_['mean_test_score']
    stds = clf_lon.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf_lon.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()
    '''

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    
    DLATS_PRED = np.array(clf_lat.predict(consensus_test_lat)) * std_dx + mean_dx
    DLONS_PRED = np.array(clf_lon.predict(consensus_test_lon)) * std_dy + mean_dy
    LATS_PRED_ = np.array(X_test['LAT_7'][index]) + DLATS_PRED
    LONS_PRED_ = np.array(X_test['LON_7'][index]) + DLONS_PRED
    LATS_TEST_ = (np.array(tgt_displacement_test[:, 0])*std_dx+mean_dx)[index]+np.array(X_test['LAT_7'][index])
    LONS_TEST_ = np.array(X_test['LON_7'][index]) + (np.array(tgt_displacement_test[:, 1])*std_dy+mean_dy)[index]
    
    d_km_pred = np.zeros(len(LONS_PRED_))
    for i in range(len(LATS_PRED_)):
        #if LONS_TEST_[i] > 160:
            #LONS_PRED_[i] -= 360
        d_km_pred[i] = get_distance_km(LONS_PRED_[i], LATS_PRED_[i], LONS_TEST_[i], LATS_TEST_[i])
        
    print(basin, 'Model | MAE | std | %age busts (>200km)')
    print("Hurricast", np.around(d_km_pred.mean(), decimals = 2), np.around(d_km_pred.std(), decimals = 2), np.around(sum(d_km_pred > 200)*100/len(LATS_PRED_), decimals = 2))
    #print(classification_report(y_true, y_pred))
# Out:
# # Tuning hyper-parameters for neg_mean_absolute_error
#
# Best parameters set found on development set:
#
# {'alpha': 0.01, 'l1_ratio': 0.5}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
# Best parameters set found on development set:
#
# {'alpha': 0.001, 'l1_ratio': 0.8}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 68.03 40.76 0.72
# # Tuning hyper-parameters for neg_mean_squared_error
#
# Best parameters set found on development set:
#
# {'alpha': 0.001, 'l1_ratio': 0.9}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
# Best parameters set found on development set:
#
# {'alpha': 0.001, 'l1_ratio': 0.9}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 68.15 40.83 0.72

# %%
# EP
# Set the parameters by cross-validation
tuned_parameters = [{'l1_ratio': [0.5, 0.3, 0.8, 0.1, 0.9], 'alpha': [1, 2, 0.1, 0.05, 0.01, 0.001, 0.0001, 0.2, 0.3, 10]}]

scores = ['neg_mean_absolute_error', 'neg_mean_squared_error']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf_lat = GridSearchCV(
        ElasticNet(), tuned_parameters, scoring= score
    )
    clf_lat.fit(consensus_val_lat, tgt_val_lat)

    print("Best parameters set found on development set:")
    print()
    print(clf_lat.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf_lat.cv_results_['mean_test_score']
    stds = clf_lat.cv_results_['std_test_score']
    #for mean, std, params in zip(means, stds, clf_lat.cv_results_['params']):
    #    print("%0.3f (+/-%0.03f) for %r"
    #          % (mean, std * 2, params))
    #print()

    ############# LONGITUDE #############
    clf_lon = GridSearchCV(
        ElasticNet(), tuned_parameters, scoring= score
    )
    clf_lon.fit(consensus_val_lon, tgt_val_lon)

    print("Best parameters set found on development set:")
    print()
    print(clf_lon.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf_lon.cv_results_['mean_test_score']
    stds = clf_lon.cv_results_['std_test_score']
    #for mean, std, params in zip(means, stds, clf_lon.cv_results_['params']):
    #    print("%0.3f (+/-%0.03f) for %r"
    #          % (mean, std * 2, params))
    #print()

    DLATS_PRED = np.array(clf_lat.predict(consensus_test_lat)) * std_dx + mean_dx
    DLONS_PRED = np.array(clf_lon.predict(consensus_test_lon)) * std_dy + mean_dy
    LATS_PRED_ = np.array(X_test['LAT_7'][index]) + DLATS_PRED
    LONS_PRED_ = np.array(X_test['LON_7'][index]) + DLONS_PRED
    LATS_TEST_ = (np.array(tgt_displacement_test[:, 0])*std_dx+mean_dx)[index]+np.array(X_test['LAT_7'][index])
    LONS_TEST_ = np.array(X_test['LON_7'][index]) + (np.array(tgt_displacement_test[:, 1])*std_dy+mean_dy)[index]
    
    d_km_pred = np.zeros(len(LONS_PRED_))
    for i in range(len(LATS_PRED_)):
        #if LONS_TEST_[i] > 160:
            #LONS_PRED_[i] -= 360
        d_km_pred[i] = get_distance_km(LONS_PRED_[i], LATS_PRED_[i], LONS_TEST_[i], LATS_TEST_[i])
        
    print(basin, 'Model | MAE | std | %age busts (>200km)')
    print("Hurricast", np.around(d_km_pred.mean(), decimals = 2), np.around(d_km_pred.std(), decimals = 2), np.around(sum(d_km_pred > 200)*100/len(LATS_PRED_), decimals = 2))
    #print(classification_report(y_true, y_pred))
# Out:
# # Tuning hyper-parameters for neg_mean_absolute_error
#
# Best parameters set found on development set:
#
# {'alpha': 0.001, 'l1_ratio': 0.3}
#
# Grid scores on development set:
#
# Best parameters set found on development set:
#
# {'alpha': 0.001, 'l1_ratio': 0.8}
#
# Grid scores on development set:
#
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 67.92 41.09 0.96
# # Tuning hyper-parameters for neg_mean_squared_error
#
# Best parameters set found on development set:
#
# {'alpha': 0.01, 'l1_ratio': 0.3}
#
# Grid scores on development set:
#
# Best parameters set found on development set:
#
# {'alpha': 0.001, 'l1_ratio': 0.8}
#
# Grid scores on development set:
#
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 67.86 41.02 0.96

# %% [markdown]
# ### Best score EP: separated targets, same input data

# %%
# EP
# Set the parameters by cross-validation
tuned_parameters = [{'l1_ratio': [0.5, 0.3, 0.8, 0.1, 0.9], 'alpha': [1, 2, 0.1, 0.05, 0.01, 0.001, 0.0001, 0.2, 0.3, 10]}]

scores = ['neg_mean_absolute_error', 'neg_mean_squared_error']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf_lat = GridSearchCV(
        ElasticNet(), tuned_parameters, scoring= score
    )
    clf_lat.fit(consensus_val, tgt_val_lat)

    print("Best parameters set found on development set:")
    print()
    print(clf_lat.best_params_)
    print()
    '''
    print("Grid scores on development set:")
    print()
    means = clf_lat.cv_results_['mean_test_score']
    stds = clf_lat.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf_lat.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    '''
    ############# LONGITUDE #############
    clf_lon = GridSearchCV(
        ElasticNet(), tuned_parameters, scoring= score
    )
    clf_lon.fit(consensus_val, tgt_val_lon)

    print("Best parameters set found on development set:")
    
    print()
    print(clf_lon.best_params_)
    '''
    print()
    print("Grid scores on development set:")
    print()
    means = clf_lon.cv_results_['mean_test_score']
    stds = clf_lon.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf_lon.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    '''
    DLATS_PRED = np.array(clf_lat.predict(consensus_test)) * std_dx + mean_dx
    DLONS_PRED = np.array(clf_lon.predict(consensus_test)) * std_dy + mean_dy
    LATS_PRED_ = np.array(X_test['LAT_7'][index]) + DLATS_PRED
    LONS_PRED_ = np.array(X_test['LON_7'][index]) + DLONS_PRED
    LATS_TEST_ = (np.array(tgt_displacement_test[:, 0])*std_dx+mean_dx)[index]+np.array(X_test['LAT_7'][index])
    LONS_TEST_ = np.array(X_test['LON_7'][index]) + (np.array(tgt_displacement_test[:, 1])*std_dy+mean_dy)[index]
    
    d_km_pred = np.zeros(len(LONS_PRED_))
    for i in range(len(LATS_PRED_)):
        #if LONS_TEST_[i] > 160:
            #LONS_PRED_[i] -= 360
        d_km_pred[i] = get_distance_km(LONS_PRED_[i], LATS_PRED_[i], LONS_TEST_[i], LATS_TEST_[i])
        
    print(basin, 'Model | MAE | std | %age busts (>200km)')
    print("Hurricast", np.around(d_km_pred.mean(), decimals = 2), np.around(d_km_pred.std(), decimals = 2), np.around(sum(d_km_pred > 200)*100/len(LATS_PRED_), decimals = 2))
    #print(classification_report(y_true, y_pred))
# Out:
# # Tuning hyper-parameters for neg_mean_absolute_error
#
# Best parameters set found on development set:
#
# {'alpha': 0.01, 'l1_ratio': 0.5}
#
# Best parameters set found on development set:
#
# {'alpha': 0.01, 'l1_ratio': 0.9}
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 67.88 40.97 0.96
# # Tuning hyper-parameters for neg_mean_squared_error
#
# Best parameters set found on development set:
#
# {'alpha': 0.01, 'l1_ratio': 0.3}
#
# Best parameters set found on development set:
#
# {'alpha': 0.001, 'l1_ratio': 0.9}
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 67.89 40.96 0.96

# %%
df['PURE_HURR_Consensus_ElasticNet'] = d_km_pred

# %%
# EP
# Set the parameters by cross-validation
tuned_parameters = [{'l1_ratio': [0.5, 0.3, 0.8, 0.1, 0.9, 0.4, 0.95, 1], 'alpha': [1, 0.1, 0.05, 0.01, 0.005, 0.001, 0.0001, 0.2, 0.3, 10]}]

scores = ['neg_mean_absolute_error', 'neg_mean_squared_error']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf_lat = GridSearchCV(
        ElasticNet(), tuned_parameters, scoring= score
    )
    clf_lat.fit(consensus_val, tgt_val_lat)

    print("Best parameters set found on development set:")
    print(clf_lat.best_params_)

    means = clf_lat.cv_results_['mean_test_score']
    stds = clf_lat.cv_results_['std_test_score']
    #for mean, std, params in zip(means, stds, clf_lat.cv_results_['params']):
    #    print("%0.3f (+/-%0.03f) for %r"
    #          % (mean, std * 2, params))
    #print()

    
    ############# LONGITUDE #############
    clf_lon = GridSearchCV(
        ElasticNet(), tuned_parameters, scoring= score
    )
    clf_lon.fit(consensus_val, tgt_val_lon)

    print("Best parameters set found on development set:")
    print(clf_lon.best_params_)
    print()
    means = clf_lon.cv_results_['mean_test_score']
    stds = clf_lon.cv_results_['std_test_score']
    #for mean, std, params in zip(means, stds, clf_lon.cv_results_['params']):
    #    print("%0.3f (+/-%0.03f) for %r"
    #          % (mean, std * 2, params))
    #print()

    
    DLATS_PRED = np.array(clf_lat.predict(consensus_test)) * std_dx + mean_dx
    DLONS_PRED = np.array(clf_lon.predict(consensus_test)) * std_dy + mean_dy
    LATS_PRED_ = np.array(X_test['LAT_7'][index]) + DLATS_PRED
    LONS_PRED_ = np.array(X_test['LON_7'][index]) + DLONS_PRED
    LATS_TEST_ = (np.array(tgt_displacement_test[:, 0])*std_dx+mean_dx)[index]+np.array(X_test['LAT_7'][index])
    LONS_TEST_ = np.array(X_test['LON_7'][index]) + (np.array(tgt_displacement_test[:, 1])*std_dy+mean_dy)[index]
    
    d_km_pred = np.zeros(len(LONS_PRED_))
    for i in range(len(LATS_PRED_)):
        #if LONS_TEST_[i] > 160:
            #LONS_PRED_[i] -= 360
        d_km_pred[i] = get_distance_km(LONS_PRED_[i], LATS_PRED_[i], LONS_TEST_[i], LATS_TEST_[i])
        
    print(basin, 'Model | MAE | std | %age busts (>200km)')
    print("Hurricast", np.around(d_km_pred.mean(), decimals = 2), np.around(d_km_pred.std(), decimals = 2), np.around(sum(d_km_pred > 200)*100/len(LATS_PRED_), decimals = 2))
    #print(classification_report(y_true, y_pred))
# Out:
# # Tuning hyper-parameters for neg_mean_absolute_error
#
# Best parameters set found on development set:
# {'alpha': 0.005, 'l1_ratio': 0.8}
# Best parameters set found on development set:
# {'alpha': 0.005, 'l1_ratio': 0.9}
#
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 67.91 41.04 0.96
# # Tuning hyper-parameters for neg_mean_squared_error
#
# Best parameters set found on development set:
# {'alpha': 0.005, 'l1_ratio': 0.1}
# Best parameters set found on development set:
# {'alpha': 0.005, 'l1_ratio': 0.95}
#
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 67.92 40.98 0.96

# %% [markdown]
# ### MLP

# %%
# EP
# Set the parameters by cross-validation
tuned_parameters = [{'hidden_layer_sizes': [(16, 8),(16),(32),(8),(32,8)], 'alpha': [0.001, 0.0001]}]

scores = ['neg_mean_absolute_error', 'neg_mean_squared_error']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf_lat = GridSearchCV(
        MLPRegressor(), tuned_parameters, scoring=score
    )
    clf_lat.fit(consensus_val_lat, tgt_val_lat)

    print("Best parameters set found on development set:")
    print()
    print(clf_lat.best_params_)
    print()
    '''
    print("Grid scores on development set:")
    print()
    means = clf_lat.cv_results_['mean_test_score']
    stds = clf_lat.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf_lat.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    '''
    ############# LONGITUDE #############
    clf_lon = GridSearchCV(
        MLPRegressor(), tuned_parameters, scoring=score
    )
    clf_lon.fit(consensus_val_lon, tgt_val_lon)

    print("Best parameters set found on development set:")
    print()
    print(clf_lon.best_params_)
    print()
    print("Grid scores on development set:")
    '''
    print()
    means = clf_lon.cv_results_['mean_test_score']
    stds = clf_lon.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf_lon.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()
    
    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    '''
    DLATS_PRED = np.array(clf_lat.predict(consensus_test_lat)) * std_dx + mean_dx
    DLONS_PRED = np.array(clf_lon.predict(consensus_test_lon)) * std_dy + mean_dy
    LATS_PRED_ = np.array(X_test['LAT_7'][index]) + DLATS_PRED
    LONS_PRED_ = np.array(X_test['LON_7'][index]) + DLONS_PRED
    LATS_TEST_ = (np.array(tgt_displacement_test[:, 0])*std_dx+mean_dx)[index]+np.array(X_test['LAT_7'][index])
    LONS_TEST_ = np.array(X_test['LON_7'][index]) + (np.array(tgt_displacement_test[:, 1])*std_dy+mean_dy)[index]
    
    d_km_pred = np.zeros(len(LONS_PRED_))
    for i in range(len(LATS_PRED_)):
        #if LONS_TEST_[i] > 160:
            #LONS_PRED_[i] -= 360
        d_km_pred[i] = get_distance_km(LONS_PRED_[i], LATS_PRED_[i], LONS_TEST_[i], LATS_TEST_[i])
        if d_km_pred[i] > 200:
            print(LONS_PRED_[i], LATS_PRED_[i], LONS_TEST_[i], LATS_TEST_[i])
        
    print(basin, 'Model | MAE | std | %age busts (>200km)')
    print("Hurricast", np.around(d_km_pred.mean(), decimals = 2), np.around(d_km_pred.std(), decimals = 2), np.around(sum(d_km_pred > 200)*100/len(LATS_PRED_), decimals = 2))
    #print(classification_report(y_true, y_pred))
# Out:
# # Tuning hyper-parameters for neg_mean_absolute_error
#
# Best parameters set found on development set:
#
# {'alpha': 0.001, 'hidden_layer_sizes': (32, 8)}
#
# Grid scores on development set:
#
# -0.212 (+/-0.013) for {'alpha': 0.001, 'hidden_layer_sizes': (16, 8)}
# -0.212 (+/-0.011) for {'alpha': 0.001, 'hidden_layer_sizes': 16}
# -0.211 (+/-0.012) for {'alpha': 0.001, 'hidden_layer_sizes': 32}
# -0.212 (+/-0.011) for {'alpha': 0.001, 'hidden_layer_sizes': 8}
# -0.211 (+/-0.012) for {'alpha': 0.001, 'hidden_layer_sizes': (32, 8)}
# -0.211 (+/-0.012) for {'alpha': 0.0001, 'hidden_layer_sizes': (16, 8)}
# -0.212 (+/-0.010) for {'alpha': 0.0001, 'hidden_layer_sizes': 16}
# -0.211 (+/-0.012) for {'alpha': 0.0001, 'hidden_layer_sizes': 32}
# -0.213 (+/-0.009) for {'alpha': 0.0001, 'hidden_layer_sizes': 8}
# -0.213 (+/-0.013) for {'alpha': 0.0001, 'hidden_layer_sizes': (32, 8)}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
# Best parameters set found on development set:
#
# {'alpha': 0.001, 'hidden_layer_sizes': 16}
#
# Grid scores on development set:
#
# -0.169 (+/-0.008) for {'alpha': 0.001, 'hidden_layer_sizes': (16, 8)}
# -0.166 (+/-0.006) for {'alpha': 0.001, 'hidden_layer_sizes': 16}
# -0.167 (+/-0.007) for {'alpha': 0.001, 'hidden_layer_sizes': 32}
# -0.167 (+/-0.010) for {'alpha': 0.001, 'hidden_layer_sizes': 8}
# -0.167 (+/-0.009) for {'alpha': 0.001, 'hidden_layer_sizes': (32, 8)}
# -0.167 (+/-0.007) for {'alpha': 0.0001, 'hidden_layer_sizes': (16, 8)}
# -0.168 (+/-0.007) for {'alpha': 0.0001, 'hidden_layer_sizes': 16}
# -0.168 (+/-0.008) for {'alpha': 0.0001, 'hidden_layer_sizes': 32}
# -0.169 (+/-0.006) for {'alpha': 0.0001, 'hidden_layer_sizes': 8}
# -0.168 (+/-0.007) for {'alpha': 0.0001, 'hidden_layer_sizes': (32, 8)}
#
# -176.40276838289464 8.79011719466362 -176.5 10.6
# 225.38864441895754 16.24395285234779 227.40001 17.0
# -47.33910577641844 43.951775465240594 -49.800003 43.1
# -112.29191902001635 16.769121090953888 -114.9 15.2
# -39.073188775307585 22.108303488424927 -37.5575 23.349901
# -39.350727838654905 23.327688870297163 -37.6354 24.3848
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 68.14 40.72 0.72
# # Tuning hyper-parameters for neg_mean_squared_error
#
# Best parameters set found on development set:
#
# {'alpha': 0.0001, 'hidden_layer_sizes': 16}
#
# Grid scores on development set:
#
# -0.092 (+/-0.004) for {'alpha': 0.001, 'hidden_layer_sizes': (16, 8)}
# -0.093 (+/-0.003) for {'alpha': 0.001, 'hidden_layer_sizes': 16}
# -0.093 (+/-0.004) for {'alpha': 0.001, 'hidden_layer_sizes': 32}
# -0.092 (+/-0.003) for {'alpha': 0.001, 'hidden_layer_sizes': 8}
# -0.092 (+/-0.003) for {'alpha': 0.001, 'hidden_layer_sizes': (32, 8)}
# -0.093 (+/-0.002) for {'alpha': 0.0001, 'hidden_layer_sizes': (16, 8)}
# -0.091 (+/-0.002) for {'alpha': 0.0001, 'hidden_layer_sizes': 16}
# -0.093 (+/-0.002) for {'alpha': 0.0001, 'hidden_layer_sizes': 32}
# -0.093 (+/-0.001) for {'alpha': 0.0001, 'hidden_layer_sizes': 8}
# -0.093 (+/-0.002) for {'alpha': 0.0001, 'hidden_layer_sizes': (32, 8)}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
# Best parameters set found on development set:
#
# {'alpha': 0.001, 'hidden_layer_sizes': (32, 8)}
#
# Grid scores on development set:
#
# -0.062 (+/-0.005) for {'alpha': 0.001, 'hidden_layer_sizes': (16, 8)}
# -0.063 (+/-0.005) for {'alpha': 0.001, 'hidden_layer_sizes': 16}
# -0.061 (+/-0.003) for {'alpha': 0.001, 'hidden_layer_sizes': 32}
# -0.063 (+/-0.002) for {'alpha': 0.001, 'hidden_layer_sizes': 8}
# -0.061 (+/-0.005) for {'alpha': 0.001, 'hidden_layer_sizes': (32, 8)}
# -0.063 (+/-0.006) for {'alpha': 0.0001, 'hidden_layer_sizes': (16, 8)}
# -0.063 (+/-0.004) for {'alpha': 0.0001, 'hidden_layer_sizes': 16}
# -0.061 (+/-0.003) for {'alpha': 0.0001, 'hidden_layer_sizes': 32}
# -0.063 (+/-0.001) for {'alpha': 0.0001, 'hidden_layer_sizes': 8}
# -0.063 (+/-0.004) for {'alpha': 0.0001, 'hidden_layer_sizes': (32, 8)}
#
# -176.30791343321167 8.72961505846678 -176.5 10.6
# -127.43259136763379 24.492909846615884 -128.9 23.0
# 225.47792684293725 16.19685905911375 227.40001 17.0
# -47.34738061637112 44.030895961139066 -49.800003 43.1
# -112.18821189163805 16.816093560435554 -114.9 15.2
# -36.21595425929426 18.968131162605367 -34.315 19.357399
# -39.28650215843669 22.167128045160215 -37.5575 23.349901
# -39.53924917084394 23.448134035469668 -37.6354 24.3848
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 68.59 40.93 0.96

# %%
# EP
# Set the parameters by cross-validation
tuned_parameters = [{'hidden_layer_sizes': [(16, 8),(16),(32),(8),(32,8)], 'alpha': [0.001, 0.0001]}]

scores = ['neg_mean_squared_error', 'neg_mean_absolute_error']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf_lat = GridSearchCV(
        MLPRegressor(), tuned_parameters, scoring=score
    )
    clf_lat.fit(consensus_val_lat, tgt_val_lat)

    print("Best parameters set found on development set:")
    print()
    print(clf_lat.best_params_)
    print()
    '''
    print("Grid scores on development set:")
    print()
    means = clf_lat.cv_results_['mean_test_score']
    stds = clf_lat.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf_lat.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    '''
    ############# LONGITUDE #############
    clf_lon = GridSearchCV(
        MLPRegressor(), tuned_parameters, scoring=score
    )
    clf_lon.fit(consensus_val_lon, tgt_val_lon)

    print("Best parameters set found on development set:")
    print()
    print(clf_lon.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    '''
    means = clf_lon.cv_results_['mean_test_score']
    stds = clf_lon.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf_lon.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    '''
    DLATS_PRED = np.array(clf_lat.predict(consensus_test_lat)) * std_dx + mean_dx
    DLONS_PRED = np.array(clf_lon.predict(consensus_test_lon)) * std_dy + mean_dy
    LATS_PRED_ = np.array(X_test['LAT_7'][index]) + DLATS_PRED
    LONS_PRED_ = np.array(X_test['LON_7'][index]) + DLONS_PRED
    LATS_TEST_ = (np.array(tgt_displacement_test[:, 0])*std_dx+mean_dx)[index]+np.array(X_test['LAT_7'][index])
    LONS_TEST_ = np.array(X_test['LON_7'][index]) + (np.array(tgt_displacement_test[:, 1])*std_dy+mean_dy)[index]
    
    d_km_pred = np.zeros(len(LONS_PRED_))
    for i in range(len(LATS_PRED_)):
        #if LONS_TEST_[i] > 160:
            #LONS_PRED_[i] -= 360
        d_km_pred[i] = get_distance_km(LONS_PRED_[i], LATS_PRED_[i], LONS_TEST_[i], LATS_TEST_[i])
        
    print(basin, 'Model | MAE | std | %age busts (>200km)')
    print("Hurricast", np.around(d_km_pred.mean(), decimals = 2), np.around(d_km_pred.std(), decimals = 2), np.around(sum(d_km_pred > 200)*100/len(LATS_PRED_), decimals = 2))
    #print(classification_report(y_true, y_pred))
# Out:
# # Tuning hyper-parameters for neg_mean_squared_error
#
# Best parameters set found on development set:
#
# {'alpha': 0.001, 'hidden_layer_sizes': 16}
#
# Best parameters set found on development set:
#
# {'alpha': 0.0001, 'hidden_layer_sizes': 32}
#
# Grid scores on development set:
#
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 68.89 40.96 0.84
# # Tuning hyper-parameters for neg_mean_absolute_error
#
# Best parameters set found on development set:
#
# {'alpha': 0.001, 'hidden_layer_sizes': 32}
#
# Best parameters set found on development set:
#
# {'alpha': 0.001, 'hidden_layer_sizes': 16}
#
# Grid scores on development set:
#
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 68.39 39.78 0.36

# %%
# EP
# Set the parameters by cross-validation
tuned_parameters = [{'hidden_layer_sizes': [(16, 8),(16),(32),(8),(32,8)], 'alpha': [0.001, 0.0001]}]

scores = ['neg_mean_absolute_error', 'neg_mean_squared_error']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(
        MLPRegressor(), tuned_parameters, scoring=score
    )
    clf.fit(consensus_val, tgt_val)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    '''
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    '''
    
    DLATS_PRED = np.array(clf.predict(consensus_test)[:,0]) * std_dx + mean_dx
    DLONS_PRED = np.array(clf.predict(consensus_test)[:,1]) * std_dy + mean_dy
    LATS_PRED_ = np.array(X_test['LAT_7'][index]) + DLATS_PRED
    LONS_PRED_ = np.array(X_test['LON_7'][index]) + DLONS_PRED
    LATS_TEST_ = (np.array(tgt_displacement_test[:, 0])*std_dx+mean_dx)[index]+np.array(X_test['LAT_7'][index])
    LONS_TEST_ = np.array(X_test['LON_7'][index]) + (np.array(tgt_displacement_test[:, 1])*std_dy+mean_dy)[index]
    
    d_km_pred = np.zeros(len(LONS_PRED_))
    for i in range(len(LATS_PRED_)):
        #if LONS_TEST_[i] > 160:
            #LONS_PRED_[i] -= 360
        d_km_pred[i] = get_distance_km(LONS_PRED_[i], LATS_PRED_[i], LONS_TEST_[i], LATS_TEST_[i])
        #if d_km_pred[i] > 200:
            #print(LONS_PRED_[i], LATS_PRED_[i], LONS_TEST_[i], LATS_TEST_[i])
        
    print(basin, 'Model | MAE | std | %age busts (>200km)')
    print("Hurricast", np.around(d_km_pred.mean(), decimals = 2), np.around(d_km_pred.std(), decimals = 2), np.around(sum(d_km_pred > 200)*100/len(LATS_PRED_), decimals = 2))
    #print(classification_report(y_true, y_pred))
# Out:
# # Tuning hyper-parameters for neg_mean_absolute_error
#
# Best parameters set found on development set:
#
# {'alpha': 0.001, 'hidden_layer_sizes': 16}
#
# -176.23555258974787 8.818453039455084 -176.5 10.6
# -47.23489575667774 43.96064030125093 -49.800003 43.1
# -112.19786200212555 16.80432649862994 -114.9 15.2
# -38.94860751846028 21.9807779598859 -37.5575 23.349901
# -39.313147968000344 23.355706544052733 -37.6354 24.3848
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 69.25 40.42 0.6
# # Tuning hyper-parameters for neg_mean_squared_error
#
# Best parameters set found on development set:
#
# {'alpha': 0.001, 'hidden_layer_sizes': 8}
#
# 225.53778141787453 16.2126125568335 227.40001 17.0
# -47.031851596216455 43.79982345308395 -49.800003 43.1
# -112.2674725883356 16.71717134778855 -114.9 15.2
# -39.156498910560344 22.04014952550571 -37.5575 23.349901
# -39.471661680928506 23.42484544289782 -37.6354 24.3848
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 69.04 40.61 0.6

# %%
# EP
# Set the parameters by cross-validation
tuned_parameters = [{'hidden_layer_sizes': [(16, 8),(16),(32),(8),(32,8)], 'alpha': [0.001, 0.0001]}]

scores = ['neg_mean_absolute_error', 'neg_mean_squared_error']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(
        MLPRegressor(), tuned_parameters, scoring=score
    )
    clf.fit(consensus_val, tgt_val)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    '''
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    '''
    
    DLATS_PRED = np.array(clf.predict(consensus_test)[:,0]) * std_dx + mean_dx
    DLONS_PRED = np.array(clf.predict(consensus_test)[:,1]) * std_dy + mean_dy
    LATS_PRED_ = np.array(X_test['LAT_7'][index]) + DLATS_PRED
    LONS_PRED_ = np.array(X_test['LON_7'][index]) + DLONS_PRED
    LATS_TEST_ = (np.array(tgt_displacement_test[:, 0])*std_dx+mean_dx)[index]+np.array(X_test['LAT_7'][index])
    LONS_TEST_ = np.array(X_test['LON_7'][index]) + (np.array(tgt_displacement_test[:, 1])*std_dy+mean_dy)[index]
    
    d_km_pred = np.zeros(len(LONS_PRED_))
    for i in range(len(LATS_PRED_)):
        #if LONS_TEST_[i] > 160:
            #LONS_PRED_[i] -= 360
        d_km_pred[i] = get_distance_km(LONS_PRED_[i], LATS_PRED_[i], LONS_TEST_[i], LATS_TEST_[i])
        #if d_km_pred[i] > 200:
            #print(LONS_PRED_[i], LATS_PRED_[i], LONS_TEST_[i], LATS_TEST_[i])
        
    print(basin, 'Model | MAE | std | %age busts (>200km)')
    print("Hurricast", np.around(d_km_pred.mean(), decimals = 2), np.around(d_km_pred.std(), decimals = 2), np.around(sum(d_km_pred > 200)*100/len(LATS_PRED_), decimals = 2))
    #print(classification_report(y_true, y_pred))
# Out:
# # Tuning hyper-parameters for neg_mean_absolute_error
#
# Best parameters set found on development set:
#
# {'alpha': 0.0001, 'hidden_layer_sizes': 8}
#
# Grid scores on development set:
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 68.63 41.52 0.72
# # Tuning hyper-parameters for neg_mean_squared_error
#
# Best parameters set found on development set:
#
# {'alpha': 0.001, 'hidden_layer_sizes': 8}
#
# Grid scores on development set:
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 68.35 41.27 1.43

# %%
# EP with models trained until 2012
# Prediction of both lat and lon at the same time
# Set the parameters by cross-validation
tuned_parameters = [{'hidden_layer_sizes': [(16, 8),(16),(32),(8),(32,8)], 'alpha': [0.001, 0.0001]}]

scores = ['neg_mean_absolute_error', 'neg_mean_squared_error']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(
        MLPRegressor(), tuned_parameters, scoring=score
    )
    clf.fit(consensus_val, tgt_val)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    #for mean, std, params in zip(means, stds, clf.cv_results_['params']):
    #    print("%0.3f (+/-%0.03f) for %r"
    #          % (mean, std * 2, params))
    #print()

    
    
    DLATS_PRED = np.array(clf.predict(consensus_test)[:,0]) * std_dx + mean_dx
    DLONS_PRED = np.array(clf.predict(consensus_test)[:,1]) * std_dy + mean_dy
    LATS_PRED_ = np.array(X_test['LAT_7'][index]) + DLATS_PRED
    LONS_PRED_ = np.array(X_test['LON_7'][index]) + DLONS_PRED
    LATS_TEST_ = (np.array(tgt_displacement_test[:, 0])*std_dx+mean_dx)[index]+np.array(X_test['LAT_7'][index])
    LONS_TEST_ = np.array(X_test['LON_7'][index]) + (np.array(tgt_displacement_test[:, 1])*std_dy+mean_dy)[index]
    
    d_km_pred = np.zeros(len(LONS_PRED_))
    for i in range(len(LATS_PRED_)):
        #if LONS_TEST_[i] > 160:
            #LONS_PRED_[i] -= 360
        d_km_pred[i] = get_distance_km(LONS_PRED_[i], LATS_PRED_[i], LONS_TEST_[i], LATS_TEST_[i])
        #if d_km_pred[i] > 200:
            #print(LONS_PRED_[i], LATS_PRED_[i], LONS_TEST_[i], LATS_TEST_[i])
        
    print(basin, 'Model | MAE | std | %age busts (>200km)')
    print("Hurricast", np.around(d_km_pred.mean(), decimals = 2), np.around(d_km_pred.std(), decimals = 2), np.around(sum(d_km_pred > 200)*100/len(LATS_PRED_), decimals = 2))
    #print(classification_report(y_true, y_pred))
# Out:
# # Tuning hyper-parameters for neg_mean_absolute_error
#
# Best parameters set found on development set:
#
# {'alpha': 0.0001, 'hidden_layer_sizes': 16}
#
# Grid scores on development set:
#
# -176.32833177115114 8.73409929980242 -176.5 10.6
# -127.49678946518931 24.350541148643952 -128.9 23.0
# 225.33538691452554 16.239463185017833 227.40001 17.0
# -112.24376897169057 16.80178735789004 -114.9 15.2
# -36.17216011919425 18.889879135191045 -34.315 19.357399
# -39.15722725720036 22.06249643318726 -37.5575 23.349901
# -39.58598578048834 23.24044797514518 -37.6354 24.3848
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 69.32 40.82 0.84
# # Tuning hyper-parameters for neg_mean_squared_error
#
# Best parameters set found on development set:
#
# {'alpha': 0.0001, 'hidden_layer_sizes': 8}
#
# Grid scores on development set:
#
# -128.07735989712964 24.715500534361205 -128.9 23.0
# 225.5210865887206 16.204708969873586 227.40001 17.0
# -47.152948421215676 44.007609515600045 -49.800003 43.1
# -112.23282937303837 16.87134413360536 -114.9 15.2
# EP Model | MAE | std | %age busts (>200km)
# Hurricast 69.39 40.74 0.48

# %%
df['PURE_HURR_Consensus_MLP'] = d_km_pred

# %%
df.mean()
# Out:
# HURR_STAT_2016                     81.016080
# HURR_STAT_2012                     81.046547
# CLP5                              120.919567
# HWRF                               66.980853
# OFCL                               54.100326
# FSSE                               55.830321
# GFSO                               64.557098
# AEMN                               59.897902
# Consensus_wo_HURR                  55.066631
# Consensus_HURR_STAT                49.294860
# HURR_GRU_ONLY_2016                 72.548798
# HURR_GRU_ONLY_2012                 73.093393
# Consensus_HURR_GRU_ONLY            50.433271
# HURR_TRANSFO_ONLY_2016             73.370190
# HURR_TRANSFO_ONLY_2012             73.688793
# Consensus_HURR_TRANSFO_ONLY        49.969422
# HURR_STAT_GRU_2016                 71.482694
# HURR_STAT_GRU_2012                 72.615698
# Consensus_HURR_STAT_GRU            50.028149
# HURR_STAT_TRANSFO_2016             72.237620
# HURR_STAT_TRANSFO_2012             72.216593
# Consensus_HURR_STAT_TRANSFO        49.617726
# HURR_STAT_COMP_2016                81.441982
# HURR_STAT_COMP_2012                81.791454
# Consensus_HURR_STAT_COMP           49.531890
# PURE_HURR_Consensus_ElasticNet     67.856321
# PURE_HURR_Consensus_MLP            68.393508
# dtype: float64

# %%
df = pd.read_csv('EP_BOXPLOT_TRACK_v3.csv')

# %%
df.std()
# Out:
# Unnamed: 0                        241.765382
# HURR_STAT_2016                     46.546860
# HURR_STAT_2012                     47.218895
# CLP5                               66.834835
# HWRF                               42.264375
# OFCL                               32.604648
# FSSE                               47.416744
# GFSO                               45.015606
# AEMN                               37.366456
# Consensus_wo_HURR                  36.593070
# Consensus_HURR_STAT                31.449053
# HURR_GRU_ONLY_2016                 42.705423
# HURR_GRU_ONLY_2012                 43.192972
# Consensus_HURR_GRU_ONLY            31.925618
# HURR_TRANSFO_ONLY_2016             43.967285
# HURR_TRANSFO_ONLY_2012             44.766064
# Consensus_HURR_TRANSFO_ONLY        32.384138
# HURR_STAT_GRU_2016                 42.700944
# HURR_STAT_GRU_2012                 44.382065
# Consensus_HURR_STAT_GRU            31.503017
# HURR_STAT_TRANSFO_2016             42.695266
# HURR_STAT_TRANSFO_2012             42.956472
# Consensus_HURR_STAT_TRANSFO        32.105606
# HURR_STAT_COMP_2016                47.621673
# HURR_STAT_COMP_2012                47.942654
# Consensus_HURR_STAT_COMP           31.739508
# PURE_HURR_Consensus_ElasticNet     41.044600
# PURE_HURR_Consensus_MLP            39.802302
# dtype: float64

# %% [markdown]
# ## NA

# %%
df, df_2012_train, df_2012_test, df_2016_train, df_2016_test = pd.DataFrame(), pd.DataFrame(), pd.DataFrame(), pd.DataFrame(), pd.DataFrame()
#df, df_2012_train, df_2012_test, df_2016_train, df_2016_test = create_df_boxplots(dict=d_stat_only_NA, dict_consensus=d_boxplot_stat_only_EP, df = df, df_2012_train= df_2012_train, df_2012_test = df_2012_test, df_2016_train = df_2016_train, df_2016_test = df_2016_test, name = 'HURR_STAT')
#df, df_2012_train, df_2012_test, df_2016_train, df_2016_test = create_df_boxplots(dict=d_gru_only_NA, dict_consensus=d_boxplot_gru_only_EP, df = df, df_2012_train= df_2012_train, df_2012_test = df_2012_test, df_2016_train = df_2016_train, df_2016_test = df_2016_test, name = 'HURR_GRU_ONLY')
#df, df_2012_train, df_2012_test, df_2016_train, df_2016_test = create_df_boxplots(dict=d_transfo_only_NA, dict_consensus=d_boxplot_transfo_only_EP, df = df, df_2012_train= df_2012_train, df_2012_test = df_2012_test, df_2016_train = df_2016_train, df_2016_test = df_2016_test, name = 'HURR_TRANSFO_ONLY')
df, df_2012_train, df_2012_test, df_2016_train, df_2016_test = create_df_boxplots(dict=d_stat_gru_NA, dict_consensus=d_boxplot_stat_gru_EP, df = df, df_2012_train= df_2012_train, df_2012_test = df_2012_test, df_2016_train = df_2016_train, df_2016_test = df_2016_test, name = 'HURR_STAT_GRU')
df, df_2012_train, df_2012_test, df_2016_train, df_2016_test = create_df_boxplots(dict=d_stat_transfo_NA, dict_consensus=d_boxplot_stat_transfo_EP, df = df, df_2012_train= df_2012_train, df_2012_test = df_2012_test, df_2016_train = df_2016_train, df_2016_test = df_2016_test, name = 'HURR_STAT_TRANSFO')
df, df_2012_train, df_2012_test, df_2016_train, df_2016_test = create_df_boxplots(dict=d_stat_comp_NA, dict_consensus=d_boxplot_stat_comp_EP, df = df, df_2012_train= df_2012_train, df_2012_test = df_2012_test, df_2016_train = df_2016_train, df_2016_test = df_2016_test, name = 'HURR_STAT_COMP')
# Out:
# full1 (899,)
# full0 (899,)
# full1 (899,)
# full0 (899,)
# full1 (899,)
# full0 (899,)

# %%
df, df_2012_train, df_2012_test, df_2016_train, df_2016_test = pd.DataFrame(), pd.DataFrame(), pd.DataFrame(), pd.DataFrame(), pd.DataFrame()
#df, df_2012_train, df_2012_test, df_2016_train, df_2016_test = create_df_boxplots(dict=d_stat_only_NA, dict_consensus=d_boxplot_stat_only_NA, df = df, df_2012_train= df_2012_train, df_2012_test = df_2012_test, df_2016_train = df_2016_train, df_2016_test = df_2016_test, name = 'HURR_STAT')
#df, df_2012_train, df_2012_test, df_2016_train, df_2016_test = create_df_boxplots(dict=d_gru_only_NA, dict_consensus=d_boxplot_gru_only_NA, df = df, df_2012_train= df_2012_train, df_2012_test = df_2012_test, df_2016_train = df_2016_train, df_2016_test = df_2016_test, name = 'HURR_GRU_ONLY')
#df, df_2012_train, df_2012_test, df_2016_train, df_2016_test = create_df_boxplots(dict=d_transfo_only_NA, dict_consensus=d_boxplot_transfo_only_NA, df = df, df_2012_train= df_2012_train, df_2012_test = df_2012_test, df_2016_train = df_2016_train, df_2016_test = df_2016_test, name = 'HURR_TRANSFO_ONLY')
df, df_2012_train, df_2012_test, df_2016_train, df_2016_test = create_df_boxplots(dict=d_stat_gru_NA, dict_consensus=d_boxplot_stat_gru_NA, df = df, df_2012_train= df_2012_train, df_2012_test = df_2012_test, df_2016_train = df_2016_train, df_2016_test = df_2016_test, name = 'HURR_STAT_GRU')
df, df_2012_train, df_2012_test, df_2016_train, df_2016_test = create_df_boxplots(dict=d_stat_transfo_NA, dict_consensus=d_boxplot_stat_transfo_NA, df = df, df_2012_train= df_2012_train, df_2012_test = df_2012_test, df_2016_train = df_2016_train, df_2016_test = df_2016_test, name = 'HURR_STAT_TRANSFO')
#df, df_2012_train, df_2012_test, df_2016_train, df_2016_test = create_df_boxplots(dict=d_stat_comp_NA, dict_consensus=d_boxplot_stat_comp_NA, df = df, df_2012_train= df_2012_train, df_2012_test = df_2012_test, df_2016_train = df_2016_train, df_2016_test = df_2016_test, name = 'HURR_STAT_COMP')
# Out:
# full1 (899,)
# full0 (899,)
# full1 (899,)
# full0 (899,)

# %%
df.to_csv('NA_BOXPLOT_TRACK_v3.csv')

# %%
df.mean()
# Out:
# HURR_STAT_GRU_2016             110.623162
# HURR_STAT_GRU_2012             111.171600
# CLP5                           201.237507
# HWRF                            74.978836
# OFCL                            71.238620
# FSSE                            68.918809
# GFSO                            70.548137
# AEMN                            73.204845
# Consensus_wo_HURR               63.809419
# Consensus_HURR_STAT_GRU         60.961652
# HURR_STAT_TRANSFO_2016         109.079865
# HURR_STAT_TRANSFO_2012         109.124757
# Consensus_HURR_STAT_TRANSFO     61.500629
# dtype: float64

# %%
df.std()
# Out:
# HURR_STAT_GRU_2016              79.601103
# HURR_STAT_GRU_2012              79.460124
# CLP5                           149.334753
# HWRF                            49.124038
# OFCL                            55.546283
# FSSE                            52.587413
# GFSO                            54.303370
# AEMN                            55.015599
# Consensus_wo_HURR               47.846071
# Consensus_HURR_STAT_GRU         43.533687
# HURR_STAT_TRANSFO_2016          71.190477
# HURR_STAT_TRANSFO_2012          72.346190
# Consensus_HURR_STAT_TRANSFO     42.517117
# HURR_STAT_COMP_2016            107.611142
# HURR_STAT_COMP_2012            108.045707
# Consensus_HURR_STAT_COMP        44.737405
# dtype: float64

# %%
mode = 'lat'
basin = 'AN'
forecast2 = 'SHIP'
forecast2 = 'HWRF'
forecast3 = 'OFCL' 
forecast4 = 'FSSE' 
forecast5 = 'GFSO' 
forecast6 = 'AEMN' 
forecast7 = 'CLP5'

test_ = X_test_baseline.loc[X_test_baseline['YEAR_0'] >= 2016].loc[
            X_test_baseline[forecast7 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast6 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast5 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast4 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast3 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast2 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast + '_24_' + mode + '_7'] > -320].loc[X_test_baseline['cat_basin_' + basin + '_0'] == 1]  # .loc[#X_test_baseline['SHIP_24_'+mode+'_7'] > 0].index

if basin == 'EP':
    test_ = test_.loc[X_test_baseline['YEAR_0'] < 2019]
    
index = test_.index


test_2 = X_test_baseline.loc[X_test_baseline['YEAR_0'] < 2016].loc[X_test_baseline['cat_basin_' + basin + '_0'] == 1]
index2 = test_2.index

test_3 = X_test_baseline.loc[X_test_baseline['YEAR_0'] < 2016]
index3 = test_3.index

# %% [markdown]
# ### ElasticNet

# %%
#2012 model 
#Version trained until 2012
consensus_test = np.array(df_2012_test)[index][:,2:]
consensus_test_lat = consensus_test[:, ::2]
consensus_test_lon = consensus_test[:, 1::2]
tgt_test_lat = np.array(df_2012_test['TRUTH_DLAT_2012_2020_test'])[index]
tgt_test_lon = np.array(df_2012_test['TRUTH_DLON_2012_2020_test'])[index]
tgt_test = np.array(df_2012_test[['TRUTH_DLAT_2012_2020_test', 'TRUTH_DLON_2012_2020_test']])[index]

consensus_val = np.array(df_2012_train)[:,2:][index2]
consensus_val_lat = consensus_val[:, ::2]
consensus_val_lon = consensus_val[:, 1::2]
tgt_val_lat = np.array(df_2012_train['TRUTH_DLAT_2012_2016_val'])[index2]
tgt_val_lon = np.array(df_2012_train['TRUTH_DLON_2012_2016_val'])[index2]
tgt_val = np.array(df_2012_train[['TRUTH_DLAT_2012_2016_val', 'TRUTH_DLON_2012_2016_val']])[index2]

# %%
#2012 model 
#Version trained until 2012
consensus_test = np.concatenate((np.array(df_2012_test)[index][:,2:],np.array(X_test[['COS_LAT_7', 'SIN_LAT_7']])[index]), axis = 1)
consensus_test_lat = consensus_test[:, ::2]
consensus_test_lon = consensus_test[:, 1::2]
tgt_test_lat = np.array(df_2012_test['TRUTH_DLAT_2012_2020_test'])[index]
tgt_test_lon = np.array(df_2012_test['TRUTH_DLON_2012_2020_test'])[index]
tgt_test = np.array(df_2012_test[['TRUTH_DLAT_2012_2020_test', 'TRUTH_DLON_2012_2020_test']])[index]

consensus_val = np.concatenate((np.array(df_2012_train)[:,2:], np.array(X_test[['COS_LAT_7', 'SIN_LAT_7']])[index3]), axis = 1)
consensus_val_lat = consensus_val[:, ::2]
consensus_val_lon = consensus_val[:, 1::2]
tgt_val_lat = np.array(df_2012_train['TRUTH_DLAT_2012_2016_val'])
tgt_val_lon = np.array(df_2012_train['TRUTH_DLON_2012_2016_val'])
tgt_val = np.array(df_2012_train[['TRUTH_DLAT_2012_2016_val', 'TRUTH_DLON_2012_2016_val']])

# %% [markdown]
# #### Target separate, data not separate

# %%
# NA
# Set the parameters by cross-validation
tuned_parameters = [{'l1_ratio': [0.5, 0.3, 0.8, 0.1, 0.9], 'alpha': [1, 2, 0.1, 0.05, 0.01, 0.001, 0.0001, 0.2, 0.3, 10]}]

scores = ['neg_mean_absolute_error', 'neg_mean_squared_error']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf_lat = GridSearchCV(
        ElasticNet(), tuned_parameters, scoring= score
    )
    clf_lat.fit(consensus_val, tgt_val_lat)

    print("Best parameters set found on development set:")
    print()
    print(clf_lat.best_params_)
    print()
    '''
    print("Grid scores on development set:")
    print()
    means = clf_lat.cv_results_['mean_test_score']
    stds = clf_lat.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf_lat.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    '''
    
    ############# LONGITUDE #############
    clf_lon = GridSearchCV(
        ElasticNet(), tuned_parameters, scoring= score
    )
    clf_lon.fit(consensus_val, tgt_val_lon)

    print("Best parameters set found on development set:")
    print()
    print(clf_lon.best_params_)
    print()
    
    '''
    print("Grid scores on development set:")
    print()
    means = clf_lon.cv_results_['mean_test_score']
    stds = clf_lon.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf_lon.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    '''
    DLATS_PRED = np.array(clf_lat.predict(consensus_test)) * std_dx + mean_dx
    DLONS_PRED = np.array(clf_lon.predict(consensus_test)) * std_dy + mean_dy
    LATS_PRED_ = np.array(X_test['LAT_7'][index]) + DLATS_PRED
    LONS_PRED_ = np.array(X_test['LON_7'][index]) + DLONS_PRED
    LATS_TEST_ = (np.array(tgt_displacement_test[:, 0])*std_dx+mean_dx)[index]+np.array(X_test['LAT_7'][index])
    LONS_TEST_ = np.array(X_test['LON_7'][index]) + (np.array(tgt_displacement_test[:, 1])*std_dy+mean_dy)[index]
    
    d_km_pred = np.zeros(len(LONS_PRED_))
    for i in range(len(LATS_PRED_)):
        #if LONS_TEST_[i] > 160:
            #LONS_PRED_[i] -= 360
        d_km_pred[i] = get_distance_km(LONS_PRED_[i], LATS_PRED_[i], LONS_TEST_[i], LATS_TEST_[i])
        
    print(basin, 'Model | MAE | std | %age busts (>200km)')
    print("Hurricast", np.around(d_km_pred.mean(), decimals = 2), np.around(d_km_pred.std(), decimals = 2), np.around(sum(d_km_pred > 200)*100/len(LATS_PRED_), decimals = 2))
    #print(classification_report(y_true, y_pred))
# Out:
# # Tuning hyper-parameters for neg_mean_absolute_error
#
# Best parameters set found on development set:
#
# {'alpha': 0.01, 'l1_ratio': 0.3}
#
# Best parameters set found on development set:
#
# {'alpha': 0.01, 'l1_ratio': 0.1}
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 107.97 77.44 9.9
# # Tuning hyper-parameters for neg_mean_squared_error
#
# Best parameters set found on development set:
#
# {'alpha': 0.01, 'l1_ratio': 0.3}
#
# Best parameters set found on development set:
#
# {'alpha': 0.001, 'l1_ratio': 0.1}
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 108.1 77.62 9.45

# %% [markdown]
# #### Target separate, Data Separate

# %%
# NA
# Set the parameters by cross-validation
tuned_parameters = [{'l1_ratio': [0.5, 0.3, 0.8, 0.1, 0.9], 'alpha': [1, 2, 0.1, 0.05, 0.01, 0.001, 0.0001, 0.2, 0.3, 10]}]

scores = ['neg_mean_absolute_error', 'neg_mean_squared_error']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf_lat = GridSearchCV(
        ElasticNet(), tuned_parameters, scoring= score
    )
    clf_lat.fit(consensus_val_lat, tgt_val_lat)

    print("Best parameters set found on development set:")
    print()
    print(clf_lat.best_params_)
    print()
    '''
    print("Grid scores on development set:")
    print()
    means = clf_lat.cv_results_['mean_test_score']
    stds = clf_lat.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf_lat.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    '''
    ############# LONGITUDE #############
    clf_lon = GridSearchCV(
        ElasticNet(), tuned_parameters, scoring= score
    )
    clf_lon.fit(consensus_val_lon, tgt_val_lon)

    print("Best parameters set found on development set:")
    print()
    print(clf_lon.best_params_)
    print()
    '''
    print("Grid scores on development set:")
    print()
    means = clf_lon.cv_results_['mean_test_score']
    stds = clf_lon.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf_lon.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    '''
    DLATS_PRED = np.array(clf_lat.predict(consensus_test_lat)) * std_dx + mean_dx
    DLONS_PRED = np.array(clf_lon.predict(consensus_test_lon)) * std_dy + mean_dy
    LATS_PRED_ = np.array(X_test['LAT_7'][index]) + DLATS_PRED
    LONS_PRED_ = np.array(X_test['LON_7'][index]) + DLONS_PRED
    LATS_TEST_ = (np.array(tgt_displacement_test[:, 0])*std_dx+mean_dx)[index]+np.array(X_test['LAT_7'][index])
    LONS_TEST_ = np.array(X_test['LON_7'][index]) + (np.array(tgt_displacement_test[:, 1])*std_dy+mean_dy)[index]
    
    d_km_pred = np.zeros(len(LONS_PRED_))
    for i in range(len(LATS_PRED_)):
        #if LONS_TEST_[i] > 160:
            #LONS_PRED_[i] -= 360
        d_km_pred[i] = get_distance_km(LONS_PRED_[i], LATS_PRED_[i], LONS_TEST_[i], LATS_TEST_[i])
        
    print(basin, 'Model | MAE | std | %age busts (>200km)')
    print("Hurricast", np.around(d_km_pred.mean(), decimals = 2), np.around(d_km_pred.std(), decimals = 2), np.around(sum(d_km_pred > 200)*100/len(LATS_PRED_), decimals = 2))
    #print(classification_report(y_true, y_pred))
# Out:
# # Tuning hyper-parameters for neg_mean_absolute_error
#
# Best parameters set found on development set:
#
# {'alpha': 0.01, 'l1_ratio': 0.3}
#
# Best parameters set found on development set:
#
# {'alpha': 0.001, 'l1_ratio': 0.8}
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 107.11 76.55 9.34
# # Tuning hyper-parameters for neg_mean_squared_error
#
# Best parameters set found on development set:
#
# {'alpha': 0.001, 'l1_ratio': 0.9}
#
# Best parameters set found on development set:
#
# {'alpha': 0.001, 'l1_ratio': 0.9}
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 107.31 76.77 9.45

# %%
df['PURE_HURR_Consensus_ElasticNet'] = d_km_pred

# %% [markdown]
# ## XGBoost ensemble

# %%
# NA
# Set the parameters by cross-validation
tuned_parameters = [{'max_depth': [2, 3, 4], 'n_estimators': [30, 50, 80], 'learning_rate': [0.2, 0.1, 0.07], 'min_child_weight': [1,3]}]

scores = ['neg_mean_absolute_error', 'neg_mean_squared_error']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf_lat = GridSearchCV(
        XGBRegressor(tree_method='gpu_hist', gpu_id=0), tuned_parameters, scoring= score
    )
    clf_lat.fit(consensus_val, tgt_val_lat)

    print("Best parameters set found on development set:")
    print()
    print(clf_lat.best_params_)
    print()
    '''
    print("Grid scores on development set:")
    print()
    means = clf_lat.cv_results_['mean_test_score']
    stds = clf_lat.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf_lat.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    '''
    ############# LONGITUDE #############
    clf_lon = GridSearchCV(
        XGBRegressor(tree_method='gpu_hist', gpu_id=0), tuned_parameters, scoring= score
    )
    clf_lon.fit(consensus_val, tgt_val_lon)

    print("Best parameters set found on development set:")
    print()
    print(clf_lon.best_params_)
    print()
    '''
    print("Grid scores on development set:")
    print()
    means = clf_lon.cv_results_['mean_test_score']
    stds = clf_lon.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf_lon.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    '''
    DLATS_PRED = np.array(clf_lat.predict(consensus_test)) * std_dx + mean_dx
    DLONS_PRED = np.array(clf_lon.predict(consensus_test)) * std_dy + mean_dy
    LATS_PRED_ = np.array(X_test['LAT_7'][index]) + DLATS_PRED
    LONS_PRED_ = np.array(X_test['LON_7'][index]) + DLONS_PRED
    LATS_TEST_ = (np.array(tgt_displacement_test[:, 0])*std_dx+mean_dx)[index]+np.array(X_test['LAT_7'][index])
    LONS_TEST_ = np.array(X_test['LON_7'][index]) + (np.array(tgt_displacement_test[:, 1])*std_dy+mean_dy)[index]
    
    d_km_pred = np.zeros(len(LONS_PRED_))
    for i in range(len(LATS_PRED_)):
        #if LONS_TEST_[i] > 160:
            #LONS_PRED_[i] -= 360
        d_km_pred[i] = get_distance_km(LONS_PRED_[i], LATS_PRED_[i], LONS_TEST_[i], LATS_TEST_[i])
        
    print(basin, 'Model | MAE | std | %age busts (>200km)')
    print("Hurricast", np.around(d_km_pred.mean(), decimals = 2), np.around(d_km_pred.std(), decimals = 2), np.around(sum(d_km_pred > 200)*100/len(LATS_PRED_), decimals = 2))
    #print(classification_report(y_true, y_pred))
# Out:
# # Tuning hyper-parameters for neg_mean_absolute_error
#
# Best parameters set found on development set:
#
# {'learning_rate': 0.07, 'max_depth': 2, 'min_child_weight': 1, 'n_estimators': 50}
#
# Best parameters set found on development set:
#
# {'learning_rate': 0.1, 'max_depth': 2, 'min_child_weight': 3, 'n_estimators': 80}
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 117.57 88.11 11.79
# # Tuning hyper-parameters for neg_mean_squared_error
#
# Best parameters set found on development set:
#
# {'learning_rate': 0.1, 'max_depth': 2, 'min_child_weight': 1, 'n_estimators': 80}
#
# Best parameters set found on development set:
#
# {'learning_rate': 0.1, 'max_depth': 2, 'min_child_weight': 3, 'n_estimators': 80}
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 117.07 87.4 12.01

# %% [markdown]
# ### MLP

# %%
#2012 model 
#Version trained until 2012
consensus_test = np.array(df_2012_test)[index][:,2:]
consensus_test_lat = consensus_test[:, ::2]
consensus_test_lon = consensus_test[:, 1::2]
tgt_test_lat = np.array(df_2012_test['TRUTH_DLAT_2012_2020_test'])[index]
tgt_test_lon = np.array(df_2012_test['TRUTH_DLON_2012_2020_test'])[index]
tgt_test = np.array(df_2012_test[['TRUTH_DLAT_2012_2020_test', 'TRUTH_DLON_2012_2020_test']])[index]

consensus_val = np.array(df_2012_train)[:,2:]
consensus_val_lat = consensus_val[:, ::2]
consensus_val_lon = consensus_val[:, 1::2]
tgt_val_lat = np.array(df_2012_train['TRUTH_DLAT_2012_2016_val'])
tgt_val_lon = np.array(df_2012_train['TRUTH_DLON_2012_2016_val'])
tgt_val = np.array(df_2012_train[['TRUTH_DLAT_2012_2016_val', 'TRUTH_DLON_2012_2016_val']])

# %% [markdown]
# #### Lat and Lon not separate at all

# %%
# NA 
# Set the parameters by cross-validation
tuned_parameters = [{'hidden_layer_sizes': [(16, 8),(16),(32),(8),(32,8)], 'alpha': [0.001, 0.0001]}]

scores = ['neg_mean_absolute_error', 'neg_mean_squared_error']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(
        MLPRegressor(), tuned_parameters, scoring=score
    )
    clf.fit(consensus_val, tgt_val)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    '''
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    '''
    
    DLATS_PRED = np.array(clf.predict(consensus_test)[:,0]) * std_dx + mean_dx
    DLONS_PRED = np.array(clf.predict(consensus_test)[:,1]) * std_dy + mean_dy
    LATS_PRED_ = np.array(X_test['LAT_7'][index]) + DLATS_PRED
    LONS_PRED_ = np.array(X_test['LON_7'][index]) + DLONS_PRED
    LATS_TEST_ = (np.array(tgt_displacement_test[:, 0])*std_dx+mean_dx)[index]+np.array(X_test['LAT_7'][index])
    LONS_TEST_ = np.array(X_test['LON_7'][index]) + (np.array(tgt_displacement_test[:, 1])*std_dy+mean_dy)[index]
    
    d_km_pred = np.zeros(len(LONS_PRED_))
    for i in range(len(LATS_PRED_)):
        #if LONS_TEST_[i] > 160:
            #LONS_PRED_[i] -= 360
        d_km_pred[i] = get_distance_km(LONS_PRED_[i], LATS_PRED_[i], LONS_TEST_[i], LATS_TEST_[i])
        
    print(basin, 'Model | MAE | std | %age busts (>200km)')
    print("Hurricast", np.around(d_km_pred.mean(), decimals = 2), np.around(d_km_pred.std(), decimals = 2), np.around(sum(d_km_pred > 200)*100/len(LATS_PRED_), decimals = 2))
    #print(classification_report(y_true, y_pred))
# Out:
# # Tuning hyper-parameters for neg_mean_absolute_error
#
# Best parameters set found on development set:
#
# {'alpha': 0.0001, 'hidden_layer_sizes': 32}
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 107.2 76.67 10.12
# # Tuning hyper-parameters for neg_mean_squared_error
#
# Best parameters set found on development set:
#
# {'alpha': 0.0001, 'hidden_layer_sizes': 16}
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 109.65 81.14 10.57

# %% [markdown]
# #### Target separate, Data not separate

# %%
# NA MLP lat and lon separate for target only
# Set the parameters by cross-validation
tuned_parameters = [{'hidden_layer_sizes': [(16, 8),(16),(32),(8),(32,8)], 'alpha': [0.001, 0.0001]}]

scores = ['neg_mean_absolute_error', 'neg_mean_squared_error']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf_lat = GridSearchCV(
        MLPRegressor(), tuned_parameters, scoring=score
    )
    clf_lat.fit(consensus_val, tgt_val_lat)

    print("Best parameters set found on development set:")
    print()
    print(clf_lat.best_params_)
    '''
    print()
    print("Grid scores on development set:")
    print()
    means = clf_lat.cv_results_['mean_test_score']
    stds = clf_lat.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf_lat.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    '''
    ############# LONGITUDE #############
    clf_lon = GridSearchCV(
        MLPRegressor(), tuned_parameters, scoring=score
    )
    clf_lon.fit(consensus_val, tgt_val_lon)

    print("Best parameters set found on development set:")
    print()
    print(clf_lon.best_params_)
    print()
    
    '''
    print("Grid scores on development set:")
    print()
    means = clf_lon.cv_results_['mean_test_score']
    stds = clf_lon.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf_lon.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    '''
    
    DLATS_PRED = np.array(clf_lat.predict(consensus_test)) * std_dx + mean_dx
    DLONS_PRED = np.array(clf_lon.predict(consensus_test)) * std_dy + mean_dy
    LATS_PRED_ = np.array(X_test['LAT_7'][index]) + DLATS_PRED
    LONS_PRED_ = np.array(X_test['LON_7'][index]) + DLONS_PRED
    LATS_TEST_ = (np.array(tgt_displacement_test[:, 0])*std_dx+mean_dx)[index]+np.array(X_test['LAT_7'][index])
    LONS_TEST_ = np.array(X_test['LON_7'][index]) + (np.array(tgt_displacement_test[:, 1])*std_dy+mean_dy)[index]
    
    d_km_pred = np.zeros(len(LONS_PRED_))
    for i in range(len(LATS_PRED_)):
        #if LONS_TEST_[i] > 160:
            #LONS_PRED_[i] -= 360
        d_km_pred[i] = get_distance_km(LONS_PRED_[i], LATS_PRED_[i], LONS_TEST_[i], LATS_TEST_[i])

        
    print(basin, 'Model | MAE | std | %age busts (>200km)')
    print("Hurricast", np.around(d_km_pred.mean(), decimals = 2), np.around(d_km_pred.std(), decimals = 2), np.around(sum(d_km_pred > 200)*100/len(LATS_PRED_), decimals = 2))
    #print(classification_report(y_true, y_pred))
# Out:
# # Tuning hyper-parameters for neg_mean_absolute_error
#
# Best parameters set found on development set:
#
# {'alpha': 0.0001, 'hidden_layer_sizes': 32}
# Best parameters set found on development set:
#
# {'alpha': 0.0001, 'hidden_layer_sizes': 32}
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 108.4 77.36 10.12
# # Tuning hyper-parameters for neg_mean_squared_error
#
# Best parameters set found on development set:
#
# {'alpha': 0.0001, 'hidden_layer_sizes': 32}
# Best parameters set found on development set:
#
# {'alpha': 0.0001, 'hidden_layer_sizes': 16}
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 109.45 81.23 10.12

# %% [markdown]
# #### Target separate, Data separate

# %%
# NA
# Set the parameters by cross-validation
tuned_parameters = [{'hidden_layer_sizes': [(16, 8),(16),(32),(8),(32,8)], 'alpha': [0.001, 0.0001]}]

scores = ['neg_mean_squared_error', 'neg_mean_absolute_error']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf_lat = GridSearchCV(
        MLPRegressor(), tuned_parameters, scoring=score
    )
    clf_lat.fit(consensus_val_lat, tgt_val_lat)

    print("Best parameters set found on development set:")
    print()
    print(clf_lat.best_params_)
    '''
    print()
    print("Grid scores on development set:")
    print()
    means = clf_lat.cv_results_['mean_test_score']
    stds = clf_lat.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf_lat.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    '''
    ############# LONGITUDE #############
    clf_lon = GridSearchCV(
        MLPRegressor(), tuned_parameters, scoring=score
    )
    clf_lon.fit(consensus_val_lon, tgt_val_lon)

    print("Best parameters set found on development set:")
    print()
    print(clf_lon.best_params_)
    print()
    '''
    print("Grid scores on development set:")
    print()
    means = clf_lon.cv_results_['mean_test_score']
    stds = clf_lon.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf_lon.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    '''
    DLATS_PRED = np.array(clf_lat.predict(consensus_test_lat)) * std_dx + mean_dx
    DLONS_PRED = np.array(clf_lon.predict(consensus_test_lon)) * std_dy + mean_dy
    LATS_PRED_ = np.array(X_test['LAT_7'][index]) + DLATS_PRED
    LONS_PRED_ = np.array(X_test['LON_7'][index]) + DLONS_PRED
    LATS_TEST_ = (np.array(tgt_displacement_test[:, 0])*std_dx+mean_dx)[index]+np.array(X_test['LAT_7'][index])
    LONS_TEST_ = np.array(X_test['LON_7'][index]) + (np.array(tgt_displacement_test[:, 1])*std_dy+mean_dy)[index]
    
    d_km_pred = np.zeros(len(LONS_PRED_))
    for i in range(len(LATS_PRED_)):
        #if LONS_TEST_[i] > 160:
            #LONS_PRED_[i] -= 360
        d_km_pred[i] = get_distance_km(LONS_PRED_[i], LATS_PRED_[i], LONS_TEST_[i], LATS_TEST_[i])

        
    print(basin, 'Model | MAE | std | %age busts (>200km)')
    print("Hurricast", np.around(d_km_pred.mean(), decimals = 2), np.around(d_km_pred.std(), decimals = 2), np.around(sum(d_km_pred > 200)*100/len(LATS_PRED_), decimals = 2))
    #print(classification_report(y_true, y_pred))
# Out:
# # Tuning hyper-parameters for neg_mean_squared_error
#
# Best parameters set found on development set:
#
# {'alpha': 0.0001, 'hidden_layer_sizes': (32, 8)}
# Best parameters set found on development set:
#
# {'alpha': 0.0001, 'hidden_layer_sizes': 32}
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 107.98 79.06 10.34
# # Tuning hyper-parameters for neg_mean_absolute_error
#
# Best parameters set found on development set:
#
# {'alpha': 0.001, 'hidden_layer_sizes': (32, 8)}
# Best parameters set found on development set:
#
# {'alpha': 0.001, 'hidden_layer_sizes': (32, 8)}
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 108.4 78.63 10.46

# %%
# NA
# Set the parameters by cross-validation
tuned_parameters = [{'hidden_layer_sizes': [(16, 8),(16),(32),(8),(32,8)], 'alpha': [0.001, 0.0001]}]

scores = ['neg_mean_absolute_error', 'neg_mean_squared_error']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf_lat = GridSearchCV(
        MLPRegressor(), tuned_parameters, scoring=score
    )
    clf_lat.fit(consensus_val_lat, tgt_val_lat)

    print("Best parameters set found on development set:")
    print()
    print(clf_lat.best_params_)
    print()
    '''
    print("Grid scores on development set:")
    print()
    means = clf_lat.cv_results_['mean_test_score']
    stds = clf_lat.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf_lat.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    '''
    ############# LONGITUDE #############
    clf_lon = GridSearchCV(
        MLPRegressor(), tuned_parameters, scoring=score
    )
    clf_lon.fit(consensus_val_lon, tgt_val_lon)

    print("Best parameters set found on development set:")
    print()
    print(clf_lon.best_params_)
    print()
    '''
    print("Grid scores on development set:")
    print()
    means = clf_lon.cv_results_['mean_test_score']
    stds = clf_lon.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf_lon.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    '''
    DLATS_PRED = np.array(clf_lat.predict(consensus_test_lat)) * std_dx + mean_dx
    DLONS_PRED = np.array(clf_lon.predict(consensus_test_lon)) * std_dy + mean_dy
    LATS_PRED_ = np.array(X_test['LAT_7'][index]) + DLATS_PRED
    LONS_PRED_ = np.array(X_test['LON_7'][index]) + DLONS_PRED
    LATS_TEST_ = (np.array(tgt_displacement_test[:, 0])*std_dx+mean_dx)[index]+np.array(X_test['LAT_7'][index])
    LONS_TEST_ = np.array(X_test['LON_7'][index]) + (np.array(tgt_displacement_test[:, 1])*std_dy+mean_dy)[index]
    
    d_km_pred = np.zeros(len(LONS_PRED_))
    for i in range(len(LATS_PRED_)):
        #if LONS_TEST_[i] > 160:
            #LONS_PRED_[i] -= 360
        d_km_pred[i] = get_distance_km(LONS_PRED_[i], LATS_PRED_[i], LONS_TEST_[i], LATS_TEST_[i])
        #if d_km_pred[i] > 200:
            #print(LONS_PRED_[i], LATS_PRED_[i], LONS_TEST_[i], LATS_TEST_[i])
        
    print(basin, 'Model | MAE | std | %age busts (>200km)')
    print("Hurricast", np.around(d_km_pred.mean(), decimals = 2), np.around(d_km_pred.std(), decimals = 2), np.around(sum(d_km_pred > 200)*100/len(LATS_PRED_), decimals = 2))
    #print(classification_report(y_true, y_pred))
# Out:
# # Tuning hyper-parameters for neg_mean_absolute_error
#
# Best parameters set found on development set:
#
# {'alpha': 0.0001, 'hidden_layer_sizes': (32, 8)}
#
# Best parameters set found on development set:
#
# {'alpha': 0.001, 'hidden_layer_sizes': 32}
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 109.05 78.84 10.12
# # Tuning hyper-parameters for neg_mean_squared_error
#
# Best parameters set found on development set:
#
# {'alpha': 0.0001, 'hidden_layer_sizes': 32}
#
# Best parameters set found on development set:
#
# {'alpha': 0.001, 'hidden_layer_sizes': 32}
#
# AN Model | MAE | std | %age busts (>200km)
# Hurricast 107.82 77.5 10.57

# %%
df['PURE_HURR_Consensus_MLP'] = d_km_pred

# %%
df.to_csv('NA_BOXPLOT_TRACK_v3.csv')

# %%
df.mean()
# Out:
# HURR_STAT_2016                    144.036493
# HURR_STAT_2012                    143.996528
# CLP5                              201.237503
# HWRF                               74.978847
# OFCL                               71.238615
# FSSE                               68.918804
# GFSO                               70.548139
# AEMN                               73.204836
# Consensus_wo_HURR                  63.809418
# Consensus_HURR_STAT                65.575915
# HURR_GRU_ONLY_2016                114.133328
# HURR_GRU_ONLY_2012                114.233897
# Consensus_HURR_GRU_ONLY            61.503820
# HURR_TRANSFO_ONLY_2016            110.084300
# HURR_TRANSFO_ONLY_2012            110.426782
# Consensus_HURR_TRANSFO_ONLY        61.696644
# HURR_STAT_GRU_2016                110.083000
# HURR_STAT_GRU_2012                111.736013
# Consensus_HURR_STAT_GRU            61.112462
# HURR_STAT_TRANSFO_2016            109.763398
# HURR_STAT_TRANSFO_2012            108.514335
# Consensus_HURR_STAT_TRANSFO        61.456306
# HURR_STAT_COMP_2016               139.712197
# HURR_STAT_COMP_2012               141.532291
# Consensus_HURR_STAT_COMP           65.373029
# PURE_HURR_Consensus_ElasticNet    107.372929
# PURE_HURR_Consensus_MLP           106.525986
# dtype: float64

# %%
df.std(axis = 0)
# Out:
# HURR_STAT_2016                    109.279126
# HURR_STAT_2012                    110.236538
# CLP5                              149.334734
# HWRF                               49.124044
# OFCL                               55.546278
# FSSE                               52.587411
# GFSO                               54.303373
# AEMN                               55.015595
# Consensus_wo_HURR                  47.846073
# Consensus_HURR_STAT                44.835988
# HURR_GRU_ONLY_2016                 83.257582
# HURR_GRU_ONLY_2012                 83.910556
# Consensus_HURR_GRU_ONLY            43.396622
# HURR_TRANSFO_ONLY_2016             71.209200
# HURR_TRANSFO_ONLY_2012             73.114216
# Consensus_HURR_TRANSFO_ONLY        42.628277
# HURR_STAT_GRU_2016                 78.475886
# HURR_STAT_GRU_2012                 79.459922
# Consensus_HURR_STAT_GRU            43.580033
# HURR_STAT_TRANSFO_2016             72.250890
# HURR_STAT_TRANSFO_2012             72.552261
# Consensus_HURR_STAT_TRANSFO        42.650202
# HURR_STAT_COMP_2016               107.894238
# HURR_STAT_COMP_2012               107.724730
# Consensus_HURR_STAT_COMP           44.792689
# PURE_HURR_Consensus_ElasticNet     77.342817
# PURE_HURR_Consensus_MLP            77.546688
# dtype: float64

# %% [markdown]
# # Table intensity AN

# %%
from sklearn.feature_selection import SelectFromModel

n = X_test_baseline.shape[0]
X_test_total = X_test_total[-n:]
tgt_intensity_test = tgt_intensity_test[-n:]
X_test = X_test[-n:]
X_test_embed = X_test_embed[-n:]
tgt_displacement_test = tgt_displacement_test[-n:]

# %%
dict6 = {'year':[], 'num_samples':[], 'MAEs_full':[], 'std_full':[], 'MAES_2012':[], 'std_2012':[], 'MAES_SHIP':[], 'std_SHIP':[], 'MAES_HWRF':[], 'std_HWRF':[], 'MAES_OFCL':[], 'std_OFCL':[], 'MAES_FSSE':[], 'std_FSSE':[], 'MAES_GFSO':[], 'std_GFSO':[], 'MAES_DSHP':[], 'std_DSHP':[]}

# %%
tgt_train = np.concatenate((tgt_intensity_train, tgt_intensity_test[:17094]), axis = 0)
tgt_train5 = tgt_train*std_+mean_
mean_intensity2 = tgt_train5.mean()
std_intensity2 = tgt_train5.std()
tgt_train5 = (tgt_train5 - mean_intensity2)/std_intensity2
tgt_intensity_test = (tgt_intensity_test*std_+mean_ - mean_intensity2)/std_intensity2
std_ = float(std_intensity2)
mean_ = float(mean_intensity2)

# %%
#FULL TRAIN WITH CNN/GRU EMBEDS + ONLY AN EP in training + only more than. 40kn winds
index_t = X_train.loc[X_train['cat_basin_AN_0'] + X_train['cat_basin_EP_0'] == 1].loc[X_train['WMO_WIND_7'] > 34].index
index_te = X_test[:17094].loc[X_test['cat_basin_AN_0'] + X_test['cat_basin_EP_0'] == 1].loc[X_test['WMO_WIND_7'] > 34].index
train = np.concatenate((X_train_total[index_t], X_test_total[index_te]), axis = 0)
#tgt_train = np.concatenate((tgt_intensity_train[index_t], tgt_intensity_test[index_te]), axis = 0)

xgb_total = XGBRegressor(max_depth=6, n_estimators=150, learning_rate=0.03, subsample=0.8, min_child_weight=1)
xgb_total.fit(train, tgt_train)
compare_perf_intensity_per_year_6cast(X_test_total, dict6, xgb_total = xgb_total, xgb_tot = xgb_total, basin='AN', forecast='SHIP', forecast2 = 'HWRF', forecast3 = 'OFCL', forecast4 = 'FSSE', forecast5 = 'GFSO', forecast6 = 'DSHP', year = 2017)
compare_perf_intensity_per_year_6cast(X_test_total, dict6, xgb_total = xgb_total, xgb_tot = xgb_total, basin='EP', forecast='SHIP', forecast2 = 'HWRF', forecast3 = 'OFCL', forecast4 = 'FSSE', forecast5 = 'GFSO', forecast6 = 'DSHP', year = 2017)
# Out:
# Total number of steps for comparison:  669
# Year 2017 Basin AN MAE intensity | std | busts > 20kn %
# Hurr full:  10.93 14.14 14.65
# Hurr until 2012:  10.93 14.14 14.65
# SHIP 11.29 15.51 17.34
# HWRF 9.59 12.59 11.21
# OFCL 8.55 11.85 7.32
# FSSE 8.44 11.29 7.32
# GFSO 14.0 15.64 22.42
# DSHP 10.28 13.59 14.8
# Consensus ofcl 8.27
# Consensus Hurr 10.09
# Total number of steps for comparison:  522
# Year 2017 Basin EP MAE intensity | std | busts > 20kn %
# Hurr full:  11.36 15.31 18.01
# Hurr until 2012:  11.36 15.31 18.01
# SHIP 11.97 15.22 16.86
# HWRF 9.95 14.02 14.18
# OFCL 9.55 12.99 7.85
# FSSE 9.22 12.38 9.96
# GFSO 16.95 19.67 31.99
# DSHP 11.85 15.13 16.86
# Consensus ofcl 9.24
# Consensus Hurr 10.98

# %%
index_t = X_train.loc[X_train['cat_basin_AN_0'] + X_train['cat_basin_EP_0'] == 1].loc[X_train['WMO_WIND_7'] > 34].index
index_te = X_test[:17094].loc[X_test['cat_basin_AN_0'] + X_test['cat_basin_EP_0'] == 1].loc[X_test['WMO_WIND_7'] > 34].index
train = np.concatenate((X_train_total[index_t], X_test_total[index_te]), axis = 0)
tgt_train = np.array(((np.concatenate((tgt_intensity_train[index_t], tgt_intensity_test[index_te]), axis = 0))*float(std_intensity)+float(mean_intensity)-mean_)/std_)
xgb_total = XGBRegressor(max_depth=8, n_estimators=150, learning_rate=0.03, subsample=0.8, min_child_weight=1)
xgb_total.fit(train, tgt_train)
compare_perf_intensity_per_year_6cast(X_test_total, dict6, xgb_total = xgb_total, xgb_tot = xgb_total, basin='AN', forecast='SHIP', forecast2 = 'HWRF', forecast3 = 'OFCL', forecast4 = 'FSSE', forecast5 = 'GFSO', forecast6 = 'DSHP', year = 2017)
compare_perf_intensity_per_year_6cast(X_test_total, dict6, xgb_total = xgb_total, xgb_tot = xgb_total, basin='EP', forecast='SHIP', forecast2 = 'HWRF', forecast3 = 'OFCL', forecast4 = 'FSSE', forecast5 = 'GFSO', forecast6 = 'DSHP', year = 2017)
# Out:
# Total number of steps for comparison:  669
# Year 2017 Basin AN MAE intensity | std | busts > 20kn %
# Hurr full:  10.8 13.98 14.5
# Hurr until 2012:  10.8 13.98 14.5
# SHIP 11.29 15.51 17.34
# HWRF 9.59 12.59 11.21
# OFCL 8.55 11.85 7.32
# FSSE 8.44 11.29 7.32
# GFSO 14.0 15.64 22.42
# DSHP 10.28 13.59 14.8
# Consensus ofcl 8.27
# Consensus Hurr 10.3
# Total number of steps for comparison:  522
# Year 2017 Basin EP MAE intensity | std | busts > 20kn %
# Hurr full:  11.13 15.08 16.09
# Hurr until 2012:  11.13 15.08 16.09
# SHIP 11.97 15.22 16.86
# HWRF 9.95 14.02 14.18
# OFCL 9.55 12.99 7.85
# FSSE 9.22 12.38 9.96
# GFSO 16.95 19.67 31.99
# DSHP 11.85 15.13 16.86
# Consensus ofcl 9.24
# Consensus Hurr 11.18

# %%
#FULL TRAIN WITH CNN/GRU EMBEDS
index_t = X_train.loc[X_train['WMO_WIND_7'] > 40].index
index_te = X_test[:17094].loc[X_test['WMO_WIND_7'] > 40].index
train = np.concatenate((X_train_total[index_t], X_test_total[index_te]), axis = 0)
tgt_train = np.concatenate((tgt_intensity_train[index_t], tgt_intensity_test[index_te]), axis = 0)

xgb_total = XGBRegressor(max_depth=8, n_estimators=150, learning_rate=0.05, subsample=0.8, min_child_weight=5)
xgb_total.fit(train, tgt_train)
compare_perf_intensity_per_year_6cast(X_test_total, dict6, xgb_total = xgb_total, xgb_tot = xgb_total, basin='AN', forecast='SHIP', forecast2 = 'HWRF', forecast3 = 'OFCL', forecast4 = 'FSSE', forecast5 = 'GFSO', forecast6 = 'DSHP', year = 2017)
compare_perf_intensity_per_year_6cast(X_test_total, dict6, xgb_total = xgb_total, xgb_tot = xgb_total, basin='EP', forecast='SHIP', forecast2 = 'HWRF', forecast3 = 'OFCL', forecast4 = 'FSSE', forecast5 = 'GFSO', forecast6 = 'DSHP', year = 2017)
# Out:
# Total number of steps for comparison:  669
# Year 2017 Basin AN MAE intensity | std | busts > 20kn %
# Hurr full:  10.68 13.84 12.71
# Hurr until 2012:  10.68 13.84 12.71
# SHIP 11.29 15.51 17.34
# HWRF 9.59 12.59 11.21
# OFCL 8.55 11.85 7.32
# FSSE 8.44 11.29 7.32
# GFSO 14.0 15.64 22.42
# DSHP 10.28 13.59 14.8
# Consensus ofcl 8.27
# Consensus Hurr 10.08
# Total number of steps for comparison:  522
# Year 2017 Basin EP MAE intensity | std | busts > 20kn %
# Hurr full:  11.24 15.15 17.05
# Hurr until 2012:  11.24 15.15 17.05
# SHIP 11.97 15.22 16.86
# HWRF 9.95 14.02 14.18
# OFCL 9.55 12.99 7.85
# FSSE 9.22 12.38 9.96
# GFSO 16.95 19.67 31.99
# DSHP 11.85 15.13 16.86
# Consensus ofcl 9.24
# Consensus Hurr 11.0

# %%
#FULL TRAIN WITH CNN/GRU EMBEDS
train = np.concatenate((X_train_total, X_test_total[:17094]), axis = 0)
#tgt_train = np.concatenate((tgt_intensity_train, tgt_intensity_test[:17094]), axis = 0)

xgb_total = XGBRegressor(max_depth=8, n_estimators=250, learning_rate=0.07, subsample=0.8, min_child_weight=1, colsample_bytree = 0.7)
xgb_total.fit(train, tgt_train5)
compare_perf_intensity_per_year_6cast(X_test_total, dict6, xgb_total = xgb_total, xgb_tot = xgb_total, basin='AN', forecast='SHIP', forecast2 = 'HWRF', forecast3 = 'OFCL', forecast4 = 'FSSE', forecast5 = 'GFSO', forecast6 = 'DSHP', year = 2017)
compare_perf_intensity_per_year_6cast(X_test_total, dict6, xgb_total = xgb_total, xgb_tot = xgb_total, basin='EP', forecast='SHIP', forecast2 = 'HWRF', forecast3 = 'OFCL', forecast4 = 'FSSE', forecast5 = 'GFSO', forecast6 = 'DSHP', year = 2017)
# Out:
# Total number of steps for comparison:  669
# Year 2017 Basin AN MAE intensity | std | busts > 20kn %
# Hurr full:  10.54 13.79 13.0
# Hurr until 2012:  10.54 13.79 13.0
# SHIP 11.29 15.51 17.34
# HWRF 9.59 12.59 11.21
# OFCL 8.55 11.85 7.32
# FSSE 8.44 11.29 7.32
# GFSO 14.0 15.64 22.42
# DSHP 10.28 13.59 14.8
# Consensus ofcl 8.39
# Consensus Hurr 8.27
# Total number of steps for comparison:  522
# Year 2017 Basin EP MAE intensity | std | busts > 20kn %
# Hurr full:  11.27 15.24 16.28
# Hurr until 2012:  11.27 15.24 16.28
# SHIP 11.97 15.22 16.86
# HWRF 9.95 14.02 14.18
# OFCL 9.55 12.99 7.85
# FSSE 9.22 12.38 9.96
# GFSO 16.95 19.67 31.99
# DSHP 11.85 15.13 16.86
# Consensus ofcl 9.79
# Consensus Hurr 9.64

# %%
compare_perf_intensity_per_year_6cast(X_test_total, dict6, xgb_total = xgb_total, xgb_tot = xgb_total, basin='AN', forecast='SHIP', forecast2 = 'HWRF', forecast3 = 'OFCL', forecast4 = 'FSSE', forecast5 = 'GFSO', forecast6 = 'DSHP', year = 2017)
compare_perf_intensity_per_year_6cast(X_test_total, dict6, xgb_total = xgb_total, xgb_tot = xgb_total, basin='EP', forecast='SHIP', forecast2 = 'HWRF', forecast3 = 'OFCL', forecast4 = 'FSSE', forecast5 = 'GFSO', forecast6 = 'DSHP', year = 2017)
# Out:
# Total number of steps for comparison:  669
# Year 2017 Basin AN MAE intensity | std | busts > 20kn %
# Hurr full:  10.54 13.79 13.0
# Hurr until 2012:  10.54 13.79 13.0
# SHIP 11.29 15.51 17.34
# HWRF 9.59 12.59 11.21
# OFCL 8.55 11.85 7.32
# FSSE 8.44 11.29 7.32
# GFSO 14.0 15.64 22.42
# DSHP 10.28 13.59 14.8
# Consensus ofcl 8.44 11.35 8.52
# Consensus Hurr 8.33 11.21 8.37
# Total number of steps for comparison:  522
# Year 2017 Basin EP MAE intensity | std | busts > 20kn %
# Hurr full:  11.27 15.24 16.28
# Hurr until 2012:  11.27 15.24 16.28
# SHIP 11.97 15.22 16.86
# HWRF 9.95 14.02 14.18
# OFCL 9.55 12.99 7.85
# FSSE 9.22 12.38 9.96
# GFSO 16.95 19.67 31.99
# DSHP 11.85 15.13 16.86
# Consensus ofcl 9.39 12.52 10.73
# Consensus Hurr 9.35 12.54 10.73

# %%
year = 2017
forecast='SHIP'
forecast2 = 'HWRF'
forecast3 = 'OFCL'
forecast4 = 'FSSE'
forecast5 = 'GFSO'
forecast6 = 'AEMN'
mode = 'vmax'
basin = 'AN'
test = X_test_total
if True:
    baseline_ = X_test_baseline.loc[X_test_baseline['YEAR_0'] < year].loc[
            X_test_baseline[forecast6 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast5 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast4 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast3 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast2 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast + '_24_' + mode + '_7'] > -320].loc[X_test_baseline['cat_basin_' + basin + '_0'] == 1]  # .loc[#X_test_baseline['SHIP_24_'+mode+'_7'] > 0].index
    if basin == 'EP':
        baseline_ = X_test_baseline.loc[X_test_baseline['YEAR_0'] < year].loc[
            X_test_baseline[forecast6 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast5 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast4 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast3 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast2 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast + '_24_' + mode + '_7'] > -320].loc[X_test_baseline['cat_basin_' + basin + '_0'] == 1]
    index = baseline_.index
    baseline_1 = baseline_[forecast + '_24_'+ mode + '_7']
    baseline_2 = baseline_[forecast2 + '_24_' + mode + '_7']
    baseline_3 = baseline_[forecast3 + '_24_' + mode + '_7']
    baseline_4 = baseline_[forecast4 + '_24_' + mode + '_7']
    baseline_5 = baseline_[forecast5 + '_24_' + mode + '_7']
    baseline_6 = baseline_[forecast6 + '_24_' + mode + '_7']
    X_test_withBASELINE_total = np.array(test)[index]
    
    tgt_ = np.array(tgt_intensity_test[index] * std_ + mean_)
    preds = xgb_total.predict(X_test_withBASELINE_total) * std_ + mean_
    train_consensus = np.stack((baseline_1, baseline_2, baseline_3, baseline_4, baseline_5, baseline_6), axis = 1)
    train_consensus_hurr = np.stack((baseline_1, baseline_2, baseline_3, baseline_4, baseline_5, baseline_6, preds), axis = 1)
   
if True:
    baseline_ = X_test_baseline.loc[X_test_baseline['YEAR_0'] >= year].loc[
            X_test_baseline[forecast6 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast5 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast4 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast3 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast2 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast + '_24_' + mode + '_7'] > -320].loc[X_test_baseline['cat_basin_' + basin + '_0'] == 1]  # .loc[#X_test_baseline['SHIP_24_'+mode+'_7'] > 0].index
    if basin == 'EP':
        baseline_ = X_test_baseline.loc[X_test_baseline['YEAR_0'] < 2019].loc[X_test_baseline['YEAR_0'] >= year].loc[
            X_test_baseline[forecast6 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast5 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast4 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast3 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast2 + '_24_' + mode + '_7'] > -320].loc[
            X_test_baseline[forecast + '_24_' + mode + '_7'] > -320].loc[X_test_baseline['cat_basin_' + basin + '_0'] == 1]
    index = baseline_.index
    baseline_1 = baseline_[forecast + '_24_'+ mode + '_7']
    baseline_2 = baseline_[forecast2 + '_24_' + mode + '_7']
    baseline_3 = baseline_[forecast3 + '_24_' + mode + '_7']
    baseline_4 = baseline_[forecast4 + '_24_' + mode + '_7']
    baseline_5 = baseline_[forecast5 + '_24_' + mode + '_7']
    baseline_6 = baseline_[forecast6 + '_24_' + mode + '_7']
    X_test_withBASELINE_total = np.array(test)[index]
    
    tgt_test = np.array(tgt_intensity_test[index] * std_ + mean_)
    preds = xgb_total.predict(X_test_withBASELINE_total) * std_ + mean_
    test_consensus = np.stack((baseline_1, baseline_2, baseline_3, baseline_4, baseline_5, baseline_6), axis = 1)
    test_consensus_hurr = np.stack((baseline_1, baseline_2, baseline_3, baseline_4, baseline_5, baseline_6, preds), axis = 1)

# %%
from sklearn.linear_model import Lasso

# %%
#AN
m = Lasso(alpha = 10)
m.fit(train_consensus, tgt_)
preds = np.array(m.predict(test_consensus))

print("consensus without Hurricast",
                np.around(mean_absolute_error(np.array(tgt_test), preds), decimals=2),
                np.around(np.std(tgt_test - preds), decimals=2),
                np.around(sum(abs(tgt_test - preds) > 20)/len(preds) * 100, decimals = 2))print(m.coef_)

m = Lasso(alpha = 3)
m.fit(train_consensus_hurr, tgt_)
preds = np.array(m.predict(test_consensus_hurr))


print("consensus with Hurricast",
                np.around(mean_absolute_error(np.array(tgt_test), preds), decimals=2),
                np.around(np.std(tgt_test - preds), decimals=2),
                np.around(sum(abs(tgt_test - preds) > 20)/len(preds) * 100, decimals = 2))print(m.coef_)
# Out:
# MAE intensity:  8.195159
# [ 0.          0.13361378  0.64414746  0.2184808   0.06403179 -0.        ]
# MAE intensity:  8.025881
# [-0.          0.11876066  0.5839296   0.28978214  0.11706416 -0.23846142
#   0.25588316]

# %%
#AN
m = Lasso(alpha = 10)
m.fit(train_consensus, tgt_)
preds = np.array(m.predict(test_consensus))

print("consensus without Hurricast",
                np.around(mean_absolute_error(np.array(tgt_test), preds), decimals=2),
                np.around(np.std(tgt_test - preds), decimals=2),
                np.around(sum(abs(tgt_test - preds) > 20)/len(preds) * 100, decimals = 2))

m = Lasso(alpha = 3)
m.fit(train_consensus_hurr, tgt_)
preds = np.array(m.predict(test_consensus_hurr))


print("consensus with Hurricast",
                np.around(mean_absolute_error(np.array(tgt_test), preds), decimals=2),
                np.around(np.std(tgt_test - preds), decimals=2),
                np.around(sum(abs(tgt_test - preds) > 20)/len(preds) * 100, decimals = 2))
# Out:
# consensus without Hurricast 8.2 11.0 8.67
# consensus with Hurricast 8.02 10.74 8.37

# %%
#EP
m = Lasso(alpha = 0.9)
m.fit(train_consensus, tgt_)
#print("MAE intensity: ", mean_absolute_error(np.array(tgt_test), np.array(m.predict(test_consensus))))
#print(m.coef_)
preds = np.array(m.predict(test_consensus))
print("consensus without Hurricast",
                np.around(mean_absolute_error(np.array(tgt_test), preds), decimals=2),
                np.around(np.std(tgt_test - preds), decimals=2),
                np.around(sum(abs(tgt_test - preds) > 20)/len(preds) * 100, decimals = 2))

m = Lasso(alpha = 2.)
m.fit(train_consensus_hurr, tgt_)
#print("MAE intensity: ", mean_absolute_error(np.array(tgt_test), np.array(m.predict(test_consensus_hurr))))
#print(m.coef_)
preds = np.array(m.predict(test_consensus_hurr))
print("consensus with Hurricast",
                np.around(mean_absolute_error(np.array(tgt_test), preds), decimals=2),
                np.around(np.std(tgt_test - preds), decimals=2),
                np.around(sum(abs(tgt_test - preds) > 20)/len(preds) * 100, decimals = 2))
# Out:
# consensus without Hurricast 8.6 11.93 10.73
# consensus with Hurricast 8.56 11.76 10.34

# %%
xgb_total = RandomForestRegressor(max_depth=8, n_estimators=250, criterion = 'mae')
xgb_total.fit(train, tgt_train5)
compare_perf_intensity_per_year_6cast(X_test_total, dict6, xgb_total = xgb_total, xgb_tot = xgb_total, basin='AN', forecast='SHIP', forecast2 = 'HWRF', forecast3 = 'OFCL', forecast4 = 'FSSE', forecast5 = 'GFSO', forecast6 = 'DSHP', year = 2017)
compare_perf_intensity_per_year_6cast(X_test_total, dict6, xgb_total = xgb_total, xgb_tot = xgb_total, basin='EP', forecast='SHIP', forecast2 = 'HWRF', forecast3 = 'OFCL', forecast4 = 'FSSE', forecast5 = 'GFSO', forecast6 = 'DSHP', year = 2017)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-46-808056b18fb1> in <module>()
#       1 xgb_total = RandomForestRegressor(max_depth=8, n_estimators=250)
# ----> 2 xgb_total.fit(train, tgt_train5)
#
# /state/partition1/llgrid/pkg/anaconda/anaconda3-2020a/lib/python3.6/site-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     331                     t, self, X, y, sample_weight, i, len(trees),
#     332                     verbose=self.verbose, class_weight=self.class_weight)
# --> 333                 for i, t in enumerate(trees))
#     334
#     335             # Collect newly grown trees
#
# /state/partition1/llgrid/pkg/anaconda/anaconda3-2020a/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     918                 self._iterating = self._original_iterator is not None
#     919
# --> 920             while self.dispatch_one_batch(iterator):
#     921                 pass
#     922
#
# /state/partition1/llgrid/pkg/anaconda/anaconda3-2020a/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# /state/partition1/llgrid/pkg/anaconda/anaconda3-2020a/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# /state/partition1/llgrid/pkg/anaconda/anaconda3-2020a/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# /state/partition1/llgrid/pkg/anaconda/anaconda3-2020a/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# /state/partition1/llgrid/pkg/anaconda/anaconda3-2020a/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# /state/partition1/llgrid/pkg/anaconda/anaconda3-2020a/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# /state/partition1/llgrid/pkg/anaconda/anaconda3-2020a/lib/python3.6/site-packages/sklearn/ensemble/forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight)
#     117             curr_sample_weight *= compute_sample_weight('balanced', y, indices)
#     118
# --> 119         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     120     else:
#     121         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# /state/partition1/llgrid/pkg/anaconda/anaconda3-2020a/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1140             sample_weight=sample_weight,
#    1141             check_input=check_input,
# -> 1142             X_idx_sorted=X_idx_sorted)
#    1143         return self
#    1144
#
# /state/partition1/llgrid/pkg/anaconda/anaconda3-2020a/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     364                                            min_impurity_split)
#     365
# --> 366         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     367
#     368         if self.n_outputs_ == 1:
#
# KeyboardInterrupt:

# %%
compare_perf_intensity_per_year_6cast(X_test_total, dict6, xgb_total = xgb_total, xgb_tot = xgb_total, basin='EP', forecast='SHIP', forecast2 = 'HWRF', forecast3 = 'OFCL', forecast4 = 'FSSE', forecast5 = 'GFDL', forecast6 = 'DSHP', year = 2017)
# Out:
# Total number of steps for comparison:  42
# Year 2017 Basin EP MAE intensity | std | busts > 20kn %
# Hurr full:  11.55 14.03 16.67
# Hurr until 2012:  11.55 14.03 16.67
# SHIP 10.74 12.94 11.9
# HWRF 7.74 10.23 14.29
# OFCL 8.45 10.79 2.38
# FSSE 6.64 8.01 0.0
# GFDL 17.38 18.83 33.33
# DSHP 10.74 12.94 11.9

# %%
#TRAIN UNTIL 2012
#AN
#xgb_total = XGBRegressor(max_depth=8, n_estimators=150, learning_rate=0.07, subsample=0.8, min_child_weight=5, colsample_bytree = 0.7)
#EP
#xgb_total = XGBRegressor(max_depth=8, n_estimators=150, learning_rate=0.05, subsample=0.7, min_child_weight=5, colsample_bytree = 0.7)
xgb_total = XGBRegressor(max_depth=8, n_estimators=150, learning_rate=0.07, subsample=0.8, min_child_weight=5, colsample_bytree = 0.7)
xgb_total.fit(X_train_total, tgt_intensity_train)
compare_perf_intensity_per_year_6cast(X_test_total, dict6, xgb_total = xgb_total, xgb_tot = xgb_total, basin='AN', forecast='SHIP', forecast2 = 'HWRF', forecast3 = 'OFCL', forecast4 = 'FSSE', forecast5 = 'GFSO', forecast6 = 'DSHP', year = 2017)
compare_perf_intensity_per_year_6cast(X_test_total, dict6, xgb_total = xgb_total, xgb_tot = xgb_total, basin='EP', forecast='SHIP', forecast2 = 'HWRF', forecast3 = 'OFCL', forecast4 = 'FSSE', forecast5 = 'GFSO', forecast6 = 'DSHP', year = 2017)
# Out:
# Total number of steps for comparison:  669
# Year 2017 Basin AN MAE intensity | std | busts > 20kn %
# Hurr full:  10.8 13.91 14.5
# Hurr until 2012:  10.8 13.91 14.5
# SHIP 11.29 15.51 17.34
# HWRF 9.59 12.59 11.21
# OFCL 8.55 11.85 7.32
# FSSE 8.44 11.29 7.32
# GFSO 14.0 15.64 22.42
# DSHP 10.28 13.59 14.8
# Consensus ofcl 8.27
# Consensus Hurr 10.03
# Total number of steps for comparison:  522
# Year 2017 Basin EP MAE intensity | std | busts > 20kn %
# Hurr full:  11.59 15.67 19.16
# Hurr until 2012:  11.59 15.67 19.16
# SHIP 11.97 15.22 16.86
# HWRF 9.95 14.02 14.18
# OFCL 9.55 12.99 7.85
# FSSE 9.22 12.38 9.96
# GFSO 16.95 19.67 31.99
# DSHP 11.85 15.13 16.86
# Consensus ofcl 9.24
# Consensus Hurr 11.0

# %%
#TABULAR ONLY
train2 = np.concatenate((X_train, X_test[:17094]), axis = 0)
#tgt_train = np.concatenate((tgt_intensity_train, tgt_intensity_test[:17094]), axis = 0)
xgb_total = XGBRegressor(max_depth=7, n_estimators=150, learning_rate=0.07, subsample=0.7, min_child_weight=5)
xgb_total.fit(train2, tgt_train5)
compare_perf_intensity_per_year_6cast(X_test, dict6, xgb_total = xgb_total, xgb_tot = xgb_total, basin='AN', forecast='SHIP', forecast2 = 'HWRF', forecast3 = 'OFCL', forecast4 = 'FSSE', forecast5 = 'GFSO', forecast6 = 'DSHP', year = 2017)
compare_perf_intensity_per_year_6cast(X_test, dict6, xgb_total = xgb_total, xgb_tot = xgb_total, basin='EP', forecast='SHIP', forecast2 = 'HWRF', forecast3 = 'OFCL', forecast4 = 'FSSE', forecast5 = 'GFSO', forecast6 = 'DSHP', year = 2017)
# Out:
# Total number of steps for comparison:  669
# Year 2017 Basin AN MAE intensity | std | busts > 20kn %
# Hurr full:  10.68 13.82 14.05
# Hurr until 2012:  10.68 13.82 14.05
# SHIP 11.29 15.51 17.34
# HWRF 9.59 12.59 11.21
# OFCL 8.55 11.85 7.32
# FSSE 8.44 11.29 7.32
# GFSO 14.0 15.64 22.42
# DSHP 10.28 13.59 14.8
# Total number of steps for comparison:  522
# Year 2017 Basin EP MAE intensity | std | busts > 20kn %
# Hurr full:  11.45 15.63 18.01
# Hurr until 2012:  11.45 15.63 18.01
# SHIP 11.97 15.22 16.86
# HWRF 9.95 14.02 14.18
# OFCL 9.55 12.99 7.85
# FSSE 9.22 12.38 9.96
# GFSO 16.95 19.67 31.99
# DSHP 11.85 15.13 16.86

# %%
#EMBED ONLY
train2 = np.concatenate((X_train_embed, X_test_embed[:17094]), axis = 0)
#tgt_train = np.concatenate((tgt_intensity_train, tgt_intensity_test[:17094]), axis = 0)
xgb_total = XGBRegressor(max_depth=7, n_estimators=150, learning_rate=0.07, subsample=0.7, min_child_weight=5)
xgb_total.fit(train2, tgt_train5)
compare_perf_intensity_per_year_6cast(X_test_embed, dict6, xgb_total = xgb_total, xgb_tot = xgb_total, basin='AN', forecast='SHIP', forecast2 = 'HWRF', forecast3 = 'OFCL', forecast4 = 'FSSE', forecast5 = 'GFSO', forecast6 = 'DSHP', year = 2017)
compare_perf_intensity_per_year_6cast(X_test_embed, dict6, xgb_total = xgb_total, xgb_tot = xgb_total, basin='EP', forecast='SHIP', forecast2 = 'HWRF', forecast3 = 'OFCL', forecast4 = 'FSSE', forecast5 = 'GFSO', forecast6 = 'DSHP', year = 2017)
# Out:
# Total number of steps for comparison:  669
# Year 2017 Basin AN MAE intensity | std | busts > 20kn %
# Hurr full:  11.27 14.57 15.4
# Hurr until 2012:  11.27 14.57 15.4
# SHIP 11.29 15.51 17.34
# HWRF 9.59 12.59 11.21
# OFCL 8.55 11.85 7.32
# FSSE 8.44 11.29 7.32
# GFSO 14.0 15.64 22.42
# DSHP 10.28 13.59 14.8
# Total number of steps for comparison:  522
# Year 2017 Basin EP MAE intensity | std | busts > 20kn %
# Hurr full:  11.28 15.42 18.01
# Hurr until 2012:  11.28 15.42 18.01
# SHIP 11.97 15.22 16.86
# HWRF 9.95 14.02 14.18
# OFCL 9.55 12.99 7.85
# FSSE 9.22 12.38 9.96
# GFSO 16.95 19.67 31.99
# DSHP 11.85 15.13 16.86

# %%
#USING OFCL
train = np.concatenate((X_test_baseline[:17094], X_test_total[:17094]), axis = 1)
tgt_train3 = tgt_intensity_test[:17094]
test = np.concatenate((X_test_baseline, X_test_total), axis = 1)
xgb_total = XGBRegressor(max_depth=8, n_estimators=150, learning_rate=0.07, subsample=0.8, min_child_weight=5)
xgb_total.fit(train, tgt_train3)
compare_perf_intensity_per_year_6cast(test, dict6, xgb_total = xgb_total, xgb_tot = xgb_total, basin='AN', forecast='SHIP', forecast2 = 'HWRF', forecast3 = 'OFCL', forecast4 = 'FSSE', forecast5 = 'GFSO', forecast6 = 'DSHP', year = 2017)
compare_perf_intensity_per_year_6cast(test, dict6, xgb_total = xgb_total, xgb_tot = xgb_total, basin='EP', forecast='SHIP', forecast2 = 'HWRF', forecast3 = 'OFCL', forecast4 = 'FSSE', forecast5 = 'GFSO', forecast6 = 'DSHP', year = 2017)
# Out:
# Total number of steps for comparison:  669
# Year 2017 Basin AN MAE intensity | std | busts > 20kn %
# Hurr full:  10.83 14.65 15.7
# Hurr until 2012:  10.83 14.65 15.7
# SHIP 11.29 15.51 17.34
# HWRF 9.59 12.59 11.21
# OFCL 8.55 11.85 7.32
# FSSE 8.44 11.29 7.32
# GFSO 14.0 15.64 22.42
# DSHP 10.28 13.59 14.8
# Total number of steps for comparison:  522
# Year 2017 Basin EP MAE intensity | std | busts > 20kn %
# Hurr full:  10.03 13.29 12.64
# Hurr until 2012:  10.03 13.29 12.64
# SHIP 11.97 15.22 16.86
# HWRF 9.95 14.02 14.18
# OFCL 9.55 12.99 7.85
# FSSE 9.22 12.38 9.96
# GFSO 16.95 19.67 31.99
# DSHP 11.85 15.13 16.86

# %%
#OFCL ONLY
#train = np.array(X_test_baseline[:17094])
#tgt_train3 = tgt_intensity_test[:17094]
train = X_test_baseline[:17094].loc[X_test_baseline['cat_basin_AN_0'] + X_test_baseline['cat_basin_EP_0'] == 1]
tgt_train3 = tgt_intensity_test[train.index]
xgb_total = XGBRegressor(max_depth=7, n_estimators=300, learning_rate=0.03, subsample=0.55, min_child_weight=1)
xgb_total.fit(np.array(train), tgt_train3)
#xgb_total = XGBRegressor(max_depth=7, n_estimators=300, learning_rate=0.03, subsample=0.55, min_child_weight=1)
#xgb_total.fit(np.array(train), tgt_train3)
compare_perf_intensity_per_year_6cast(X_test_baseline, dict6, xgb_total = xgb_total, xgb_tot = xgb_total, basin='AN', forecast='SHIP', forecast2 = 'HWRF', forecast3 = 'OFCL', forecast4 = 'FSSE', forecast5 = 'GFSO', forecast6 = 'DSHP', year = 2017)
compare_perf_intensity_per_year_6cast(X_test_baseline, dict6, xgb_total = xgb_total, xgb_tot = xgb_total, basin='EP', forecast='SHIP', forecast2 = 'HWRF', forecast3 = 'OFCL', forecast4 = 'FSSE', forecast5 = 'GFSO', forecast6 = 'DSHP', year = 2017)
#compare_perf_intensity_per_year_4cast(X_test_baseline, dict = {'year':[], 'num_samples':[], 'MAEs_full':[], 'std_full':[], 'MAES_2012':[], 'std_2012':[], 'MAES_SHIP':[], 'std_SHIP':[], 'MAES_HWRF':[], 'std_HWRF':[], 'MAES_OFCL':[], 'std_OFCL':[], 'MAES_FSSE':[], 'std_FSSE':[]}, xgb_total = xgb_total, xgb_tot = xgb_total, basin='AN', forecast='SHIP', mode='vmax', forecast2 = 'HWRF', forecast3 = 'OFCL', forecast4 = 'FSSE', year = 2017)
#xgb_total = XGBRegressor(max_depth=9, n_estimators=150, learning_rate=0.05, subsample=0.7, min_child_weight=7)
#xgb_total.fit(train, tgt_train3)
#compare_perf_intensity_per_year_4cast(X_test_baseline, dict = {'year':[], 'num_samples':[], 'MAEs_full':[], 'std_full':[], 'MAES_2012':[], 'std_2012':[], 'MAES_SHIP':[], 'std_SHIP':[], 'MAES_HWRF':[], 'std_HWRF':[], 'MAES_OFCL':[], 'std_OFCL':[], 'MAES_FSSE':[], 'std_FSSE':[]}, xgb_total = xgb_total, xgb_tot = xgb_total, basin='EP', forecast='SHIP', mode='vmax', forecast2 = 'HWRF', forecast3 = 'OFCL', forecast4 = 'FSSE', year = 2017)
# Out:
# Total number of steps for comparison:  669
# Year 2017 Basin AN MAE intensity | std | busts > 20kn %
# Hurr full:  9.46 13.28 11.66
# Hurr until 2012:  9.46 13.28 11.66
# SHIP 11.29 15.51 17.34
# HWRF 9.59 12.59 11.21
# OFCL 8.55 11.85 7.32
# FSSE 8.44 11.29 7.32
# GFSO 14.0 15.64 22.42
# DSHP 10.28 13.59 14.8
# Total number of steps for comparison:  522
# Year 2017 Basin EP MAE intensity | std | busts > 20kn %
# Hurr full:  9.29 12.46 11.88
# Hurr until 2012:  9.29 12.46 11.88
# SHIP 11.97 15.22 16.86
# HWRF 9.95 14.02 14.18
# OFCL 9.55 12.99 7.85
# FSSE 9.22 12.38 9.96
# GFSO 16.95 19.67 31.99
# DSHP 11.85 15.13 16.86

# %%
11.02/11.85*100
# Out:
# 92.9957805907173

# %%
#OFCL with AN EP ONLY
train_0 = X_test_baseline[:17094].loc[X_test_baseline['cat_basin_AN_0'] + X_test_baseline['cat_basin_EP_0'] == 1]
train = np.concatenate((train_0, X_test_total[train_0.index]), axis = 1)
tgt_train3 = tgt_intensity_test[train_0.index]
test = np.concatenate((X_test_baseline, X_test_total), axis = 1)
#xgb_total = XGBRegressor(max_depth=5, n_estimators=150, learning_rate=0.05, subsample=0.8, min_child_weight=1, colsample_bytree = 0.7)
#xgb_total.fit(train, tgt_train3)
xgb_total = XGBRegressor(max_depth=7, n_estimators=300, learning_rate=0.03, subsample=0.55, min_child_weight=1)
xgb_total.fit(np.array(train), tgt_train3)
compare_perf_intensity_per_year_6cast(test, dict6, xgb_total = xgb_total, xgb_tot = xgb_total, basin='AN', forecast='SHIP', forecast2 = 'HWRF', forecast3 = 'OFCL', forecast4 = 'FSSE', forecast5 = 'GFSO', forecast6 = 'DSHP', year = 2017)
compare_perf_intensity_per_year_6cast(test, dict6, xgb_total = xgb_total, xgb_tot = xgb_total, basin='EP', forecast='SHIP', forecast2 = 'HWRF', forecast3 = 'OFCL', forecast4 = 'FSSE', forecast5 = 'GFSO', forecast6 = 'DSHP', year = 2017)
# Out:
# Total number of steps for comparison:  669
# Year 2017 Basin AN MAE intensity | std | busts > 20kn %
# Hurr full:  10.32 13.99 13.75
# Hurr until 2012:  10.32 13.99 13.75
# SHIP 11.29 15.51 17.34
# HWRF 9.59 12.59 11.21
# OFCL 8.55 11.85 7.32
# FSSE 8.44 11.29 7.32
# GFSO 14.0 15.64 22.42
# DSHP 10.28 13.59 14.8
# Total number of steps for comparison:  522
# Year 2017 Basin EP MAE intensity | std | busts > 20kn %
# Hurr full:  9.44 12.7 10.54
# Hurr until 2012:  9.44 12.7 10.54
# SHIP 11.97 15.22 16.86
# HWRF 9.95 14.02 14.18
# OFCL 9.55 12.99 7.85
# FSSE 9.22 12.38 9.96
# GFSO 16.95 19.67 31.99
# DSHP 11.85 15.13 16.86

# %%
#OFCL with AN EP ONLY
train_0 = X_test_baseline[:17094].loc[X_test_baseline['cat_basin_AN_0'] + X_test_baseline['cat_basin_EP_0'] == 1]
train = np.concatenate((train_0, X_test_total[train_0.index]), axis = 1)
tgt_train3 = tgt_intensity_test[train_0.index]
test = np.concatenate((X_test_baseline, X_test_total), axis = 1)
#xgb_total = XGBRegressor(max_depth=5, n_estimators=150, learning_rate=0.05, subsample=0.8, min_child_weight=1, colsample_bytree = 0.7)
#xgb_total.fit(train, tgt_train3)
xgb_total = XGBRegressor(max_depth=6, n_estimators=200, learning_rate=0.03, subsample=0.8, min_child_weight=3, colsample_bytree = 1)
xgb_total.fit(train, tgt_train3)
compare_perf_intensity_per_year_6cast(test, dict6, xgb_total = xgb_total, xgb_tot = xgb_total, basin='AN', forecast='SHIP', forecast2 = 'HWRF', forecast3 = 'OFCL', forecast4 = 'FSSE', forecast5 = 'GFSO', forecast6 = 'DSHP', year = 2017)
#xgb_total = XGBRegressor(max_depth=7, n_estimators=200, learning_rate=0.03, subsample=0.8, min_child_weight=3, colsample_bytree = 1)
#xgb_total.fit(train, tgt_train3)
#reached 9.1§
compare_perf_intensity_per_year_6cast(test, dict6, xgb_total = xgb_total, xgb_tot = xgb_total, basin='EP', forecast='SHIP', forecast2 = 'HWRF', forecast3 = 'OFCL', forecast4 = 'FSSE', forecast5 = 'GFSO', forecast6 = 'DSHP', year = 2017)
# Out:
# Total number of steps for comparison:  669
# Year 2017 Basin AN MAE intensity | std | busts > 20kn %
# Hurr full:  10.27 13.92 13.9
# Hurr until 2012:  10.27 13.92 13.9
# SHIP 11.29 15.51 17.34
# HWRF 9.59 12.59 11.21
# OFCL 8.55 11.85 7.32
# FSSE 8.44 11.29 7.32
# GFSO 14.0 15.64 22.42
# DSHP 10.28 13.59 14.8
# Total number of steps for comparison:  522
# Year 2017 Basin EP MAE intensity | std | busts > 20kn %
# Hurr full:  9.25 12.56 10.73
# Hurr until 2012:  9.25 12.56 10.73
# SHIP 11.97 15.22 16.86
# HWRF 9.95 14.02 14.18
# OFCL 9.55 12.99 7.85
# FSSE 9.22 12.38 9.96
# GFSO 16.95 19.67 31.99
# DSHP 11.85 15.13 16.86

# %%
#OFCL with AN EP ONLY
train_0 = X_test_baseline[:17094].loc[X_test_baseline['cat_basin_AN_0'] + X_test_baseline['cat_basin_EP_0'] == 1]
train = np.concatenate((train_0, X_test_embed[train_0.index]), axis = 1)
tgt_train3 = tgt_intensity_test[train_0.index]
test = np.concatenate((X_test_baseline, X_test_embed), axis = 1)
xgb_total = XGBRegressor(max_depth=6, n_estimators=300, learning_rate=0.03, subsample=0.55, min_child_weight=1)
xgb_total.fit(np.array(train), tgt_train3)
#xgb_total = XGBRegressor(max_depth=6, n_estimators=150, learning_rate=0.03, subsample=0.8, min_child_weight=2)
#xgb_total.fit(train, tgt_train3)
compare_perf_intensity_per_year_6cast(test, dict6, xgb_total = xgb_total, xgb_tot = xgb_total, basin='AN', forecast='SHIP', forecast2 = 'HWRF', forecast3 = 'OFCL', forecast4 = 'FSSE', forecast5 = 'GFSO', forecast6 = 'DSHP', year = 2017)
compare_perf_intensity_per_year_6cast(test, dict6, xgb_total = xgb_total, xgb_tot = xgb_total, basin='EP', forecast='SHIP', forecast2 = 'HWRF', forecast3 = 'OFCL', forecast4 = 'FSSE', forecast5 = 'GFSO', forecast6 = 'DSHP', year = 2017)
# Out:
# Total number of steps for comparison:  669
# Year 2017 Basin AN MAE intensity | std | busts > 20kn %
# Hurr full:  10.41 14.01 14.05
# Hurr until 2012:  10.41 14.01 14.05
# SHIP 11.29 15.51 17.34
# HWRF 9.59 12.59 11.21
# OFCL 8.55 11.85 7.32
# FSSE 8.44 11.29 7.32
# GFSO 14.0 15.64 22.42
# DSHP 10.28 13.59 14.8
# Total number of steps for comparison:  522
# Year 2017 Basin EP MAE intensity | std | busts > 20kn %
# Hurr full:  9.64 13.04 11.88
# Hurr until 2012:  9.64 13.04 11.88
# SHIP 11.97 15.22 16.86
# HWRF 9.95 14.02 14.18
# OFCL 9.55 12.99 7.85
# FSSE 9.22 12.38 9.96
# GFSO 16.95 19.67 31.99
# DSHP 11.85 15.13 16.86

# %%
#problem with NaN
#xgb2 = XGBRegressor(max_depth=8, n_estimators=140, learning_rate = 0.07, subsample = 0.7, min_child_weight = 5)
#xgb2.fit(train, tgt_train3)
#select = SelectFromModel(xgb2, prefit=True)
#X_train_sparse = select.transform(train)
#X_test_sparse = select.transform(test)
#xgb_sparse2 = XGBRegressor(max_depth=3, n_estimators=150, learning_rate=0.07, subsample=0.8, min_child_weight=2, colsample_bytree = 0.7)
#xgb_sparse2.fit(X_train_sparse, tgt_train3)
#compare_perf_intensity_per_year_4cast(X_test_sparse, dict = {'year':[], 'num_samples':[], 'MAEs_full':[], 'std_full':[], 'MAES_2012':[], 'std_2012':[], 'MAES_SHIP':[], 'std_SHIP':[], 'MAES_HWRF':[], 'std_HWRF':[], 'MAES_OFCL':[], 'std_OFCL':[], 'MAES_FSSE':[], 'std_FSSE':[]}, xgb_total = xgb_sparse2, xgb_tot = xgb_sparse2, basin='AN', forecast='SHIP', mode='vmax', forecast2 = 'HWRF', forecast3 = 'OFCL', forecast4 = 'FSSE', year = 2017)

# %%
#FULL TRAIN WITH CNN/GRU EMBEDS
train = np.concatenate((X_test_baseline[:17094], X_test_embed[:17094]), axis = 1)
tgt_train3 = tgt_intensity_test[:17094]
test = np.concatenate((X_test_baseline, X_test_embed), axis = 1)
xgb_total = XGBRegressor(max_depth=9, n_estimators=150, learning_rate=0.05, subsample=0.7, min_child_weight=7)
xgb_total.fit(train, tgt_train3)
compare_perf_intensity_per_year_6cast(test, dict6, xgb_total = xgb_total, xgb_tot = xgb_total, basin='AN', forecast='SHIP', forecast2 = 'HWRF', forecast3 = 'OFCL', forecast4 = 'FSSE', forecast5 = 'GFSO', forecast6 = 'DSHP', year = 2017)
compare_perf_intensity_per_year_6cast(test, dict6, xgb_total = xgb_total, xgb_tot = xgb_total, basin='EP', forecast='SHIP', forecast2 = 'HWRF', forecast3 = 'OFCL', forecast4 = 'FSSE', forecast5 = 'GFSO', forecast6 = 'DSHP', year = 2017)
# Out:
# Total number of steps for comparison:  669
# Year 2017 Basin AN MAE intensity | std | busts > 20kn %
# Hurr full:  10.88 14.64 15.25
# Hurr until 2012:  10.88 14.64 15.25
# SHIP 11.29 15.51 17.34
# HWRF 9.59 12.59 11.21
# OFCL 8.55 11.85 7.32
# FSSE 8.44 11.29 7.32
# GFSO 14.0 15.64 22.42
# DSHP 10.28 13.59 14.8
# Total number of steps for comparison:  522
# Year 2017 Basin EP MAE intensity | std | busts > 20kn %
# Hurr full:  9.93 13.43 12.45
# Hurr until 2012:  9.93 13.43 12.45
# SHIP 11.97 15.22 16.86
# HWRF 9.95 14.02 14.18
# OFCL 9.55 12.99 7.85
# FSSE 9.22 12.38 9.96
# GFSO 16.95 19.67 31.99
# DSHP 11.85 15.13 16.86

# %%
train_xgb_intensity_all_years_full_train_4cast(forecast = 'SHIP', basin_only = False, sparse = False, max_depth = 8, n_estimators = 100, learning_rate = 0.07, subsample = 0.7, min_child_weight=5, basin = 'AN', forecast2 = 'HWRF', forecast3 = 'OFCL', forecast4 = 'FSSE')
# Out:
# Total number of steps for comparison:  41
# Year  2012  MAE intensity basin AN Hurricast trained full:  9.13 with std  11.62
# Year  2012  MAE intensity basin AN Hurricast trained until 2012:  9.19 with std  11.32
# Year  2012  MAE intensity basin AN Official Forecast SHIP :  9.56 with std  10.79
# Year  2012  MAE intensity basin AN Official Forecast HWRF :  8.1 with std  11.14
# Year  2012  MAE intensity basin AN Official Forecast OFCL :  9.02 with std  11.36
# Year  2012  MAE intensity basin AN Official Forecast FSSE :  10.37 with std  11.62
#
#
# Total number of steps for comparison:  8
# Year  2013  MAE intensity basin AN Hurricast trained full:  12.06 with std  11.75
# Year  2013  MAE intensity basin AN Hurricast trained until 2012:  11.28 with std  10.57
# Year  2013  MAE intensity basin AN Official Forecast SHIP :  19.31 with std  12.82
# Year  2013  MAE intensity basin AN Official Forecast HWRF :  9.31 with std  9.22
# Year  2013  MAE intensity basin AN Official Forecast OFCL :  14.06 with std  5.44
# Year  2013  MAE intensity basin AN Official Forecast FSSE :  8.56 with std  8.28
#
#
# Total number of steps for comparison:  72
# Year  2014  MAE intensity basin AN Hurricast trained full:  6.73 with std  8.32
# Year  2014  MAE intensity basin AN Hurricast trained until 2012:  6.36 with std  8.0
# Year  2014  MAE intensity basin AN Official Forecast SHIP :  7.02 with std  8.36
# Year  2014  MAE intensity basin AN Official Forecast HWRF :  12.13 with std  13.58
# Year  2014  MAE intensity basin AN Official Forecast OFCL :  6.7 with std  8.39
# Year  2014  MAE intensity basin AN Official Forecast FSSE :  8.16 with std  8.09
#
#
# Total number of steps for comparison:  122
# Year  2015  MAE intensity basin AN Hurricast trained full:  8.29 with std  11.25
# Year  2015  MAE intensity basin AN Hurricast trained until 2012:  8.48 with std  11.76
# Year  2015  MAE intensity basin AN Official Forecast SHIP :  9.52 with std  12.95
# Year  2015  MAE intensity basin AN Official Forecast HWRF :  9.44 with std  13.77
# Year  2015  MAE intensity basin AN Official Forecast OFCL :  7.93 with std  11.75
# Year  2015  MAE intensity basin AN Official Forecast FSSE :  8.0 with std  11.84
#
#
# Total number of steps for comparison:  231
# Year  2016  MAE intensity basin AN Hurricast trained full:  11.42 with std  14.84
# Year  2016  MAE intensity basin AN Hurricast trained until 2012:  11.36 with std  14.99
# Year  2016  MAE intensity basin AN Official Forecast SHIP :  10.38 with std  14.57
# Year  2016  MAE intensity basin AN Official Forecast HWRF :  10.11 with std  14.34
# Year  2016  MAE intensity basin AN Official Forecast OFCL :  8.42 with std  11.4
# Year  2016  MAE intensity basin AN Official Forecast FSSE :  8.87 with std  12.22
#
#
# Total number of steps for comparison:  228
# Year  2017  MAE intensity basin AN Hurricast trained full:  12.37 with std  15.73
# Year  2017  MAE intensity basin AN Hurricast trained until 2012:  12.42 with std  15.8
# Year  2017  MAE intensity basin AN Official Forecast SHIP :  12.32 with std  17.27
# Year  2017  MAE intensity basin AN Official Forecast HWRF :  10.05 with std  12.65
# Year  2017  MAE intensity basin AN Official Forecast OFCL :  8.59 with std  11.83
# Year  2017  MAE intensity basin AN Official Forecast FSSE :  7.72 with std  10.07
#
#
# Total number of steps for comparison:  236
# Year  2018  MAE intensity basin AN Hurricast trained full:  9.78 with std  12.7
# Year  2018  MAE intensity basin AN Hurricast trained until 2012:  9.89 with std  12.82
# Year  2018  MAE intensity basin AN Official Forecast SHIP :  10.79 with std  14.97
# Year  2018  MAE intensity basin AN Official Forecast HWRF :  8.8 with std  12.37
# Year  2018  MAE intensity basin AN Official Forecast OFCL :  8.53 with std  12.1
# Year  2018  MAE intensity basin AN Official Forecast FSSE :  8.82 with std  12.16
#
#
# Total number of steps for comparison:  208
# Year  2019  MAE intensity basin AN Hurricast trained full:  10.36 with std  13.38
# Year  2019  MAE intensity basin AN Hurricast trained until 2012:  10.52 with std  13.46
# Year  2019  MAE intensity basin AN Official Forecast SHIP :  10.89 with std  14.22
# Year  2019  MAE intensity basin AN Official Forecast HWRF :  9.89 with std  12.68
# Year  2019  MAE intensity basin AN Official Forecast OFCL :  8.55 with std  11.53
# Year  2019  MAE intensity basin AN Official Forecast FSSE :  8.73 with std  11.42
# {'MAES_2012': [9.19, 11.28, 6.36, 8.48, 11.36, 12.42, 9.89, 10.52],
#  'MAES_FSSE': [10.37, 8.56, 8.16, 8.0, 8.87, 7.72, 8.82, 8.73],
#  'MAES_HWRF': [8.1, 9.31, 12.13, 9.44, 10.11, 10.05, 8.8, 9.89],
#  'MAES_OFCL': [9.02, 14.06, 6.7, 7.93, 8.42, 8.59, 8.53, 8.55],
#  'MAES_SHIP': [9.56, 19.31, 7.02, 9.52, 10.38, 12.32, 10.79, 10.89],
#  'MAEs_full': [9.13, 12.06, 6.73, 8.29, 11.42, 12.37, 9.78, 10.36],
#  'num_samples': [41, 8, 72, 122, 231, 228, 236, 208],
#  'std_2012': [11.32, 10.57, 8.0, 11.76, 14.99, 15.8, 12.82, 13.46],
#  'std_FSSE': [11.62, 8.28, 8.09, 11.84, 12.22, 10.07, 12.16, 11.42],
#  'std_HWRF': [11.14, 9.22, 13.58, 13.77, 14.34, 12.65, 12.37, 12.68],
#  'std_OFCL': [11.36, 5.44, 8.39, 11.75, 11.4, 11.83, 12.1, 11.53],
#  'std_SHIP': [10.79, 12.82, 8.36, 12.95, 14.57, 17.27, 14.97, 14.22],
#  'std_full': [11.62, 11.75, 8.32, 11.25, 14.84, 15.73, 12.7, 13.38],
#  'year': [2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]}

# %%
train_xgb_intensity_all_years_full_train_6cast(forecast = 'SHIP', max_depth = 8, n_estimators = 150, learning_rate = 0.07, subsample = 0.7, min_child_weight=5, basin = 'AN', forecast2 = 'HWRF', forecast3 = 'OFCL', forecast4 = 'FSSE', forecast5 = 'GFSO', forecast6 = 'DSHP')
# Out:
# Total number of steps for comparison:  0
# Year 2012 Basin AN MAE intensity | std | busts > 20kn %
#
#  No forecasts for year  2012
# Total number of steps for comparison:  0
# Year 2013 Basin AN MAE intensity | std | busts > 20kn %
#
#  No forecasts for year  2013
# Total number of steps for comparison:  0
# Year 2014 Basin AN MAE intensity | std | busts > 20kn %
#
#  No forecasts for year  2014
# Total number of steps for comparison:  113
# Year 2015 Basin AN MAE intensity | std | busts > 20kn %
# Hurr full:  8.25 11.46 11.5
# Hurr until 2012:  8.48 11.83 11.5
# SHIP 9.88 13.33 11.5
# HWRF 9.86 14.21 9.73
# OFCL 8.5 12.2 8.85
# FSSE 8.35 12.25 10.62
# GFSO 13.36 16.04 22.12
# DSHP 9.87 13.33 11.5
#
#
# Total number of steps for comparison:  230
# Year 2016 Basin AN MAE intensity | std | busts > 20kn %
# Hurr full:  11.49 15.0 16.09
# Hurr until 2012:  11.41 15.03 15.65
# SHIP 10.36 14.57 11.74
# HWRF 10.06 14.32 13.48
# OFCL 8.37 11.36 4.78
# FSSE 8.83 12.2 7.83
# GFSO 14.74 18.35 23.48
# DSHP 10.1 13.78 10.87
#
#
# Total number of steps for comparison:  227
# Year 2017 Basin AN MAE intensity | std | busts > 20kn %
# Hurr full:  12.17 15.41 20.26
# Hurr until 2012:  12.3 15.56 18.94
# SHIP 12.13 16.94 19.82
# HWRF 10.06 12.67 12.33
# OFCL 8.56 11.82 6.61
# FSSE 7.74 10.09 5.73
# GFSO 17.29 17.77 31.28
# DSHP 10.02 13.38 13.66
#
#
# Total number of steps for comparison:  234
# Year 2018 Basin AN MAE intensity | std | busts > 20kn %
# Hurr full:  9.8 12.75 12.82
# Hurr until 2012:  9.82 12.8 12.82
# SHIP 10.84 15.02 14.53
# HWRF 8.85 12.42 9.83
# OFCL 8.56 12.13 8.12
# FSSE 8.87 12.21 8.97
# GFSO 11.21 12.87 14.96
# DSHP 10.24 13.42 14.1
#
#
# Total number of steps for comparison:  208
# Year 2019 Basin AN MAE intensity | std | busts > 20kn %
# Hurr full:  10.35 13.28 10.58
# Hurr until 2012:  10.42 13.34 12.02
# SHIP 10.89 14.22 17.79
# HWRF 9.89 12.68 11.54
# OFCL 8.55 11.53 7.21
# FSSE 8.73 11.42 7.21
# GFSO 13.54 15.47 21.15
# DSHP 10.6 13.9 16.83
# {'MAES_2012': [8.48, 11.41, 12.3, 9.82, 10.42],
#  'MAES_DSHP': [9.87, 10.1, 10.02, 10.24, 10.6],
#  'MAES_FSSE': [8.35, 8.83, 7.74, 8.87, 8.73],
#  'MAES_GFSO': [13.36, 14.74, 17.29, 11.21, 13.54],
#  'MAES_HWRF': [9.86, 10.06, 10.06, 8.85, 9.89],
#  'MAES_OFCL': [8.5, 8.37, 8.56, 8.56, 8.55],
#  'MAES_SHIP': [9.88, 10.36, 12.13, 10.84, 10.89],
#  'MAEs_full': [8.25, 11.49, 12.17, 9.8, 10.35],
#  'num_samples': [113, 230, 227, 234, 208],
#  'std_2012': [11.83, 15.03, 15.56, 12.8, 13.34],
#  'std_DSHP': [13.33, 13.78, 13.38, 13.42, 13.9],
#  'std_FSSE': [12.25, 12.2, 10.09, 12.21, 11.42],
#  'std_GFSO': [16.04, 18.35, 17.77, 12.87, 15.47],
#  'std_HWRF': [14.21, 14.32, 12.67, 12.42, 12.68],
#  'std_OFCL': [12.2, 11.36, 11.82, 12.13, 11.53],
#  'std_SHIP': [13.33, 14.57, 16.94, 15.02, 14.22],
#  'std_full': [11.46, 15.0, 15.41, 12.75, 13.28],
#  'year': [2015, 2016, 2017, 2018, 2019]}

# %%
train_xgb_intensity_all_years_full_train_6cast(forecast = 'SHIP', max_depth = 8, n_estimators = 150, learning_rate = 0.07, subsample = 0.7, min_child_weight=5, basin = 'EP', forecast2 = 'HWRF', forecast3 = 'OFCL', forecast4 = 'FSSE', forecast5 = 'GFSO', forecast6 = 'DSHP')
# Out:
# Total number of steps for comparison:  0
# Year 2012 Basin EP MAE intensity | std | busts > 20kn %
#
#  No forecasts for year  2012
# Total number of steps for comparison:  0
# Year 2013 Basin EP MAE intensity | std | busts > 20kn %
#
#  No forecasts for year  2013
# Total number of steps for comparison:  0
# Year 2014 Basin EP MAE intensity | std | busts > 20kn %
#
#  No forecasts for year  2014
# Total number of steps for comparison:  255
# Year 2015 Basin EP MAE intensity | std | busts > 20kn %
# Hurr full:  11.65 16.07 17.65
# Hurr until 2012:  11.83 16.22 17.65
# SHIP 12.75 17.89 17.65
# HWRF 11.79 17.29 16.86
# OFCL 10.42 15.35 11.37
# FSSE 9.93 13.96 11.76
# GFSO 15.62 20.14 25.49
# DSHP 12.41 16.99 17.65
#
#
# Total number of steps for comparison:  315
# Year 2016 Basin EP MAE intensity | std | busts > 20kn %
# Hurr full:  9.64 13.24 13.97
# Hurr until 2012:  9.95 13.44 14.29
# SHIP 9.87 12.84 10.79
# HWRF 10.38 13.74 11.75
# OFCL 8.72 11.89 6.67
# FSSE 8.51 11.53 8.57
# GFSO 13.02 16.38 21.27
# DSHP 9.69 12.58 10.16
#
#
# Total number of steps for comparison:  167
# Year 2017 Basin EP MAE intensity | std | busts > 20kn %
# Hurr full:  9.02 12.96 8.98
# Hurr until 2012:  9.1 13.04 10.18
# SHIP 9.97 13.0 10.78
# HWRF 7.87 11.61 8.38
# OFCL 8.14 11.67 4.79
# FSSE 7.92 10.67 4.79
# GFSO 11.93 16.27 17.96
# DSHP 9.49 12.71 10.18
#
#
# Total number of steps for comparison:  355
# Year 2018 Basin EP MAE intensity | std | busts > 20kn %
# Hurr full:  12.09 15.73 20.0
# Hurr until 2012:  12.4 16.1 21.13
# SHIP 12.91 15.83 19.72
# HWRF 10.94 14.86 16.9
# OFCL 10.22 13.48 9.3
# FSSE 9.83 12.64 12.39
# GFSO 19.32 20.45 38.59
# DSHP 12.96 15.85 20.0
#
#
# Total number of steps for comparison:  0
# Year 2019 Basin EP MAE intensity | std | busts > 20kn %
#
#  No forecasts for year  2019
# {'MAES_2012': [11.83, 9.95, 9.1, 12.4],
#  'MAES_DSHP': [12.41, 9.69, 9.49, 12.96],
#  'MAES_FSSE': [9.93, 8.51, 7.92, 9.83],
#  'MAES_GFSO': [15.62, 13.02, 11.93, 19.32],
#  'MAES_HWRF': [11.79, 10.38, 7.87, 10.94],
#  'MAES_OFCL': [10.42, 8.72, 8.14, 10.22],
#  'MAES_SHIP': [12.75, 9.87, 9.97, 12.91],
#  'MAEs_full': [11.65, 9.64, 9.02, 12.09],
#  'num_samples': [255, 315, 167, 355],
#  'std_2012': [16.22, 13.44, 13.04, 16.1],
#  'std_DSHP': [16.99, 12.58, 12.71, 15.85],
#  'std_FSSE': [13.96, 11.53, 10.67, 12.64],
#  'std_GFSO': [20.14, 16.38, 16.27, 20.45],
#  'std_HWRF': [17.29, 13.74, 11.61, 14.86],
#  'std_OFCL': [15.35, 11.89, 11.67, 13.48],
#  'std_SHIP': [17.89, 12.84, 13.0, 15.83],
#  'std_full': [16.07, 13.24, 12.96, 15.73],
#  'year': [2015, 2016, 2017, 2018]}

# %%
baseline_1 = X_test_baseline.loc[X_test_baseline['YEAR_0'] <= 2016].loc[X_test_baseline['cat_basin_' + 'AN' + '_0'] == 1].loc[
            X_test_baseline['SHIP' + '_24_' + 'lat' + '_7'] > -320]

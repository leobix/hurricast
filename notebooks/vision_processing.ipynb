# %%
import cdsapi
import numpy as np
import netCDF4
import matplotlib.pyplot as plt
from datetime import datetime
from utils.data_processing import *
import os
import warnings; warnings.simplefilter('ignore')

# %%
#data_2016 = prepare_data2(min_wind = 30, min_steps= 20, max_steps=60, one_hot = False, secondary = False)

# %%
c = cdsapi.Client()

#Example of an API request
c.retrieve(
    'reanalysis-era5-pressure-levels',
    {
        'product_type': 'reanalysis',
        'variable': [
            'relative_humidity', 'temperature', 'u_component_of_wind',
            'v_component_of_wind', 'vorticity', 'geopotential'
        ],
        'pressure_level': [
            '700', '1000',
        ],
        'year': '1996',
        'month': '04',
        'day': ['06'],
        'area'          : [21.92801, 127.78100000000002, -2.12, 151.82100000000003], # North, West, South, East. Default: global
        'grid'          : [1.0, 1.0], # Latitude/longitude grid: east-west (longitude) and north-south resolution (latitude). Default: 0.25 x 0.25
        'time': [
            '18:00'
        ],
        'format': 'netcdf',
    },
    'test4.nc') #here specify filepath
# Out:
# 2020-04-12 01:58:33,409 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-pressure-levels
# 2020-04-12 01:58:33,874 INFO Request is completed
# 2020-04-12 01:58:33,876 INFO Downloading http://136.156.133.39/cache-compute-0012/cache/data9/adaptor.mars.internal-1586467096.351193-21212-29-d91f2791-a4c4-4e34-b672-d20987b5c46e.nc to test4.nc (17.5K)
# 2020-04-12 01:58:34,205 INFO Download rate 53.5K/s
# Result(content_length=17916,content_type=application/x-netcdf,location=http://136.156.133.39/cache-compute-0012/cache/data9/adaptor.mars.internal-1586467096.351193-21212-29-d91f2791-a4c4-4e34-b672-d20987b5c46e.nc)

# %%
#here example to process file from netcdf format to np.array
#nc_file = 'data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_2016_10_5_18_coord_25.1_-63.3.nc'
nc_file = 'data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_2018_11_2_6_coord_20.7_116.075.nc'#'test4.nc'
nc = netCDF4.Dataset(nc_file, mode='r')

nc.variables.keys()

lat = nc.variables['latitude'][:]
lat = np.array(lat)
lon = nc.variables['longitude'][:]
lon = np.array(lon)

time_var = nc.variables['time']
p = nc.variables['z']
dtime = netCDF4.num2date(time_var[:],time_var.units)
grid = nc.variables['u'][:]

grid = np.array(grid).squeeze(0)#reshape(grid.shape[1],grid.shape[2], grid.shape[3])

# %%
lat
# Out:
# array([32.692, 31.692, 30.692, 29.692, 28.692, 27.692, 26.692, 25.692,
#        24.692, 23.692, 22.692, 21.692, 20.692, 19.692, 18.692, 17.692,
#        16.692, 15.692, 14.692, 13.692, 12.692, 11.692, 10.692,  9.692,
#         8.692], dtype=float32)

# %%
a = process_netcdf('data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_2018_11_2_6_coord_20.7_116.075.nc', 'u')

# %%
get_timestep_vision(datetime(2016, 1, 7, 6, 0), 3.4, -171.3)
# Out:
# array([[[[-7.03420532e+00, -6.91183698e+00, -6.74913492e+00, ...,
#           -3.69334430e+00, -3.16422082e+00, -2.29396994e+00],
#          [-8.17311968e+00, -7.89146739e+00, -8.05485307e+00, ...,
#           -4.22725313e+00, -3.38981610e+00, -2.38967703e+00],
#          [-9.04815592e+00, -9.67093562e+00, -1.02581670e+01, ...,
#           -3.62019674e+00, -2.90854617e+00, -2.24133104e+00],
#          ...,
#          [ 1.71003880e+01,  1.66033948e+01,  1.54706330e+01, ...,
#            1.00166962e+01,  5.05496725e+00,  1.14054731e+00],
#          [ 1.40780949e+01,  1.44356292e+01,  1.39078730e+01, ...,
#            5.94162506e+00,  1.45227897e+00,  1.65702248e-01],
#          [ 1.26089910e+01,  1.26260816e+01,  1.34826600e+01, ...,
#            1.37297881e+00,  9.87072859e-02, -9.74922464e-02]],
#
#         [[-5.00111331e+00, -4.32022573e+00, -3.64959249e+00, ...,
#           -1.55634173e+00, -3.68890206e-01,  1.19455345e+00],
#          [-7.24476092e+00, -7.40404486e+00, -7.84361385e+00, ...,
#            1.26052168e-01,  9.77845260e-01,  1.10363172e+00],
#          [-1.10819316e+01, -1.12138706e+01, -1.05986108e+01, ...,
#           -2.07931261e+00, -1.54198567e+00, -5.41846588e-01],
#          ...,
#          [ 1.37109898e+01,  1.35804180e+01,  1.30266841e+01, ...,
#           -6.36699019e+00, -8.07741259e+00, -8.32009843e+00],
#          [ 1.20928564e+01,  1.20798676e+01,  1.13894093e+01, ...,
#           -3.60378981e+00, -7.04514328e+00, -7.57631762e+00],
#          [ 8.91606466e+00,  9.80067161e+00,  9.56960735e+00, ...,
#           -1.86602252e+00,  2.05352328e-01, -2.78617782e+00]],
#
#         [[-6.81305489e-01, -3.62737607e-01, -3.39153945e-02, ...,
#            2.08521059e+01,  2.22473785e+01,  2.35004578e+01],
#          [-5.38530891e+00, -4.60529613e+00, -3.04253610e+00, ...,
#            1.51930824e+01,  1.71256820e+01,  1.97630959e+01],
#          [-8.08424881e+00, -5.70729490e+00, -3.59626997e+00, ...,
#            1.51117314e+01,  1.79282543e+01,  1.97562597e+01],
#          ...,
#          [-2.06290568e+00,  1.29709676e+00, -3.96235088e-01, ...,
#            8.03521633e-01,  1.96636276e+00,  2.90565948e+00],
#          [-3.66668304e+00, -3.67830461e+00, -4.78850685e+00, ...,
#            4.05653592e-01,  2.34030403e+00,  3.21055492e+00],
#          [-1.22683590e+00, -1.97882017e+00, -2.07794536e+00, ...,
#            4.73332177e-01,  6.08005723e-01,  8.99228722e-01]]],
#
#
#        [[[-6.70984162e+00, -6.61863628e+00, -6.53889988e+00, ...,
#           -2.16240134e-01, -4.07389042e-01, -5.13340151e-01],
#          [-6.85347637e+00, -6.66505816e+00, -6.29204472e+00, ...,
#            6.28091901e-01,  8.36171141e-01,  9.05530888e-01],
#          [-5.84912539e+00, -5.41221360e+00, -4.77596080e+00, ...,
#            1.46641640e+00,  2.10867673e+00,  2.76404442e+00],
#          ...,
#          [-3.32923664e+00, -3.32978278e+00, -2.02287039e+00, ...,
#            6.04743652e+00,  3.44726523e+00, -6.27483356e-01],
#          [-3.02394453e+00, -3.26369987e+00, -3.54332342e+00, ...,
#            3.56195457e+00,  2.22310076e-01, -2.27136397e+00],
#          [-2.57174082e+00, -2.96823827e+00, -2.89724011e+00, ...,
#            1.79573866e+00, -6.65166998e-01, -2.90707062e+00]],
#
#         [[-1.71607716e+01, -1.75141240e+01, -1.76364594e+01, ...,
#           -5.08424893e-01, -2.98707234e-01, -6.54244203e-01],
#          [-1.42897150e+01, -1.48003557e+01, -1.41499033e+01, ...,
#            1.12999432e+00,  3.29353464e-01, -2.68123409e-01],
#          [-1.03553244e+01, -9.62185870e+00, -9.28598276e+00, ...,
#           -1.97125243e-01,  2.35417430e-01,  3.87244277e-01],
#          ...,
#          [ 4.85357505e+00,  4.66133386e+00,  4.84319840e+00, ...,
#           -8.66666030e+00, -7.90971062e+00, -7.69999296e+00],
#          [ 4.94532653e+00,  5.36366957e+00,  6.14355711e+00, ...,
#           -8.18114207e+00, -7.38050121e+00, -6.01624415e+00],
#          [ 5.56737969e+00,  5.43302931e+00,  5.99227641e+00, ...,
#           -6.14349471e+00, -8.64918383e+00, -5.79942667e+00]],
#
#         [[-1.79731467e+00, -3.52228928e-01,  1.92681220e+00, ...,
#           -2.71919855e+00, -3.26752285e+00, -4.36144074e+00],
#          [ 2.82411979e+00,  4.80387634e+00,  5.43576001e+00, ...,
#           -7.42583081e+00, -7.77262955e+00, -8.23848674e+00],
#          [ 4.30907373e+00,  4.23643715e+00,  3.95080607e+00, ...,
#           -8.58747003e+00, -8.19424942e+00, -7.86165032e+00],
#          ...,
#          [-1.11190930e+00,  4.31762418e-02, -2.23750330e+00, ...,
#           -2.01140145e+00, -2.48763530e+00, -3.21946255e+00],
#          [-9.77278105e-02, -1.32326538e+00, -2.55262593e+00, ...,
#           -3.14791825e+00, -3.22601623e+00, -4.55204351e+00],
#          [-3.06272045e+00, -1.99447112e+00, -3.69405798e+00, ...,
#           -2.86938698e+00, -2.93219305e+00, -5.13532075e+00]]],
#
#
#        [[[ 3.11172728e+04,  3.11107854e+04,  3.11030004e+04, ...,
#            3.10627782e+04,  3.10601832e+04,  3.10653732e+04],
#          [ 3.10874305e+04,  3.10822406e+04,  3.10744556e+04, ...,
#            3.10666707e+04,  3.10666707e+04,  3.10666707e+04],
#          [ 3.10601832e+04,  3.10601832e+04,  3.10627782e+04, ...,
#            3.10523983e+04,  3.10511008e+04,  3.10433159e+04],
#          ...,
#          [ 3.08694521e+04,  3.08746421e+04,  3.08785346e+04, ...,
#            3.08681546e+04,  3.08811295e+04,  3.08863195e+04],
#          [ 3.08214450e+04,  3.08279324e+04,  3.08409073e+04, ...,
#            3.08409073e+04,  3.08603697e+04,  3.08798320e+04],
#          [ 3.07825203e+04,  3.07993876e+04,  3.08162550e+04, ...,
#            3.08253374e+04,  3.08551797e+04,  3.08837245e+04]],
#
#         [[ 5.79169404e+04,  5.79065605e+04,  5.78948831e+04, ...,
#            5.77832989e+04,  5.77832989e+04,  5.77858939e+04],
#          [ 5.78922881e+04,  5.78858007e+04,  5.78858007e+04, ...,
#            5.78001663e+04,  5.78027613e+04,  5.78092487e+04],
#          [ 5.79143455e+04,  5.79130480e+04,  5.78974781e+04, ...,
#            5.78157362e+04,  5.78300086e+04,  5.78429835e+04],
#          ...,
#          [ 5.76963670e+04,  5.76976645e+04,  5.76963670e+04, ...,
#            5.77171269e+04,  5.77301018e+04,  5.77534566e+04],
#          [ 5.76691197e+04,  5.76587398e+04,  5.76522524e+04, ...,
#            5.77313993e+04,  5.77443742e+04,  5.77482667e+04],
#          [ 5.76509549e+04,  5.76470624e+04,  5.76457649e+04, ...,
#            5.77378867e+04,  5.77469692e+04,  5.77482667e+04]],
#
#         [[ 1.15302353e+05,  1.15299758e+05,  1.15297163e+05, ...,
#            1.15160927e+05,  1.15160927e+05,  1.15157034e+05],
#          [ 1.15295866e+05,  1.15301056e+05,  1.15294568e+05, ...,
#            1.15250454e+05,  1.15242669e+05,  1.15223206e+05],
#          [ 1.15273808e+05,  1.15269916e+05,  1.15254346e+05, ...,
#            1.15301056e+05,  1.15288081e+05,  1.15280296e+05],
#          ...,
#          [ 1.14962411e+05,  1.14962411e+05,  1.14977981e+05, ...,
#            1.15338683e+05,  1.15345170e+05,  1.15346468e+05],
#          [ 1.14979278e+05,  1.14985765e+05,  1.14994848e+05, ...,
#            1.15328303e+05,  1.15329600e+05,  1.15328303e+05],
#          [ 1.14994848e+05,  1.15006525e+05,  1.15015608e+05, ...,
#            1.15316626e+05,  1.15316626e+05,  1.15321816e+05]]]])

# %%
#Example of a plot, colors are artificial
plt.figure(figsize=(10,10))
plt.imshow(grid[1], cmap ='cool')
#plt.xticks(lon)
#plt.yticks(lat)
plt.show()

# %% [markdown]
# # Actual code to use

# %%
def process_netcdf(filepath, param):
    '''
    input: netcdf filepath and the specific corresponding parameter in str format (eg. 'z', 'u', 'v'...) 
    '''
    nc = netCDF4.Dataset(filepath, mode='r')
    nc.variables.keys()
    lat = nc.variables['latitude'][:]
    lon = nc.variables['longitude'][:]
    time_var = nc.variables['time']
    dtime = netCDF4.num2date(time_var[:],time_var.units)
    grid = nc.variables[param][:]
    #transform into np.array format and reshape something in (1,grid_size,grid_size) into (grid_size,grid_size)
    grid = np.array(grid).reshape(grid.shape[1],grid.shape[2], grid.shape[3])    
    return grid

# %%
#a = process_netcdf('data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_2016_10_5_18_coord_25.1_-63.3.nc', 'u')

# %%
def get_storms(extraction = False, min_wind = 30, min_steps= 20, max_steps=60, path = "ibtracs.since1980.list.v04r00.csv"):
    '''
    returns an array of elements of type [datetime, lat, lon]
    set extraction to True if used for downloading data and False if used to convert netcdf files to tensor
    '''
    data = prepare_data2(path = path, min_wind = min_wind, min_steps= min_steps, max_steps=max_steps, one_hot = False, secondary = False)
    e = data.transpose((2,0,1))
    d = e.reshape(e.shape[0]*e.shape[1],3)
    for t in d:
        try:
            t[0] = datetime.strptime(t[0], "%Y-%m-%d %H:%M:%S")
        except:
            pass
    if extraction :
        f = d.reshape(e.shape[0],e.shape[1],3)
        return f
    return d

# %%
def get_timestep_vision(time, lat, lon):
    '''
    given a datetime and latitute, longitude returns a processed array obtained after donwload
    '''
    filepath = get_filename(['700', '500', '225'], ['geopotential', 'u_component_of_wind', 'v_component_of_wind'], time, lat, lon)
    u, v, z = process_netcdf(filepath, 'u'), process_netcdf(filepath, 'v'), process_netcdf(filepath, 'z')
    return np.array([u, v, z])

# %%
bad_shapes = []
times, lati, long = [], [], []
def get_storm_vision(storm, epsilon = 0):
    '''
    given a storm (list of timesteps with time and lat/lon), returns the vision array
    epsilon is a parameter in case there is a scenario whith not correct grid size
    '''
    l = np.zeros((len(storm), 3, 3, 25, 25))
    
    for i in range(len(storm)):
        time, lat, lon = storm[i]
        try :
            l[i]=get_timestep_vision(time, lat, lon)
        except:
            try :
                b = get_timestep_vision(time, lat, lon)
                print(b.shape)
                print(time, lat, lon)
                get_data(['700', '500', '225'], ['geopotential', 'u_component_of_wind', 'v_component_of_wind'], time, lat, lon, grid_size = 25, force = True, epsilon = epsilon)
                times.append(time)
                lati.append(lat)
                long.append(lon)
                bad_shapes.append(b)
            except:
                pass
    return l

# %%
def extract_vision(data, epsilon):
    '''
    processes all the data to get the vision array
    '''
    
    vision = []
    for storm in data:
        vision.append(get_storm_vision(storm, epsilon))
    return np.array(vision)

# %%
def get_filename(pressure, params, time, lat, lon):
    '''
    returns filename to save the netcdf file
    '''
    params_str = '_'.join(map(str, params))
    pressure_str = '_'.join(map(str, pressure))
    year, month, day, hour = str(time.year), str(time.month), str(time.day), str(time.hour)
    return 'data_era/'+params_str+'/eradata_'+pressure_str+'hPa'+'_'+year+'_'+month+'_'+day+'_'+hour+'_'+'coord'+'_'+str(lat)+'_'+str(lon)+'.nc'

# %%
#get_data(['700', '500', '225'], ['geopotential', 'u_component_of_wind', 'v_component_of_wind'], times[0], lati[0], long[0], grid_size = 25)

# %%
def get_area(lat, lon, grid_size, e = 0.008):
    '''
    input : center of the storm, 
    output: returns a centered squared grid of size grid_size degrees
    '''
    val = grid_size // 2
    return [lat + val + e, lon - val, lat - val - e, lon + val]

# %%
def get_data(pressure_level, params, time, lat, lon, grid_size = 25, degbypix = 1.0, force = False, epsilon = 0.008):
    '''
    pressure_level is the the pressure level we wish to get the data.
    params has to be in format e.g: 'geopotential' or 'u_component_of_wind' or 'v_component_of_wind'
    grid_size should be odd
    '''
    if not os.path.exists(get_filename(pressure_level, params, time, lat, lon)) or force:
        c = cdsapi.Client()
        year, month, day, hour = str(time.year), str(time.month), str(time.day), str(time.hour)
    
        c.retrieve('reanalysis-era5-pressure-levels', {
            'variable'      : params,
            'pressure_level': pressure_level,
            'product_type'  : 'reanalysis',
            'year'          : year,
            'month'         : month,
            'day'           : day,
            'area'          : get_area(lat, lon, grid_size, epsilon), # North, West, South, East. Default: global
            'grid'          : [degbypix, degbypix], # Latitude/longitude grid: east-west (longitude) and north-south resolution (latitude). Default: 0.25 x 0.25
            'time'          : hour,
            'format'        : 'netcdf' # Supported format: grib and netcdf. Default: grib
        }, get_filename(pressure_level, params, time, lat, lon))
    else:
        print("Already downloaded", get_filename(pressure_level, params, time, lat, lon))

# %%
#Example
#get_data('700', 'u_component_of_wind', datetime.now(), 55.4467, 177.3241, 11)

# %%
def download_all(data):
    for storm in data:
        time, lat, lon = storm[0], storm[1], storm[2]
        get_data(['700', '500', '225'], 'geopotential', time, lat, lon, grid_size = 25)
        get_data(['700', '500', '225'], 'u_component_of_wind', time, lat, lon, grid_size = 25)
        get_data(['700', '500', '225'], 'v_component_of_wind', time, lat, lon, grid_size = 25)
        #get_data('700', 'vorticity', time, lat, lon, grid_size = 11, degbypix=1.0)
        #get_data('1000', 'relative_humidity', time, lat, lon, grid_size = 11, degbypix=1.0)
    print("Download complete.")

# %%
def download_all2(data):
    i = 0
    for storm in data:
        for t in storm:
            time, lat, lon = t[0], t[1], t[2]
            try:
                get_data(['700', '500', '225'], ['geopotential', 'u_component_of_wind', 'v_component_of_wind'], time, lat, lon, grid_size = 25)
            except:
                print("False request.")
        i+=1
        print("Storm ", i, " completed.")
    print("Download complete.")

# %%
data = get_storms(extraction=True, min_wind = 50, min_steps= 30, max_steps=60)
# Out:
# The dictionary of storms has been created.
# The trajectories have now been padded.
# There are 1096 storms with 9 features, and maximum number of steps is 60 and minimum is 60.
# The tensor has now been created.

# %%
download_all2(data)
# Out:
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_6_0_coord_-15.0667_119.23299999999999.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_6_3_coord_-15.0481_119.01.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_6_6_coord_-15.0076_118.773.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_6_9_coord_-14.9683_118.57.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_6_12_coord_-14.9333_118.43299999999999.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_6_15_coord_-14.904_118.40299999999999.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_6_18_coord_-14.8812_118.42.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_6_21_coord_-14.8354_118.416.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_7_0_coord_-14.8667_118.4.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_7_3_coord_-15.0526_118.35.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_7_6_coord_-15.3383_118.305.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_7_9_coord_-15.6553_118.285.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_7_12_coord_-16.0_118.3.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_7_15_coord_-16.3331_118.35700000000001.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_7_18_coord_-16.6742_118.443.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_7_21_coord_-17.0382_118.54799999999999.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_8_0_coord_-17.3667_118.633.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_8_3_coord_-17.6068_118.645.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_8_6_coord_-17.7991_118.633.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_8_9_coord_-17.9852_118.634.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_8_12_coord_-18.1667_118.667.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_8_15_coord_-18.3668_118.764.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_8_18_coord_-18.5654_118.89200000000001.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_8_21_coord_-18.7493_119.016.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_9_0_coord_-18.9333_119.133.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_9_3_coord_-19.1406_119.227.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_9_6_coord_-19.3421_119.301.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_9_9_coord_-19.5246_119.34899999999999.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_9_12_coord_-19.6667_119.4.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_9_15_coord_-19.7458_119.49600000000001.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_9_18_coord_-19.7879_119.596.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_9_21_coord_-19.8032_119.675.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_10_0_coord_-19.8667_119.73299999999999.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_10_3_coord_-20.051_119.794.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_10_6_coord_-20.3048_119.824.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_10_9_coord_-20.5666_119.837.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_10_12_coord_-20.8667_119.73299999999999.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_10_15_coord_-21.1934_119.461.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_10_18_coord_-21.536_118.984.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_10_21_coord_-21.9385_118.402.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_11_0_coord_-22.3267_117.853.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_11_3_coord_-22.5134_117.51899999999999.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_11_6_coord_-22.8333_117.26700000000001.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_11_9_coord_-23.3716_117.105.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_11_12_coord_-24.0_117.03299999999999.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_11_15_coord_-24.605_117.01799999999999.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_11_18_coord_-25.2_117.03299999999999.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_11_21_coord_-25.6999_116.96799999999999.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_12_0_coord_-26.3_117.0.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_12_3_coord_-27.2106_117.236.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_12_6_coord_-28.1667_117.667.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_12_9_coord_-28.9135_118.211.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_12_12_coord_-29.46_118.92.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_12_15_coord_-29.9027_119.69200000000001.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_12_18_coord_-30.32_120.4.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_12_21_coord_-30.1877_120.259.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_13_0_coord_-30.8_120.7.nc
# False request.
# False request.
# False request.
# Storm  1  completed.
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_20_12_coord_-14.7333_119.333.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_20_15_coord_-15.0678_118.42.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_20_18_coord_-15.4122_117.419.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_20_21_coord_-15.7095_116.417.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_21_0_coord_-15.9333_115.43299999999999.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_21_3_coord_-16.0489_114.51899999999999.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_21_6_coord_-16.1088_113.617.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_21_9_coord_-16.1535_112.641.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_21_12_coord_-16.2333_111.73299999999999.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_21_15_coord_-16.4184_111.03.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_21_18_coord_-16.642_110.37700000000001.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_21_21_coord_-16.8462_109.61399999999999.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_22_0_coord_-17.0333_108.833.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_22_3_coord_-17.1932_108.09200000000001.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_22_6_coord_-17.3406_107.37.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_22_9_coord_-17.5014_106.652.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_22_12_coord_-17.6333_105.93299999999999.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_22_15_coord_-17.6823_105.198.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_22_18_coord_-17.7284_104.459.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_22_21_coord_-17.8337_103.708.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_23_0_coord_-18.0_103.0.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_23_3_coord_-18.2157_102.37.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_23_6_coord_-18.499_101.802.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_23_9_coord_-18.8507_101.26299999999999.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_23_12_coord_-19.2333_100.76700000000001.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_23_15_coord_-19.5735_100.324.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_23_18_coord_-19.9393_99.8871.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_23_21_coord_-20.3669_99.428.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_24_0_coord_-20.8333_98.8667.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_24_3_coord_-21.309_98.1113.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_24_6_coord_-21.7962_97.2567.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_24_9_coord_-22.2818_96.3685.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_24_12_coord_-22.7667_95.5667.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_24_15_coord_-23.2384_94.9724.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_24_18_coord_-23.7178_94.5176.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_24_21_coord_-24.1984_94.1206.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_25_0_coord_-24.7333_93.8.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_25_3_coord_-25.3327_93.5024.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_25_6_coord_-26.0122_93.2745.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_25_9_coord_-26.8158_93.0234.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_25_12_coord_-27.6667_92.7.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_25_15_coord_-28.4522_92.2014.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_25_18_coord_-29.3_92.3.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_25_21_coord_-29.925_92.4771.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_26_0_coord_-30.4_92.7.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_26_3_coord_-30.845_92.8652.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_26_6_coord_-31.2_93.0.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_26_9_coord_-31.4799_93.1002.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_26_12_coord_-31.7_93.2.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_26_15_coord_-31.915_93.35.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_26_18_coord_-32.1_93.5.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_26_21_coord_-32.2574_93.5993.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_27_0_coord_-32.4_93.7.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_27_3_coord_-32.5723_93.8549.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_27_6_coord_-32.7_94.1.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_27_9_coord_-32.7602_94.4848.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_27_12_coord_-32.7_94.9.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_27_15_coord_-32.525_95.2985.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_27_18_coord_-32.2_95.5.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_27_21_coord_-31.6696_95.3838.nc
# Storm  2  completed.
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_28_6_coord_-11.4667_127.633.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_28_9_coord_-11.4924_127.046.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_28_12_coord_-11.5267_126.167.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_28_15_coord_-11.6722_125.279.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_28_18_coord_-11.8547_124.431.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_28_21_coord_-12.016_123.697.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_29_0_coord_-12.1167_123.03299999999999.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_29_3_coord_-12.1682_122.287.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_29_6_coord_-12.2032_121.625.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_29_9_coord_-12.2507_121.205.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_29_12_coord_-12.35_120.85.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_29_15_coord_-12.5355_120.37700000000001.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_29_18_coord_-12.7762_119.87299999999999.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_29_21_coord_-13.0258_119.38.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_30_0_coord_-13.3167_118.883.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_30_3_coord_-13.6593_118.361.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_30_6_coord_-14.0359_117.866.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_30_9_coord_-14.4137_117.41799999999999.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_30_12_coord_-14.7833_117.06700000000001.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_30_15_coord_-15.1269_116.815.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_30_18_coord_-15.432_116.691.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_30_21_coord_-15.6362_116.637.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_31_0_coord_-15.85_116.68299999999999.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_31_3_coord_-16.1805_116.815.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_31_6_coord_-16.5921_117.02.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_31_9_coord_-17.0569_117.249.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_31_12_coord_-17.5667_117.5.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_31_15_coord_-18.07_117.741.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_31_18_coord_-18.6062_117.988.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_1_31_21_coord_-19.1713_118.23700000000001.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_1_0_coord_-19.8_118.5.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_1_3_coord_-20.5171_118.787.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_1_6_coord_-21.2657_119.117.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_1_9_coord_-21.9733_119.381.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_1_12_coord_-22.5467_119.573.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_1_15_coord_-22.8309_119.725.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_1_18_coord_-23.1333_120.03299999999999.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_1_21_coord_-23.4491_120.31.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_2_0_coord_-23.7_120.56700000000001.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_2_3_coord_-23.8608_120.791.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_2_6_coord_-23.9667_121.0.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_2_9_coord_-24.0716_121.21700000000001.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_2_12_coord_-24.1667_121.43299999999999.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_2_15_coord_-24.2666_121.645.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_2_18_coord_-24.3667_121.867.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_2_21_coord_-24.4738_122.081.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_3_0_coord_-24.5665_122.366.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_3_0_coord_-24.5669_122.368.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_3_3_coord_-24.6214_122.764.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_3_6_coord_-24.6667_123.26700000000001.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_3_9_coord_-24.7482_123.836.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_3_12_coord_-24.8_124.46700000000001.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_3_15_coord_-24.7928_125.152.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_3_18_coord_-24.7_125.76700000000001.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_3_21_coord_-24.5107_126.193.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_4_0_coord_-24.2667_126.5.nc
# False request.
# False request.
# False request.
# False request.
# Storm  3  completed.
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_21_12_coord_-13.2_103.0.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_21_15_coord_-13.3274_102.714.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_21_18_coord_-13.4268_102.376.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_21_21_coord_-13.4986_102.065.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_22_0_coord_-13.5333_101.8.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_22_3_coord_-13.5299_101.631.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_22_6_coord_-13.5049_101.49600000000001.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_22_9_coord_-13.4849_101.337.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_22_12_coord_-13.4667_101.167.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_22_15_coord_-13.445_101.001.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_22_18_coord_-13.4412_100.79700000000001.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_22_21_coord_-13.4705_100.53299999999999.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_23_0_coord_-13.5333_100.2.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_23_3_coord_-13.6214_99.8154.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_23_6_coord_-13.7354_99.3746.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_23_9_coord_-13.8648_98.9098.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_23_12_coord_-14.0_98.4.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_23_15_coord_-14.1123_97.8596.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_23_18_coord_-14.2353_97.2744.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_23_21_coord_-14.3879_96.6589.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_24_0_coord_-14.5667_96.0.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_24_3_coord_-14.7533_95.2875.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_24_6_coord_-14.9735_94.5655.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_24_9_coord_-15.2401_93.8776.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_24_12_coord_-15.5333_93.2333.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_24_15_coord_-15.8233_92.648.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_24_18_coord_-16.1223_92.0874.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_24_21_coord_-16.4269_91.5.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_25_0_coord_-16.7333_90.9333.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_25_3_coord_-17.0311_90.4182.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_25_6_coord_-17.3332_89.9331.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_25_9_coord_-17.6467_89.4557.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_25_12_coord_-17.9667_88.9667.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_25_15_coord_-18.2692_88.4061.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_25_18_coord_-18.5961_87.8561.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_25_21_coord_-18.9767_87.338.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_26_0_coord_-19.4_86.9667.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_26_3_coord_-19.8641_86.8394.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_26_6_coord_-20.3469_86.8553.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_26_9_coord_-20.8528_86.8865.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_26_12_coord_-21.2667_86.9333.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_26_15_coord_-21.4639_86.9416.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_26_18_coord_-21.5654_86.942.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_26_21_coord_-21.6509_86.9455.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_27_0_coord_-21.8333_86.9333.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_27_3_coord_-22.2467_86.8802.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_27_6_coord_-22.7771_86.8059.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_27_9_coord_-23.306_86.6965.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_27_12_coord_-23.8667_86.6667.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_27_15_coord_-24.441_86.8009.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_27_18_coord_-25.0441_87.0781.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_27_21_coord_-25.6799_87.4605.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_28_0_coord_-26.3333_87.9.nc
# False request.
# False request.
# False request.
# False request.
# False request.
# False request.
# False request.
# Storm  4  completed.
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_22_21_coord_-20.3901_152.06.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_23_0_coord_-20.7_151.857.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_23_3_coord_-21.0175_151.624.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_23_6_coord_-21.2886_151.41.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_23_9_coord_-21.4614_151.24.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_23_12_coord_-21.6143_151.143.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_23_15_coord_-21.8421_151.14.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_23_18_coord_-22.0657_151.202.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_23_21_coord_-22.2325_151.30100000000002.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_24_0_coord_-22.3714_151.371.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_24_3_coord_-22.513_151.312.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_24_6_coord_-22.6393_151.237.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_24_9_coord_-22.7571_151.234.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_24_12_coord_-22.8429_151.3.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_24_15_coord_-22.8743_151.452.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_24_18_coord_-22.8932_151.641.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_24_21_coord_-22.9513_151.8.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_25_0_coord_-23.0143_151.957.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_25_3_coord_-23.0579_152.138.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_25_6_coord_-23.0961_152.319.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_25_9_coord_-23.1473_152.49200000000002.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_25_12_coord_-23.1857_152.614.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_25_15_coord_-23.1736_152.648.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_25_18_coord_-23.1711_152.619.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_25_21_coord_-23.2348_152.532.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_26_0_coord_-23.3286_152.486.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_26_3_coord_-23.4088_152.59.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_26_6_coord_-23.5093_152.755.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_26_9_coord_-23.6441_152.916.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_26_12_coord_-23.8143_153.05700000000002.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_26_15_coord_-24.0075_153.116.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_26_18_coord_-24.2219_153.18200000000002.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_26_21_coord_-24.4153_153.31.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_27_0_coord_-24.6714_153.529.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_27_3_coord_-25.0505_153.85299999999998.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_27_6_coord_-25.5105_154.27100000000002.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_27_9_coord_-26.0023_154.746.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_27_12_coord_-26.5_155.257.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_27_15_coord_-26.9383_155.738.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_27_18_coord_-27.3659_156.233.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_27_21_coord_-27.7933_156.751.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_28_0_coord_-28.2714_157.314.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_28_3_coord_-28.8317_157.924.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_28_6_coord_-29.4602_158.561.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_28_9_coord_-30.1575_159.25799999999998.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_28_12_coord_-30.9545_160.045.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_28_15_coord_-31.8907_160.959.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_28_18_coord_-32.8081_161.983.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_28_21_coord_-33.7079_163.013.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_29_0_coord_-34.5_164.0.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_29_3_coord_-35.1118_164.892.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_29_6_coord_-35.5876_165.72299999999998.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_29_9_coord_-35.9762_166.535.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_29_12_coord_-36.3_167.3.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_29_15_coord_-36.6237_168.02599999999998.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_29_18_coord_-36.9229_168.706.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_2_29_21_coord_-37.2145_169.362.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_1_0_coord_-37.5_170.0.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_1_3_coord_-37.8106_170.658.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_1_6_coord_-38.0957_171.3.nc
# Storm  5  completed.
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_22_12_coord_-17.1333_115.46700000000001.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_22_15_coord_-17.1532_114.336.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_22_18_coord_-17.1333_113.167.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_22_21_coord_-17.1076_111.993.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_23_0_coord_-17.0231_110.86200000000001.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_23_3_coord_-16.8982_109.92.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_23_6_coord_-16.8352_109.208.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_23_9_coord_-16.829_108.575.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_23_12_coord_-16.85_107.96700000000001.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_23_15_coord_-16.8836_107.286.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_23_18_coord_-16.9002_106.58.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_23_21_coord_-16.8804_105.86399999999999.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_24_0_coord_-16.85_105.23299999999999.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_24_3_coord_-16.8369_104.789.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_24_6_coord_-16.8317_104.43799999999999.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_24_9_coord_-16.8265_104.089.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_24_12_coord_-16.8333_103.71700000000001.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_24_15_coord_-16.8544_103.24700000000001.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_24_18_coord_-16.8918_102.75200000000001.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_24_21_coord_-16.9416_102.28299999999999.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_25_0_coord_-17.0_101.85.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_25_3_coord_-17.0481_101.45700000000001.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_25_6_coord_-17.1104_101.118.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_25_9_coord_-17.1924_100.835.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_25_12_coord_-17.3167_100.6.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_25_15_coord_-17.4776_100.382.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_25_18_coord_-17.6853_100.196.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_25_21_coord_-17.9063_100.029.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_26_0_coord_-18.2167_99.8833.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_26_3_coord_-18.6667_99.7384.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_26_6_coord_-19.2075_99.6215.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_26_9_coord_-19.7742_99.5359.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_26_12_coord_-20.35_99.4833.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_26_15_coord_-20.8787_99.437.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_26_18_coord_-21.4024_99.4278.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_26_21_coord_-21.9215_99.4478.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_27_0_coord_-22.4833_99.55.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_27_3_coord_-23.1016_99.7703.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_27_6_coord_-23.7903_100.065.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_27_9_coord_-24.5314_100.37700000000001.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_27_12_coord_-25.3667_100.68299999999999.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_27_15_coord_-26.2927_100.94.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_27_18_coord_-27.3498_101.17299999999999.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_27_21_coord_-28.4058_101.42399999999999.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1980_3_28_0_coord_-29.3733_101.76.nc
# ...
# 2020-04-12 02:00:44,159 INFO Request is running
# 2020-04-12 02:00:48,112 INFO Request is completed
# 2020-04-12 02:00:48,114 INFO Downloading http://136.156.132.110/cache-compute-0001/cache/data8/adaptor.mars.internal-1586671243.1610303-14089-33-9d6b546e-7a59-43e0-9023-5299e13df8c9.nc to data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_11_29_6_coord_9.24981_158.451.nc (13K)
# 2020-04-12 02:00:48,404 INFO Download rate 45K/s
# 2020-04-12 02:00:49,690 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-pressure-levels
# 2020-04-12 02:00:50,917 INFO Request is queued
# 2020-04-12 02:00:52,022 INFO Request is running
# 2020-04-12 02:00:55,972 INFO Request is completed
# 2020-04-12 02:00:55,974 INFO Downloading http://136.156.132.105/cache-compute-0000/cache/data5/adaptor.mars.internal-1586671251.3945985-569-9-dad773dd-f337-459d-bf7c-910226dc712a.nc to data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_11_29_9_coord_9.31335_157.969.nc (13K)
# 2020-04-12 02:00:56,247 INFO Download rate 47.9K/s
# 2020-04-12 02:00:56,859 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-pressure-levels
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_11_29_12_coord_9.4_157.5.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_11_29_15_coord_9.52645_157.05.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_11_29_18_coord_9.695219999999999_156.612.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_11_29_21_coord_9.89675_156.167.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_11_30_0_coord_10.14_155.74.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_11_30_3_coord_10.4094_155.357.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_11_30_6_coord_10.7148_154.995.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_11_30_9_coord_11.0407_154.63299999999998.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_11_30_12_coord_11.4_154.28.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_11_30_15_coord_11.782_153.941.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_11_30_18_coord_12.2056_153.601.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_11_30_21_coord_12.6817_153.22299999999998.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_1_0_coord_13.16_152.84.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_1_3_coord_13.595_152.477.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_1_6_coord_13.9919_152.121.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_1_9_coord_14.3617_151.776.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_1_12_coord_14.68_151.42.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_1_15_coord_14.9571_151.029.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_1_18_coord_15.1755_150.623.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_1_21_coord_15.346_150.217.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_2_0_coord_15.46_149.82.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_2_3_coord_15.5364_149.451.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_2_6_coord_15.5634_149.08100000000002.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_2_9_coord_15.5506_148.687.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_2_12_coord_15.52_148.28.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_2_15_coord_15.5069_147.88.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_2_18_coord_15.4983_147.461.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_2_21_coord_15.4989_147.017.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_3_0_coord_15.5_146.52.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_3_3_coord_15.4822_145.94799999999998.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_3_6_coord_15.474_145.339.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_3_9_coord_15.4921_144.737.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_3_12_coord_15.54_144.14.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_3_15_coord_15.6063_143.545.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_3_18_coord_15.6976_142.972.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_3_21_coord_15.799_142.418.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_4_0_coord_15.94_141.94.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_4_3_coord_16.1438_141.572.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_4_6_coord_16.3943_141.286.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_4_9_coord_16.6791_141.029.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_4_12_coord_16.94_140.82.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_4_15_coord_17.1154_140.64700000000002.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_4_18_coord_17.2325_140.501.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_4_21_coord_17.3083_140.347.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_5_0_coord_17.36_140.2.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_5_3_coord_17.4358_140.076.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_5_6_coord_17.4859_139.942.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_5_9_coord_17.4915_139.77700000000002.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_5_12_coord_17.46_139.56.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_5_15_coord_17.4006_139.292.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_5_18_coord_17.3315_138.952.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_5_21_coord_17.2785_138.54.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_6_0_coord_17.24_138.08.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_6_3_coord_17.2211_137.628.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_6_6_coord_17.2025_137.14600000000002.nc
# Already downloaded data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_6_9_coord_17.1531_136.614.nc
# Storm  206  completed.
# 2020-04-12 02:00:57,675 INFO Request is queued
# 2020-04-12 02:00:58,781 INFO Request is running
# 2020-04-12 02:01:02,739 INFO Request is completed
# 2020-04-12 02:01:02,741 INFO Downloading http://136.156.132.235/cache-compute-0006/cache/data9/adaptor.mars.internal-1586671257.8140128-10462-1-ef6abbd1-80d4-4a93-8ef2-4822fd74f986.nc to data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_16_15_coord_9.93795_147.757.nc (13K)
# 2020-04-12 02:01:03,019 INFO Download rate 46.9K/s
# 2020-04-12 02:01:03,294 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-pressure-levels
# 2020-04-12 02:01:03,879 INFO Request is queued
# 2020-04-12 02:01:04,984 INFO Request is running
# 2020-04-12 02:01:08,940 INFO Request is completed
# 2020-04-12 02:01:08,942 INFO Downloading http://136.156.132.210/cache-compute-0005/cache/data0/adaptor.mars.internal-1586671264.637768-480-7-51342c72-6997-4919-a376-bf266093e65c.nc to data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_16_18_coord_10.159_147.208.nc (13K)
# 2020-04-12 02:01:09,223 INFO Download rate 46.4K/s
# 2020-04-12 02:01:09,854 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-pressure-levels
# 2020-04-12 02:01:10,577 INFO Request is queued
# 2020-04-12 02:01:11,676 INFO Request is running
# 2020-04-12 02:01:15,634 INFO Request is completed
# 2020-04-12 02:01:15,636 INFO Downloading http://136.156.132.105/cache-compute-0000/cache/data9/adaptor.mars.internal-1586671270.782058-7347-1-7a3c9c51-eadc-4c68-b276-21485adc65b1.nc to data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_16_21_coord_10.3339_146.689.nc (13K)
# 2020-04-12 02:01:15,923 INFO Download rate 45.5K/s
# 2020-04-12 02:01:16,060 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-pressure-levels
# 2020-04-12 02:01:18,668 INFO Request is queued
# 2020-04-12 02:01:19,774 INFO Request is running
# 2020-04-12 02:01:21,375 INFO Request is completed
# 2020-04-12 02:01:21,377 INFO Downloading http://136.156.132.201/cache-compute-0004/cache/data1/adaptor.mars.internal-1586671277.0416868-25284-23-888b3aee-a1a4-4085-930b-3d799e553306.nc to data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_17_0_coord_10.46_146.2.nc (13K)
# 2020-04-12 02:01:21,668 INFO Download rate 44.9K/s
# 2020-04-12 02:01:22,561 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-pressure-levels
# 2020-04-12 02:01:24,095 INFO Request is queued
# 2020-04-12 02:01:25,193 INFO Request is running
# 2020-04-12 02:01:32,610 INFO Request is completed
# 2020-04-12 02:01:32,612 INFO Downloading http://136.156.132.198/cache-compute-0003/cache/data1/adaptor.mars.internal-1586671283.8951142-8216-7-e813d762-edf2-4bb4-9169-601842526f65.nc to data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_17_3_coord_10.5437_145.73.nc (13K)
# 2020-04-12 02:01:32,901 INFO Download rate 45.2K/s
# 2020-04-12 02:01:33,118 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-pressure-levels
# 2020-04-12 02:01:33,926 INFO Request is queued
# 2020-04-12 02:01:35,034 INFO Request is running
# 2020-04-12 02:01:38,983 INFO Request is completed
# 2020-04-12 02:01:38,985 INFO Downloading http://136.156.133.46/cache-compute-0015/cache/data5/adaptor.mars.internal-1586671293.7141635-28011-21-d98ed568-2a0b-4ff2-95f4-e70e16a8d91c.nc to data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_17_6_coord_10.5904_145.299.nc (13K)
# 2020-04-12 02:01:39,268 INFO Download rate 46.1K/s
# 2020-04-12 02:01:40,071 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-pressure-levels
# 2020-04-12 02:01:41,296 INFO Request is queued
# 2020-04-12 02:01:42,397 INFO Request is running
# 2020-04-12 02:01:45,687 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-pressure-levels
# False request.
# 2020-04-12 02:01:46,154 INFO Request is queued
# 2020-04-12 02:01:47,254 INFO Request is running
# 2020-04-12 02:01:51,205 INFO Request is completed
# 2020-04-12 02:01:51,207 INFO Downloading http://136.156.133.25/cache-compute-0008/cache/data1/adaptor.mars.internal-1586671306.1736152-323-5-251eda0d-2620-4acb-9e12-b8e8129b5dcf.nc to data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_17_12_coord_10.64_144.56.nc (13K)
# 2020-04-12 02:01:51,493 INFO Download rate 45.7K/s
# 2020-04-12 02:01:51,694 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-pressure-levels
# 2020-04-12 02:01:52,507 INFO Request is queued
# 2020-04-12 02:01:53,610 INFO Request is running
# 2020-04-12 02:01:57,563 INFO Request is completed
# 2020-04-12 02:01:57,566 INFO Downloading http://136.156.132.201/cache-compute-0004/cache/data6/adaptor.mars.internal-1586671313.1204956-28374-27-5eccf1b9-16b4-40cd-aa5a-e8c453169279.nc to data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_17_15_coord_10.664_144.222.nc (13K)
# 2020-04-12 02:01:57,859 INFO Download rate 44.5K/s
# 2020-04-12 02:01:58,197 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-pressure-levels
# 2020-04-12 02:01:59,117 INFO Request is queued
# 2020-04-12 02:02:00,227 INFO Request is running
# 2020-04-12 02:02:04,184 INFO Request is completed
# 2020-04-12 02:02:04,186 INFO Downloading http://136.156.132.201/cache-compute-0004/cache/data9/adaptor.mars.internal-1586671319.268064-16644-31-1e8b20ee-14fd-48df-bc30-1cc0ce85de8b.nc to data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_17_18_coord_10.6644_143.882.nc (13K)
# 2020-04-12 02:02:04,476 INFO Download rate 45K/s
# 2020-04-12 02:02:05,263 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-pressure-levels
# 2020-04-12 02:02:06,182 INFO Request is queued
# 2020-04-12 02:02:07,290 INFO Request is running
# 2020-04-12 02:02:11,248 INFO Request is completed
# 2020-04-12 02:02:11,250 INFO Downloading http://136.156.132.210/cache-compute-0005/cache/data9/adaptor.mars.internal-1586671326.1391532-26263-31-c93e2e6c-de02-41ef-b6d7-41ae82186ee0.nc to data_era/geopotential_u_component_of_wind_v_component_of_wind/eradata_700_500_225hPa_1986_12_17_21_coord_10.6234_143.529.nc (13K)
# 2020-04-12 02:02:11,544 INFO Download rate 44.3K/s
# 2020-04-12 02:02:12,021 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-pressure-levels
# 2020-04-12 02:02:12,940 INFO Request is queued
# 2020-04-12 02:02:14,044 INFO Request is running

# %% [markdown]
# # OBSERVE DATA

# %%
vision_data = extract_vision(get_storms(extraction=True, min_wind = 30, min_steps= 20, max_steps=60), epsilon = 0.052)

# %%
get_area(9.90801, 139.80100000000002, 25, 0.03)

# %%
print(vision_data.shape)
vision_data[0][7,0,0,:,:]

# %%
a = vision_data[1, 9, 0, 1]
plt.imshow(a)
plt.show()

# %% [markdown]
# # CNN

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import math


# CNN for one stream : z (pressure field) : 2d data

class Net_2d_conv3_4fc(nn.Module):
    def __init__(self, dropout = 0.5):
        super(Net_2d_conv3_4fc, self).__init__()
        self.in_channels = 3 * 3
        #self.adjust_dim = False
       # if len(levellist) > 1 and len(params) >1:
            #self.adjust_dim = True

        self.conv1 = nn.Conv2d(in_channels=self.in_channels, out_channels=64, kernel_size=3, stride=1, padding=0, groups=1, bias=True)
        self.conv1_bn = nn.BatchNorm2d(64)
        self.conv2 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, stride=1, padding=0, groups=1, bias=True)
        self.conv2_bn = nn.BatchNorm2d(64)
        self.conv3 = nn.Conv2d(in_channels=64, out_channels=256, kernel_size=3, stride=1, padding=0, groups=1, bias=True)
        self.conv3_bn = nn.BatchNorm2d(256)

        self.fc1 = nn.Linear(in_features=256*4*4, out_features=576)
        self.fc1_bn = nn.BatchNorm1d(576)
        self.fc2 = nn.Linear(in_features=576, out_features=128)
        self.fc2_bn = nn.BatchNorm1d(128)
        self.fc3 = nn.Linear(in_features=128, out_features=64)
        self.fc3_bn = nn.BatchNorm1d(64)
        self.fc4 = nn.Linear(in_features=64, out_features=2)
        self.init_weights()

    def init_weights(self):
        for idx, m in enumerate(self.modules()):
            if isinstance(m, nn.Conv2d) and idx==1:
                nn.init.xavier_normal_(m.weight, gain=1)
                nn.init.normal_(m.bias,mean=0, std=1)
            if isinstance(m, nn.Conv2d) and idx!=1:
                nn.init.xavier_normal_(m.weight, gain=math.sqrt(2))
                nn.init.normal_(m.bias,mean=0, std=1)
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.BatchNorm1d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.Linear) and idx==1:
                nn.init.xavier_normal_(m.weight, gain=1)
                nn.init.normal_(m.bias,mean=0, std=1)
            elif isinstance(m, nn.Linear) and idx!=1:
                nn.init.xavier_normal_(m.weight, gain=math.sqrt(2))
                nn.init.normal_(m.bias,mean=0, std=1)

    def forward(self, x):
        x = F.relu(self.conv1_bn(self.conv1(x)))
        x = F.relu(self.conv2_bn(self.conv2(x)))
        x = F.max_pool2d(x, kernel_size=2, stride=2, padding=0)
        x = F.relu(self.conv3_bn(self.conv3(x)))
        x = F.max_pool2d(x, kernel_size=2, stride=2, padding=0)
        x = x.view(1, -1)
        x = F.relu(self.fc1_bn(self.fc1(x)))
        x = F.relu(self.fc2_bn(self.fc2(x)))
        x = F.relu(self.fc3_bn(self.fc3(x)))
        x = self.fc4(x)
        return x
    
class EncoderCNN(nn.Module):
    def __init__(self, dropout = 0.5):
        super(EncoderCNN, self).__init__()
        self.in_channels = 3 * 3
        #self.adjust_dim = False
       # if len(levellist) > 1 and len(params) >1:
            #self.adjust_dim = True

        self.conv1 = nn.Conv2d(in_channels=self.in_channels, out_channels=64, kernel_size=3, stride=1, padding=0, groups=1, bias=True)
        self.conv1_bn = nn.BatchNorm2d(64)
        self.conv2 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, stride=1, padding=0, groups=1, bias=True)
        self.conv2_bn = nn.BatchNorm2d(64)
        self.conv3 = nn.Conv2d(in_channels=64, out_channels=256, kernel_size=3, stride=1, padding=0, groups=1, bias=True)
        self.conv3_bn = nn.BatchNorm2d(256)
        self.init_weights()


    def init_weights(self):
        for idx, m in enumerate(self.modules()):
            if isinstance(m, nn.Conv2d) and idx==1:
                nn.init.xavier_normal_(m.weight, gain=1)
                nn.init.normal_(m.bias,mean=0, std=1)
            if isinstance(m, nn.Conv2d) and idx!=1:
                nn.init.xavier_normal_(m.weight, gain=math.sqrt(2))
                nn.init.normal_(m.bias,mean=0, std=1)
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)

    def forward(self, x):
        x = F.relu(self.conv1_bn(self.conv1(x)))
        x = F.relu(self.conv2_bn(self.conv2(x)))
        x = F.max_pool2d(x, kernel_size=2, stride=2, padding=0)
        x = F.relu(self.conv3_bn(self.conv3(x)))
        x = F.max_pool2d(x, kernel_size=2, stride=2, padding=0)
        x = x.view(1, -1)
    
        return x
    
class EncoderLinear1(nn.Module):
    def __init__(self, rnn_decoder, dropout = 0.5):
        super(EncoderLinear1, self).__init__()

        self.fc1 = nn.Linear(in_features=256*4*4, out_features=576)
        self.fc1_bn = nn.BatchNorm1d(576)
        self.fc2 = nn.Linear(in_features=576, out_features=128)
        self.fc2_bn = nn.BatchNorm1d(128)
        self.fc3 = nn.Linear(in_features=128, out_features=64)
        self.fc3_bn = nn.BatchNorm1d(64)
        self.fc4 = nn.Linear(in_features=64, out_features=2)
        self.init_weights()
        self.rnn_decoder = rnn_decoder

    def init_weights(self):
        for idx, m in enumerate(self.modules()):
            if isinstance(m, nn.BatchNorm1d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.Linear) and idx==1:
                nn.init.xavier_normal_(m.weight, gain=1)
                nn.init.normal_(m.bias,mean=0, std=1)
            elif isinstance(m, nn.Linear) and idx!=1:
                nn.init.xavier_normal_(m.weight, gain=math.sqrt(2))
                nn.init.normal_(m.bias,mean=0, std=1)

    def forward(self, x):
        x = F.relu(self.fc1_bn(self.fc1(x)))
        x = F.relu(self.fc2_bn(self.fc2(x)))
        if self.rnn_decoder:
            return x
        x = F.relu(self.fc3_bn(self.fc3(x)))
        x = self.fc4(x)
        return x
    
class EncoderCNNLinear1(nn.Module):
    def __init__(self, dropout = 0.5, rnn_decoder = False):
        super(EncoderCNNLinear1, self).__init__()

        self.cnn = EncoderCNN()
        self.linear = EncoderLinear1(rnn_decoder)

    def forward(self, x):
        x = self.cnn(x)
        x = self.linear(x)
        return x

# %%
class DecoderGRU(nn.Module):
    def __init__(self, input_size, hidden_size, dropout = 0.5):
        super(DecoderGRU, self).__init__()
        self.in_channels = 3 * 3
        #self.adjust_dim = False
       # if len(levellist) > 1 and len(params) >1:
            #self.adjust_dim = True
        self.hidden_size = hidden_size
        self.rnn = nn.GRU(input_size=input_size, hidden_size=hidden_size)

    def forward(self, inputs, hidden = None):
        if hidden is None:
            hidden = self.init_hidden(self.hidden_size)
        outputs, hiddens = self.rnn(inputs.unsqueeze(0), hidden)
        return outputs, hiddens

    def init_hidden(self, hidden_size):
        return torch.zeros((1, 1, hidden_size))
    
class EncoderDecoder(nn.Module):
    def __init__(self, input_size, hidden_size, rnn_decoder = True, dropout = 0.5):
        super(EncoderDecoder, self).__init__()
        self.in_channels = 3 * 3
        #self.adjust_dim = False
       # if len(levellist) > 1 and len(params) >1:
            #self.adjust_dim = True
        self.hidden_size = hidden_size
        self.encoder = EncoderCNNLinear1(rnn_decoder=True)
        self.decoder = DecoderGRU(input_size, hidden_size)
        self.lastlinear = nn.Linear(hidden_size, 2)
        self.hidden = self.init_hidden(hidden_size)

    def forward(self, inputs, hidden = None):
        x = self.encoder(inputs)
        o, self.hidden = self.decoder(x, self.hidden)
        y = self.lastlinear(o)
        return y

    def init_hidden(self, hidden_size):
        return torch.zeros((1, 1, hidden_size))

# %%
test = torch.Tensor(vision_data[0][0]).reshape(1, 9, 25, 25)

# %%
e_d = EncoderDecoder(128, 128)
e_d.eval()
e_d(test)

# %%
class ConvLSTMCell(nn.Module):

    def __init__(self, input_dim, hidden_dim, kernel_size, bias):
        """
        Initialize ConvLSTM cell.

        Parameters
        ----------
        input_dim: int
            Number of channels of input tensor.
        hidden_dim: int
            Number of channels of hidden state.
        kernel_size: (int, int)
            Size of the convolutional kernel.
        bias: bool
            Whether or not to add the bias.
        """

        super(ConvLSTMCell, self).__init__()

        self.input_dim = input_dim
        self.hidden_dim = hidden_dim

        self.kernel_size = kernel_size
        self.padding = kernel_size[0] // 2, kernel_size[1] // 2
        self.bias = bias

        self.conv = nn.Conv2d(in_channels=self.input_dim + self.hidden_dim,
                              out_channels=4 * self.hidden_dim,
                              kernel_size=self.kernel_size,
                              padding=self.padding,
                              bias=self.bias)

    def forward(self, input_tensor, cur_state):
        h_cur, c_cur = cur_state

        combined = torch.cat([input_tensor, h_cur], dim=1)  # concatenate along channel axis

        combined_conv = self.conv(combined)
        cc_i, cc_f, cc_o, cc_g = torch.split(combined_conv, self.hidden_dim, dim=1)
        i = torch.sigmoid(cc_i)
        f = torch.sigmoid(cc_f)
        o = torch.sigmoid(cc_o)
        g = torch.tanh(cc_g)

        c_next = f * c_cur + i * g
        h_next = o * torch.tanh(c_next)

        return h_next, c_next

    def init_hidden(self, batch_size, image_size):
        height, width = image_size
        return (torch.zeros(batch_size, self.hidden_dim, height, width, device=self.conv.weight.device),
                torch.zeros(batch_size, self.hidden_dim, height, width, device=self.conv.weight.device))

# %%
class ConvLSTM(nn.Module):

    """

    Parameters:
        input_dim: Number of channels in input
        hidden_dim: Number of hidden channels
        kernel_size: Size of kernel in convolutions
        num_layers: Number of LSTM layers stacked on each other
        batch_first: Whether or not dimension 0 is the batch or not
        bias: Bias or no bias in Convolution
        return_all_layers: Return the list of computations for all layers
        Note: Will do same padding.

    Input:
        A tensor of size B, T, C, H, W or T, B, C, H, W
    Output:
        A tuple of two lists of length num_layers (or length 1 if return_all_layers is False).
            0 - layer_output_list is the list of lists of length T of each output
            1 - last_state_list is the list of last states
                    each element of the list is a tuple (h, c) for hidden state and memory
    Example:
        >> x = torch.rand((32, 10, 64, 128, 128))
        >> convlstm = ConvLSTM(64, 16, 3, 1, True, True, False)
        >> _, last_states = convlstm(x)
        >> h = last_states[0][0]  # 0 for layer index, 0 for h index
    """

    def __init__(self, input_dim, hidden_dim, kernel_size, num_layers,
                 batch_first=False, bias=True, return_all_layers=False):
        super(ConvLSTM, self).__init__()

        self._check_kernel_size_consistency(kernel_size)

        # Make sure that both `kernel_size` and `hidden_dim` are lists having len == num_layers
        kernel_size = self._extend_for_multilayer(kernel_size, num_layers)
        hidden_dim = self._extend_for_multilayer(hidden_dim, num_layers)
        if not len(kernel_size) == len(hidden_dim) == num_layers:
            raise ValueError('Inconsistent list length.')

        self.input_dim = input_dim
        self.hidden_dim = hidden_dim
        self.kernel_size = kernel_size
        self.num_layers = num_layers
        self.batch_first = batch_first
        self.bias = bias
        self.return_all_layers = return_all_layers

        cell_list = []
        for i in range(0, self.num_layers):
            cur_input_dim = self.input_dim if i == 0 else self.hidden_dim[i - 1]

            cell_list.append(ConvLSTMCell(input_dim=cur_input_dim,
                                          hidden_dim=self.hidden_dim[i],
                                          kernel_size=self.kernel_size[i],
                                          bias=self.bias))

        self.cell_list = nn.ModuleList(cell_list)

    def forward(self, input_tensor, hidden_state=None):
        """

        Parameters
        ----------
        input_tensor: todo
            5-D Tensor either of shape (t, b, c, h, w) or (b, t, c, h, w)
        hidden_state: todo
            None. todo implement stateful

        Returns
        -------
        last_state_list, layer_output
        """
        if not self.batch_first:
            # (t, b, c, h, w) -> (b, t, c, h, w)
            input_tensor = input_tensor.permute(1, 0, 2, 3, 4)

        b, _, _, h, w = input_tensor.size()

        # Implement stateful ConvLSTM
        if hidden_state is not None:
            raise NotImplementedError()
        else:
            # Since the init is done in forward. Can send image size here
            hidden_state = self._init_hidden(batch_size=b,
                                             image_size=(h, w))

        layer_output_list = []
        last_state_list = []

        seq_len = input_tensor.size(1)
        cur_layer_input = input_tensor

        for layer_idx in range(self.num_layers):

            h, c = hidden_state[layer_idx]
            output_inner = []
            for t in range(seq_len):
                h, c = self.cell_list[layer_idx](input_tensor=cur_layer_input[:, t, :, :, :],
                                                 cur_state=[h, c])
                output_inner.append(h)

            layer_output = torch.stack(output_inner, dim=1)
            cur_layer_input = layer_output

            layer_output_list.append(layer_output)
            last_state_list.append([h, c])

        if not self.return_all_layers:
            layer_output_list = layer_output_list[-1:]
            last_state_list = last_state_list[-1:]

        return layer_output_list, last_state_list

    def _init_hidden(self, batch_size, image_size):
        init_states = []
        for i in range(self.num_layers):
            init_states.append(self.cell_list[i].init_hidden(batch_size, image_size))
        return init_states

    @staticmethod
    def _check_kernel_size_consistency(kernel_size):
        if not (isinstance(kernel_size, tuple) or
                (isinstance(kernel_size, list) and all([isinstance(elem, tuple) for elem in kernel_size]))):
            raise ValueError('`kernel_size` must be tuple or list of tuples')

    @staticmethod
    def _extend_for_multilayer(param, num_layers):
        if not isinstance(param, list):
            param = [param] * num_layers
        return param

# %%
c = ConvLSTM(input_dim = 9, hidden_dim=128, kernel_size=(3,3), num_layers=1, batch_first=True, bias = True)

# %%
v = vision_data.reshape(18, 60, 9, 25, 25)
v = torch.Tensor(v)

# %%
v[0].unsqueeze(0).shape

# %%
c.eval()
outputs, last_states = c(v[0][:10].unsqueeze(0))

# %%
outputs[0][0].shape

# %%
len(a[0])
